# %% [markdown]
# # Description

# %% [markdown]
# It takes a GWAS on a random phenotype and verifies that the Manhattan and QQ-plots look fine (without inflation).

# %% [markdown]
# # Modules

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
library(qqman)
# Out:
# For example usage please run: vignette('qqman')
#
#
#
# Citation appreciated but not required:
#
# Turner, (2018). qqman: an R package for visualizing GWAS results using Q-Q and manhattan plots. Journal of Open Source Software, 3(25), 731, https://doi.org/10.21105/joss.00731.

# %% [markdown]
# # Paths

# %%
GLS_NULL_SIMS_DIR <- Sys.getenv("PHENOPLIER_RESULTS_GLS_NULL_SIMS")

# %%
GLS_NULL_SIMS_DIR
# Out:
# [1] "/opt/data/results/gls/null_sims"

# %%
GWAS_DIR <- file.path(GLS_NULL_SIMS_DIR, "gwas")

# %%
GWAS_DIR
# Out:
# [1] "/opt/data/results/gls/null_sims/gwas"

# %% [markdown]
# # Random pheno 0

# %% [markdown]
# ## Load data

# %%
gwas <- as.data.frame(read_table(file.path(GWAS_DIR, "random.pheno0.glm.linear.tsv.gz")))
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   `#CHROM` = col_double(),
#   POS = col_double(),
#   ID = col_character(),
#   REF = col_character(),
#   A1 = col_character(),
#   BETA = col_double(),
#   SE = col_double(),
#   P = col_double()
# )

# %%
dim(gwas)
# Out:
# [1] 5923554       8

# %%
head(gwas)
# Out:
#   #CHROM POS   ID          REF A1 BETA       SE       P
# 1 1      11008 rs575272151 C   G  -0.1059130 0.154626 0.493918
# 2 1      11012 rs544419019 C   G  -0.1059130 0.154626 0.493918
# 3 1      13110 rs540538026 G   A  -0.1005660 0.179485 0.575707
# 4 1      13116 rs62635286  T   G   0.0252533 0.107234 0.813991
# 5 1      13118 rs200579949 A   G   0.0252533 0.107234 0.813991
# 6 1      13273 rs531730856 G   C  -0.0808900 0.116964 0.489758

# %%
gwas <- gwas %>% filter(P >= 0 & P <= 1)

# %%
dim(gwas)
# Out:
# [1] 5923554       8

# %% [markdown]
# ## Manhattan plot

# %%
options(repr.plot.width = 20, repr.plot.height = 10)

manhattan(
  gwas,
  chr = "#CHROM",
  bp = "POS",
  p = "P",
  snp = "ID",
  main = "Manhattan plot",
  suggestiveline = F,
  genomewideline = -log10(5e-08),
  cex = 0.6,
  cex.axis = 0.9,
  ylim = c(0, 10),
)
# Out:
# Plot with title “Manhattan plot”

# %% [markdown]
# ## QQ-plot

# %%
options(repr.plot.width = 10, repr.plot.height = 10)

qq(gwas$P, main = "Q-Q plot of GWAS p-values")
# Out:
# Plot with title “Q-Q plot of GWAS p-values”

# %% [markdown]
# # Random pheno 373

# %% [markdown]
# Random phenotype 373 has the largest inflation factor (although within the acceptable limits).

# %% [markdown]
# ## Load data

# %%
gwas <- as.data.frame(read_table(file.path(GWAS_DIR, "random.pheno373.glm.linear.tsv.gz")))
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   `#CHROM` = col_double(),
#   POS = col_double(),
#   ID = col_character(),
#   REF = col_character(),
#   A1 = col_character(),
#   BETA = col_double(),
#   SE = col_double(),
#   P = col_double()
# )

# %%
dim(gwas)
# Out:
# [1] 5923554       8

# %%
head(gwas)
# Out:
#   #CHROM POS   ID          REF A1 BETA       SE       P
# 1 1      11008 rs575272151 C   G  -0.0736685 0.151471 0.6270860
# 2 1      11012 rs544419019 C   G  -0.0736685 0.151471 0.6270860
# 3 1      13110 rs540538026 G   A  -0.1875190 0.175502 0.2862000
# 4 1      13116 rs62635286  T   G  -0.0176082 0.105009 0.8669510
# 5 1      13118 rs200579949 A   G  -0.0176082 0.105009 0.8669510
# 6 1      13273 rs531730856 G   C  -0.2141590 0.113932 0.0611545

# %%
gwas <- gwas %>% filter(P >= 0 & P <= 1)

# %%
dim(gwas)
# Out:
# [1] 5923554       8

# %% [markdown]
# ## Manhattan plot

# %%
options(repr.plot.width = 20, repr.plot.height = 10)

manhattan(
  gwas,
  chr = "#CHROM",
  bp = "POS",
  p = "P",
  snp = "ID",
  main = "Manhattan plot",
  suggestiveline = F,
  genomewideline = -log10(5e-08),
  cex = 0.6,
  cex.axis = 0.9,
  ylim = c(0, 10),
)
# Out:
# Plot with title “Manhattan plot”

# %% [markdown]
# ## QQ-plot

# %%
options(repr.plot.width = 10, repr.plot.height = 10)

qq(gwas$P, main = "Q-Q plot of GWAS p-values")
# Out:
# Plot with title “Q-Q plot of GWAS p-values”

# %% [markdown]
# # Random pheno 622

# %% [markdown]
# ## Load data

# %%
gwas <- as.data.frame(read_table(file.path(GWAS_DIR, "random.pheno622.glm.linear.tsv.gz")))
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   `#CHROM` = col_double(),
#   POS = col_double(),
#   ID = col_character(),
#   REF = col_character(),
#   A1 = col_character(),
#   BETA = col_double(),
#   SE = col_double(),
#   P = col_double()
# )

# %%
dim(gwas)
# Out:
# [1] 5923554       8

# %%
head(gwas)
# Out:
#   #CHROM POS   ID          REF A1 BETA      SE       P
# 1 1      11008 rs575272151 C   G  0.0742731 0.172143 0.6664540
# 2 1      11012 rs544419019 C   G  0.0742731 0.172143 0.6664540
# 3 1      13110 rs540538026 G   A  0.3982980 0.198451 0.0456765
# 4 1      13116 rs62635286  T   G  0.0306344 0.119322 0.7975640
# 5 1      13118 rs200579949 A   G  0.0306344 0.119322 0.7975640
# 6 1      13273 rs531730856 G   C  0.0490285 0.130227 0.7068320

# %%
gwas <- gwas %>% filter(P >= 0 & P <= 1)

# %%
dim(gwas)
# Out:
# [1] 5923554       8

# %% [markdown]
# ## Manhattan plot

# %%
options(repr.plot.width = 20, repr.plot.height = 10)

manhattan(
  gwas,
  chr = "#CHROM",
  bp = "POS",
  p = "P",
  snp = "ID",
  main = "Manhattan plot",
  suggestiveline = F,
  genomewideline = -log10(5e-08),
  cex = 0.6,
  cex.axis = 0.9,
  ylim = c(0, 10),
)
# Out:
# Plot with title “Manhattan plot”

# %% [markdown]
# ## QQ-plot

# %%
options(repr.plot.width = 10, repr.plot.height = 10)

qq(gwas$P, main = "Q-Q plot of GWAS p-values")
# Out:
# Plot with title “Q-Q plot of GWAS p-values”

# %% [markdown]
# # Random pheno 825

# %% [markdown]
# ## Load data

# %%
gwas <- as.data.frame(read_table(file.path(GWAS_DIR, "random.pheno825.glm.linear.tsv.gz")))
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   `#CHROM` = col_double(),
#   POS = col_double(),
#   ID = col_character(),
#   REF = col_character(),
#   A1 = col_character(),
#   BETA = col_double(),
#   SE = col_double(),
#   P = col_double()
# )

# %%
dim(gwas)
# Out:
# [1] 5923554       8

# %%
head(gwas)
# Out:
#   #CHROM POS   ID          REF A1 BETA      SE       P
# 1 1      11008 rs575272151 C   G  0.1611110 0.154553 0.298084
# 2 1      11012 rs544419019 C   G  0.1611110 0.154553 0.298084
# 3 1      13110 rs540538026 G   A  0.0277942 0.179682 0.877177
# 4 1      13116 rs62635286  T   G  0.0338799 0.107290 0.752398
# 5 1      13118 rs200579949 A   G  0.0338799 0.107290 0.752398
# 6 1      13273 rs531730856 G   C  0.0772555 0.117043 0.509739

# %%
gwas <- gwas %>% filter(P >= 0 & P <= 1)

# %%
dim(gwas)
# Out:
# [1] 5923554       8

# %% [markdown]
# ## Manhattan plot

# %%
options(repr.plot.width = 20, repr.plot.height = 10)

manhattan(
  gwas,
  chr = "#CHROM",
  bp = "POS",
  p = "P",
  snp = "ID",
  main = "Manhattan plot",
  suggestiveline = F,
  genomewideline = -log10(5e-08),
  cex = 0.6,
  cex.axis = 0.9,
  ylim = c(0, 10),
)
# Out:
# Plot with title “Manhattan plot”

# %% [markdown]
# ## QQ-plot

# %%
options(repr.plot.width = 10, repr.plot.height = 10)

qq(gwas$P, main = "Q-Q plot of GWAS p-values")
# Out:
# Plot with title “Q-Q plot of GWAS p-values”

# %% [markdown]
# # Random pheno 135

# %% [markdown]
# ## Load data

# %%
gwas <- as.data.frame(read_table(file.path(GWAS_DIR, "random.pheno135.glm.linear.tsv.gz")))
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   `#CHROM` = col_double(),
#   POS = col_double(),
#   ID = col_character(),
#   REF = col_character(),
#   A1 = col_character(),
#   BETA = col_double(),
#   SE = col_double(),
#   P = col_double()
# )

# %%
dim(gwas)
# Out:
# [1] 5923554       8

# %%
head(gwas)
# Out:
#   #CHROM POS   ID          REF A1 BETA        SE       P
# 1 1      11008 rs575272151 C   G  -0.11294100 0.153761 0.463225
# 2 1      11012 rs544419019 C   G  -0.11294100 0.153761 0.463225
# 3 1      13110 rs540538026 G   A  -0.13167200 0.178432 0.461151
# 4 1      13116 rs62635286  T   G  -0.00416068 0.106658 0.968910
# 5 1      13118 rs200579949 A   G  -0.00416068 0.106658 0.968910
# 6 1      13273 rs531730856 G   C  -0.00374452 0.116420 0.974364

# %%
gwas <- gwas %>% filter(P >= 0 & P <= 1)

# %%
dim(gwas)
# Out:
# [1] 5923554       8

# %% [markdown]
# ## Manhattan plot

# %%
options(repr.plot.width = 20, repr.plot.height = 10)

manhattan(
  gwas,
  chr = "#CHROM",
  bp = "POS",
  p = "P",
  snp = "ID",
  main = "Manhattan plot",
  suggestiveline = F,
  genomewideline = -log10(5e-08),
  cex = 0.6,
  cex.axis = 0.9,
  ylim = c(0, 10),
)
# Out:
# Plot with title “Manhattan plot”

# %% [markdown]
# ## QQ-plot

# %%
options(repr.plot.width = 10, repr.plot.height = 10)

qq(gwas$P, main = "Q-Q plot of GWAS p-values")
# Out:
# Plot with title “Q-Q plot of GWAS p-values”

# %% [markdown]
# # Random pheno 412

# %% [markdown]
# ## Load data

# %%
gwas <- as.data.frame(read_table(file.path(GWAS_DIR, "random.pheno412.glm.linear.tsv.gz")))
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   `#CHROM` = col_double(),
#   POS = col_double(),
#   ID = col_character(),
#   REF = col_character(),
#   A1 = col_character(),
#   BETA = col_double(),
#   SE = col_double(),
#   P = col_double()
# )

# %%
dim(gwas)
# Out:
# [1] 5923554       8

# %%
head(gwas)
# Out:
#   #CHROM POS   ID          REF A1 BETA       SE       P
# 1 1      11008 rs575272151 C   G   0.2302130 0.152513 0.132273
# 2 1      11012 rs544419019 C   G   0.2302130 0.152513 0.132273
# 3 1      13110 rs540538026 G   A   0.1748820 0.177383 0.325007
# 4 1      13116 rs62635286  T   G  -0.0779981 0.106010 0.462473
# 5 1      13118 rs200579949 A   G  -0.0779981 0.106010 0.462473
# 6 1      13273 rs531730856 G   C  -0.1116250 0.115635 0.335194

# %%
gwas <- gwas %>% filter(P >= 0 & P <= 1)

# %%
dim(gwas)
# Out:
# [1] 5923554       8

# %% [markdown]
# ## Manhattan plot

# %%
options(repr.plot.width = 20, repr.plot.height = 10)

manhattan(
  gwas,
  chr = "#CHROM",
  bp = "POS",
  p = "P",
  snp = "ID",
  main = "Manhattan plot",
  suggestiveline = F,
  genomewideline = -log10(5e-08),
  cex = 0.6,
  cex.axis = 0.9,
  ylim = c(0, 10),
)
# Out:
# Plot with title “Manhattan plot”

# %% [markdown]
# ## QQ-plot

# %%
options(repr.plot.width = 10, repr.plot.height = 10)

qq(gwas$P, main = "Q-Q plot of GWAS p-values")
# Out:
# Plot with title “Q-Q plot of GWAS p-values”
