# %% [markdown]
# # Description

# %% [markdown]
# This notebook will show the structure of the main data matrices in PhenoPLIER, and will guide you in analyzing gene associations for a particular trait: basophil percentage, which is presented in the [manuscript](https://greenelab.github.io/phenoplier_manuscript/#phenoplier-an-integration-framework-based-on-gene-co-expression-patterns) in Figure 1c.

# %% [markdown]
# # Modules

# %%
import tempfile

import numpy as np
from scipy import stats
import pandas as pd

from entity import Trait, Gene
import conf

# %% [markdown]
# # Load gene module-gene membership matrix (matrix Z)

# %% [markdown]
# Here we load the gene module-gene membership matri, or "latent variables loadings matrix" (from the terminology of the [MultiPLIER article](https://doi.org/10.1016/j.cels.2019.04.003)).

# %%
matrix_z = pd.read_pickle(conf.MULTIPLIER["MODEL_Z_MATRIX_FILE"])

# %%
matrix_z.shape
# Out:
# (6750, 987)

# %%
matrix_z.head()
# Out:
#                LV1  LV2       LV3  LV4       LV5       LV6  LV7       LV8  \
# GAS6      0.000000  0.0  0.039438  0.0  0.050476  0.000000  0.0  0.000000
# MMP14     0.000000  0.0  0.000000  0.0  0.070072  0.000000  0.0  0.004904
# DSP       0.000000  0.0  0.000000  0.0  0.000000  0.041697  0.0  0.005718
# MARCKSL1  0.305212  0.0  0.000000  0.0  0.000000  0.000000  0.0  0.000000
# SPARC     0.000000  0.0  0.000000  0.0  0.000000  0.000000  0.0  0.000000
#
#                LV9      LV10  ...     LV978    LV979     LV980     LV981  \
# GAS6      0.590949  0.000000  ...  0.050125  0.00000  0.033407  0.000000
# MMP14     1.720179  2.423595  ...  0.000000  0.00000  0.001007  0.000000
# DSP       0.000000  0.000000  ...  0.020853  0.00000  0.000000  0.000000
# MARCKSL1  0.161843  0.149471  ...  0.027134  0.05272  0.000000  0.030189
# SPARC     0.000000  0.014014  ...  0.000000  0.00000  0.000000  0.000000
#
#              LV982     LV983     LV984  LV985     LV986     LV987
# GAS6      0.000000  0.005963  0.347362    0.0  0.000000  0.000000
# MMP14     0.035747  0.000000  0.000000    0.0  0.014978  0.000000
# DSP       0.000000  0.005774  0.000000    0.0  0.000000  0.416405
# MARCKSL1  0.060884  0.000000  0.000000    0.0  0.000000  0.448480
# SPARC     0.000000  0.000000  0.067779    0.0  0.122417  0.062665
#
# [5 rows x 987 columns]

# %% [markdown]
# As you can see, this matrix Z contains the membership value for each gene across all LVs (or gene modules).
# A value of zero means that the gene does not belong to that LV, whereas a larger value represents how strongly that gene belongs to the LV.
# A group of genes that belong to the same LV represent a gene-set that has a similar expression profile across a set of tissues or cell types.
# We'll cover this in more detail in the next notebook (`02-LV_cell_types-...`).

# %% [markdown]
# # Load information about LV alignment with pathways

# %% [markdown]
# LV in matrix Z can represent a group of genes that align well with prior pathways (or prior knowledge) or be "novel" in the sense that the combination of genes do not represent a known unit but was found the PLIER when factorizing the recount2 data (see the MultiPLIER article for more details).
#
# Here we load that information, where for each LV and pathway, we have a p-value and area under the curve (AUC) that indicate how well the LV aligns to that pathway.

# %%
lv_metadata = pd.read_pickle(conf.MULTIPLIER["MODEL_SUMMARY_FILE"])

# %%
lv_metadata.shape
# Out:
# (2157, 5)

# %%
lv_metadata.head()
# Out:
#                                    pathway LV index       AUC   p-value  \
# 1                  KEGG_LYSINE_DEGRADATION        1  0.388059  0.866078
# 2                   REACTOME_MRNA_SPLICING        1  0.733057  0.000048
# 3  MIPS_NOP56P_ASSOCIATED_PRE_RRNA_COMPLEX        1  0.680555  0.001628
# 4                     KEGG_DNA_REPLICATION        1  0.549473  0.312155
# 5                     PID_MYC_ACTIVPATHWAY        1  0.639303  0.021702
#
#         FDR
# 1  0.956005
# 2  0.000582
# 3  0.011366
# 4  0.539951
# 5  0.083739

# %% [markdown]
# # Load gene associations from PhenomeXcan

# %% [markdown]
# Now we load gene-trait association from [PhenomeXcan](https://doi.org/10.1126/sciadv.aba2083).
# PhenomeXcan provides TWAS results (using [Summary-MultiXcan](https://doi.org/10.1371/journal.pgen.1007889) and [Summary-PrediXcan](https://doi.org/10.1038/s41467-018-03621-1)) across ~4,000 traits.
# If you are interested in PhenomeXcan you can also check out the [Github repo](https://github.com/hakyimlab/phenomexcan) to know how to download results.
#
# For this demo, we'll load a file that contains Summary-MultiXcan (or S-MultiXcan) results for basophil percentage.
# This file contains a list of p-values for ~22k genes, where a significant p-value means that the gene's predicted expression (across different tissues) is associated with basophil percentage.
# In the notebook I refer to these results generically as "TWAS results", meaning that we have gene-trait associations.
# All these TWAS results were derived solely from GWAS summary stats, so you can also generate yours relatively easily by using [S-MultiXcan](https://doi.org/10.1371/journal.pgen.1007889).

# %%
# %%bash
# # download S-MultiXcan results for basophil percentage
# wget https://uchicago.box.com/shared/static/g70nq1c6wjvado242t9yg05jrhvdykrv.gz -O /tmp/smultixcan_30220_raw_ccn30.tsv.gz
# Out:
# --2022-11-15 22:27:42--  https://uchicago.box.com/shared/static/g70nq1c6wjvado242t9yg05jrhvdykrv.gz
# Resolving uchicago.box.com (uchicago.box.com)... 74.112.186.144
# Connecting to uchicago.box.com (uchicago.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/g70nq1c6wjvado242t9yg05jrhvdykrv.gz [following]
# --2022-11-15 22:27:42--  https://uchicago.box.com/public/static/g70nq1c6wjvado242t9yg05jrhvdykrv.gz
# Reusing existing connection to uchicago.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://uchicago.app.box.com/public/static/g70nq1c6wjvado242t9yg05jrhvdykrv.gz [following]
# --2022-11-15 22:27:42--  https://uchicago.app.box.com/public/static/g70nq1c6wjvado242t9yg05jrhvdykrv.gz
# Resolving uchicago.app.box.com (uchicago.app.box.com)... 74.112.186.144
# Connecting to uchicago.app.box.com (uchicago.app.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dl2.boxcloud.com/d/1/b1!6xVHh6btBC1o_unkrAGziI5hio9l2dYRrpnyiOadgVhw2PLoXHf7P1NL_36qOdk4Ufj7FYFER2mFb9XFvE_GnzRumFZ4GVp17Ws7RzDzvF5gHOJJjdEZmHGMSOAa5GkaY0CqfpjrMlevd2ZpBFYJUUwxgTHkUxZeytR1i9jZSebx718YLMUjqEdcqG7-ZnE4Xhj6fdo61sutMQESRUUKZ0KddIqzrUJgBl-TZ8c2gkISszy3zqVfMS-rWHOz_jBr6v5zPKlclLNc6mdElrH6_wyZU4Gjwe7oljczDnZJ-QmciRIuxEJAqWk7gMQbhg5qWN9fNid_VDAekBuNupFYNviIfbhnn--Dl2B1QLpxr3idaQHfFvDF7sVHGDHAPFPoFCJdYCylwr1t-QP6l9W8f3pl5c0-D_spbr5p0tY0AWZo9o8EICWEykVA-kAPJdeDY5GtNWkgWk3XkK93LcLZMqlQ08pGCHEOabiVbr9uprdOgIfsS-Qww2yA1OTTA0750ws-Jd-nBqoRStXfSPyBv0QobS7qYZOUS1ZtQCj5aK0oio2VOvlmn-R8DQMy_lbYrBxe3SLVGjfVskgACR2kgdtN8nIxGjyafYZZGYYzrfTeJEt_xsbUbWvI4DIrNZmvhB4WHHPYfd28-4HRYrlyK2CKTGhSZ-dlopyOy-2slmBSRdHfj6_0ERwBo-Beesf8etCBocWXwhxgdTom2OpyuxEwBCbdC5f2CMl2wtY2rrCDPN4uKTx_PtB9raXeVwK-YPAiXZKwmvXSv5NR5w3OccldD5mftVF2qLMqp9m4BEDzk3gRNsl1-Xbir05RHSDSESLtaFT4SinbpumJRfIquLRh7eEiF773RvQnTlwxffHvNVopO9bSQhgYDlq73cXM-0Xjkr5PfvnE-n02smb3pZy_2tzS5GOwyE6ErMGdzgJsBCXrSLfAHrNEYQBfqFIGAZWqVZnS7eMJi2F7FBax-quq5SbGhKgV8kT5rz1ecgIqdSAPolx2iVA8Eg5b-XePBuJj-dQHVyiIcXmwNcGm1hcuCdFgfkzZDo2F-ptm0dmdtcGpYEbq15nMt6Y0MAfigAcFvcIkJ3UGC6VVh4-5X0yaDxfK-XbEX0Z_ZRf7qXRZ7Glo9xfouhbLTqhRB8Xo_YZAhsb5JYg0iUSpUIbQSKKzYaW4JqcInBpWXJMgYhdoHmjBUZw1M1YhZmatzKSjq7XxdCijP95iImHNZ-525JQ8S2kvqb0U7DMUGri0cPXHlafnLV4UI5sObAqAMRcakQ5absMa3j5b7o_vLMDe7qgy5UabQHOgbj0wB_Son7Ar-HJ_iNFkbXagQqenugbMca-DIVg0kiZQ4n4EyVGR6hOGoW-Fi3qGQH3ocTPFIHM_jf6D0D9mAYDS8X6NBTyADZL3Z78ZGv_kB0t4ZzblqW_5rTNpUlgupD_7J-WDd9kLA5xcSzS_ortMwChU3nAmQpaNx-BSLFaHG6jJIWO03XFpCBNPBZSelA../download [following]
# --2022-11-15 22:27:43--  https://dl2.boxcloud.com/d/1/b1!6xVHh6btBC1o_unkrAGziI5hio9l2dYRrpnyiOadgVhw2PLoXHf7P1NL_36qOdk4Ufj7FYFER2mFb9XFvE_GnzRumFZ4GVp17Ws7RzDzvF5gHOJJjdEZmHGMSOAa5GkaY0CqfpjrMlevd2ZpBFYJUUwxgTHkUxZeytR1i9jZSebx718YLMUjqEdcqG7-ZnE4Xhj6fdo61sutMQESRUUKZ0KddIqzrUJgBl-TZ8c2gkISszy3zqVfMS-rWHOz_jBr6v5zPKlclLNc6mdElrH6_wyZU4Gjwe7oljczDnZJ-QmciRIuxEJAqWk7gMQbhg5qWN9fNid_VDAekBuNupFYNviIfbhnn--Dl2B1QLpxr3idaQHfFvDF7sVHGDHAPFPoFCJdYCylwr1t-QP6l9W8f3pl5c0-D_spbr5p0tY0AWZo9o8EICWEykVA-kAPJdeDY5GtNWkgWk3XkK93LcLZMqlQ08pGCHEOabiVbr9uprdOgIfsS-Qww2yA1OTTA0750ws-Jd-nBqoRStXfSPyBv0QobS7qYZOUS1ZtQCj5aK0oio2VOvlmn-R8DQMy_lbYrBxe3SLVGjfVskgACR2kgdtN8nIxGjyafYZZGYYzrfTeJEt_xsbUbWvI4DIrNZmvhB4WHHPYfd28-4HRYrlyK2CKTGhSZ-dlopyOy-2slmBSRdHfj6_0ERwBo-Beesf8etCBocWXwhxgdTom2OpyuxEwBCbdC5f2CMl2wtY2rrCDPN4uKTx_PtB9raXeVwK-YPAiXZKwmvXSv5NR5w3OccldD5mftVF2qLMqp9m4BEDzk3gRNsl1-Xbir05RHSDSESLtaFT4SinbpumJRfIquLRh7eEiF773RvQnTlwxffHvNVopO9bSQhgYDlq73cXM-0Xjkr5PfvnE-n02smb3pZy_2tzS5GOwyE6ErMGdzgJsBCXrSLfAHrNEYQBfqFIGAZWqVZnS7eMJi2F7FBax-quq5SbGhKgV8kT5rz1ecgIqdSAPolx2iVA8Eg5b-XePBuJj-dQHVyiIcXmwNcGm1hcuCdFgfkzZDo2F-ptm0dmdtcGpYEbq15nMt6Y0MAfigAcFvcIkJ3UGC6VVh4-5X0yaDxfK-XbEX0Z_ZRf7qXRZ7Glo9xfouhbLTqhRB8Xo_YZAhsb5JYg0iUSpUIbQSKKzYaW4JqcInBpWXJMgYhdoHmjBUZw1M1YhZmatzKSjq7XxdCijP95iImHNZ-525JQ8S2kvqb0U7DMUGri0cPXHlafnLV4UI5sObAqAMRcakQ5absMa3j5b7o_vLMDe7qgy5UabQHOgbj0wB_Son7Ar-HJ_iNFkbXagQqenugbMca-DIVg0kiZQ4n4EyVGR6hOGoW-Fi3qGQH3ocTPFIHM_jf6D0D9mAYDS8X6NBTyADZL3Z78ZGv_kB0t4ZzblqW_5rTNpUlgupD_7J-WDd9kLA5xcSzS_ortMwChU3nAmQpaNx-BSLFaHG6jJIWO03XFpCBNPBZSelA../download
# Resolving dl2.boxcloud.com (dl2.boxcloud.com)... 74.112.186.128
# Connecting to dl2.boxcloud.com (dl2.boxcloud.com)|74.112.186.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2445491 (2.3M) [application/octet-stream]
# Saving to: ‘/tmp/smultixcan_30220_raw_ccn30.tsv.gz’
#
#      0K .......... .......... .......... .......... ..........  2% 2.03M 1s
#     50K .......... .......... .......... .......... ..........  4%  992K 2s
#    100K .......... .......... .......... .......... ..........  6% 3.40M 1s
#    150K .......... .......... .......... .......... ..........  8% 3.68M 1s
#    200K .......... .......... .......... .......... .......... 10% 3.41M 1s
#    250K .......... .......... .......... .......... .......... 12% 3.68M 1s
#    300K .......... .......... .......... .......... .......... 14% 3.31M 1s
#    350K .......... .......... .......... .......... .......... 16% 3.95M 1s
#    400K .......... .......... .......... .......... .......... 18% 4.38M 1s
#    450K .......... .......... .......... .......... .......... 20% 5.29M 1s
#    500K .......... .......... .......... .......... .......... 23% 6.52M 1s
#    550K .......... .......... .......... .......... .......... 25% 10.6M 1s
#    600K .......... .......... .......... .......... .......... 27% 9.86M 1s
#    650K .......... .......... .......... .......... .......... 29% 10.3M 0s
#    700K .......... .......... .......... .......... .......... 31% 10.5M 0s
#    750K .......... .......... .......... .......... .......... 33% 9.90M 0s
#    800K .......... .......... .......... .......... .......... 35% 10.7M 0s
#    850K .......... .......... .......... .......... .......... 37% 8.93M 0s
#    900K .......... .......... .......... .......... .......... 39% 8.01M 0s
#    950K .......... .......... .......... .......... .......... 41% 10.1M 0s
#   1000K .......... .......... .......... .......... .......... 43% 9.08M 0s
#   1050K .......... .......... .......... .......... .......... 46% 14.8M 0s
#   1100K .......... .......... .......... .......... .......... 48% 11.8M 0s
#   1150K .......... .......... .......... .......... .......... 50% 13.2M 0s
#   1200K .......... .......... .......... .......... .......... 52% 13.1M 0s
#   1250K .......... .......... .......... .......... .......... 54% 16.0M 0s
#   1300K .......... .......... .......... .......... .......... 56% 17.5M 0s
#   1350K .......... .......... .......... .......... .......... 58% 15.7M 0s
#   1400K .......... .......... .......... .......... .......... 60% 16.3M 0s
#   1450K .......... .......... .......... .......... .......... 62% 17.9M 0s
#   1500K .......... .......... .......... .......... .......... 64% 22.1M 0s
#   1550K .......... .......... .......... .......... .......... 66% 19.4M 0s
#   1600K .......... .......... .......... .......... .......... 69% 16.0M 0s
#   1650K .......... .......... .......... .......... .......... 71% 24.1M 0s
#   1700K .......... .......... .......... .......... .......... 73% 21.4M 0s
#   1750K .......... .......... .......... .......... .......... 75% 42.5M 0s
#   1800K .......... .......... .......... .......... .......... 77% 17.8M 0s
#   1850K .......... .......... .......... .......... .......... 79% 25.2M 0s
#   1900K .......... .......... .......... .......... .......... 81% 24.3M 0s
#   1950K .......... .......... .......... .......... .......... 83% 23.6M 0s
#   2000K .......... .......... .......... .......... .......... 85% 28.0M 0s
#   2050K .......... .......... .......... .......... .......... 87% 25.0M 0s
#   2100K .......... .......... .......... .......... .......... 90% 12.9M 0s
#   2150K .......... .......... .......... .......... .......... 92% 20.5M 0s
#   2200K .......... .......... .......... .......... .......... 94% 23.5M 0s
#   2250K .......... .......... .......... .......... .......... 96% 30.8M 0s
#   2300K .......... .......... .......... .......... .......... 98% 34.6M 0s
#   2350K .......... .......... .......... ........             100% 19.7M=0.3s
#
# 2022-11-15 22:27:44 (7.69 MB/s) - ‘/tmp/smultixcan_30220_raw_ccn30.tsv.gz’ saved [2445491/2445491]

# %%
df = pd.read_csv("/tmp/smultixcan_30220_raw_ccn30.tsv.gz", sep="\t")

# %%
df.shape
# Out:
# (22258, 18)

# %%
df.head()
# Out:
#                  gene gene_name        pvalue     n  n_indep      p_i_best  \
# 0  ENSG00000143669.13      LYST  3.430090e-78  40.0      5.0  5.887514e-67
# 1  ENSG00000140575.12    IQGAP1  5.312061e-56  49.0      2.0  1.792379e-55
# 2   ENSG00000239839.6     DEFA3  6.178319e-52  25.0      8.0  1.735510e-30
# 3  ENSG00000140577.15     CRTC3  3.633540e-46  47.0      5.0  3.326635e-48
# 4  ENSG00000107929.14    LARP4B  5.229144e-43  35.0      4.0  4.209043e-45
#
#                             t_i_best     p_i_worst  \
# 0         Cells_Cultured_fibroblasts  5.715454e-01
# 1  Cells_EBV-transformed_lymphocytes  2.034382e-18
# 2           Brain_Frontal_Cortex_BA9  4.821369e-01
# 3    Skin_Not_Sun_Exposed_Suprapubic  2.188896e-01
# 4           Brain_Frontal_Cortex_BA9  3.858258e-01
#
#                      t_i_worst  eigen_max     eigen_min  eigen_min_kept  \
# 0                        Ovary  25.575879  5.685765e-16        1.091354
# 1     Brain_Frontal_Cortex_BA9  43.159657  1.197089e-15        3.913487
# 2       Heart_Atrial_Appendage  13.021527  1.362063e-17        0.438362
# 3                Artery_Tibial  25.991131  1.853057e-15        1.183360
# 4  Brain_Cerebellar_Hemisphere  24.531853  5.407442e-16        2.055242
#
#        z_min      z_max     z_mean       z_sd  tmi  status
# 0 -17.287064  16.985176  -6.255059  11.905653  5.0       0
# 1 -15.689222  -8.755368 -11.930501   2.305056  2.0       0
# 2 -11.476299   3.676225  -6.196329   4.534728  8.0       0
# 3  -7.376543  14.588451   7.294836   5.294380  5.0       0
# 4 -13.906881  14.092741   6.933903   8.977076  4.0       0

# %% [markdown]
# # Take a look at genes associated with basophil percentage

# %% [markdown]
# Show the sample size for this trait.

# %%
trait_code = "30220_raw-Basophill_percentage"
t = Trait.get_trait(full_code=trait_code)
display(f"{trait_code} - sample size: {t.n}")
# Out:
# '30220_raw-Basophill_percentage - sample size: 349861'

# %% [markdown]
# Below I list the top associated genes for basophil percentage.

# %%
traits_df = df[["gene_name", "pvalue"]].dropna().set_index("gene_name")

# remove duplicated gene names
traits_df = traits_df.loc[~traits_df.index.duplicated()]

# %%
traits_df.shape
# Out:
# (22248, 1)

# %%
traits_df.head()
# Out:
#                  pvalue
# gene_name
# LYST       3.430090e-78
# IQGAP1     5.312061e-56
# DEFA3      6.178319e-52
# CRTC3      3.633540e-46
# LARP4B     5.229144e-43

# %% [markdown]
# Here I quickly show the data summary for this trait's gene associations:

# %%
traits_df["pvalue"].apply(lambda x: -np.log10(x)).describe()
# Out:
# count    22248.000000
# mean         0.695257
# std          1.556005
# min          0.000120
# 25%          0.166637
# 50%          0.393855
# 75%          0.815005
# max         77.464694
# Name: pvalue, dtype: float64

# %% [markdown]
# # Get a set of common genes between TWAS and LVs

# %%
common_genes = traits_df.index.intersection(matrix_z.index)

# %%
common_genes
# Out:
# Index(['IQGAP1', 'CCR1', 'CCR3', 'PRTN3', 'FCGR3B', 'RASGRP4', 'ZYX', 'RYR1',
#        'EPHA1', 'MYB',
#        ...
#        'NPTX2', 'RNASE2', 'WDTC1', 'NLK', 'GADD45B', 'ARHGAP22', 'POLR1E',
#        'ATP6V1D', 'NEDD4L', 'CACNG6'],
#       dtype='object', length=6430)

# %%
# keep only the genes in common
traits_df = traits_df.loc[common_genes]

# %%
traits_df.shape
# Out:
# (6430, 1)

# %%
matrix_z = matrix_z.loc[common_genes]

# %%
matrix_z.shape
# Out:
# (6430, 987)

# %% [markdown]
# # Analysis of a neutrophil-termed LV

# %% [markdown]
# Let's take as an example an LV that was previously analyzed in the MultiPLIER study, which we identify as `LV603`. This LV aligns well with pathways related to neutrophils, as you can see below. In the next notebook (`02-LV_cell_types...`) we'll see that this LV is expressed in neutrophils and other granulocytes.

# %%
lv_metadata[
    (lv_metadata["LV index"] == "603") & (lv_metadata["FDR"] < 0.05)
].sort_values("FDR")
# Out:
#                                   pathway LV index       AUC       p-value  \
# 1511              IRIS_Neutrophil-Resting      603  0.905751  8.355936e-38
# 1512                      SVM Neutrophils      603  0.979789  2.856571e-11
# 1513                 PID_IL8CXCR2_PATHWAY      603  0.810732  8.814671e-04
# 1516  SIG_PIP3_SIGNALING_IN_B_LYMPHOCYTES      603  0.769292  3.387907e-03
#
#                FDR
# 1511  4.505939e-35
# 1512  1.432936e-09
# 1513  7.041943e-03
# 1516  1.948724e-02

# %% [markdown]
# Let's see which genes more strongly belong to LV603 (the numbers are the gene weights in this LV):

# %%
lv603_top_genes = matrix_z["LV603"].sort_values(ascending=False)
display(lv603_top_genes.head(20))
# Out:
# CXCR2        5.320459
# FCGR3B       5.128372
# TNFRSF10C    5.035457
# VNN2         4.680865
# ZDHHC18      4.495976
# MNDA         4.488505
# CXCR1        4.442062
# P2RY13       4.404405
# VNN3         4.253184
# FPR2         4.187560
# CEACAM3      4.139476
# C5AR1        4.101986
# SLC45A4      4.068913
# AQP9         3.939923
# CCR3         3.883533
# ABTB1        3.745259
# CSF3R        3.735651
# FPR1         3.720018
# DPEP2        3.656125
# SIRPB1       3.632251
# Name: LV603, dtype: float64

# %% [markdown]
# Are these top genes associated with our trait of interest?

# %%
traits_df.loc[lv603_top_genes.index].head(20)
# Out:
#                  pvalue
# CXCR2      1.281640e-02
# FCGR3B     3.297587e-32
# TNFRSF10C  1.655229e-07
# VNN2       9.217389e-01
# ZDHHC18    8.370749e-02
# MNDA       4.876452e-01
# CXCR1      1.315804e-02
# P2RY13     2.734939e-02
# VNN3       4.231949e-01
# FPR2       8.199449e-01
# CEACAM3    2.023499e-02
# C5AR1      9.653734e-02
# SLC45A4    1.859938e-01
# AQP9       2.934985e-02
# CCR3       1.525115e-35
# ABTB1      1.323314e-02
# CSF3R      1.692547e-01
# FPR1       8.057217e-01
# DPEP2      8.727988e-02
# SIRPB1     5.318173e-01

# %% [markdown]
# It seems so. But what about the rest of the genes? They might be also strongly associated.
# Let's take a random sample:

# %%
traits_df.sample(n=20, random_state=0)
# Out:
#             pvalue
# GPR171    0.170912
# SGCA      0.070701
# P4HA2     0.324261
# ANAPC7    0.032241
# CYP11A1   0.215818
# NUMB      0.126148
# IGF1      0.603579
# C10orf10  0.018192
# CISH      0.558913
# NDUFB9    0.574156
# ACTA1     0.672696
# LEF1      0.333482
# EIF4E     0.292698
# CLEC4E    0.827772
# GPLD1     0.473381
# MCEE      0.571339
# SSPO      0.423126
# MAP2K1    0.222102
# EPS15L1   0.164045
# TUBA1A    0.284552

# %% [markdown]
# They do not seem as significant as those within the top genes in LV603.
#
# If we compute the correlation between LV603 gene weights (`lv603_top_genes`) and gene associations for basophil percentage (`traits_df`) we get this:

# %%
lv603_top_genes
# Out:
# CXCR2        5.320459
# FCGR3B       5.128372
# TNFRSF10C    5.035457
# VNN2         4.680865
# ZDHHC18      4.495976
#                ...
# GTF2H2       0.000000
# TRIM28       0.000000
# DPYD         0.000000
# ASPM         0.000000
# PDE2A        0.000000
# Name: LV603, Length: 6430, dtype: float64

# %%
stats.pearsonr(
    traits_df["pvalue"]
    .apply(lambda x: -np.log10(x))
    .loc[lv603_top_genes.index]
    .to_numpy(),
    lv603_top_genes.to_numpy(),
)
# Out:
# (0.13428177436972902, 2.935462151415347e-27)

# %% [markdown]
# Although the correlation is significant (`2.94e-27`) and the slope positive (we are interested only in genes at the top of the LV), we need to account for correlated predicted expression from the TWAS models (for example, if the expression of two genes at the top of the LV is correlated that would invalidate our test).
# We provide a class, `GLSPhenoplier` (implemented in Python) that computes this. We also provide a command-line tool, `gls_cli.py`, that performs several preprocessing steps, and below we show how to use it for our example.

# %% [markdown]
# # `gls_cli.py`: association between an LV and a trait

# %% [markdown]
# The `gls_cli.py` command-line tool needs as input the S-MultiXcan TWAS results and a gene correlation matrix (which is specific to the TWAS results, see below).

# %%
# %%bash
# # remove previously computed results (if exist)
# rm /tmp/gls_phenoplier-basophill_percentage.tsv.gz
#
# # print full path of gls_cli.py tool
# echo ${PHENOPLIER_CODE_DIR}/libs/gls_cli.py
#
# # print full path of gene correlations file (which is trait-specific!)
# COHORT_NAME="phenomexcan_rapid_gwas"
# REFERENCE_PANEL="gtex_v8"
# GENE_CORR_DIR="${PHENOPLIER_RESULTS_GLS}/gene_corrs/cohorts/${COHORT_NAME}/${REFERENCE_PANEL}/mashr/gene_corrs-symbols-within_distance_5mb.per_lv/"
# echo ${GENE_CORR_DIR}
#
# python ${PHENOPLIER_CODE_DIR}/libs/gls_cli.py \
#   --input-file /tmp/smultixcan_30220_raw_ccn30.tsv.gz \
#   --duplicated-genes-action keep-first \
#   --gene-corr-file ${GENE_CORR_DIR} \
#   --debug-use-sub-gene-corr \
#   --covars gene_size gene_size_log gene_density gene_density_log \
#   --output-file /tmp/gls_phenoplier-basophill_percentage.tsv.gz
# Out:
# rm: cannot remove '/tmp/gls_phenoplier-basophill_percentage.tsv.gz': No such file or directory
# /opt/code/libs/gls_cli.py
# /opt/data/results/gls/gene_corrs/cohorts/phenomexcan_rapid_gwas/gtex_v8/mashr/gene_corrs-symbols-within_distance_5mb.per_lv/
# [2022-11-15 22:27:46,367] INFO: Reading input file /tmp/smultixcan_30220_raw_ccn30.tsv.gz
# [2022-11-15 22:27:46,489] INFO: Input file has 22258 genes
# [2022-11-15 22:27:46,496] INFO: Removed duplicated genes symbols using 'keep-first'. Data now has 22251 genes
# [2022-11-15 22:27:46,498] INFO: p-values statistics: min=3.4e-78 | mean=4.3e-01 | max=1.0e+00 | # missing=3 (0.0%)
# [2022-11-15 22:27:46,499] INFO: Using covariates: ['gene_density', 'gene_density_log', 'gene_size', 'gene_size_log']
# [2022-11-15 22:27:46,797] INFO: NumExpr defaulting to 8 threads.
# [2022-11-15 22:27:46,803] INFO: Replacing zero p-values by nonzero minimum divided by 10
# [2022-11-15 22:27:46,807] INFO: Using -log10(pvalue)
# [2022-11-15 22:27:46,808] INFO: Using gene correlation file: /opt/data/results/gls/gene_corrs/cohorts/phenomexcan_rapid_gwas/gtex_v8/mashr/gene_corrs-symbols-within_distance_5mb.per_lv/
# [2022-11-15 22:27:46,834] INFO: 987 LVs (gene modules) were found in LV model
# [2022-11-15 22:27:46,834] INFO: All LVs in models will be used
# [2022-11-15 22:27:46,834] INFO: Computing for LV1
# [2022-11-15 22:27:46,870] WARNING: 3 genes with missing values have been removed
# [2022-11-15 22:27:46,882] WARNING: 22248 genes in phenotype associations, but only 6430 were found in LV models
# [2022-11-15 22:27:46,889] INFO: Using binarized LV at 1% (65 / 6365)
# [2022-11-15 22:27:46,894] INFO: Final number of genes in training data: 6430
# [2022-11-15 22:27:46,894] INFO: Correlation matrix is a directory, reading inverse of Cholesky decomposition for each LV
# [2022-11-15 22:27:46,906] INFO: Data has all genes in LV-specific correlation matrix
# [2022-11-15 22:27:47,068] INFO: Computing for LV2
# [2022-11-15 22:27:47,311] INFO: Computing for LV3
# [2022-11-15 22:27:47,534] INFO: Computing for LV4
# [2022-11-15 22:27:47,740] INFO: Computing for LV5
# [2022-11-15 22:27:47,941] INFO: Computing for LV6
# [2022-11-15 22:27:48,145] INFO: Computing for LV7
# [2022-11-15 22:27:48,366] INFO: Computing for LV8
# [2022-11-15 22:27:48,578] INFO: Computing for LV9
# [2022-11-15 22:27:48,799] INFO: Computing for LV10
# [2022-11-15 22:27:49,007] INFO: Computing for LV11
# [2022-11-15 22:27:49,212] INFO: Computing for LV12
# [2022-11-15 22:27:49,413] INFO: Computing for LV13
# [2022-11-15 22:27:49,676] INFO: Computing for LV14
# [2022-11-15 22:27:49,957] INFO: Computing for LV15
# [2022-11-15 22:27:50,203] INFO: Computing for LV16
# [2022-11-15 22:27:50,450] INFO: Computing for LV17
# [2022-11-15 22:27:50,683] INFO: Computing for LV18
# [2022-11-15 22:27:50,928] INFO: Computing for LV19
# [2022-11-15 22:27:51,158] INFO: Computing for LV20
# [2022-11-15 22:27:51,410] INFO: Computing for LV21
# [2022-11-15 22:27:51,645] INFO: Computing for LV22
# [2022-11-15 22:27:51,929] INFO: Computing for LV23
# [2022-11-15 22:27:52,134] INFO: Computing for LV24
# [2022-11-15 22:27:52,395] INFO: Computing for LV25
# [2022-11-15 22:27:52,649] INFO: Computing for LV26
# [2022-11-15 22:27:52,905] INFO: Computing for LV27
# [2022-11-15 22:27:53,144] INFO: Computing for LV28
# [2022-11-15 22:27:53,514] INFO: Computing for LV29
# [2022-11-15 22:27:53,766] INFO: Computing for LV30
# [2022-11-15 22:27:54,044] INFO: Computing for LV31
# [2022-11-15 22:27:54,394] INFO: Computing for LV32
# [2022-11-15 22:27:54,713] INFO: Computing for LV33
# [2022-11-15 22:27:54,957] INFO: Computing for LV34
# [2022-11-15 22:27:55,199] INFO: Computing for LV35
# [2022-11-15 22:27:55,452] INFO: Computing for LV36
# [2022-11-15 22:27:55,695] INFO: Computing for LV37
# [2022-11-15 22:27:55,964] INFO: Computing for LV38
# [2022-11-15 22:27:56,203] INFO: Computing for LV39
# [2022-11-15 22:27:56,518] INFO: Computing for LV40
# [2022-11-15 22:27:56,748] INFO: Computing for LV41
# [2022-11-15 22:27:56,989] INFO: Computing for LV42
# [2022-11-15 22:27:57,243] INFO: Computing for LV43
# [2022-11-15 22:27:57,476] INFO: Computing for LV44
# [2022-11-15 22:27:57,695] INFO: Computing for LV45
# [2022-11-15 22:27:57,919] INFO: Computing for LV46
# [2022-11-15 22:27:58,155] INFO: Computing for LV47
# [2022-11-15 22:27:58,395] INFO: Computing for LV48
# [2022-11-15 22:27:58,602] INFO: Computing for LV49
# [2022-11-15 22:27:58,872] INFO: Computing for LV50
# [2022-11-15 22:27:59,153] INFO: Computing for LV51
# [2022-11-15 22:27:59,413] INFO: Computing for LV52
# [2022-11-15 22:27:59,660] INFO: Computing for LV53
# [2022-11-15 22:27:59,885] INFO: Computing for LV54
# [2022-11-15 22:28:00,121] INFO: Computing for LV55
# [2022-11-15 22:28:00,363] INFO: Computing for LV56
# [2022-11-15 22:28:00,610] INFO: Computing for LV57
# [2022-11-15 22:28:00,865] INFO: Computing for LV58
# [2022-11-15 22:28:01,120] INFO: Computing for LV59
# [2022-11-15 22:28:01,360] INFO: Computing for LV60
# [2022-11-15 22:28:01,602] INFO: Computing for LV61
# [2022-11-15 22:28:01,817] INFO: Computing for LV62
# [2022-11-15 22:28:02,070] INFO: Computing for LV63
# [2022-11-15 22:28:02,306] INFO: Computing for LV64
# [2022-11-15 22:28:02,519] INFO: Computing for LV65
# [2022-11-15 22:28:02,736] INFO: Computing for LV66
# [2022-11-15 22:28:02,951] INFO: Computing for LV67
# [2022-11-15 22:28:03,180] INFO: Computing for LV68
# [2022-11-15 22:28:03,483] INFO: Computing for LV69
# [2022-11-15 22:28:03,728] INFO: Computing for LV70
# [2022-11-15 22:28:03,936] INFO: Computing for LV71
# [2022-11-15 22:28:04,175] INFO: Computing for LV72
# [2022-11-15 22:28:04,408] INFO: Computing for LV73
# [2022-11-15 22:28:04,634] INFO: Computing for LV74
# [2022-11-15 22:28:04,864] INFO: Computing for LV75
# [2022-11-15 22:28:05,101] INFO: Computing for LV76
# [2022-11-15 22:28:05,356] INFO: Computing for LV77
# [2022-11-15 22:28:05,583] INFO: Computing for LV78
# [2022-11-15 22:28:05,814] INFO: Computing for LV79
# [2022-11-15 22:28:06,030] INFO: Computing for LV80
# [2022-11-15 22:28:06,257] INFO: Computing for LV81
# [2022-11-15 22:28:06,485] INFO: Computing for LV82
# [2022-11-15 22:28:06,725] INFO: Computing for LV83
# [2022-11-15 22:28:06,947] INFO: Computing for LV84
# [2022-11-15 22:28:07,169] INFO: Computing for LV85
# [2022-11-15 22:28:07,404] INFO: Computing for LV86
# [2022-11-15 22:28:07,641] INFO: Computing for LV87
# [2022-11-15 22:28:07,907] INFO: Computing for LV88
# [2022-11-15 22:28:08,143] INFO: Computing for LV89
# [2022-11-15 22:28:08,366] INFO: Computing for LV90
# [2022-11-15 22:28:08,587] INFO: Computing for LV91
# [2022-11-15 22:28:08,832] INFO: Computing for LV92
# [2022-11-15 22:28:09,069] INFO: Computing for LV93
# [2022-11-15 22:28:09,363] INFO: Computing for LV94
# [2022-11-15 22:28:09,586] INFO: Computing for LV95
# [2022-11-15 22:28:09,824] INFO: Computing for LV96
# [2022-11-15 22:28:10,059] INFO: Computing for LV97
# [2022-11-15 22:28:10,282] INFO: Computing for LV98
# [2022-11-15 22:28:10,525] INFO: Computing for LV99
# [2022-11-15 22:28:10,763] INFO: Computing for LV100
# [2022-11-15 22:28:11,030] INFO: Computing for LV101
# [2022-11-15 22:28:11,268] INFO: Computing for LV102
# [2022-11-15 22:28:11,523] INFO: Computing for LV103
# [2022-11-15 22:28:11,745] INFO: Computing for LV104
# [2022-11-15 22:28:12,010] INFO: Computing for LV105
# [2022-11-15 22:28:12,230] INFO: Computing for LV106
# [2022-11-15 22:28:12,443] INFO: Computing for LV107
# [2022-11-15 22:28:12,675] INFO: Computing for LV108
# [2022-11-15 22:28:12,889] INFO: Computing for LV109
# [2022-11-15 22:28:13,095] INFO: Computing for LV110
# [2022-11-15 22:28:13,319] INFO: Computing for LV111
# [2022-11-15 22:28:13,530] INFO: Computing for LV112
# [2022-11-15 22:28:13,739] INFO: Computing for LV113
# [2022-11-15 22:28:13,975] INFO: Computing for LV114
# [2022-11-15 22:28:14,195] INFO: Computing for LV115
# [2022-11-15 22:28:14,458] INFO: Computing for LV116
# [2022-11-15 22:28:14,779] INFO: Computing for LV117
# [2022-11-15 22:28:15,115] INFO: Computing for LV118
# [2022-11-15 22:28:15,480] INFO: Computing for LV119
# [2022-11-15 22:28:15,887] INFO: Computing for LV120
# [2022-11-15 22:28:16,205] INFO: Computing for LV121
# [2022-11-15 22:28:16,502] INFO: Computing for LV122
# [2022-11-15 22:28:16,803] INFO: Computing for LV123
# [2022-11-15 22:28:17,070] INFO: Computing for LV124
# [2022-11-15 22:28:17,333] INFO: Computing for LV125
# [2022-11-15 22:28:17,542] INFO: Computing for LV126
# [2022-11-15 22:28:17,748] INFO: Computing for LV127
# [2022-11-15 22:28:17,964] INFO: Computing for LV128
# [2022-11-15 22:28:18,172] INFO: Computing for LV129
# [2022-11-15 22:28:18,374] INFO: Computing for LV130
# [2022-11-15 22:28:18,578] INFO: Computing for LV131
# [2022-11-15 22:28:18,781] INFO: Computing for LV132
# [2022-11-15 22:28:18,988] INFO: Computing for LV133
# [2022-11-15 22:28:19,192] INFO: Computing for LV134
# [2022-11-15 22:28:19,394] INFO: Computing for LV135
# [2022-11-15 22:28:19,596] INFO: Computing for LV136
# [2022-11-15 22:28:19,821] INFO: Computing for LV137
# [2022-11-15 22:28:20,036] INFO: Computing for LV138
# [2022-11-15 22:28:20,286] INFO: Computing for LV139
# [2022-11-15 22:28:20,505] INFO: Computing for LV140
# [2022-11-15 22:28:20,714] INFO: Computing for LV141
# [2022-11-15 22:28:21,055] INFO: Computing for LV142
# [2022-11-15 22:28:21,358] INFO: Computing for LV143
# [2022-11-15 22:28:21,571] INFO: Computing for LV144
# [2022-11-15 22:28:21,776] INFO: Computing for LV145
# [2022-11-15 22:28:21,988] INFO: Computing for LV146
# [2022-11-15 22:28:22,255] INFO: Computing for LV147
# [2022-11-15 22:28:22,598] INFO: Computing for LV148
# [2022-11-15 22:28:22,948] INFO: Computing for LV149
# [2022-11-15 22:28:23,267] INFO: Computing for LV150
# [2022-11-15 22:28:23,536] INFO: Computing for LV151
# [2022-11-15 22:28:23,835] INFO: Computing for LV152
# [2022-11-15 22:28:24,057] INFO: Computing for LV153
# [2022-11-15 22:28:24,292] INFO: Computing for LV154
# [2022-11-15 22:28:24,527] INFO: Computing for LV155
# [2022-11-15 22:28:24,802] INFO: Computing for LV156
# [2022-11-15 22:28:25,139] INFO: Computing for LV157
# [2022-11-15 22:28:25,390] INFO: Computing for LV158
# [2022-11-15 22:28:25,674] INFO: Computing for LV159
# [2022-11-15 22:28:25,936] INFO: Computing for LV160
# [2022-11-15 22:28:26,170] INFO: Computing for LV161
# [2022-11-15 22:28:26,380] INFO: Computing for LV162
# [2022-11-15 22:28:26,591] INFO: Computing for LV163
# [2022-11-15 22:28:26,798] INFO: Computing for LV164
# [2022-11-15 22:28:27,012] INFO: Computing for LV165
# [2022-11-15 22:28:27,225] INFO: Computing for LV166
# [2022-11-15 22:28:27,439] INFO: Computing for LV167
# [2022-11-15 22:28:27,645] INFO: Computing for LV168
# [2022-11-15 22:28:27,854] INFO: Computing for LV169
# [2022-11-15 22:28:28,066] INFO: Computing for LV170
# [2022-11-15 22:28:28,270] INFO: Computing for LV171
# [2022-11-15 22:28:28,476] INFO: Computing for LV172
# [2022-11-15 22:28:28,681] INFO: Computing for LV173
# [2022-11-15 22:28:28,897] INFO: Computing for LV174
# [2022-11-15 22:28:29,118] INFO: Computing for LV175
# [2022-11-15 22:28:29,333] INFO: Computing for LV176
# [2022-11-15 22:28:29,538] INFO: Computing for LV177
# [2022-11-15 22:28:29,743] INFO: Computing for LV178
# [2022-11-15 22:28:29,982] INFO: Computing for LV179
# [2022-11-15 22:28:30,223] INFO: Computing for LV180
# [2022-11-15 22:28:30,441] INFO: Computing for LV181
# [2022-11-15 22:28:30,646] INFO: Computing for LV182
# [2022-11-15 22:28:30,854] INFO: Computing for LV183
# [2022-11-15 22:28:31,069] INFO: Computing for LV184
# [2022-11-15 22:28:31,277] INFO: Computing for LV185
# [2022-11-15 22:28:31,484] INFO: Computing for LV186
# [2022-11-15 22:28:31,689] INFO: Computing for LV187
# [2022-11-15 22:28:31,906] INFO: Computing for LV188
# [2022-11-15 22:28:32,115] INFO: Computing for LV189
# [2022-11-15 22:28:32,321] INFO: Computing for LV190
# [2022-11-15 22:28:32,529] INFO: Computing for LV191
# [2022-11-15 22:28:32,733] INFO: Computing for LV192
# [2022-11-15 22:28:32,938] INFO: Computing for LV193
# [2022-11-15 22:28:33,147] INFO: Computing for LV194
# [2022-11-15 22:28:33,363] INFO: Computing for LV195
# [2022-11-15 22:28:33,587] INFO: Computing for LV196
# [2022-11-15 22:28:33,796] INFO: Computing for LV197
# [2022-11-15 22:28:34,010] INFO: Computing for LV198
# [2022-11-15 22:28:34,221] INFO: Computing for LV199
# [2022-11-15 22:28:34,437] INFO: Computing for LV200
# [2022-11-15 22:28:34,645] INFO: Computing for LV201
# [2022-11-15 22:28:34,857] INFO: Computing for LV202
# [2022-11-15 22:28:35,080] INFO: Computing for LV203
# [2022-11-15 22:28:35,288] INFO: Computing for LV204
# [2022-11-15 22:28:35,496] INFO: Computing for LV205
# [2022-11-15 22:28:35,710] INFO: Computing for LV206
# [2022-11-15 22:28:35,918] INFO: Computing for LV207
# [2022-11-15 22:28:36,139] INFO: Computing for LV208
# [2022-11-15 22:28:36,346] INFO: Computing for LV209
# [2022-11-15 22:28:36,554] INFO: Computing for LV210
# [2022-11-15 22:28:36,758] INFO: Computing for LV211
# [2022-11-15 22:28:36,971] INFO: Computing for LV212
# [2022-11-15 22:28:37,180] INFO: Computing for LV213
# [2022-11-15 22:28:37,385] INFO: Computing for LV214
# [2022-11-15 22:28:37,592] INFO: Computing for LV215
# [2022-11-15 22:28:37,802] INFO: Computing for LV216
# [2022-11-15 22:28:38,011] INFO: Computing for LV217
# [2022-11-15 22:28:38,219] INFO: Computing for LV218
# [2022-11-15 22:28:38,427] INFO: Computing for LV219
# [2022-11-15 22:28:38,636] INFO: Computing for LV220
# [2022-11-15 22:28:38,850] INFO: Computing for LV221
# [2022-11-15 22:28:39,068] INFO: Computing for LV222
# [2022-11-15 22:28:39,274] INFO: Computing for LV223
# [2022-11-15 22:28:39,480] INFO: Computing for LV224
# [2022-11-15 22:28:39,691] INFO: Computing for LV225
# [2022-11-15 22:28:39,916] INFO: Computing for LV226
# [2022-11-15 22:28:40,131] INFO: Computing for LV227
# [2022-11-15 22:28:40,337] INFO: Computing for LV228
# [2022-11-15 22:28:40,544] INFO: Computing for LV229
# [2022-11-15 22:28:40,773] INFO: Computing for LV230
# [2022-11-15 22:28:40,987] INFO: Computing for LV231
# [2022-11-15 22:28:41,196] INFO: Computing for LV232
# [2022-11-15 22:28:41,405] INFO: Computing for LV233
# [2022-11-15 22:28:41,615] INFO: Computing for LV234
# [2022-11-15 22:28:41,825] INFO: Computing for LV235
# [2022-11-15 22:28:42,038] INFO: Computing for LV236
# [2022-11-15 22:28:42,243] INFO: Computing for LV237
# [2022-11-15 22:28:42,451] INFO: Computing for LV238
# [2022-11-15 22:28:42,657] INFO: Computing for LV239
# [2022-11-15 22:28:42,891] INFO: Computing for LV240
# [2022-11-15 22:28:43,119] INFO: Computing for LV241
# [2022-11-15 22:28:43,359] INFO: Computing for LV242
# [2022-11-15 22:28:43,577] INFO: Computing for LV243
# [2022-11-15 22:28:43,800] INFO: Computing for LV244
# [2022-11-15 22:28:44,084] INFO: Computing for LV245
# [2022-11-15 22:28:44,350] INFO: Computing for LV246
# [2022-11-15 22:28:44,599] INFO: Computing for LV247
# [2022-11-15 22:28:44,834] INFO: Computing for LV248
# [2022-11-15 22:28:45,053] INFO: Computing for LV249
# [2022-11-15 22:28:45,263] INFO: Computing for LV250
# [2022-11-15 22:28:45,504] INFO: Computing for LV251
# [2022-11-15 22:28:45,746] INFO: Computing for LV252
# [2022-11-15 22:28:45,972] INFO: Computing for LV253
# [2022-11-15 22:28:46,225] INFO: Computing for LV254
# [2022-11-15 22:28:46,573] INFO: Computing for LV255
# [2022-11-15 22:28:46,865] INFO: Computing for LV256
# [2022-11-15 22:28:47,092] INFO: Computing for LV257
# [2022-11-15 22:28:47,309] INFO: Computing for LV258
# [2022-11-15 22:28:47,532] INFO: Computing for LV259
# [2022-11-15 22:28:47,753] INFO: Computing for LV260
# [2022-11-15 22:28:47,998] INFO: Computing for LV261
# [2022-11-15 22:28:48,241] INFO: Computing for LV262
# [2022-11-15 22:28:48,461] INFO: Computing for LV263
# [2022-11-15 22:28:48,687] INFO: Computing for LV264
# [2022-11-15 22:28:48,941] INFO: Computing for LV265
# [2022-11-15 22:28:49,163] INFO: Computing for LV266
# [2022-11-15 22:28:49,384] INFO: Computing for LV267
# [2022-11-15 22:28:49,619] INFO: Computing for LV268
# [2022-11-15 22:28:49,851] INFO: Computing for LV269
# [2022-11-15 22:28:50,081] INFO: Computing for LV270
# [2022-11-15 22:28:50,304] INFO: Computing for LV271
# [2022-11-15 22:28:50,516] INFO: Computing for LV272
# [2022-11-15 22:28:50,745] INFO: Computing for LV273
# [2022-11-15 22:28:50,957] INFO: Computing for LV274
# [2022-11-15 22:28:51,172] INFO: Computing for LV275
# [2022-11-15 22:28:51,391] INFO: Computing for LV276
# [2022-11-15 22:28:51,602] INFO: Computing for LV277
# [2022-11-15 22:28:51,814] INFO: Computing for LV278
# [2022-11-15 22:28:52,026] INFO: Computing for LV279
# [2022-11-15 22:28:52,235] INFO: Computing for LV280
# [2022-11-15 22:28:52,447] INFO: Computing for LV281
# [2022-11-15 22:28:52,671] INFO: Computing for LV282
# [2022-11-15 22:28:52,912] INFO: Computing for LV283
# [2022-11-15 22:28:53,138] INFO: Computing for LV284
# [2022-11-15 22:28:53,368] INFO: Computing for LV285
# [2022-11-15 22:28:53,595] INFO: Computing for LV286
# [2022-11-15 22:28:53,859] INFO: Computing for LV287
# [2022-11-15 22:28:54,101] INFO: Computing for LV288
# [2022-11-15 22:28:54,317] INFO: Computing for LV289
# [2022-11-15 22:28:54,526] INFO: Computing for LV290
# [2022-11-15 22:28:54,736] INFO: Computing for LV291
# [2022-11-15 22:28:54,994] INFO: Computing for LV292
# [2022-11-15 22:28:55,237] INFO: Computing for LV293
# [2022-11-15 22:28:55,446] INFO: Computing for LV294
# [2022-11-15 22:28:55,657] INFO: Computing for LV295
# [2022-11-15 22:28:55,888] INFO: Computing for LV296
# [2022-11-15 22:28:56,191] INFO: Computing for LV297
# [2022-11-15 22:28:56,465] INFO: Computing for LV298
# [2022-11-15 22:28:56,741] INFO: Computing for LV299
# [2022-11-15 22:28:56,986] INFO: Computing for LV300
# [2022-11-15 22:28:57,323] INFO: Computing for LV301
# [2022-11-15 22:28:57,635] INFO: Computing for LV302
# [2022-11-15 22:28:57,924] INFO: Computing for LV303
# [2022-11-15 22:28:58,208] INFO: Computing for LV304
# [2022-11-15 22:28:58,427] INFO: Computing for LV305
# [2022-11-15 22:28:58,723] INFO: Computing for LV306
# [2022-11-15 22:28:58,959] INFO: Computing for LV307
# [2022-11-15 22:28:59,172] INFO: Computing for LV308
# [2022-11-15 22:28:59,386] INFO: Computing for LV309
# [2022-11-15 22:28:59,596] INFO: Computing for LV310
# [2022-11-15 22:28:59,811] INFO: Computing for LV311
# [2022-11-15 22:29:00,025] INFO: Computing for LV312
# [2022-11-15 22:29:00,246] INFO: Computing for LV313
# [2022-11-15 22:29:00,483] INFO: Computing for LV314
# [2022-11-15 22:29:00,726] INFO: Computing for LV315
# [2022-11-15 22:29:00,946] INFO: Computing for LV316
# [2022-11-15 22:29:01,209] INFO: Computing for LV317
# [2022-11-15 22:29:01,465] INFO: Computing for LV318
# [2022-11-15 22:29:01,693] INFO: Computing for LV319
# [2022-11-15 22:29:01,908] INFO: Computing for LV320
# [2022-11-15 22:29:02,131] INFO: Computing for LV321
# [2022-11-15 22:29:02,372] INFO: Computing for LV322
# [2022-11-15 22:29:02,591] INFO: Computing for LV323
# [2022-11-15 22:29:02,813] INFO: Computing for LV324
# [2022-11-15 22:29:03,036] INFO: Computing for LV325
# [2022-11-15 22:29:03,252] INFO: Computing for LV326
# [2022-11-15 22:29:03,470] INFO: Computing for LV327
# [2022-11-15 22:29:03,681] INFO: Computing for LV328
# [2022-11-15 22:29:03,903] INFO: Computing for LV329
# [2022-11-15 22:29:04,126] INFO: Computing for LV330
# [2022-11-15 22:29:04,350] INFO: Computing for LV331
# [2022-11-15 22:29:04,576] INFO: Computing for LV332
# [2022-11-15 22:29:04,800] INFO: Computing for LV333
# [2022-11-15 22:29:05,026] INFO: Computing for LV334
# [2022-11-15 22:29:05,249] INFO: Computing for LV335
# [2022-11-15 22:29:05,478] INFO: Computing for LV336
# [2022-11-15 22:29:05,708] INFO: Computing for LV337
# [2022-11-15 22:29:05,941] INFO: Computing for LV338
# [2022-11-15 22:29:06,164] INFO: Computing for LV339
# [2022-11-15 22:29:06,384] INFO: Computing for LV340
# [2022-11-15 22:29:06,609] INFO: Computing for LV341
# [2022-11-15 22:29:06,838] INFO: Computing for LV342
# [2022-11-15 22:29:07,063] INFO: Computing for LV343
# [2022-11-15 22:29:07,287] INFO: Computing for LV344
# [2022-11-15 22:29:07,517] INFO: Computing for LV345
# [2022-11-15 22:29:07,771] INFO: Computing for LV346
# [2022-11-15 22:29:08,010] INFO: Computing for LV347
# [2022-11-15 22:29:08,247] INFO: Computing for LV348
# [2022-11-15 22:29:08,492] INFO: Computing for LV349
# [2022-11-15 22:29:08,708] INFO: Computing for LV350
# [2022-11-15 22:29:08,918] INFO: Computing for LV351
# [2022-11-15 22:29:09,132] INFO: Computing for LV352
# [2022-11-15 22:29:09,343] INFO: Computing for LV353
# [2022-11-15 22:29:09,552] INFO: Computing for LV354
# [2022-11-15 22:29:09,837] INFO: Computing for LV355
# [2022-11-15 22:29:10,119] INFO: Computing for LV356
# [2022-11-15 22:29:10,378] INFO: Computing for LV357
# [2022-11-15 22:29:10,609] INFO: Computing for LV358
# [2022-11-15 22:29:10,869] INFO: Computing for LV359
# [2022-11-15 22:29:11,089] INFO: Computing for LV360
# [2022-11-15 22:29:11,311] INFO: Computing for LV361
# [2022-11-15 22:29:11,530] INFO: Computing for LV362
# [2022-11-15 22:29:11,751] INFO: Computing for LV363
# [2022-11-15 22:29:11,971] INFO: Computing for LV364
# [2022-11-15 22:29:12,191] INFO: Computing for LV365
# [2022-11-15 22:29:12,445] INFO: Computing for LV366
# [2022-11-15 22:29:12,665] INFO: Computing for LV367
# [2022-11-15 22:29:12,891] INFO: Computing for LV368
# [2022-11-15 22:29:13,117] INFO: Computing for LV369
# [2022-11-15 22:29:13,339] INFO: Computing for LV370
# [2022-11-15 22:29:13,561] INFO: Computing for LV371
# [2022-11-15 22:29:13,779] INFO: Computing for LV372
# [2022-11-15 22:29:14,059] INFO: Computing for LV373
# [2022-11-15 22:29:14,279] INFO: Computing for LV374
# [2022-11-15 22:29:14,499] INFO: Computing for LV375
# [2022-11-15 22:29:14,775] INFO: Computing for LV376
# [2022-11-15 22:29:15,009] INFO: Computing for LV377
# [2022-11-15 22:29:15,241] INFO: Computing for LV378
# [2022-11-15 22:29:15,469] INFO: Computing for LV379
# [2022-11-15 22:29:15,690] INFO: Computing for LV380
# [2022-11-15 22:29:15,910] INFO: Computing for LV381
# [2022-11-15 22:29:16,128] INFO: Computing for LV382
# [2022-11-15 22:29:16,362] INFO: Computing for LV383
# [2022-11-15 22:29:16,633] INFO: Computing for LV384
# [2022-11-15 22:29:16,852] INFO: Computing for LV385
# [2022-11-15 22:29:17,071] INFO: Computing for LV386
# [2022-11-15 22:29:17,283] INFO: Computing for LV387
# [2022-11-15 22:29:17,579] INFO: Computing for LV388
# [2022-11-15 22:29:17,798] INFO: Computing for LV389
# [2022-11-15 22:29:18,095] INFO: Computing for LV390
# [2022-11-15 22:29:18,350] INFO: Computing for LV391
# [2022-11-15 22:29:18,605] INFO: Computing for LV392
# [2022-11-15 22:29:18,881] INFO: Computing for LV393
# [2022-11-15 22:29:19,125] INFO: Computing for LV394
# [2022-11-15 22:29:19,353] INFO: Computing for LV395
# [2022-11-15 22:29:19,566] INFO: Computing for LV396
# [2022-11-15 22:29:19,804] INFO: Computing for LV397
# [2022-11-15 22:29:20,048] INFO: Computing for LV398
# [2022-11-15 22:29:20,269] INFO: Computing for LV399
# [2022-11-15 22:29:20,513] INFO: Computing for LV400
# [2022-11-15 22:29:20,739] INFO: Computing for LV401
# [2022-11-15 22:29:21,087] INFO: Computing for LV402
# [2022-11-15 22:29:21,379] INFO: Computing for LV403
# [2022-11-15 22:29:21,592] INFO: Computing for LV404
# [2022-11-15 22:29:21,836] INFO: Computing for LV405
# [2022-11-15 22:29:22,080] INFO: Computing for LV406
# [2022-11-15 22:29:22,309] INFO: Computing for LV407
# [2022-11-15 22:29:22,524] INFO: Computing for LV408
# [2022-11-15 22:29:22,742] INFO: Computing for LV409
# [2022-11-15 22:29:22,967] INFO: Computing for LV410
# [2022-11-15 22:29:23,189] INFO: Computing for LV411
# [2022-11-15 22:29:23,414] INFO: Computing for LV412
# [2022-11-15 22:29:23,645] INFO: Computing for LV413
# [2022-11-15 22:29:23,901] INFO: Computing for LV414
# [2022-11-15 22:29:24,122] INFO: Computing for LV415
# [2022-11-15 22:29:24,335] INFO: Computing for LV416
# [2022-11-15 22:29:24,549] INFO: Computing for LV417
# [2022-11-15 22:29:24,769] INFO: Computing for LV418
# [2022-11-15 22:29:24,980] INFO: Computing for LV419
# [2022-11-15 22:29:25,218] INFO: Computing for LV420
# [2022-11-15 22:29:25,436] INFO: Computing for LV421
# [2022-11-15 22:29:25,653] INFO: Computing for LV422
# [2022-11-15 22:29:25,862] INFO: Computing for LV423
# [2022-11-15 22:29:26,118] INFO: Computing for LV424
# [2022-11-15 22:29:26,402] INFO: Computing for LV425
# [2022-11-15 22:29:26,631] INFO: Computing for LV426
# [2022-11-15 22:29:26,873] INFO: Computing for LV427
# [2022-11-15 22:29:27,098] INFO: Computing for LV428
# [2022-11-15 22:29:27,312] INFO: Computing for LV429
# [2022-11-15 22:29:27,523] INFO: Computing for LV430
# [2022-11-15 22:29:27,741] INFO: Computing for LV431
# [2022-11-15 22:29:27,948] INFO: Computing for LV432
# [2022-11-15 22:29:28,199] INFO: Computing for LV433
# [2022-11-15 22:29:28,427] INFO: Computing for LV434
# [2022-11-15 22:29:28,642] INFO: Computing for LV435
# [2022-11-15 22:29:28,901] INFO: Computing for LV436
# [2022-11-15 22:29:29,117] INFO: Computing for LV437
# [2022-11-15 22:29:29,333] INFO: Computing for LV438
# [2022-11-15 22:29:29,544] INFO: Computing for LV439
# [2022-11-15 22:29:29,758] INFO: Computing for LV440
# [2022-11-15 22:29:29,971] INFO: Computing for LV441
# [2022-11-15 22:29:30,211] INFO: Computing for LV442
# [2022-11-15 22:29:30,479] INFO: Computing for LV443
# [2022-11-15 22:29:30,695] INFO: Computing for LV444
# [2022-11-15 22:29:30,910] INFO: Computing for LV445
# [2022-11-15 22:29:31,120] INFO: Computing for LV446
# [2022-11-15 22:29:31,332] INFO: Computing for LV447
# [2022-11-15 22:29:31,545] INFO: Computing for LV448
# [2022-11-15 22:29:31,755] INFO: Computing for LV449
# [2022-11-15 22:29:31,971] INFO: Computing for LV450
# [2022-11-15 22:29:32,182] INFO: Computing for LV451
# [2022-11-15 22:29:32,390] INFO: Computing for LV452
# [2022-11-15 22:29:32,601] INFO: Computing for LV453
# [2022-11-15 22:29:32,862] INFO: Computing for LV454
# [2022-11-15 22:29:33,112] INFO: Computing for LV455
# [2022-11-15 22:29:33,337] INFO: Computing for LV456
# [2022-11-15 22:29:33,566] INFO: Computing for LV457
# [2022-11-15 22:29:33,774] INFO: Computing for LV458
# [2022-11-15 22:29:34,094] INFO: Computing for LV459
# [2022-11-15 22:29:34,440] INFO: Computing for LV460
# [2022-11-15 22:29:34,729] INFO: Computing for LV461
# [2022-11-15 22:29:35,039] INFO: Computing for LV462
# [2022-11-15 22:29:35,373] INFO: Computing for LV463
# [2022-11-15 22:29:35,626] INFO: Computing for LV464
# [2022-11-15 22:29:35,851] INFO: Computing for LV465
# [2022-11-15 22:29:36,187] INFO: Computing for LV466
# [2022-11-15 22:29:36,463] INFO: Computing for LV467
# [2022-11-15 22:29:36,763] INFO: Computing for LV468
# [2022-11-15 22:29:37,103] INFO: Computing for LV469
# [2022-11-15 22:29:37,360] INFO: Computing for LV470
# [2022-11-15 22:29:37,656] INFO: Computing for LV471
# [2022-11-15 22:29:37,953] INFO: Computing for LV472
# [2022-11-15 22:29:38,239] INFO: Computing for LV473
# [2022-11-15 22:29:38,542] INFO: Computing for LV474
# [2022-11-15 22:29:38,842] INFO: Computing for LV475
# [2022-11-15 22:29:39,126] INFO: Computing for LV476
# [2022-11-15 22:29:39,382] INFO: Computing for LV477
# [2022-11-15 22:29:39,632] INFO: Computing for LV478
# [2022-11-15 22:29:39,894] INFO: Computing for LV479
# [2022-11-15 22:29:40,136] INFO: Computing for LV480
# [2022-11-15 22:29:40,360] INFO: Computing for LV481
# [2022-11-15 22:29:40,606] INFO: Computing for LV482
# [2022-11-15 22:29:40,868] INFO: Computing for LV483
# [2022-11-15 22:29:41,090] INFO: Computing for LV484
# [2022-11-15 22:29:41,303] INFO: Computing for LV485
# [2022-11-15 22:29:41,540] INFO: Computing for LV486
# [2022-11-15 22:29:41,844] INFO: Computing for LV487
# [2022-11-15 22:29:42,099] INFO: Computing for LV488
# [2022-11-15 22:29:42,353] INFO: Computing for LV489
# [2022-11-15 22:29:42,645] INFO: Computing for LV490
# [2022-11-15 22:29:42,954] INFO: Computing for LV491
# [2022-11-15 22:29:43,189] INFO: Computing for LV492
# [2022-11-15 22:29:43,393] INFO: Computing for LV493
# [2022-11-15 22:29:43,674] INFO: Computing for LV494
# [2022-11-15 22:29:43,965] INFO: Computing for LV495
# [2022-11-15 22:29:44,294] INFO: Computing for LV496
# [2022-11-15 22:29:44,527] INFO: Computing for LV497
# [2022-11-15 22:29:44,765] INFO: Computing for LV498
# [2022-11-15 22:29:44,982] INFO: Computing for LV499
# [2022-11-15 22:29:45,211] INFO: Computing for LV500
# [2022-11-15 22:29:45,435] INFO: Computing for LV501
# [2022-11-15 22:29:45,649] INFO: Computing for LV502
# [2022-11-15 22:29:45,859] INFO: Computing for LV503
# [2022-11-15 22:29:46,075] INFO: Computing for LV504
# [2022-11-15 22:29:46,292] INFO: Computing for LV505
# [2022-11-15 22:29:46,511] INFO: Computing for LV506
# [2022-11-15 22:29:46,724] INFO: Computing for LV507
# [2022-11-15 22:29:46,937] INFO: Computing for LV508
# [2022-11-15 22:29:47,150] INFO: Computing for LV509
# [2022-11-15 22:29:47,363] INFO: Computing for LV510
# [2022-11-15 22:29:47,579] INFO: Computing for LV511
# [2022-11-15 22:29:47,792] INFO: Computing for LV512
# [2022-11-15 22:29:48,003] INFO: Computing for LV513
# [2022-11-15 22:29:48,211] INFO: Computing for LV514
# [2022-11-15 22:29:48,431] INFO: Computing for LV515
# [2022-11-15 22:29:48,640] INFO: Computing for LV516
# [2022-11-15 22:29:48,866] INFO: Computing for LV517
# [2022-11-15 22:29:49,090] INFO: Computing for LV518
# [2022-11-15 22:29:49,328] INFO: Computing for LV519
# [2022-11-15 22:29:49,544] INFO: Computing for LV520
# [2022-11-15 22:29:49,776] INFO: Computing for LV521
# [2022-11-15 22:29:50,007] INFO: Computing for LV522
# [2022-11-15 22:29:50,218] INFO: Computing for LV523
# [2022-11-15 22:29:50,427] INFO: Computing for LV524
# [2022-11-15 22:29:50,645] INFO: Computing for LV525
# [2022-11-15 22:29:50,857] INFO: Computing for LV526
# [2022-11-15 22:29:51,068] INFO: Computing for LV527
# [2022-11-15 22:29:51,277] INFO: Computing for LV528
# [2022-11-15 22:29:51,489] INFO: Computing for LV529
# [2022-11-15 22:29:51,701] INFO: Computing for LV530
# [2022-11-15 22:29:51,909] INFO: Computing for LV531
# [2022-11-15 22:29:52,116] INFO: Computing for LV532
# [2022-11-15 22:29:52,325] INFO: Computing for LV533
# [2022-11-15 22:29:52,536] INFO: Computing for LV534
# [2022-11-15 22:29:52,744] INFO: Computing for LV535
# [2022-11-15 22:29:52,967] INFO: Computing for LV536
# [2022-11-15 22:29:53,196] INFO: Computing for LV537
# [2022-11-15 22:29:53,427] INFO: Computing for LV538
# [2022-11-15 22:29:53,646] INFO: Computing for LV539
# [2022-11-15 22:29:53,860] INFO: Computing for LV540
# [2022-11-15 22:29:54,115] INFO: Computing for LV541
# [2022-11-15 22:29:54,374] INFO: Computing for LV542
# [2022-11-15 22:29:54,610] INFO: Computing for LV543
# [2022-11-15 22:29:54,838] INFO: Computing for LV544
# [2022-11-15 22:29:55,049] INFO: Computing for LV545
# [2022-11-15 22:29:55,283] INFO: Computing for LV546
# [2022-11-15 22:29:55,512] INFO: Computing for LV547
# [2022-11-15 22:29:55,725] INFO: Computing for LV548
# [2022-11-15 22:29:55,944] INFO: Computing for LV549
# [2022-11-15 22:29:56,158] INFO: Computing for LV550
# [2022-11-15 22:29:56,386] INFO: Computing for LV551
# [2022-11-15 22:29:56,616] INFO: Computing for LV552
# [2022-11-15 22:29:56,844] INFO: Computing for LV553
# [2022-11-15 22:29:57,059] INFO: Computing for LV554
# [2022-11-15 22:29:57,292] INFO: Computing for LV555
# [2022-11-15 22:29:57,519] INFO: Computing for LV556
# [2022-11-15 22:29:57,730] INFO: Computing for LV557
# [2022-11-15 22:29:57,943] INFO: Computing for LV558
# [2022-11-15 22:29:58,161] INFO: Computing for LV559
# [2022-11-15 22:29:58,372] INFO: Computing for LV560
# [2022-11-15 22:29:58,587] INFO: Computing for LV561
# [2022-11-15 22:29:58,811] INFO: Computing for LV562
# [2022-11-15 22:29:59,035] INFO: Computing for LV563
# [2022-11-15 22:29:59,244] INFO: Computing for LV564
# [2022-11-15 22:29:59,512] INFO: Computing for LV565
# [2022-11-15 22:29:59,721] INFO: Computing for LV566
# [2022-11-15 22:29:59,931] INFO: Computing for LV567
# [2022-11-15 22:30:00,151] INFO: Computing for LV568
# [2022-11-15 22:30:00,367] INFO: Computing for LV569
# [2022-11-15 22:30:00,642] INFO: Computing for LV570
# [2022-11-15 22:30:00,861] INFO: Computing for LV571
# [2022-11-15 22:30:01,078] INFO: Computing for LV572
# [2022-11-15 22:30:01,317] INFO: Computing for LV573
# [2022-11-15 22:30:01,557] INFO: Computing for LV574
# [2022-11-15 22:30:01,770] INFO: Computing for LV575
# [2022-11-15 22:30:01,984] INFO: Computing for LV576
# [2022-11-15 22:30:02,196] INFO: Computing for LV577
# [2022-11-15 22:30:02,460] INFO: Computing for LV578
# [2022-11-15 22:30:02,673] INFO: Computing for LV579
# [2022-11-15 22:30:02,883] INFO: Computing for LV580
# [2022-11-15 22:30:03,094] INFO: Computing for LV581
# [2022-11-15 22:30:03,304] INFO: Computing for LV582
# [2022-11-15 22:30:03,517] INFO: Computing for LV583
# [2022-11-15 22:30:03,776] INFO: Computing for LV584
# [2022-11-15 22:30:04,066] INFO: Computing for LV585
# [2022-11-15 22:30:04,293] INFO: Computing for LV586
# [2022-11-15 22:30:04,508] INFO: Computing for LV587
# [2022-11-15 22:30:04,735] INFO: Computing for LV588
# [2022-11-15 22:30:04,958] INFO: Computing for LV589
# [2022-11-15 22:30:05,208] INFO: Computing for LV590
# [2022-11-15 22:30:05,440] INFO: Computing for LV591
# [2022-11-15 22:30:05,696] INFO: Computing for LV592
# [2022-11-15 22:30:05,913] INFO: Computing for LV593
# [2022-11-15 22:30:06,135] INFO: Computing for LV594
# [2022-11-15 22:30:06,350] INFO: Computing for LV595
# [2022-11-15 22:30:06,566] INFO: Computing for LV596
# [2022-11-15 22:30:06,793] INFO: Computing for LV597
# [2022-11-15 22:30:07,014] INFO: Computing for LV598
# [2022-11-15 22:30:07,227] INFO: Computing for LV599
# [2022-11-15 22:30:07,440] INFO: Computing for LV600
# [2022-11-15 22:30:07,653] INFO: Computing for LV601
# [2022-11-15 22:30:07,861] INFO: Computing for LV602
# [2022-11-15 22:30:08,078] INFO: Computing for LV603
# [2022-11-15 22:30:08,288] INFO: Computing for LV604
# [2022-11-15 22:30:08,537] INFO: Computing for LV605
# [2022-11-15 22:30:08,788] INFO: Computing for LV606
# [2022-11-15 22:30:08,996] INFO: Computing for LV607
# [2022-11-15 22:30:09,207] INFO: Computing for LV608
# [2022-11-15 22:30:09,418] INFO: Computing for LV609
# [2022-11-15 22:30:09,629] INFO: Computing for LV610
# [2022-11-15 22:30:09,958] INFO: Computing for LV611
# [2022-11-15 22:30:10,263] INFO: Computing for LV612
# [2022-11-15 22:30:10,486] INFO: Computing for LV613
# [2022-11-15 22:30:10,701] INFO: Computing for LV614
# [2022-11-15 22:30:10,945] INFO: Computing for LV615
# [2022-11-15 22:30:11,186] INFO: Computing for LV616
# [2022-11-15 22:30:11,397] INFO: Computing for LV617
# [2022-11-15 22:30:11,602] INFO: Computing for LV618
# [2022-11-15 22:30:11,813] INFO: Computing for LV619
# [2022-11-15 22:30:12,023] INFO: Computing for LV620
# [2022-11-15 22:30:12,256] INFO: Computing for LV621
# [2022-11-15 22:30:12,471] INFO: Computing for LV622
# [2022-11-15 22:30:12,692] INFO: Computing for LV623
# [2022-11-15 22:30:12,901] INFO: Computing for LV624
# [2022-11-15 22:30:13,113] INFO: Computing for LV625
# [2022-11-15 22:30:13,327] INFO: Computing for LV626
# [2022-11-15 22:30:13,542] INFO: Computing for LV627
# [2022-11-15 22:30:13,757] INFO: Computing for LV628
# [2022-11-15 22:30:13,968] INFO: Computing for LV629
# [2022-11-15 22:30:14,186] INFO: Computing for LV630
# [2022-11-15 22:30:14,422] INFO: Computing for LV631
# [2022-11-15 22:30:14,627] INFO: Computing for LV632
# [2022-11-15 22:30:14,837] INFO: Computing for LV633
# [2022-11-15 22:30:15,049] INFO: Computing for LV634
# [2022-11-15 22:30:15,264] INFO: Computing for LV635
# [2022-11-15 22:30:15,477] INFO: Computing for LV636
# [2022-11-15 22:30:15,686] INFO: Computing for LV637
# [2022-11-15 22:30:15,892] INFO: Computing for LV638
# [2022-11-15 22:30:16,106] INFO: Computing for LV639
# [2022-11-15 22:30:16,318] INFO: Computing for LV640
# [2022-11-15 22:30:16,537] INFO: Computing for LV641
# [2022-11-15 22:30:16,763] INFO: Computing for LV642
# [2022-11-15 22:30:16,979] INFO: Computing for LV643
# [2022-11-15 22:30:17,192] INFO: Computing for LV644
# [2022-11-15 22:30:17,401] INFO: Computing for LV645
# [2022-11-15 22:30:17,616] INFO: Computing for LV646
# [2022-11-15 22:30:17,830] INFO: Computing for LV647
# [2022-11-15 22:30:18,045] INFO: Computing for LV648
# [2022-11-15 22:30:18,254] INFO: Computing for LV649
# [2022-11-15 22:30:18,472] INFO: Computing for LV650
# [2022-11-15 22:30:18,681] INFO: Computing for LV651
# [2022-11-15 22:30:18,902] INFO: Computing for LV652
# [2022-11-15 22:30:19,138] INFO: Computing for LV653
# [2022-11-15 22:30:19,421] INFO: Computing for LV654
# [2022-11-15 22:30:19,631] INFO: Computing for LV655
# [2022-11-15 22:30:19,870] INFO: Computing for LV656
# [2022-11-15 22:30:20,086] INFO: Computing for LV657
# [2022-11-15 22:30:20,292] INFO: Computing for LV658
# [2022-11-15 22:30:20,495] INFO: Computing for LV659
# [2022-11-15 22:30:20,700] INFO: Computing for LV660
# [2022-11-15 22:30:21,002] INFO: Computing for LV661
# [2022-11-15 22:30:21,332] INFO: Computing for LV662
# [2022-11-15 22:30:21,658] INFO: Computing for LV663
# [2022-11-15 22:30:21,901] INFO: Computing for LV664
# [2022-11-15 22:30:22,140] INFO: Computing for LV665
# [2022-11-15 22:30:22,354] INFO: Computing for LV666
# [2022-11-15 22:30:22,570] INFO: Computing for LV667
# [2022-11-15 22:30:22,811] INFO: Computing for LV668
# [2022-11-15 22:30:23,068] INFO: Computing for LV669
# [2022-11-15 22:30:23,400] INFO: Computing for LV670
# [2022-11-15 22:30:23,625] INFO: Computing for LV671
# [2022-11-15 22:30:23,911] INFO: Computing for LV672
# [2022-11-15 22:30:24,155] INFO: Computing for LV673
# [2022-11-15 22:30:24,381] INFO: Computing for LV674
# [2022-11-15 22:30:24,618] INFO: Computing for LV675
# [2022-11-15 22:30:24,934] INFO: Computing for LV676
# [2022-11-15 22:30:25,148] INFO: Computing for LV677
# [2022-11-15 22:30:25,357] INFO: Computing for LV678
# [2022-11-15 22:30:25,580] INFO: Computing for LV679
# [2022-11-15 22:30:25,803] INFO: Computing for LV680
# [2022-11-15 22:30:26,010] INFO: Computing for LV681
# [2022-11-15 22:30:26,216] INFO: Computing for LV682
# [2022-11-15 22:30:26,455] INFO: Computing for LV683
# [2022-11-15 22:30:26,742] INFO: Computing for LV684
# [2022-11-15 22:30:26,974] INFO: Computing for LV685
# [2022-11-15 22:30:27,185] INFO: Computing for LV686
# [2022-11-15 22:30:27,406] INFO: Computing for LV687
# [2022-11-15 22:30:27,623] INFO: Computing for LV688
# [2022-11-15 22:30:27,849] INFO: Computing for LV689
# [2022-11-15 22:30:28,071] INFO: Computing for LV690
# [2022-11-15 22:30:28,311] INFO: Computing for LV691
# [2022-11-15 22:30:28,588] INFO: Computing for LV692
# [2022-11-15 22:30:28,848] INFO: Computing for LV693
# [2022-11-15 22:30:29,059] INFO: Computing for LV694
# [2022-11-15 22:30:29,290] INFO: Computing for LV695
# [2022-11-15 22:30:29,502] INFO: Computing for LV696
# [2022-11-15 22:30:29,713] INFO: Computing for LV697
# [2022-11-15 22:30:29,928] INFO: Computing for LV698
# [2022-11-15 22:30:30,152] INFO: Computing for LV699
# [2022-11-15 22:30:30,363] INFO: Computing for LV700
# [2022-11-15 22:30:30,576] INFO: Computing for LV701
# [2022-11-15 22:30:30,783] INFO: Computing for LV702
# [2022-11-15 22:30:31,021] INFO: Computing for LV703
# [2022-11-15 22:30:31,239] INFO: Computing for LV704
# [2022-11-15 22:30:31,488] INFO: Computing for LV705
# [2022-11-15 22:30:31,709] INFO: Computing for LV706
# [2022-11-15 22:30:31,929] INFO: Computing for LV707
# [2022-11-15 22:30:32,146] INFO: Computing for LV708
# [2022-11-15 22:30:32,361] INFO: Computing for LV709
# [2022-11-15 22:30:32,594] INFO: Computing for LV710
# [2022-11-15 22:30:32,831] INFO: Computing for LV711
# [2022-11-15 22:30:33,106] INFO: Computing for LV712
# [2022-11-15 22:30:33,413] INFO: Computing for LV713
# [2022-11-15 22:30:33,694] INFO: Computing for LV714
# [2022-11-15 22:30:33,929] INFO: Computing for LV715
# [2022-11-15 22:30:34,181] INFO: Computing for LV716
# [2022-11-15 22:30:34,541] INFO: Computing for LV717
# [2022-11-15 22:30:34,808] INFO: Computing for LV718
# [2022-11-15 22:30:35,101] INFO: Computing for LV719
# [2022-11-15 22:30:35,358] INFO: Computing for LV720
# [2022-11-15 22:30:35,646] INFO: Computing for LV721
# [2022-11-15 22:30:35,975] INFO: Computing for LV722
# [2022-11-15 22:30:36,201] INFO: Computing for LV723
# [2022-11-15 22:30:36,412] INFO: Computing for LV724
# [2022-11-15 22:30:36,626] INFO: Computing for LV725
# [2022-11-15 22:30:36,855] INFO: Computing for LV726
# [2022-11-15 22:30:37,065] INFO: Computing for LV727
# [2022-11-15 22:30:37,269] INFO: Computing for LV728
# [2022-11-15 22:30:37,480] INFO: Computing for LV729
# [2022-11-15 22:30:37,714] INFO: Computing for LV730
# [2022-11-15 22:30:37,936] INFO: Computing for LV731
# [2022-11-15 22:30:38,180] INFO: Computing for LV732
# [2022-11-15 22:30:38,409] INFO: Computing for LV733
# [2022-11-15 22:30:38,640] INFO: Computing for LV734
# [2022-11-15 22:30:38,849] INFO: Computing for LV735
# [2022-11-15 22:30:39,087] INFO: Computing for LV736
# [2022-11-15 22:30:39,296] INFO: Computing for LV737
# [2022-11-15 22:30:39,528] INFO: Computing for LV738
# [2022-11-15 22:30:39,741] INFO: Computing for LV739
# [2022-11-15 22:30:39,954] INFO: Computing for LV740
# [2022-11-15 22:30:40,162] INFO: Computing for LV741
# [2022-11-15 22:30:40,374] INFO: Computing for LV742
# [2022-11-15 22:30:40,585] INFO: Computing for LV743
# [2022-11-15 22:30:40,803] INFO: Computing for LV744
# [2022-11-15 22:30:41,019] INFO: Computing for LV745
# [2022-11-15 22:30:41,229] INFO: Computing for LV746
# [2022-11-15 22:30:41,441] INFO: Computing for LV747
# [2022-11-15 22:30:41,662] INFO: Computing for LV748
# [2022-11-15 22:30:41,864] INFO: Computing for LV749
# [2022-11-15 22:30:42,068] INFO: Computing for LV750
# [2022-11-15 22:30:42,295] INFO: Computing for LV751
# [2022-11-15 22:30:42,542] INFO: Computing for LV752
# [2022-11-15 22:30:42,787] INFO: Computing for LV753
# [2022-11-15 22:30:43,038] INFO: Computing for LV754
# [2022-11-15 22:30:43,252] INFO: Computing for LV755
# [2022-11-15 22:30:43,521] INFO: Computing for LV756
# [2022-11-15 22:30:43,820] INFO: Computing for LV757
# [2022-11-15 22:30:44,030] INFO: Computing for LV758
# [2022-11-15 22:30:44,258] INFO: Computing for LV759
# [2022-11-15 22:30:44,470] INFO: Computing for LV760
# [2022-11-15 22:30:44,681] INFO: Computing for LV761
# [2022-11-15 22:30:44,894] INFO: Computing for LV762
# [2022-11-15 22:30:45,136] INFO: Computing for LV763
# [2022-11-15 22:30:45,370] INFO: Computing for LV764
# [2022-11-15 22:30:45,592] INFO: Computing for LV765
# [2022-11-15 22:30:45,806] INFO: Computing for LV766
# [2022-11-15 22:30:46,024] INFO: Computing for LV767
# [2022-11-15 22:30:46,276] INFO: Computing for LV768
# [2022-11-15 22:30:46,531] INFO: Computing for LV769
# [2022-11-15 22:30:46,753] INFO: Computing for LV770
# [2022-11-15 22:30:46,974] INFO: Computing for LV771
# [2022-11-15 22:30:47,186] INFO: Computing for LV772
# [2022-11-15 22:30:47,400] INFO: Computing for LV773
# [2022-11-15 22:30:47,622] INFO: Computing for LV774
# [2022-11-15 22:30:47,886] INFO: Computing for LV775
# [2022-11-15 22:30:48,122] INFO: Computing for LV776
# [2022-11-15 22:30:48,363] INFO: Computing for LV777
# [2022-11-15 22:30:48,579] INFO: Computing for LV778
# [2022-11-15 22:30:48,833] INFO: Computing for LV779
# [2022-11-15 22:30:49,047] INFO: Computing for LV780
# [2022-11-15 22:30:49,256] INFO: Computing for LV781
# [2022-11-15 22:30:49,473] INFO: Computing for LV782
# [2022-11-15 22:30:49,687] INFO: Computing for LV783
# [2022-11-15 22:30:49,962] INFO: Computing for LV784
# [2022-11-15 22:30:50,220] INFO: Computing for LV785
# [2022-11-15 22:30:50,497] INFO: Computing for LV786
# [2022-11-15 22:30:50,745] INFO: Computing for LV787
# [2022-11-15 22:30:50,960] INFO: Computing for LV788
# [2022-11-15 22:30:51,185] INFO: Computing for LV789
# [2022-11-15 22:30:51,418] INFO: Computing for LV790
# [2022-11-15 22:30:51,658] INFO: Computing for LV791
# [2022-11-15 22:30:51,875] INFO: Computing for LV792
# [2022-11-15 22:30:52,107] INFO: Computing for LV793
# [2022-11-15 22:30:52,318] INFO: Computing for LV794
# [2022-11-15 22:30:52,534] INFO: Computing for LV795
# [2022-11-15 22:30:52,741] INFO: Computing for LV796
# [2022-11-15 22:30:52,977] INFO: Computing for LV797
# [2022-11-15 22:30:53,194] INFO: Computing for LV798
# [2022-11-15 22:30:53,437] INFO: Computing for LV799
# [2022-11-15 22:30:53,699] INFO: Computing for LV800
# [2022-11-15 22:30:53,910] INFO: Computing for LV801
# [2022-11-15 22:30:54,125] INFO: Computing for LV802
# [2022-11-15 22:30:54,337] INFO: Computing for LV803
# [2022-11-15 22:30:54,586] INFO: Computing for LV804
# [2022-11-15 22:30:54,803] INFO: Computing for LV805
# [2022-11-15 22:30:55,023] INFO: Computing for LV806
# [2022-11-15 22:30:55,257] INFO: Computing for LV807
# [2022-11-15 22:30:55,477] INFO: Computing for LV808
# [2022-11-15 22:30:55,705] INFO: Computing for LV809
# [2022-11-15 22:30:55,989] INFO: Computing for LV810
# [2022-11-15 22:30:56,231] INFO: Computing for LV811
# [2022-11-15 22:30:56,447] INFO: Computing for LV812
# [2022-11-15 22:30:56,659] INFO: Computing for LV813
# [2022-11-15 22:30:56,917] INFO: Computing for LV814
# [2022-11-15 22:30:57,154] INFO: Computing for LV815
# [2022-11-15 22:30:57,369] INFO: Computing for LV816
# [2022-11-15 22:30:57,577] INFO: Computing for LV817
# [2022-11-15 22:30:57,812] INFO: Computing for LV818
# [2022-11-15 22:30:58,025] INFO: Computing for LV819
# [2022-11-15 22:30:58,234] INFO: Computing for LV820
# [2022-11-15 22:30:58,493] INFO: Computing for LV821
# [2022-11-15 22:30:58,736] INFO: Computing for LV822
# [2022-11-15 22:30:58,968] INFO: Computing for LV823
# [2022-11-15 22:30:59,191] INFO: Computing for LV824
# [2022-11-15 22:30:59,456] INFO: Computing for LV825
# [2022-11-15 22:30:59,673] INFO: Computing for LV826
# [2022-11-15 22:30:59,927] INFO: Computing for LV827
# [2022-11-15 22:31:00,184] INFO: Computing for LV828
# [2022-11-15 22:31:00,395] INFO: Computing for LV829
# [2022-11-15 22:31:00,616] INFO: Computing for LV830
# [2022-11-15 22:31:00,883] INFO: Computing for LV831
# [2022-11-15 22:31:01,167] INFO: Computing for LV832
# [2022-11-15 22:31:01,458] INFO: Computing for LV833
# [2022-11-15 22:31:01,711] INFO: Computing for LV834
# [2022-11-15 22:31:01,949] INFO: Computing for LV835
# [2022-11-15 22:31:02,188] INFO: Computing for LV836
# [2022-11-15 22:31:02,447] INFO: Computing for LV837
# [2022-11-15 22:31:02,701] INFO: Computing for LV838
# [2022-11-15 22:31:02,971] INFO: Computing for LV839
# [2022-11-15 22:31:03,238] INFO: Computing for LV840
# [2022-11-15 22:31:03,526] INFO: Computing for LV841
# [2022-11-15 22:31:03,802] INFO: Computing for LV842
# [2022-11-15 22:31:04,037] INFO: Computing for LV843
# [2022-11-15 22:31:04,388] INFO: Computing for LV844
# [2022-11-15 22:31:04,656] INFO: Computing for LV845
# [2022-11-15 22:31:04,959] INFO: Computing for LV846
# [2022-11-15 22:31:05,199] INFO: Computing for LV847
# [2022-11-15 22:31:05,451] INFO: Computing for LV848
# [2022-11-15 22:31:05,696] INFO: Computing for LV849
# [2022-11-15 22:31:05,942] INFO: Computing for LV850
# [2022-11-15 22:31:06,231] INFO: Computing for LV851
# [2022-11-15 22:31:06,483] INFO: Computing for LV852
# [2022-11-15 22:31:06,748] INFO: Computing for LV853
# [2022-11-15 22:31:07,066] INFO: Computing for LV854
# [2022-11-15 22:31:07,320] INFO: Computing for LV855
# [2022-11-15 22:31:07,596] INFO: Computing for LV856
# [2022-11-15 22:31:07,872] INFO: Computing for LV857
# [2022-11-15 22:31:08,084] INFO: Computing for LV858
# [2022-11-15 22:31:08,294] INFO: Computing for LV859
# [2022-11-15 22:31:08,516] INFO: Computing for LV860
# [2022-11-15 22:31:08,746] INFO: Computing for LV861
# [2022-11-15 22:31:08,962] INFO: Computing for LV862
# [2022-11-15 22:31:09,173] INFO: Computing for LV863
# [2022-11-15 22:31:09,378] INFO: Computing for LV864
# [2022-11-15 22:31:09,588] INFO: Computing for LV865
# [2022-11-15 22:31:09,823] INFO: Computing for LV866
# [2022-11-15 22:31:10,033] INFO: Computing for LV867
# [2022-11-15 22:31:10,244] INFO: Computing for LV868
# [2022-11-15 22:31:10,466] INFO: Computing for LV869
# [2022-11-15 22:31:10,693] INFO: Computing for LV870
# [2022-11-15 22:31:10,986] INFO: Computing for LV871
# [2022-11-15 22:31:11,312] INFO: Computing for LV872
# [2022-11-15 22:31:11,609] INFO: Computing for LV873
# [2022-11-15 22:31:11,883] INFO: Computing for LV874
# [2022-11-15 22:31:12,102] INFO: Computing for LV875
# [2022-11-15 22:31:12,406] INFO: Computing for LV876
# [2022-11-15 22:31:12,660] INFO: Computing for LV877
# [2022-11-15 22:31:12,919] INFO: Computing for LV878
# [2022-11-15 22:31:13,171] INFO: Computing for LV879
# [2022-11-15 22:31:13,386] INFO: Computing for LV880
# [2022-11-15 22:31:13,598] INFO: Computing for LV881
# [2022-11-15 22:31:13,828] INFO: Computing for LV882
# [2022-11-15 22:31:14,058] INFO: Computing for LV883
# [2022-11-15 22:31:14,273] INFO: Computing for LV884
# [2022-11-15 22:31:14,480] INFO: Computing for LV885
# [2022-11-15 22:31:14,696] INFO: Computing for LV886
# [2022-11-15 22:31:14,936] INFO: Computing for LV887
# [2022-11-15 22:31:15,147] INFO: Computing for LV888
# [2022-11-15 22:31:15,357] INFO: Computing for LV889
# [2022-11-15 22:31:15,567] INFO: Computing for LV890
# [2022-11-15 22:31:15,782] INFO: Computing for LV891
# [2022-11-15 22:31:15,994] INFO: Computing for LV892
# [2022-11-15 22:31:16,202] INFO: Computing for LV893
# [2022-11-15 22:31:16,429] INFO: Computing for LV894
# [2022-11-15 22:31:16,648] INFO: Computing for LV895
# [2022-11-15 22:31:16,865] INFO: Computing for LV896
# [2022-11-15 22:31:17,199] INFO: Computing for LV897
# [2022-11-15 22:31:17,443] INFO: Computing for LV898
# [2022-11-15 22:31:17,742] INFO: Computing for LV899
# [2022-11-15 22:31:17,966] INFO: Computing for LV900
# [2022-11-15 22:31:18,211] INFO: Computing for LV901
# [2022-11-15 22:31:18,464] INFO: Computing for LV902
# [2022-11-15 22:31:18,769] INFO: Computing for LV903
# [2022-11-15 22:31:19,015] INFO: Computing for LV904
# [2022-11-15 22:31:19,229] INFO: Computing for LV905
# [2022-11-15 22:31:19,457] INFO: Computing for LV906
# [2022-11-15 22:31:19,712] INFO: Computing for LV907
# [2022-11-15 22:31:19,925] INFO: Computing for LV908
# [2022-11-15 22:31:20,146] INFO: Computing for LV909
# [2022-11-15 22:31:20,366] INFO: Computing for LV910
# [2022-11-15 22:31:20,580] INFO: Computing for LV911
# [2022-11-15 22:31:20,878] INFO: Computing for LV912
# [2022-11-15 22:31:21,186] INFO: Computing for LV913
# [2022-11-15 22:31:21,519] INFO: Computing for LV914
# [2022-11-15 22:31:21,785] INFO: Computing for LV915
# [2022-11-15 22:31:22,002] INFO: Computing for LV916
# [2022-11-15 22:31:22,214] INFO: Computing for LV917
# [2022-11-15 22:31:22,436] INFO: Computing for LV918
# [2022-11-15 22:31:22,680] INFO: Computing for LV919
# [2022-11-15 22:31:22,900] INFO: Computing for LV920
# [2022-11-15 22:31:23,125] INFO: Computing for LV921
# [2022-11-15 22:31:23,339] INFO: Computing for LV922
# [2022-11-15 22:31:23,543] INFO: Computing for LV923
# [2022-11-15 22:31:23,781] INFO: Computing for LV924
# [2022-11-15 22:31:23,996] INFO: Computing for LV925
# [2022-11-15 22:31:24,217] INFO: Computing for LV926
# [2022-11-15 22:31:24,430] INFO: Computing for LV927
# [2022-11-15 22:31:24,644] INFO: Computing for LV928
# [2022-11-15 22:31:24,864] INFO: Computing for LV929
# [2022-11-15 22:31:25,069] INFO: Computing for LV930
# [2022-11-15 22:31:25,279] INFO: Computing for LV931
# [2022-11-15 22:31:25,497] INFO: Computing for LV932
# [2022-11-15 22:31:25,712] INFO: Computing for LV933
# [2022-11-15 22:31:25,925] INFO: Computing for LV934
# [2022-11-15 22:31:26,135] INFO: Computing for LV935
# [2022-11-15 22:31:26,347] INFO: Computing for LV936
# [2022-11-15 22:31:26,554] INFO: Computing for LV937
# [2022-11-15 22:31:26,756] INFO: Computing for LV938
# [2022-11-15 22:31:26,959] INFO: Computing for LV939
# [2022-11-15 22:31:27,174] INFO: Computing for LV940
# [2022-11-15 22:31:27,402] INFO: Computing for LV941
# [2022-11-15 22:31:27,610] INFO: Computing for LV942
# [2022-11-15 22:31:27,831] INFO: Computing for LV943
# [2022-11-15 22:31:28,049] INFO: Computing for LV944
# [2022-11-15 22:31:28,259] INFO: Computing for LV945
# [2022-11-15 22:31:28,485] INFO: Computing for LV946
# [2022-11-15 22:31:28,707] INFO: Computing for LV947
# [2022-11-15 22:31:28,946] INFO: Computing for LV948
# [2022-11-15 22:31:29,165] INFO: Computing for LV949
# [2022-11-15 22:31:29,388] INFO: Computing for LV950
# [2022-11-15 22:31:29,605] INFO: Computing for LV951
# [2022-11-15 22:31:29,823] INFO: Computing for LV952
# [2022-11-15 22:31:30,041] INFO: Computing for LV953
# [2022-11-15 22:31:30,262] INFO: Computing for LV954
# [2022-11-15 22:31:30,478] INFO: Computing for LV955
# [2022-11-15 22:31:30,703] INFO: Computing for LV956
# [2022-11-15 22:31:30,931] INFO: Computing for LV957
# [2022-11-15 22:31:31,149] INFO: Computing for LV958
# [2022-11-15 22:31:31,371] INFO: Computing for LV959
# [2022-11-15 22:31:31,586] INFO: Computing for LV960
# [2022-11-15 22:31:31,835] INFO: Computing for LV961
# [2022-11-15 22:31:32,073] INFO: Computing for LV962
# [2022-11-15 22:31:32,299] INFO: Computing for LV963
# [2022-11-15 22:31:32,519] INFO: Computing for LV964
# [2022-11-15 22:31:32,751] INFO: Computing for LV965
# [2022-11-15 22:31:33,014] INFO: Computing for LV966
# [2022-11-15 22:31:33,250] INFO: Computing for LV967
# [2022-11-15 22:31:33,465] INFO: Computing for LV968
# [2022-11-15 22:31:33,676] INFO: Computing for LV969
# [2022-11-15 22:31:33,891] INFO: Computing for LV970
# [2022-11-15 22:31:34,104] INFO: Computing for LV971
# [2022-11-15 22:31:34,314] INFO: Computing for LV972
# [2022-11-15 22:31:34,527] INFO: Computing for LV973
# [2022-11-15 22:31:34,739] INFO: Computing for LV974
# [2022-11-15 22:31:34,949] INFO: Computing for LV975
# [2022-11-15 22:31:35,169] INFO: Computing for LV976
# [2022-11-15 22:31:35,378] INFO: Computing for LV977
# [2022-11-15 22:31:35,593] INFO: Computing for LV978
# [2022-11-15 22:31:35,809] INFO: Computing for LV979
# [2022-11-15 22:31:36,019] INFO: Computing for LV980
# [2022-11-15 22:31:36,235] INFO: Computing for LV981
# [2022-11-15 22:31:36,449] INFO: Computing for LV982
# [2022-11-15 22:31:36,652] INFO: Computing for LV983
# [2022-11-15 22:31:36,908] INFO: Computing for LV984
# [2022-11-15 22:31:37,146] INFO: Computing for LV985
# [2022-11-15 22:31:37,412] INFO: Computing for LV986
# [2022-11-15 22:31:37,652] INFO: Computing for LV987
# [2022-11-15 22:31:37,937] INFO: Writing results to /tmp/gls_phenoplier-basophill_percentage.tsv.gz

# %% [markdown]
# As you can see from the output, the tool performs some preprocessing of the input TWAS file, and then computes an association for all LVs in the model (987 in our case) and the gene p-values from TWAS. The output is finally written to the path specified.
#
# **IMPORTANT:** keep in mind that you have to use a gene correlation matrix that is specific to your TWAS results. This is because gene correlations depend on the variants present in the original GWAS used. Check out [the notebooks here](https://github.com/greenelab/phenoplier/tree/main/nbs/15_gsa_gls) to see how to compute a gene correlation matrix specific for your trait of interest.

# %% [markdown]
# # Load LV-trait results

# %%
lv_df = pd.read_csv("/tmp/gls_phenoplier-basophill_percentage.tsv.gz", sep="\t")

# %%
lv_df
# Out:
#         lv      beta   beta_se         t  pvalue_twosided  pvalue_onesided
# 0    LV603  0.988076  0.127500  7.749615     1.064641e-14     5.323207e-15
# 1    LV719  0.903596  0.130457  6.926399     4.736869e-12     2.368434e-12
# 2     LV68  0.859876  0.126886  6.776776     1.338216e-11     6.691079e-12
# 3    LV517  0.831304  0.125022  6.649252     3.188491e-11     1.594246e-11
# 4    LV599  0.728474  0.126189  5.772889     8.156289e-09     4.078144e-09
# ..     ...       ...       ...       ...              ...              ...
# 982  LV213 -0.194986  0.125889 -1.548863     1.214639e-01     9.392681e-01
# 983  LV322 -0.202912  0.125966 -1.610849     1.072618e-01     9.463691e-01
# 984  LV632 -0.203234  0.124819 -1.628234     1.035242e-01     9.482379e-01
# 985  LV776 -0.205448  0.125552 -1.636362     1.018129e-01     9.490936e-01
# 986  LV317 -0.215741  0.127047 -1.698124     8.953278e-02     9.552336e-01
#
# [987 rows x 6 columns]

# %% [markdown]
# As you can see, LV603 is at the top of the LVs associations for basophil percentage.
# However, the onesided p-value here (`5.32e-15`) is larger than a simple correlation (`2.94e-27`), suggesting that we have correlated genes at the top of the LV.

# %% [markdown]
# # Conclusions

# %% [markdown]
# Hopefully, now you have a more clear idea of the main data matrices involved in PhenoPLIER (matrix Z, PhenomeXcan gene-trait associations, etc).
# We also see how to compute a p-value between an LV (group of genes or gene module) and a trait of interest.
# To do this with your own data, you need to compute the S-MultiXcan TWAS results (gene-based) from your GWAS summary stats and generate your own gene correlation matrix.
#
# In the next notebook (`02-LV_cell_types-...`), we'll see how to check in which tissues or cell types are our LV603'genes expressed.
