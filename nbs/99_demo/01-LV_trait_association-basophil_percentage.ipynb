# %% [markdown]
# # Description

# %% [markdown]
# This notebook will show the structure of the main data matrices in PhenoPLIER, and will guide you in analyzing gene associations for a particular trait: basophil percentage, which is presented in the [manuscript](https://greenelab.github.io/phenoplier_manuscript/#phenoplier-an-integration-framework-based-on-gene-co-expression-patterns) in Figure 1c.

# %% [markdown]
# # Modules

# %%
import tempfile

import numpy as np
from scipy import stats
import pandas as pd

from entity import Trait, Gene
import conf

# %% [markdown]
# # Load gene module-gene membership matrix (matrix Z)

# %% [markdown]
# Here we load the gene module-gene membership matri, or "latent variables loadings matrix" (from the terminology of the [MultiPLIER article](https://doi.org/10.1016/j.cels.2019.04.003)).

# %%
matrix_z = pd.read_pickle(conf.MULTIPLIER["MODEL_Z_MATRIX_FILE"])

# %%
matrix_z.shape
# Out:
# (6750, 987)

# %%
matrix_z.head()
# Out:
#                LV1  LV2       LV3  LV4       LV5       LV6  LV7       LV8  \
# GAS6      0.000000  0.0  0.039438  0.0  0.050476  0.000000  0.0  0.000000
# MMP14     0.000000  0.0  0.000000  0.0  0.070072  0.000000  0.0  0.004904
# DSP       0.000000  0.0  0.000000  0.0  0.000000  0.041697  0.0  0.005718
# MARCKSL1  0.305212  0.0  0.000000  0.0  0.000000  0.000000  0.0  0.000000
# SPARC     0.000000  0.0  0.000000  0.0  0.000000  0.000000  0.0  0.000000
#
#                LV9      LV10  ...     LV978    LV979     LV980     LV981  \
# GAS6      0.590949  0.000000  ...  0.050125  0.00000  0.033407  0.000000
# MMP14     1.720179  2.423595  ...  0.000000  0.00000  0.001007  0.000000
# DSP       0.000000  0.000000  ...  0.020853  0.00000  0.000000  0.000000
# MARCKSL1  0.161843  0.149471  ...  0.027134  0.05272  0.000000  0.030189
# SPARC     0.000000  0.014014  ...  0.000000  0.00000  0.000000  0.000000
#
#              LV982     LV983     LV984  LV985     LV986     LV987
# GAS6      0.000000  0.005963  0.347362    0.0  0.000000  0.000000
# MMP14     0.035747  0.000000  0.000000    0.0  0.014978  0.000000
# DSP       0.000000  0.005774  0.000000    0.0  0.000000  0.416405
# MARCKSL1  0.060884  0.000000  0.000000    0.0  0.000000  0.448480
# SPARC     0.000000  0.000000  0.067779    0.0  0.122417  0.062665
#
# [5 rows x 987 columns]

# %% [markdown]
# As you can see, this matrix Z contains the membership value for each gene across all LVs (or gene modules).
# A value of zero means that the gene does not belong to that LV, whereas a larger value represents how strongly that gene belongs to the LV.
# A group of genes that belong to the same LV represent a gene-set that has a similar expression profile across a set of tissues or cell types.
# We'll cover this in more detail in the next notebook (`02-LV_cell_types-...`).

# %% [markdown]
# # Load information about LV alignment with pathways

# %% [markdown]
# LV in matrix Z can represent a group of genes that align well with prior pathways (or prior knowledge) or be "novel" in the sense that the combination of genes do not represent a known unit but was found the PLIER when factorizing the recount2 data (see the MultiPLIER article for more details).
#
# Here we load that information, where for each LV and pathway, we have a p-value and area under the curve (AUC) that indicate how well the LV aligns to that pathway.

# %%
lv_metadata = pd.read_pickle(conf.MULTIPLIER["MODEL_SUMMARY_FILE"])

# %%
lv_metadata.shape
# Out:
# (2157, 5)

# %%
lv_metadata.head()
# Out:
#                                    pathway LV index       AUC   p-value  \
# 1                  KEGG_LYSINE_DEGRADATION        1  0.388059  0.866078
# 2                   REACTOME_MRNA_SPLICING        1  0.733057  0.000048
# 3  MIPS_NOP56P_ASSOCIATED_PRE_RRNA_COMPLEX        1  0.680555  0.001628
# 4                     KEGG_DNA_REPLICATION        1  0.549473  0.312155
# 5                     PID_MYC_ACTIVPATHWAY        1  0.639303  0.021702
#
#         FDR
# 1  0.956005
# 2  0.000582
# 3  0.011366
# 4  0.539951
# 5  0.083739

# %% [markdown]
# # Load gene associations from PhenomeXcan

# %% [markdown]
# Now we load gene-trait association from [PhenomeXcan](https://doi.org/10.1126/sciadv.aba2083).
# PhenomeXcan provides TWAS results (using [Summary-MultiXcan](https://doi.org/10.1371/journal.pgen.1007889) and [Summary-PrediXcan](https://doi.org/10.1038/s41467-018-03621-1)) across ~4,000 traits.
# If you are interested in PhenomeXcan you can also check out the [Github repo](https://github.com/hakyimlab/phenomexcan) to know how to download results.
#
# For this demo, we'll load a file that contains Summary-MultiXcan (or S-MultiXcan) results for basophil percentage.
# This file contains a list of p-values for ~22k genes, where a significant p-value means that the gene's predicted expression (across different tissues) is associated with basophil percentage.
# In the notebook I refer to these results generically as "TWAS results", meaning that we have gene-trait associations.
# All these TWAS results were derived solely from GWAS summary stats, so you can also generate yours relatively easily by using [S-MultiXcan](https://doi.org/10.1371/journal.pgen.1007889).

# %%
# %%bash
# # download S-MultiXcan results for basophil percentage
# wget https://uchicago.box.com/shared/static/g70nq1c6wjvado242t9yg05jrhvdykrv.gz -O /tmp/smultixcan_30220_raw_ccn30.tsv.gz
# Out:
# --2022-11-14 22:11:04--  https://uchicago.box.com/shared/static/g70nq1c6wjvado242t9yg05jrhvdykrv.gz
# Resolving uchicago.box.com (uchicago.box.com)... 74.112.186.144
# Connecting to uchicago.box.com (uchicago.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/g70nq1c6wjvado242t9yg05jrhvdykrv.gz [following]
# --2022-11-14 22:11:04--  https://uchicago.box.com/public/static/g70nq1c6wjvado242t9yg05jrhvdykrv.gz
# Reusing existing connection to uchicago.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://uchicago.app.box.com/public/static/g70nq1c6wjvado242t9yg05jrhvdykrv.gz [following]
# --2022-11-14 22:11:04--  https://uchicago.app.box.com/public/static/g70nq1c6wjvado242t9yg05jrhvdykrv.gz
# Resolving uchicago.app.box.com (uchicago.app.box.com)... 74.112.186.144
# Connecting to uchicago.app.box.com (uchicago.app.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dl2.boxcloud.com/d/1/b1!4mBJUgNOvZG-QNFi1wxlOrMwM6BWMS31pOyt_n4s0RuPDu5AbRqn39g-G6gZeb14mEePTOVAWJcmD-oIVVaVNHhZUqC6ixsS-Sch2TSnOe2HWImqOI3dYRbxGqKPQ9_1s6ane1DmgP4VUknIowRXCIPt75IJnqOsjk7yXE4nqoi1neUUBenN9SwfV4yxCq0aUD4JX-oid5G7KtAT9y6iUhnyGn8_-AUtzXYW6lTs7yttGRsN4dnQz5rVH5-uzJiezo7Zyq0inwC8riNmZAnjkmLgOrlOm0BfQzyxjEUItAZHXvAY9x_UVPtxE_QaUUJsW8Y-gbGpda-twPcGqBE6NMjWLOWbNygGQKPGo6U42VoX9g4cnMvytjfJjbV4yYa-g1G7yrQIlBNtSzRACgjiFM7Rku9n_qNvlpYWaTLJPMg4zAt43x4C8WmwGkkChAChaE9nT1zPMnLi8xdrm3SW-h23m3vBLCfiqG_tx2SrYLsMWuukk8ypCvsf03U8AMIOw7Zh0lHijPRIxje_lrnH2ZzXHRaCEpEmar_eAdrsQhLqHQPoL-qERATalclBG_tniN_KwldjFEMKVKv1pVOLPLyjF2LU_bL0qbLfMOkpla9kpixHBKiPvfQ4s1bXVm6doYun8qPcf5CzIsnC0FuYnI66B5wZpoOXysi6cE-6OLZEi7v5s0Xj8_HUKrPpH_kXzuk5QJ7NJKhgNbl4KysznLYtkKhuqjirq8JqMtbeLFYXveeKBOf9D2Fv5bOspuhH5sHFh0vxJYuIElTbHrTdgKLnOmPD4kKHK_8S3YUU6qoucChYNAr2_1C_25RzcHWtmWn0PkXkNs1MC1skpAdd7OX3p4IZ08jA96Kbjy4azb8w9ZsvMvDUPGb6s-_Ul_RhxFD3HFBhbBHSOOHnF9qZFPo-Ktg4t21licZfu1qfAeOvg7GKnBN2VJ5hBlOvuG30SonmhGfB8Y1DsWiPvpFMjUF8EJduPWeY9y02yyQci1ae7VemoUSIIrbbXKX4R8eJuMBBzAT1tXbMbqfvPu0E7G_agEwnRrIyGikQxc6zRddGwrTnwmoN-dtZAFz8JSmPkzQc2wlyi0s3niIYXJrtGRe33thyUyO3urtzKuBsARA8A_TV23nFvcEhR7dGq33m4Hg8gkedIfFbgDjOkpLzO05YNhw35c_s421Fs1X4-dcOBgpsc1aWO2qTV3kku4RSbzUg1VW4LEuS5ApGd40ahxu1g9bNL1mS0N0jg-3mv2DfgEu-zqGADdfp15Vel3cGgGJBgiqcE7DTr7ye_tyTahgLEATYxL0KFFGM8sdp8WpqI8Ztw1N7n0n-Rkk5FdJJV3i-kr_r-pVx7XSZGV7GgtGvOL2TDl8-W08cOnw8pn9fAUyJ_rjfA5Fy2VL9tnxnS7y8aFfcxYOu_rag1dJGjsXfRFHC73nYYTO4NajKxmBoZBQC5jI2JeRMa8hdd8W3vUiFaCkT6rbNcWGtlGpWozOgXR3qcF77/download [following]
# --2022-11-14 22:11:05--  https://dl2.boxcloud.com/d/1/b1!4mBJUgNOvZG-QNFi1wxlOrMwM6BWMS31pOyt_n4s0RuPDu5AbRqn39g-G6gZeb14mEePTOVAWJcmD-oIVVaVNHhZUqC6ixsS-Sch2TSnOe2HWImqOI3dYRbxGqKPQ9_1s6ane1DmgP4VUknIowRXCIPt75IJnqOsjk7yXE4nqoi1neUUBenN9SwfV4yxCq0aUD4JX-oid5G7KtAT9y6iUhnyGn8_-AUtzXYW6lTs7yttGRsN4dnQz5rVH5-uzJiezo7Zyq0inwC8riNmZAnjkmLgOrlOm0BfQzyxjEUItAZHXvAY9x_UVPtxE_QaUUJsW8Y-gbGpda-twPcGqBE6NMjWLOWbNygGQKPGo6U42VoX9g4cnMvytjfJjbV4yYa-g1G7yrQIlBNtSzRACgjiFM7Rku9n_qNvlpYWaTLJPMg4zAt43x4C8WmwGkkChAChaE9nT1zPMnLi8xdrm3SW-h23m3vBLCfiqG_tx2SrYLsMWuukk8ypCvsf03U8AMIOw7Zh0lHijPRIxje_lrnH2ZzXHRaCEpEmar_eAdrsQhLqHQPoL-qERATalclBG_tniN_KwldjFEMKVKv1pVOLPLyjF2LU_bL0qbLfMOkpla9kpixHBKiPvfQ4s1bXVm6doYun8qPcf5CzIsnC0FuYnI66B5wZpoOXysi6cE-6OLZEi7v5s0Xj8_HUKrPpH_kXzuk5QJ7NJKhgNbl4KysznLYtkKhuqjirq8JqMtbeLFYXveeKBOf9D2Fv5bOspuhH5sHFh0vxJYuIElTbHrTdgKLnOmPD4kKHK_8S3YUU6qoucChYNAr2_1C_25RzcHWtmWn0PkXkNs1MC1skpAdd7OX3p4IZ08jA96Kbjy4azb8w9ZsvMvDUPGb6s-_Ul_RhxFD3HFBhbBHSOOHnF9qZFPo-Ktg4t21licZfu1qfAeOvg7GKnBN2VJ5hBlOvuG30SonmhGfB8Y1DsWiPvpFMjUF8EJduPWeY9y02yyQci1ae7VemoUSIIrbbXKX4R8eJuMBBzAT1tXbMbqfvPu0E7G_agEwnRrIyGikQxc6zRddGwrTnwmoN-dtZAFz8JSmPkzQc2wlyi0s3niIYXJrtGRe33thyUyO3urtzKuBsARA8A_TV23nFvcEhR7dGq33m4Hg8gkedIfFbgDjOkpLzO05YNhw35c_s421Fs1X4-dcOBgpsc1aWO2qTV3kku4RSbzUg1VW4LEuS5ApGd40ahxu1g9bNL1mS0N0jg-3mv2DfgEu-zqGADdfp15Vel3cGgGJBgiqcE7DTr7ye_tyTahgLEATYxL0KFFGM8sdp8WpqI8Ztw1N7n0n-Rkk5FdJJV3i-kr_r-pVx7XSZGV7GgtGvOL2TDl8-W08cOnw8pn9fAUyJ_rjfA5Fy2VL9tnxnS7y8aFfcxYOu_rag1dJGjsXfRFHC73nYYTO4NajKxmBoZBQC5jI2JeRMa8hdd8W3vUiFaCkT6rbNcWGtlGpWozOgXR3qcF77/download
# Resolving dl2.boxcloud.com (dl2.boxcloud.com)... 74.112.186.128
# Connecting to dl2.boxcloud.com (dl2.boxcloud.com)|74.112.186.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2445491 (2.3M) [application/octet-stream]
# Saving to: ‘/tmp/smultixcan_30220_raw_ccn30.tsv.gz’
#
#      0K .......... .......... .......... .......... ..........  2% 5.85M 0s
#     50K .......... .......... .......... .......... ..........  4%  895K 1s
#    100K .......... .......... .......... .......... ..........  6% 7.79M 1s
#    150K .......... .......... .......... .......... ..........  8% 7.09M 1s
#    200K .......... .......... .......... .......... .......... 10% 8.45M 1s
#    250K .......... .......... .......... .......... .......... 12% 7.68M 1s
#    300K .......... .......... .......... .......... .......... 14% 7.76M 1s
#    350K .......... .......... .......... .......... .......... 16% 8.47M 1s
#    400K .......... .......... .......... .......... .......... 18% 7.52M 0s
#    450K .......... .......... .......... .......... .......... 20% 7.98M 0s
#    500K .......... .......... .......... .......... .......... 23%  999K 1s
#    550K .......... .......... .......... .......... .......... 25% 7.64M 1s
#    600K .......... .......... .......... .......... .......... 27% 1.00M 1s
#    650K .......... .......... .......... .......... .......... 29% 8.79M 1s
#    700K .......... .......... .......... .......... .......... 31% 8.81M 1s
#    750K .......... .......... .......... .......... .......... 33%  994K 1s
#    800K .......... .......... .......... .......... .......... 35% 8.59M 1s
#    850K .......... .......... .......... .......... .......... 37% 1.01M 1s
#    900K .......... .......... .......... .......... .......... 39% 6.97M 1s
#    950K .......... .......... .......... .......... .......... 41% 7.63M 0s
#   1000K .......... .......... .......... .......... .......... 43% 1.08M 1s
#   1050K .......... .......... .......... .......... .......... 46% 11.5M 0s
#   1100K .......... .......... .......... .......... .......... 48% 11.8M 0s
#   1150K .......... .......... .......... .......... .......... 50% 11.7M 0s
#   1200K .......... .......... .......... .......... .......... 52% 12.1M 0s
#   1250K .......... .......... .......... .......... .......... 54% 11.4M 0s
#   1300K .......... .......... .......... .......... .......... 56% 12.2M 0s
#   1350K .......... .......... .......... .......... .......... 58% 11.3M 0s
#   1400K .......... .......... .......... .......... .......... 60% 13.1M 0s
#   1450K .......... .......... .......... .......... .......... 62% 10.6M 0s
#   1500K .......... .......... .......... .......... .......... 64% 13.6M 0s
#   1550K .......... .......... .......... .......... .......... 66% 12.7M 0s
#   1600K .......... .......... .......... .......... .......... 69% 3.57M 0s
#   1650K .......... .......... .......... .......... .......... 71% 11.9M 0s
#   1700K .......... .......... .......... .......... .......... 73% 11.4M 0s
#   1750K .......... .......... .......... .......... .......... 75% 12.3M 0s
#   1800K .......... .......... .......... .......... .......... 77% 12.3M 0s
#   1850K .......... .......... .......... .......... .......... 79% 10.5M 0s
#   1900K .......... .......... .......... .......... .......... 81% 13.8M 0s
#   1950K .......... .......... .......... .......... .......... 83% 11.4M 0s
#   2000K .......... .......... .......... .......... .......... 85% 18.5M 0s
#   2050K .......... .......... .......... .......... .......... 87% 15.7M 0s
#   2100K .......... .......... .......... .......... .......... 90% 16.8M 0s
#   2150K .......... .......... .......... .......... .......... 92% 16.7M 0s
#   2200K .......... .......... .......... .......... .......... 94% 16.2M 0s
#   2250K .......... .......... .......... .......... .......... 96% 22.0M 0s
#   2300K .......... .......... .......... .......... .......... 98% 16.3M 0s
#   2350K .......... .......... .......... ........             100% 25.8M=0.5s
#
# 2022-11-14 22:11:06 (4.64 MB/s) - ‘/tmp/smultixcan_30220_raw_ccn30.tsv.gz’ saved [2445491/2445491]

# %%
df = pd.read_csv("/tmp/smultixcan_30220_raw_ccn30.tsv.gz", sep="\t")

# %%
df.shape
# Out:
# (22258, 18)

# %%
df.head()
# Out:
#                  gene gene_name        pvalue     n  n_indep      p_i_best  \
# 0  ENSG00000143669.13      LYST  3.430090e-78  40.0      5.0  5.887514e-67
# 1  ENSG00000140575.12    IQGAP1  5.312061e-56  49.0      2.0  1.792379e-55
# 2   ENSG00000239839.6     DEFA3  6.178319e-52  25.0      8.0  1.735510e-30
# 3  ENSG00000140577.15     CRTC3  3.633540e-46  47.0      5.0  3.326635e-48
# 4  ENSG00000107929.14    LARP4B  5.229144e-43  35.0      4.0  4.209043e-45
#
#                             t_i_best     p_i_worst  \
# 0         Cells_Cultured_fibroblasts  5.715454e-01
# 1  Cells_EBV-transformed_lymphocytes  2.034382e-18
# 2           Brain_Frontal_Cortex_BA9  4.821369e-01
# 3    Skin_Not_Sun_Exposed_Suprapubic  2.188896e-01
# 4           Brain_Frontal_Cortex_BA9  3.858258e-01
#
#                      t_i_worst  eigen_max     eigen_min  eigen_min_kept  \
# 0                        Ovary  25.575879  5.685765e-16        1.091354
# 1     Brain_Frontal_Cortex_BA9  43.159657  1.197089e-15        3.913487
# 2       Heart_Atrial_Appendage  13.021527  1.362063e-17        0.438362
# 3                Artery_Tibial  25.991131  1.853057e-15        1.183360
# 4  Brain_Cerebellar_Hemisphere  24.531853  5.407442e-16        2.055242
#
#        z_min      z_max     z_mean       z_sd  tmi  status
# 0 -17.287064  16.985176  -6.255059  11.905653  5.0       0
# 1 -15.689222  -8.755368 -11.930501   2.305056  2.0       0
# 2 -11.476299   3.676225  -6.196329   4.534728  8.0       0
# 3  -7.376543  14.588451   7.294836   5.294380  5.0       0
# 4 -13.906881  14.092741   6.933903   8.977076  4.0       0

# %% [markdown]
# # Take a look at genes associated with basophil percentage

# %% [markdown]
# Show the sample size for this trait.

# %%
trait_code = "30220_raw-Basophill_percentage"
t = Trait.get_trait(full_code=trait_code)
display(f"{trait_code} - sample size: {t.n}")
# Out:
# '30220_raw-Basophill_percentage - sample size: 349861'

# %% [markdown]
# Below I list the top associated genes for basophil percentage.

# %%
traits_df = df[["gene_name", "pvalue"]].dropna().set_index("gene_name")

# remove duplicated gene names
traits_df = traits_df.loc[~traits_df.index.duplicated()]

# %%
traits_df.shape
# Out:
# (22248, 1)

# %%
traits_df.head()
# Out:
#                  pvalue
# gene_name
# LYST       3.430090e-78
# IQGAP1     5.312061e-56
# DEFA3      6.178319e-52
# CRTC3      3.633540e-46
# LARP4B     5.229144e-43

# %% [markdown]
# Here I quickly show the data summary for this trait's gene associations:

# %%
traits_df["pvalue"].apply(lambda x: -np.log10(x)).describe()
# Out:
# count    22248.000000
# mean         0.695257
# std          1.556005
# min          0.000120
# 25%          0.166637
# 50%          0.393855
# 75%          0.815005
# max         77.464694
# Name: pvalue, dtype: float64

# %% [markdown]
# # Get a set of common genes between TWAS and LVs

# %%
common_genes = traits_df.index.intersection(matrix_z.index)

# %%
common_genes
# Out:
# Index(['IQGAP1', 'CCR1', 'CCR3', 'PRTN3', 'FCGR3B', 'RASGRP4', 'ZYX', 'RYR1',
#        'EPHA1', 'MYB',
#        ...
#        'NPTX2', 'RNASE2', 'WDTC1', 'NLK', 'GADD45B', 'ARHGAP22', 'POLR1E',
#        'ATP6V1D', 'NEDD4L', 'CACNG6'],
#       dtype='object', length=6430)

# %%
# keep only the genes in common
traits_df = traits_df.loc[common_genes]

# %%
traits_df.shape
# Out:
# (6430, 1)

# %%
matrix_z = matrix_z.loc[common_genes]

# %%
matrix_z.shape
# Out:
# (6430, 987)

# %% [markdown]
# # Analysis of a neutrophil-termed LV

# %% [markdown]
# Let's take as an example an LV that was previously analyzed in the MultiPLIER study, which we identify as `LV603`. This LV aligns well with pathways related to neutrophils, as you can see below. In the next notebook (`02-LV_cell_types...`) we'll see that this LV is expressed in neutrophils and other granulocytes.

# %%
lv_metadata[
    (lv_metadata["LV index"] == "603") & (lv_metadata["FDR"] < 0.05)
].sort_values("FDR")
# Out:
#                                   pathway LV index       AUC       p-value  \
# 1511              IRIS_Neutrophil-Resting      603  0.905751  8.355936e-38
# 1512                      SVM Neutrophils      603  0.979789  2.856571e-11
# 1513                 PID_IL8CXCR2_PATHWAY      603  0.810732  8.814671e-04
# 1516  SIG_PIP3_SIGNALING_IN_B_LYMPHOCYTES      603  0.769292  3.387907e-03
#
#                FDR
# 1511  4.505939e-35
# 1512  1.432936e-09
# 1513  7.041943e-03
# 1516  1.948724e-02

# %% [markdown]
# Let's see which genes more strongly belong to LV603 (the numbers are the gene weights in this LV):

# %%
lv603_top_genes = matrix_z["LV603"].sort_values(ascending=False)
display(lv603_top_genes.head(20))
# Out:
# CXCR2        5.320459
# FCGR3B       5.128372
# TNFRSF10C    5.035457
# VNN2         4.680865
# ZDHHC18      4.495976
# MNDA         4.488505
# CXCR1        4.442062
# P2RY13       4.404405
# VNN3         4.253184
# FPR2         4.187560
# CEACAM3      4.139476
# C5AR1        4.101986
# SLC45A4      4.068913
# AQP9         3.939923
# CCR3         3.883533
# ABTB1        3.745259
# CSF3R        3.735651
# FPR1         3.720018
# DPEP2        3.656125
# SIRPB1       3.632251
# Name: LV603, dtype: float64

# %% [markdown]
# Are these top genes associated with our trait of interest?

# %%
traits_df.loc[lv603_top_genes.index].head(20)
# Out:
#                  pvalue
# CXCR2      1.281640e-02
# FCGR3B     3.297587e-32
# TNFRSF10C  1.655229e-07
# VNN2       9.217389e-01
# ZDHHC18    8.370749e-02
# MNDA       4.876452e-01
# CXCR1      1.315804e-02
# P2RY13     2.734939e-02
# VNN3       4.231949e-01
# FPR2       8.199449e-01
# CEACAM3    2.023499e-02
# C5AR1      9.653734e-02
# SLC45A4    1.859938e-01
# AQP9       2.934985e-02
# CCR3       1.525115e-35
# ABTB1      1.323314e-02
# CSF3R      1.692547e-01
# FPR1       8.057217e-01
# DPEP2      8.727988e-02
# SIRPB1     5.318173e-01

# %% [markdown]
# It seems so. But what about the rest of the genes? They might be also strongly associated.
# Let's take a random sample:

# %%
traits_df.sample(n=20, random_state=0)
# Out:
#             pvalue
# GPR171    0.170912
# SGCA      0.070701
# P4HA2     0.324261
# ANAPC7    0.032241
# CYP11A1   0.215818
# NUMB      0.126148
# IGF1      0.603579
# C10orf10  0.018192
# CISH      0.558913
# NDUFB9    0.574156
# ACTA1     0.672696
# LEF1      0.333482
# EIF4E     0.292698
# CLEC4E    0.827772
# GPLD1     0.473381
# MCEE      0.571339
# SSPO      0.423126
# MAP2K1    0.222102
# EPS15L1   0.164045
# TUBA1A    0.284552

# %% [markdown]
# They do not seem as significant as those within the top genes in LV603.
#
# If we compute the correlation between LV603 gene weights (`lv603_top_genes`) and gene associations for basophil percentage (`traits_df`) we get this:

# %%
lv603_top_genes
# Out:
# CXCR2        5.320459
# FCGR3B       5.128372
# TNFRSF10C    5.035457
# VNN2         4.680865
# ZDHHC18      4.495976
#                ...
# GTF2H2       0.000000
# TRIM28       0.000000
# DPYD         0.000000
# ASPM         0.000000
# PDE2A        0.000000
# Name: LV603, Length: 6430, dtype: float64

# %%
stats.pearsonr(
    traits_df["pvalue"]
    .apply(lambda x: -np.log10(x))
    .loc[lv603_top_genes.index]
    .to_numpy(),
    lv603_top_genes.to_numpy(),
)
# Out:
# (0.13428177436972902, 2.935462151415347e-27)

# %% [markdown]
# Although the correlation is significant (`2.94e-27`) and the slope positive (we are interested only in genes at the top of the LV), we need to account for correlated predicted expression from the TWAS models (for example, if the expression of two genes at the top of the LV is correlated that would invalidate our test).
# We provide a class, `GLSPhenoplier` (implemented in Python) that computes this. We also provide a command-line tool, `gls_cli.py`, that performs several preprocessing steps, and below we show how to use it for our example.

# %% [markdown]
# # `gls_cli.py`: association between an LV and a trait

# %% [markdown]
# The `gls_cli.py` command-line tool needs as input the S-MultiXcan TWAS results and a gene correlation matrix (which is specific to the TWAS results, see below).

# %%
# %%bash
# # remove previously computed results (if exist)
# rm /tmp/gls_phenoplier-basophill_percentage.tsv.gz
#
# # print full path of gls_cli.py tool
# echo ${PHENOPLIER_CODE_DIR}/libs/gls_cli.py
#
# # print full path of gene correlations file (which is trait-specific!)
# COHORT_NAME="phenomexcan_rapid_gwas"
# REFERENCE_PANEL="gtex_v8"
# GENE_CORR_DIR="${PHENOPLIER_RESULTS_GLS}/gene_corrs/cohorts/${COHORT_NAME}/${REFERENCE_PANEL}/mashr/gene_corrs-symbols-within_distance_5mb.per_lv/"
# echo ${GENE_CORR_DIR}
#
# python ${PHENOPLIER_CODE_DIR}/libs/gls_cli.py \
#   --input-file /tmp/smultixcan_30220_raw_ccn30.tsv.gz \
#   --duplicated-genes-action keep-first \
#   --gene-corr-file ${GENE_CORR_DIR} \
#   --debug-use-sub-gene-corr \
#   --covars gene_size gene_size_log gene_density gene_density_log \
#   --output-file /tmp/gls_phenoplier-basophill_percentage.tsv.gz
# Out:
# rm: cannot remove '/tmp/gls_phenoplier-basophill_percentage.tsv.gz': No such file or directory
# /opt/code/libs/gls_cli.py
# /opt/data/results/gls/gene_corrs/cohorts/phenomexcan_rapid_gwas/gtex_v8/mashr/gene_corrs-symbols-within_distance_5mb.per_lv/
# [2022-11-14 22:11:07,561] INFO: Reading input file /tmp/smultixcan_30220_raw_ccn30.tsv.gz
# [2022-11-14 22:11:07,668] INFO: Input file has 22258 genes
# [2022-11-14 22:11:07,677] INFO: Removed duplicated genes symbols using 'keep-first'. Data now has 22251 genes
# [2022-11-14 22:11:07,679] INFO: p-values statistics: min=3.4e-78 | mean=4.3e-01 | max=1.0e+00 | # missing=3 (0.0%)
# [2022-11-14 22:11:07,680] INFO: Using covariates: ['gene_density', 'gene_density_log', 'gene_size', 'gene_size_log']
# [2022-11-14 22:11:07,930] INFO: NumExpr defaulting to 4 threads.
# [2022-11-14 22:11:07,935] INFO: Replacing zero p-values by nonzero minimum divided by 10
# [2022-11-14 22:11:07,939] INFO: Using -log10(pvalue)
# [2022-11-14 22:11:07,940] INFO: Using gene correlation file: /opt/data/results/gls/gene_corrs/cohorts/phenomexcan_rapid_gwas/gtex_v8/mashr/gene_corrs-symbols-within_distance_5mb.per_lv/
# [2022-11-14 22:11:07,966] INFO: 987 LVs (gene modules) were found in LV model
# [2022-11-14 22:11:07,966] INFO: All LVs in models will be used
# [2022-11-14 22:11:07,966] INFO: Computing for LV1
# [2022-11-14 22:11:07,997] WARNING: 3 genes with missing values have been removed
# [2022-11-14 22:11:08,007] WARNING: 22248 genes in phenotype associations, but only 6430 were found in LV models
# [2022-11-14 22:11:08,012] INFO: Using binarized LV at 1% (65 / 6365)
# [2022-11-14 22:11:08,017] INFO: Final number of genes in training data: 6430
# [2022-11-14 22:11:08,017] INFO: Correlation matrix is a directory, reading inverse of Cholesky decomposition for each LV
# [2022-11-14 22:11:08,027] INFO: Data has all genes in LV-specific correlation matrix
# [2022-11-14 22:11:08,131] INFO: Computing for LV2
# [2022-11-14 22:11:08,271] INFO: Computing for LV3
# [2022-11-14 22:11:08,409] INFO: Computing for LV4
# [2022-11-14 22:11:08,549] INFO: Computing for LV5
# [2022-11-14 22:11:08,688] INFO: Computing for LV6
# [2022-11-14 22:11:08,839] INFO: Computing for LV7
# [2022-11-14 22:11:08,996] INFO: Computing for LV8
# [2022-11-14 22:11:09,129] INFO: Computing for LV9
# [2022-11-14 22:11:09,264] INFO: Computing for LV10
# [2022-11-14 22:11:09,398] INFO: Computing for LV11
# [2022-11-14 22:11:09,532] INFO: Computing for LV12
# [2022-11-14 22:11:09,665] INFO: Computing for LV13
# [2022-11-14 22:11:09,818] INFO: Computing for LV14
# [2022-11-14 22:11:09,951] INFO: Computing for LV15
# [2022-11-14 22:11:10,117] INFO: Computing for LV16
# [2022-11-14 22:11:10,251] INFO: Computing for LV17
# [2022-11-14 22:11:10,384] INFO: Computing for LV18
# [2022-11-14 22:11:10,518] INFO: Computing for LV19
# [2022-11-14 22:11:10,651] INFO: Computing for LV20
# [2022-11-14 22:11:10,785] INFO: Computing for LV21
# [2022-11-14 22:11:10,939] INFO: Computing for LV22
# [2022-11-14 22:11:11,095] INFO: Computing for LV23
# [2022-11-14 22:11:11,227] INFO: Computing for LV24
# [2022-11-14 22:11:11,361] INFO: Computing for LV25
# [2022-11-14 22:11:11,494] INFO: Computing for LV26
# [2022-11-14 22:11:11,627] INFO: Computing for LV27
# [2022-11-14 22:11:11,760] INFO: Computing for LV28
# [2022-11-14 22:11:11,893] INFO: Computing for LV29
# [2022-11-14 22:11:12,067] INFO: Computing for LV30
# [2022-11-14 22:11:12,199] INFO: Computing for LV31
# [2022-11-14 22:11:12,333] INFO: Computing for LV32
# [2022-11-14 22:11:12,467] INFO: Computing for LV33
# [2022-11-14 22:11:12,600] INFO: Computing for LV34
# [2022-11-14 22:11:12,734] INFO: Computing for LV35
# [2022-11-14 22:11:12,868] INFO: Computing for LV36
# [2022-11-14 22:11:13,002] INFO: Computing for LV37
# [2022-11-14 22:11:13,134] INFO: Computing for LV38
# [2022-11-14 22:11:13,268] INFO: Computing for LV39
# [2022-11-14 22:11:13,402] INFO: Computing for LV40
# [2022-11-14 22:11:13,536] INFO: Computing for LV41
# [2022-11-14 22:11:13,670] INFO: Computing for LV42
# [2022-11-14 22:11:13,803] INFO: Computing for LV43
# [2022-11-14 22:11:13,941] INFO: Computing for LV44
# [2022-11-14 22:11:14,103] INFO: Computing for LV45
# [2022-11-14 22:11:14,237] INFO: Computing for LV46
# [2022-11-14 22:11:14,373] INFO: Computing for LV47
# [2022-11-14 22:11:14,508] INFO: Computing for LV48
# [2022-11-14 22:11:14,643] INFO: Computing for LV49
# [2022-11-14 22:11:14,779] INFO: Computing for LV50
# [2022-11-14 22:11:14,915] INFO: Computing for LV51
# [2022-11-14 22:11:15,053] INFO: Computing for LV52
# [2022-11-14 22:11:15,197] INFO: Computing for LV53
# [2022-11-14 22:11:15,333] INFO: Computing for LV54
# [2022-11-14 22:11:15,469] INFO: Computing for LV55
# [2022-11-14 22:11:15,605] INFO: Computing for LV56
# [2022-11-14 22:11:15,740] INFO: Computing for LV57
# [2022-11-14 22:11:15,875] INFO: Computing for LV58
# [2022-11-14 22:11:16,040] INFO: Computing for LV59
# [2022-11-14 22:11:16,182] INFO: Computing for LV60
# [2022-11-14 22:11:16,319] INFO: Computing for LV61
# [2022-11-14 22:11:16,456] INFO: Computing for LV62
# [2022-11-14 22:11:16,594] INFO: Computing for LV63
# [2022-11-14 22:11:16,732] INFO: Computing for LV64
# [2022-11-14 22:11:16,889] INFO: Computing for LV65
# [2022-11-14 22:11:17,026] INFO: Computing for LV66
# [2022-11-14 22:11:17,165] INFO: Computing for LV67
# [2022-11-14 22:11:17,302] INFO: Computing for LV68
# [2022-11-14 22:11:17,438] INFO: Computing for LV69
# [2022-11-14 22:11:17,575] INFO: Computing for LV70
# [2022-11-14 22:11:17,713] INFO: Computing for LV71
# [2022-11-14 22:11:17,872] INFO: Computing for LV72
# [2022-11-14 22:11:18,023] INFO: Computing for LV73
# [2022-11-14 22:11:18,167] INFO: Computing for LV74
# [2022-11-14 22:11:18,304] INFO: Computing for LV75
# [2022-11-14 22:11:18,440] INFO: Computing for LV76
# [2022-11-14 22:11:18,578] INFO: Computing for LV77
# [2022-11-14 22:11:18,716] INFO: Computing for LV78
# [2022-11-14 22:11:18,854] INFO: Computing for LV79
# [2022-11-14 22:11:19,011] INFO: Computing for LV80
# [2022-11-14 22:11:19,149] INFO: Computing for LV81
# [2022-11-14 22:11:19,293] INFO: Computing for LV82
# [2022-11-14 22:11:19,431] INFO: Computing for LV83
# [2022-11-14 22:11:19,569] INFO: Computing for LV84
# [2022-11-14 22:11:19,705] INFO: Computing for LV85
# [2022-11-14 22:11:19,844] INFO: Computing for LV86
# [2022-11-14 22:11:19,982] INFO: Computing for LV87
# [2022-11-14 22:11:20,131] INFO: Computing for LV88
# [2022-11-14 22:11:20,270] INFO: Computing for LV89
# [2022-11-14 22:11:20,407] INFO: Computing for LV90
# [2022-11-14 22:11:20,546] INFO: Computing for LV91
# [2022-11-14 22:11:20,684] INFO: Computing for LV92
# [2022-11-14 22:11:20,821] INFO: Computing for LV93
# [2022-11-14 22:11:20,958] INFO: Computing for LV94
# [2022-11-14 22:11:21,114] INFO: Computing for LV95
# [2022-11-14 22:11:21,252] INFO: Computing for LV96
# [2022-11-14 22:11:21,389] INFO: Computing for LV97
# [2022-11-14 22:11:21,526] INFO: Computing for LV98
# [2022-11-14 22:11:21,665] INFO: Computing for LV99
# [2022-11-14 22:11:21,802] INFO: Computing for LV100
# [2022-11-14 22:11:21,940] INFO: Computing for LV101
# [2022-11-14 22:11:22,103] INFO: Computing for LV102
# [2022-11-14 22:11:22,240] INFO: Computing for LV103
# [2022-11-14 22:11:22,378] INFO: Computing for LV104
# [2022-11-14 22:11:22,516] INFO: Computing for LV105
# [2022-11-14 22:11:22,654] INFO: Computing for LV106
# [2022-11-14 22:11:22,790] INFO: Computing for LV107
# [2022-11-14 22:11:22,928] INFO: Computing for LV108
# [2022-11-14 22:11:23,093] INFO: Computing for LV109
# [2022-11-14 22:11:23,231] INFO: Computing for LV110
# [2022-11-14 22:11:23,369] INFO: Computing for LV111
# [2022-11-14 22:11:23,506] INFO: Computing for LV112
# [2022-11-14 22:11:23,643] INFO: Computing for LV113
# [2022-11-14 22:11:23,782] INFO: Computing for LV114
# [2022-11-14 22:11:23,920] INFO: Computing for LV115
# [2022-11-14 22:11:24,082] INFO: Computing for LV116
# [2022-11-14 22:11:24,219] INFO: Computing for LV117
# [2022-11-14 22:11:24,356] INFO: Computing for LV118
# [2022-11-14 22:11:24,492] INFO: Computing for LV119
# [2022-11-14 22:11:24,631] INFO: Computing for LV120
# [2022-11-14 22:11:24,771] INFO: Computing for LV121
# [2022-11-14 22:11:24,921] INFO: Computing for LV122
# [2022-11-14 22:11:25,080] INFO: Computing for LV123
# [2022-11-14 22:11:25,217] INFO: Computing for LV124
# [2022-11-14 22:11:25,357] INFO: Computing for LV125
# [2022-11-14 22:11:25,495] INFO: Computing for LV126
# [2022-11-14 22:11:25,633] INFO: Computing for LV127
# [2022-11-14 22:11:25,771] INFO: Computing for LV128
# [2022-11-14 22:11:25,924] INFO: Computing for LV129
# [2022-11-14 22:11:26,084] INFO: Computing for LV130
# [2022-11-14 22:11:26,222] INFO: Computing for LV131
# [2022-11-14 22:11:26,360] INFO: Computing for LV132
# [2022-11-14 22:11:26,499] INFO: Computing for LV133
# [2022-11-14 22:11:26,636] INFO: Computing for LV134
# [2022-11-14 22:11:26,775] INFO: Computing for LV135
# [2022-11-14 22:11:26,913] INFO: Computing for LV136
# [2022-11-14 22:11:27,087] INFO: Computing for LV137
# [2022-11-14 22:11:27,225] INFO: Computing for LV138
# [2022-11-14 22:11:27,363] INFO: Computing for LV139
# [2022-11-14 22:11:27,501] INFO: Computing for LV140
# [2022-11-14 22:11:27,638] INFO: Computing for LV141
# [2022-11-14 22:11:27,776] INFO: Computing for LV142
# [2022-11-14 22:11:27,915] INFO: Computing for LV143
# [2022-11-14 22:11:28,067] INFO: Computing for LV144
# [2022-11-14 22:11:28,206] INFO: Computing for LV145
# [2022-11-14 22:11:28,344] INFO: Computing for LV146
# [2022-11-14 22:11:28,482] INFO: Computing for LV147
# [2022-11-14 22:11:28,641] INFO: Computing for LV148
# [2022-11-14 22:11:28,778] INFO: Computing for LV149
# [2022-11-14 22:11:28,916] INFO: Computing for LV150
# [2022-11-14 22:11:29,075] INFO: Computing for LV151
# [2022-11-14 22:11:29,217] INFO: Computing for LV152
# [2022-11-14 22:11:29,356] INFO: Computing for LV153
# [2022-11-14 22:11:29,491] INFO: Computing for LV154
# [2022-11-14 22:11:29,630] INFO: Computing for LV155
# [2022-11-14 22:11:29,767] INFO: Computing for LV156
# [2022-11-14 22:11:29,905] INFO: Computing for LV157
# [2022-11-14 22:11:30,043] INFO: Computing for LV158
# [2022-11-14 22:11:30,193] INFO: Computing for LV159
# [2022-11-14 22:11:30,331] INFO: Computing for LV160
# [2022-11-14 22:11:30,470] INFO: Computing for LV161
# [2022-11-14 22:11:30,608] INFO: Computing for LV162
# [2022-11-14 22:11:30,747] INFO: Computing for LV163
# [2022-11-14 22:11:30,887] INFO: Computing for LV164
# [2022-11-14 22:11:31,025] INFO: Computing for LV165
# [2022-11-14 22:11:31,167] INFO: Computing for LV166
# [2022-11-14 22:11:31,304] INFO: Computing for LV167
# [2022-11-14 22:11:31,441] INFO: Computing for LV168
# [2022-11-14 22:11:31,579] INFO: Computing for LV169
# [2022-11-14 22:11:31,717] INFO: Computing for LV170
# [2022-11-14 22:11:31,854] INFO: Computing for LV171
# [2022-11-14 22:11:31,992] INFO: Computing for LV172
# [2022-11-14 22:11:32,148] INFO: Computing for LV173
# [2022-11-14 22:11:32,286] INFO: Computing for LV174
# [2022-11-14 22:11:32,422] INFO: Computing for LV175
# [2022-11-14 22:11:32,561] INFO: Computing for LV176
# [2022-11-14 22:11:32,698] INFO: Computing for LV177
# [2022-11-14 22:11:32,833] INFO: Computing for LV178
# [2022-11-14 22:11:32,984] INFO: Computing for LV179
# [2022-11-14 22:11:33,138] INFO: Computing for LV180
# [2022-11-14 22:11:33,274] INFO: Computing for LV181
# [2022-11-14 22:11:33,411] INFO: Computing for LV182
# [2022-11-14 22:11:33,548] INFO: Computing for LV183
# [2022-11-14 22:11:33,684] INFO: Computing for LV184
# [2022-11-14 22:11:33,822] INFO: Computing for LV185
# [2022-11-14 22:11:33,958] INFO: Computing for LV186
# [2022-11-14 22:11:34,141] INFO: Computing for LV187
# [2022-11-14 22:11:34,298] INFO: Computing for LV188
# [2022-11-14 22:11:34,435] INFO: Computing for LV189
# [2022-11-14 22:11:34,571] INFO: Computing for LV190
# [2022-11-14 22:11:34,708] INFO: Computing for LV191
# [2022-11-14 22:11:34,851] INFO: Computing for LV192
# [2022-11-14 22:11:34,987] INFO: Computing for LV193
# [2022-11-14 22:11:35,157] INFO: Computing for LV194
# [2022-11-14 22:11:35,295] INFO: Computing for LV195
# [2022-11-14 22:11:35,429] INFO: Computing for LV196
# [2022-11-14 22:11:35,563] INFO: Computing for LV197
# [2022-11-14 22:11:35,697] INFO: Computing for LV198
# [2022-11-14 22:11:35,831] INFO: Computing for LV199
# [2022-11-14 22:11:35,965] INFO: Computing for LV200
# [2022-11-14 22:11:36,122] INFO: Computing for LV201
# [2022-11-14 22:11:36,259] INFO: Computing for LV202
# [2022-11-14 22:11:36,406] INFO: Computing for LV203
# [2022-11-14 22:11:36,542] INFO: Computing for LV204
# [2022-11-14 22:11:36,678] INFO: Computing for LV205
# [2022-11-14 22:11:36,815] INFO: Computing for LV206
# [2022-11-14 22:11:36,950] INFO: Computing for LV207
# [2022-11-14 22:11:37,097] INFO: Computing for LV208
# [2022-11-14 22:11:37,235] INFO: Computing for LV209
# [2022-11-14 22:11:37,373] INFO: Computing for LV210
# [2022-11-14 22:11:37,509] INFO: Computing for LV211
# [2022-11-14 22:11:37,646] INFO: Computing for LV212
# [2022-11-14 22:11:37,783] INFO: Computing for LV213
# [2022-11-14 22:11:37,919] INFO: Computing for LV214
# [2022-11-14 22:11:38,056] INFO: Computing for LV215
# [2022-11-14 22:11:38,222] INFO: Computing for LV216
# [2022-11-14 22:11:38,358] INFO: Computing for LV217
# [2022-11-14 22:11:38,494] INFO: Computing for LV218
# [2022-11-14 22:11:38,630] INFO: Computing for LV219
# [2022-11-14 22:11:38,766] INFO: Computing for LV220
# [2022-11-14 22:11:38,903] INFO: Computing for LV221
# [2022-11-14 22:11:39,040] INFO: Computing for LV222
# [2022-11-14 22:11:39,185] INFO: Computing for LV223
# [2022-11-14 22:11:39,321] INFO: Computing for LV224
# [2022-11-14 22:11:39,457] INFO: Computing for LV225
# [2022-11-14 22:11:39,593] INFO: Computing for LV226
# [2022-11-14 22:11:39,730] INFO: Computing for LV227
# [2022-11-14 22:11:39,867] INFO: Computing for LV228
# [2022-11-14 22:11:40,003] INFO: Computing for LV229
# [2022-11-14 22:11:40,162] INFO: Computing for LV230
# [2022-11-14 22:11:40,299] INFO: Computing for LV231
# [2022-11-14 22:11:40,438] INFO: Computing for LV232
# [2022-11-14 22:11:40,574] INFO: Computing for LV233
# [2022-11-14 22:11:40,710] INFO: Computing for LV234
# [2022-11-14 22:11:40,846] INFO: Computing for LV235
# [2022-11-14 22:11:40,983] INFO: Computing for LV236
# [2022-11-14 22:11:41,135] INFO: Computing for LV237
# [2022-11-14 22:11:41,272] INFO: Computing for LV238
# [2022-11-14 22:11:41,409] INFO: Computing for LV239
# [2022-11-14 22:11:41,546] INFO: Computing for LV240
# [2022-11-14 22:11:41,682] INFO: Computing for LV241
# [2022-11-14 22:11:41,817] INFO: Computing for LV242
# [2022-11-14 22:11:41,954] INFO: Computing for LV243
# [2022-11-14 22:11:42,117] INFO: Computing for LV244
# [2022-11-14 22:11:42,255] INFO: Computing for LV245
# [2022-11-14 22:11:42,392] INFO: Computing for LV246
# [2022-11-14 22:11:42,529] INFO: Computing for LV247
# [2022-11-14 22:11:42,665] INFO: Computing for LV248
# [2022-11-14 22:11:42,801] INFO: Computing for LV249
# [2022-11-14 22:11:42,937] INFO: Computing for LV250
# [2022-11-14 22:11:43,076] INFO: Computing for LV251
# [2022-11-14 22:11:43,222] INFO: Computing for LV252
# [2022-11-14 22:11:43,359] INFO: Computing for LV253
# [2022-11-14 22:11:43,495] INFO: Computing for LV254
# [2022-11-14 22:11:43,631] INFO: Computing for LV255
# [2022-11-14 22:11:43,767] INFO: Computing for LV256
# [2022-11-14 22:11:43,903] INFO: Computing for LV257
# [2022-11-14 22:11:44,039] INFO: Computing for LV258
# [2022-11-14 22:11:44,200] INFO: Computing for LV259
# [2022-11-14 22:11:44,336] INFO: Computing for LV260
# [2022-11-14 22:11:44,473] INFO: Computing for LV261
# [2022-11-14 22:11:44,609] INFO: Computing for LV262
# [2022-11-14 22:11:44,745] INFO: Computing for LV263
# [2022-11-14 22:11:44,881] INFO: Computing for LV264
# [2022-11-14 22:11:45,017] INFO: Computing for LV265
# [2022-11-14 22:11:45,177] INFO: Computing for LV266
# [2022-11-14 22:11:45,315] INFO: Computing for LV267
# [2022-11-14 22:11:45,452] INFO: Computing for LV268
# [2022-11-14 22:11:45,592] INFO: Computing for LV269
# [2022-11-14 22:11:45,728] INFO: Computing for LV270
# [2022-11-14 22:11:45,865] INFO: Computing for LV271
# [2022-11-14 22:11:46,001] INFO: Computing for LV272
# [2022-11-14 22:11:46,155] INFO: Computing for LV273
# [2022-11-14 22:11:46,293] INFO: Computing for LV274
# [2022-11-14 22:11:46,430] INFO: Computing for LV275
# [2022-11-14 22:11:46,566] INFO: Computing for LV276
# [2022-11-14 22:11:46,702] INFO: Computing for LV277
# [2022-11-14 22:11:46,839] INFO: Computing for LV278
# [2022-11-14 22:11:46,977] INFO: Computing for LV279
# [2022-11-14 22:11:47,113] INFO: Computing for LV280
# [2022-11-14 22:11:47,262] INFO: Computing for LV281
# [2022-11-14 22:11:47,398] INFO: Computing for LV282
# [2022-11-14 22:11:47,535] INFO: Computing for LV283
# [2022-11-14 22:11:47,672] INFO: Computing for LV284
# [2022-11-14 22:11:47,808] INFO: Computing for LV285
# [2022-11-14 22:11:47,944] INFO: Computing for LV286
# [2022-11-14 22:11:48,080] INFO: Computing for LV287
# [2022-11-14 22:11:48,225] INFO: Computing for LV288
# [2022-11-14 22:11:48,362] INFO: Computing for LV289
# [2022-11-14 22:11:48,498] INFO: Computing for LV290
# [2022-11-14 22:11:48,634] INFO: Computing for LV291
# [2022-11-14 22:11:48,770] INFO: Computing for LV292
# [2022-11-14 22:11:48,906] INFO: Computing for LV293
# [2022-11-14 22:11:49,043] INFO: Computing for LV294
# [2022-11-14 22:11:49,199] INFO: Computing for LV295
# [2022-11-14 22:11:49,336] INFO: Computing for LV296
# [2022-11-14 22:11:49,473] INFO: Computing for LV297
# [2022-11-14 22:11:49,609] INFO: Computing for LV298
# [2022-11-14 22:11:49,746] INFO: Computing for LV299
# [2022-11-14 22:11:49,882] INFO: Computing for LV300
# [2022-11-14 22:11:50,018] INFO: Computing for LV301
# [2022-11-14 22:11:50,193] INFO: Computing for LV302
# [2022-11-14 22:11:50,329] INFO: Computing for LV303
# [2022-11-14 22:11:50,466] INFO: Computing for LV304
# [2022-11-14 22:11:50,602] INFO: Computing for LV305
# [2022-11-14 22:11:50,738] INFO: Computing for LV306
# [2022-11-14 22:11:50,873] INFO: Computing for LV307
# [2022-11-14 22:11:51,010] INFO: Computing for LV308
# [2022-11-14 22:11:51,167] INFO: Computing for LV309
# [2022-11-14 22:11:51,306] INFO: Computing for LV310
# [2022-11-14 22:11:51,444] INFO: Computing for LV311
# [2022-11-14 22:11:51,580] INFO: Computing for LV312
# [2022-11-14 22:11:51,716] INFO: Computing for LV313
# [2022-11-14 22:11:51,852] INFO: Computing for LV314
# [2022-11-14 22:11:51,988] INFO: Computing for LV315
# [2022-11-14 22:11:52,124] INFO: Computing for LV316
# [2022-11-14 22:11:52,269] INFO: Computing for LV317
# [2022-11-14 22:11:52,407] INFO: Computing for LV318
# [2022-11-14 22:11:52,543] INFO: Computing for LV319
# [2022-11-14 22:11:52,679] INFO: Computing for LV320
# [2022-11-14 22:11:52,815] INFO: Computing for LV321
# [2022-11-14 22:11:52,951] INFO: Computing for LV322
# [2022-11-14 22:11:53,088] INFO: Computing for LV323
# [2022-11-14 22:11:53,244] INFO: Computing for LV324
# [2022-11-14 22:11:53,380] INFO: Computing for LV325
# [2022-11-14 22:11:53,518] INFO: Computing for LV326
# [2022-11-14 22:11:53,654] INFO: Computing for LV327
# [2022-11-14 22:11:53,790] INFO: Computing for LV328
# [2022-11-14 22:11:53,929] INFO: Computing for LV329
# [2022-11-14 22:11:54,066] INFO: Computing for LV330
# [2022-11-14 22:11:54,227] INFO: Computing for LV331
# [2022-11-14 22:11:54,363] INFO: Computing for LV332
# [2022-11-14 22:11:54,499] INFO: Computing for LV333
# [2022-11-14 22:11:54,635] INFO: Computing for LV334
# [2022-11-14 22:11:54,773] INFO: Computing for LV335
# [2022-11-14 22:11:54,909] INFO: Computing for LV336
# [2022-11-14 22:11:55,047] INFO: Computing for LV337
# [2022-11-14 22:11:55,202] INFO: Computing for LV338
# [2022-11-14 22:11:55,339] INFO: Computing for LV339
# [2022-11-14 22:11:55,478] INFO: Computing for LV340
# [2022-11-14 22:11:55,616] INFO: Computing for LV341
# [2022-11-14 22:11:55,752] INFO: Computing for LV342
# [2022-11-14 22:11:55,888] INFO: Computing for LV343
# [2022-11-14 22:11:56,025] INFO: Computing for LV344
# [2022-11-14 22:11:56,161] INFO: Computing for LV345
# [2022-11-14 22:11:56,318] INFO: Computing for LV346
# [2022-11-14 22:11:56,455] INFO: Computing for LV347
# [2022-11-14 22:11:56,592] INFO: Computing for LV348
# [2022-11-14 22:11:56,729] INFO: Computing for LV349
# [2022-11-14 22:11:56,865] INFO: Computing for LV350
# [2022-11-14 22:11:57,001] INFO: Computing for LV351
# [2022-11-14 22:11:57,154] INFO: Computing for LV352
# [2022-11-14 22:11:57,296] INFO: Computing for LV353
# [2022-11-14 22:11:57,433] INFO: Computing for LV354
# [2022-11-14 22:11:57,570] INFO: Computing for LV355
# [2022-11-14 22:11:57,708] INFO: Computing for LV356
# [2022-11-14 22:11:57,845] INFO: Computing for LV357
# [2022-11-14 22:11:57,982] INFO: Computing for LV358
# [2022-11-14 22:11:58,118] INFO: Computing for LV359
# [2022-11-14 22:11:58,280] INFO: Computing for LV360
# [2022-11-14 22:11:58,417] INFO: Computing for LV361
# [2022-11-14 22:11:58,555] INFO: Computing for LV362
# [2022-11-14 22:11:58,692] INFO: Computing for LV363
# [2022-11-14 22:11:58,828] INFO: Computing for LV364
# [2022-11-14 22:11:58,964] INFO: Computing for LV365
# [2022-11-14 22:11:59,102] INFO: Computing for LV366
# [2022-11-14 22:11:59,262] INFO: Computing for LV367
# [2022-11-14 22:11:59,399] INFO: Computing for LV368
# [2022-11-14 22:11:59,535] INFO: Computing for LV369
# [2022-11-14 22:11:59,671] INFO: Computing for LV370
# [2022-11-14 22:11:59,809] INFO: Computing for LV371
# [2022-11-14 22:11:59,945] INFO: Computing for LV372
# [2022-11-14 22:12:00,082] INFO: Computing for LV373
# [2022-11-14 22:12:00,239] INFO: Computing for LV374
# [2022-11-14 22:12:00,380] INFO: Computing for LV375
# [2022-11-14 22:12:00,518] INFO: Computing for LV376
# [2022-11-14 22:12:00,655] INFO: Computing for LV377
# [2022-11-14 22:12:00,794] INFO: Computing for LV378
# [2022-11-14 22:12:00,931] INFO: Computing for LV379
# [2022-11-14 22:12:01,067] INFO: Computing for LV380
# [2022-11-14 22:12:01,222] INFO: Computing for LV381
# [2022-11-14 22:12:01,364] INFO: Computing for LV382
# [2022-11-14 22:12:01,501] INFO: Computing for LV383
# [2022-11-14 22:12:01,639] INFO: Computing for LV384
# [2022-11-14 22:12:01,775] INFO: Computing for LV385
# [2022-11-14 22:12:01,912] INFO: Computing for LV386
# [2022-11-14 22:12:02,049] INFO: Computing for LV387
# [2022-11-14 22:12:02,227] INFO: Computing for LV388
# [2022-11-14 22:12:02,364] INFO: Computing for LV389
# [2022-11-14 22:12:02,500] INFO: Computing for LV390
# [2022-11-14 22:12:02,636] INFO: Computing for LV391
# [2022-11-14 22:12:02,773] INFO: Computing for LV392
# [2022-11-14 22:12:02,910] INFO: Computing for LV393
# [2022-11-14 22:12:03,046] INFO: Computing for LV394
# [2022-11-14 22:12:03,182] INFO: Computing for LV395
# [2022-11-14 22:12:03,326] INFO: Computing for LV396
# [2022-11-14 22:12:03,462] INFO: Computing for LV397
# [2022-11-14 22:12:03,599] INFO: Computing for LV398
# [2022-11-14 22:12:03,735] INFO: Computing for LV399
# [2022-11-14 22:12:03,872] INFO: Computing for LV400
# [2022-11-14 22:12:04,008] INFO: Computing for LV401
# [2022-11-14 22:12:04,145] INFO: Computing for LV402
# [2022-11-14 22:12:04,304] INFO: Computing for LV403
# [2022-11-14 22:12:04,440] INFO: Computing for LV404
# [2022-11-14 22:12:04,577] INFO: Computing for LV405
# [2022-11-14 22:12:04,713] INFO: Computing for LV406
# [2022-11-14 22:12:04,849] INFO: Computing for LV407
# [2022-11-14 22:12:04,985] INFO: Computing for LV408
# [2022-11-14 22:12:05,121] INFO: Computing for LV409
# [2022-11-14 22:12:05,296] INFO: Computing for LV410
# [2022-11-14 22:12:05,432] INFO: Computing for LV411
# [2022-11-14 22:12:05,569] INFO: Computing for LV412
# [2022-11-14 22:12:05,705] INFO: Computing for LV413
# [2022-11-14 22:12:05,842] INFO: Computing for LV414
# [2022-11-14 22:12:05,980] INFO: Computing for LV415
# [2022-11-14 22:12:06,116] INFO: Computing for LV416
# [2022-11-14 22:12:06,278] INFO: Computing for LV417
# [2022-11-14 22:12:06,415] INFO: Computing for LV418
# [2022-11-14 22:12:06,552] INFO: Computing for LV419
# [2022-11-14 22:12:06,689] INFO: Computing for LV420
# [2022-11-14 22:12:06,828] INFO: Computing for LV421
# [2022-11-14 22:12:06,966] INFO: Computing for LV422
# [2022-11-14 22:12:07,106] INFO: Computing for LV423
# [2022-11-14 22:12:07,259] INFO: Computing for LV424
# [2022-11-14 22:12:07,399] INFO: Computing for LV425
# [2022-11-14 22:12:07,537] INFO: Computing for LV426
# [2022-11-14 22:12:07,678] INFO: Computing for LV427
# [2022-11-14 22:12:07,816] INFO: Computing for LV428
# [2022-11-14 22:12:07,955] INFO: Computing for LV429
# [2022-11-14 22:12:08,093] INFO: Computing for LV430
# [2022-11-14 22:12:08,242] INFO: Computing for LV431
# [2022-11-14 22:12:08,395] INFO: Computing for LV432
# [2022-11-14 22:12:08,534] INFO: Computing for LV433
# [2022-11-14 22:12:08,672] INFO: Computing for LV434
# [2022-11-14 22:12:08,811] INFO: Computing for LV435
# [2022-11-14 22:12:08,950] INFO: Computing for LV436
# [2022-11-14 22:12:09,088] INFO: Computing for LV437
# [2022-11-14 22:12:09,226] INFO: Computing for LV438
# [2022-11-14 22:12:09,373] INFO: Computing for LV439
# [2022-11-14 22:12:09,510] INFO: Computing for LV440
# [2022-11-14 22:12:09,647] INFO: Computing for LV441
# [2022-11-14 22:12:09,784] INFO: Computing for LV442
# [2022-11-14 22:12:09,922] INFO: Computing for LV443
# [2022-11-14 22:12:10,059] INFO: Computing for LV444
# [2022-11-14 22:12:10,195] INFO: Computing for LV445
# [2022-11-14 22:12:10,343] INFO: Computing for LV446
# [2022-11-14 22:12:10,480] INFO: Computing for LV447
# [2022-11-14 22:12:10,616] INFO: Computing for LV448
# [2022-11-14 22:12:10,753] INFO: Computing for LV449
# [2022-11-14 22:12:10,890] INFO: Computing for LV450
# [2022-11-14 22:12:11,028] INFO: Computing for LV451
# [2022-11-14 22:12:11,165] INFO: Computing for LV452
# [2022-11-14 22:12:11,322] INFO: Computing for LV453
# [2022-11-14 22:12:11,459] INFO: Computing for LV454
# [2022-11-14 22:12:11,595] INFO: Computing for LV455
# [2022-11-14 22:12:11,732] INFO: Computing for LV456
# [2022-11-14 22:12:11,869] INFO: Computing for LV457
# [2022-11-14 22:12:12,006] INFO: Computing for LV458
# [2022-11-14 22:12:12,143] INFO: Computing for LV459
# [2022-11-14 22:12:12,305] INFO: Computing for LV460
# [2022-11-14 22:12:12,446] INFO: Computing for LV461
# [2022-11-14 22:12:12,583] INFO: Computing for LV462
# [2022-11-14 22:12:12,721] INFO: Computing for LV463
# [2022-11-14 22:12:12,859] INFO: Computing for LV464
# [2022-11-14 22:12:12,996] INFO: Computing for LV465
# [2022-11-14 22:12:13,134] INFO: Computing for LV466
# [2022-11-14 22:12:13,310] INFO: Computing for LV467
# [2022-11-14 22:12:13,448] INFO: Computing for LV468
# [2022-11-14 22:12:13,584] INFO: Computing for LV469
# [2022-11-14 22:12:13,722] INFO: Computing for LV470
# [2022-11-14 22:12:13,859] INFO: Computing for LV471
# [2022-11-14 22:12:13,997] INFO: Computing for LV472
# [2022-11-14 22:12:14,134] INFO: Computing for LV473
# [2022-11-14 22:12:14,286] INFO: Computing for LV474
# [2022-11-14 22:12:14,428] INFO: Computing for LV475
# [2022-11-14 22:12:14,565] INFO: Computing for LV476
# [2022-11-14 22:12:14,702] INFO: Computing for LV477
# [2022-11-14 22:12:14,840] INFO: Computing for LV478
# [2022-11-14 22:12:14,977] INFO: Computing for LV479
# [2022-11-14 22:12:15,114] INFO: Computing for LV480
# [2022-11-14 22:12:15,251] INFO: Computing for LV481
# [2022-11-14 22:12:15,426] INFO: Computing for LV482
# [2022-11-14 22:12:15,562] INFO: Computing for LV483
# [2022-11-14 22:12:15,699] INFO: Computing for LV484
# [2022-11-14 22:12:15,834] INFO: Computing for LV485
# [2022-11-14 22:12:15,971] INFO: Computing for LV486
# [2022-11-14 22:12:16,107] INFO: Computing for LV487
# [2022-11-14 22:12:16,243] INFO: Computing for LV488
# [2022-11-14 22:12:16,386] INFO: Computing for LV489
# [2022-11-14 22:12:16,522] INFO: Computing for LV490
# [2022-11-14 22:12:16,658] INFO: Computing for LV491
# [2022-11-14 22:12:16,796] INFO: Computing for LV492
# [2022-11-14 22:12:16,933] INFO: Computing for LV493
# [2022-11-14 22:12:17,072] INFO: Computing for LV494
# [2022-11-14 22:12:17,213] INFO: Computing for LV495
# [2022-11-14 22:12:17,365] INFO: Computing for LV496
# [2022-11-14 22:12:17,501] INFO: Computing for LV497
# [2022-11-14 22:12:17,638] INFO: Computing for LV498
# [2022-11-14 22:12:17,774] INFO: Computing for LV499
# [2022-11-14 22:12:17,911] INFO: Computing for LV500
# [2022-11-14 22:12:18,047] INFO: Computing for LV501
# [2022-11-14 22:12:18,185] INFO: Computing for LV502
# [2022-11-14 22:12:18,346] INFO: Computing for LV503
# [2022-11-14 22:12:18,483] INFO: Computing for LV504
# [2022-11-14 22:12:18,619] INFO: Computing for LV505
# [2022-11-14 22:12:18,756] INFO: Computing for LV506
# [2022-11-14 22:12:18,892] INFO: Computing for LV507
# [2022-11-14 22:12:19,029] INFO: Computing for LV508
# [2022-11-14 22:12:19,168] INFO: Computing for LV509
# [2022-11-14 22:12:19,331] INFO: Computing for LV510
# [2022-11-14 22:12:19,468] INFO: Computing for LV511
# [2022-11-14 22:12:19,604] INFO: Computing for LV512
# [2022-11-14 22:12:19,740] INFO: Computing for LV513
# [2022-11-14 22:12:19,884] INFO: Computing for LV514
# [2022-11-14 22:12:20,020] INFO: Computing for LV515
# [2022-11-14 22:12:20,159] INFO: Computing for LV516
# [2022-11-14 22:12:20,315] INFO: Computing for LV517
# [2022-11-14 22:12:20,459] INFO: Computing for LV518
# [2022-11-14 22:12:20,598] INFO: Computing for LV519
# [2022-11-14 22:12:20,736] INFO: Computing for LV520
# [2022-11-14 22:12:20,874] INFO: Computing for LV521
# [2022-11-14 22:12:21,013] INFO: Computing for LV522
# [2022-11-14 22:12:21,151] INFO: Computing for LV523
# [2022-11-14 22:12:21,302] INFO: Computing for LV524
# [2022-11-14 22:12:21,453] INFO: Computing for LV525
# [2022-11-14 22:12:21,592] INFO: Computing for LV526
# [2022-11-14 22:12:21,729] INFO: Computing for LV527
# [2022-11-14 22:12:21,867] INFO: Computing for LV528
# [2022-11-14 22:12:22,004] INFO: Computing for LV529
# [2022-11-14 22:12:22,141] INFO: Computing for LV530
# [2022-11-14 22:12:22,278] INFO: Computing for LV531
# [2022-11-14 22:12:22,445] INFO: Computing for LV532
# [2022-11-14 22:12:22,582] INFO: Computing for LV533
# [2022-11-14 22:12:22,719] INFO: Computing for LV534
# [2022-11-14 22:12:22,856] INFO: Computing for LV535
# [2022-11-14 22:12:22,992] INFO: Computing for LV536
# [2022-11-14 22:12:23,130] INFO: Computing for LV537
# [2022-11-14 22:12:23,267] INFO: Computing for LV538
# [2022-11-14 22:12:23,413] INFO: Computing for LV539
# [2022-11-14 22:12:23,551] INFO: Computing for LV540
# [2022-11-14 22:12:23,690] INFO: Computing for LV541
# [2022-11-14 22:12:23,826] INFO: Computing for LV542
# [2022-11-14 22:12:23,963] INFO: Computing for LV543
# [2022-11-14 22:12:24,100] INFO: Computing for LV544
# [2022-11-14 22:12:24,238] INFO: Computing for LV545
# [2022-11-14 22:12:24,390] INFO: Computing for LV546
# [2022-11-14 22:12:24,526] INFO: Computing for LV547
# [2022-11-14 22:12:24,664] INFO: Computing for LV548
# [2022-11-14 22:12:24,804] INFO: Computing for LV549
# [2022-11-14 22:12:24,941] INFO: Computing for LV550
# [2022-11-14 22:12:25,078] INFO: Computing for LV551
# [2022-11-14 22:12:25,215] INFO: Computing for LV552
# [2022-11-14 22:12:25,373] INFO: Computing for LV553
# [2022-11-14 22:12:25,510] INFO: Computing for LV554
# [2022-11-14 22:12:25,646] INFO: Computing for LV555
# [2022-11-14 22:12:25,784] INFO: Computing for LV556
# [2022-11-14 22:12:25,921] INFO: Computing for LV557
# [2022-11-14 22:12:26,060] INFO: Computing for LV558
# [2022-11-14 22:12:26,196] INFO: Computing for LV559
# [2022-11-14 22:12:26,347] INFO: Computing for LV560
# [2022-11-14 22:12:26,489] INFO: Computing for LV561
# [2022-11-14 22:12:26,627] INFO: Computing for LV562
# [2022-11-14 22:12:26,764] INFO: Computing for LV563
# [2022-11-14 22:12:26,903] INFO: Computing for LV564
# [2022-11-14 22:12:27,041] INFO: Computing for LV565
# [2022-11-14 22:12:27,180] INFO: Computing for LV566
# [2022-11-14 22:12:27,334] INFO: Computing for LV567
# [2022-11-14 22:12:27,471] INFO: Computing for LV568
# [2022-11-14 22:12:27,608] INFO: Computing for LV569
# [2022-11-14 22:12:27,745] INFO: Computing for LV570
# [2022-11-14 22:12:27,883] INFO: Computing for LV571
# [2022-11-14 22:12:28,020] INFO: Computing for LV572
# [2022-11-14 22:12:28,157] INFO: Computing for LV573
# [2022-11-14 22:12:28,294] INFO: Computing for LV574
# [2022-11-14 22:12:28,443] INFO: Computing for LV575
# [2022-11-14 22:12:28,581] INFO: Computing for LV576
# [2022-11-14 22:12:28,717] INFO: Computing for LV577
# [2022-11-14 22:12:28,855] INFO: Computing for LV578
# [2022-11-14 22:12:28,992] INFO: Computing for LV579
# [2022-11-14 22:12:29,129] INFO: Computing for LV580
# [2022-11-14 22:12:29,268] INFO: Computing for LV581
# [2022-11-14 22:12:29,428] INFO: Computing for LV582
# [2022-11-14 22:12:29,566] INFO: Computing for LV583
# [2022-11-14 22:12:29,711] INFO: Computing for LV584
# [2022-11-14 22:12:29,849] INFO: Computing for LV585
# [2022-11-14 22:12:29,988] INFO: Computing for LV586
# [2022-11-14 22:12:30,125] INFO: Computing for LV587
# [2022-11-14 22:12:30,264] INFO: Computing for LV588
# [2022-11-14 22:12:30,421] INFO: Computing for LV589
# [2022-11-14 22:12:30,559] INFO: Computing for LV590
# [2022-11-14 22:12:30,698] INFO: Computing for LV591
# [2022-11-14 22:12:30,836] INFO: Computing for LV592
# [2022-11-14 22:12:30,974] INFO: Computing for LV593
# [2022-11-14 22:12:31,110] INFO: Computing for LV594
# [2022-11-14 22:12:31,249] INFO: Computing for LV595
# [2022-11-14 22:12:31,408] INFO: Computing for LV596
# [2022-11-14 22:12:31,559] INFO: Computing for LV597
# [2022-11-14 22:12:31,696] INFO: Computing for LV598
# [2022-11-14 22:12:31,834] INFO: Computing for LV599
# [2022-11-14 22:12:31,975] INFO: Computing for LV600
# [2022-11-14 22:12:32,113] INFO: Computing for LV601
# [2022-11-14 22:12:32,249] INFO: Computing for LV602
# [2022-11-14 22:12:32,407] INFO: Computing for LV603
# [2022-11-14 22:12:32,544] INFO: Computing for LV604
# [2022-11-14 22:12:32,681] INFO: Computing for LV605
# [2022-11-14 22:12:32,818] INFO: Computing for LV606
# [2022-11-14 22:12:32,955] INFO: Computing for LV607
# [2022-11-14 22:12:33,092] INFO: Computing for LV608
# [2022-11-14 22:12:33,228] INFO: Computing for LV609
# [2022-11-14 22:12:33,379] INFO: Computing for LV610
# [2022-11-14 22:12:33,518] INFO: Computing for LV611
# [2022-11-14 22:12:33,656] INFO: Computing for LV612
# [2022-11-14 22:12:33,793] INFO: Computing for LV613
# [2022-11-14 22:12:33,930] INFO: Computing for LV614
# [2022-11-14 22:12:34,067] INFO: Computing for LV615
# [2022-11-14 22:12:34,205] INFO: Computing for LV616
# [2022-11-14 22:12:34,358] INFO: Computing for LV617
# [2022-11-14 22:12:34,505] INFO: Computing for LV618
# [2022-11-14 22:12:34,643] INFO: Computing for LV619
# [2022-11-14 22:12:34,779] INFO: Computing for LV620
# [2022-11-14 22:12:34,916] INFO: Computing for LV621
# [2022-11-14 22:12:35,054] INFO: Computing for LV622
# [2022-11-14 22:12:35,193] INFO: Computing for LV623
# [2022-11-14 22:12:35,330] INFO: Computing for LV624
# [2022-11-14 22:12:35,478] INFO: Computing for LV625
# [2022-11-14 22:12:35,614] INFO: Computing for LV626
# [2022-11-14 22:12:35,750] INFO: Computing for LV627
# [2022-11-14 22:12:35,887] INFO: Computing for LV628
# [2022-11-14 22:12:36,025] INFO: Computing for LV629
# [2022-11-14 22:12:36,162] INFO: Computing for LV630
# [2022-11-14 22:12:36,300] INFO: Computing for LV631
# [2022-11-14 22:12:36,446] INFO: Computing for LV632
# [2022-11-14 22:12:36,584] INFO: Computing for LV633
# [2022-11-14 22:12:36,721] INFO: Computing for LV634
# [2022-11-14 22:12:36,858] INFO: Computing for LV635
# [2022-11-14 22:12:36,996] INFO: Computing for LV636
# [2022-11-14 22:12:37,135] INFO: Computing for LV637
# [2022-11-14 22:12:37,272] INFO: Computing for LV638
# [2022-11-14 22:12:37,435] INFO: Computing for LV639
# [2022-11-14 22:12:37,574] INFO: Computing for LV640
# [2022-11-14 22:12:37,712] INFO: Computing for LV641
# [2022-11-14 22:12:37,849] INFO: Computing for LV642
# [2022-11-14 22:12:37,986] INFO: Computing for LV643
# [2022-11-14 22:12:38,124] INFO: Computing for LV644
# [2022-11-14 22:12:38,272] INFO: Computing for LV645
# [2022-11-14 22:12:38,431] INFO: Computing for LV646
# [2022-11-14 22:12:38,579] INFO: Computing for LV647
# [2022-11-14 22:12:38,716] INFO: Computing for LV648
# [2022-11-14 22:12:38,854] INFO: Computing for LV649
# [2022-11-14 22:12:38,991] INFO: Computing for LV650
# [2022-11-14 22:12:39,128] INFO: Computing for LV651
# [2022-11-14 22:12:39,265] INFO: Computing for LV652
# [2022-11-14 22:12:39,434] INFO: Computing for LV653
# [2022-11-14 22:12:39,587] INFO: Computing for LV654
# [2022-11-14 22:12:39,726] INFO: Computing for LV655
# [2022-11-14 22:12:39,864] INFO: Computing for LV656
# [2022-11-14 22:12:40,000] INFO: Computing for LV657
# [2022-11-14 22:12:40,137] INFO: Computing for LV658
# [2022-11-14 22:12:40,274] INFO: Computing for LV659
# [2022-11-14 22:12:40,436] INFO: Computing for LV660
# [2022-11-14 22:12:40,575] INFO: Computing for LV661
# [2022-11-14 22:12:40,712] INFO: Computing for LV662
# [2022-11-14 22:12:40,849] INFO: Computing for LV663
# [2022-11-14 22:12:40,987] INFO: Computing for LV664
# [2022-11-14 22:12:41,124] INFO: Computing for LV665
# [2022-11-14 22:12:41,261] INFO: Computing for LV666
# [2022-11-14 22:12:41,418] INFO: Computing for LV667
# [2022-11-14 22:12:41,555] INFO: Computing for LV668
# [2022-11-14 22:12:41,693] INFO: Computing for LV669
# [2022-11-14 22:12:41,829] INFO: Computing for LV670
# [2022-11-14 22:12:41,967] INFO: Computing for LV671
# [2022-11-14 22:12:42,104] INFO: Computing for LV672
# [2022-11-14 22:12:42,241] INFO: Computing for LV673
# [2022-11-14 22:12:42,386] INFO: Computing for LV674
# [2022-11-14 22:12:42,539] INFO: Computing for LV675
# [2022-11-14 22:12:42,677] INFO: Computing for LV676
# [2022-11-14 22:12:42,815] INFO: Computing for LV677
# [2022-11-14 22:12:42,953] INFO: Computing for LV678
# [2022-11-14 22:12:43,090] INFO: Computing for LV679
# [2022-11-14 22:12:43,227] INFO: Computing for LV680
# [2022-11-14 22:12:43,364] INFO: Computing for LV681
# [2022-11-14 22:12:43,510] INFO: Computing for LV682
# [2022-11-14 22:12:43,647] INFO: Computing for LV683
# [2022-11-14 22:12:43,784] INFO: Computing for LV684
# [2022-11-14 22:12:43,921] INFO: Computing for LV685
# [2022-11-14 22:12:44,060] INFO: Computing for LV686
# [2022-11-14 22:12:44,197] INFO: Computing for LV687
# [2022-11-14 22:12:44,335] INFO: Computing for LV688
# [2022-11-14 22:12:44,481] INFO: Computing for LV689
# [2022-11-14 22:12:44,618] INFO: Computing for LV690
# [2022-11-14 22:12:44,756] INFO: Computing for LV691
# [2022-11-14 22:12:44,893] INFO: Computing for LV692
# [2022-11-14 22:12:45,030] INFO: Computing for LV693
# [2022-11-14 22:12:45,167] INFO: Computing for LV694
# [2022-11-14 22:12:45,305] INFO: Computing for LV695
# [2022-11-14 22:12:45,466] INFO: Computing for LV696
# [2022-11-14 22:12:45,615] INFO: Computing for LV697
# [2022-11-14 22:12:45,753] INFO: Computing for LV698
# [2022-11-14 22:12:45,891] INFO: Computing for LV699
# [2022-11-14 22:12:46,028] INFO: Computing for LV700
# [2022-11-14 22:12:46,165] INFO: Computing for LV701
# [2022-11-14 22:12:46,303] INFO: Computing for LV702
# [2022-11-14 22:12:46,466] INFO: Computing for LV703
# [2022-11-14 22:12:46,616] INFO: Computing for LV704
# [2022-11-14 22:12:46,754] INFO: Computing for LV705
# [2022-11-14 22:12:46,892] INFO: Computing for LV706
# [2022-11-14 22:12:47,029] INFO: Computing for LV707
# [2022-11-14 22:12:47,166] INFO: Computing for LV708
# [2022-11-14 22:12:47,304] INFO: Computing for LV709
# [2022-11-14 22:12:47,466] INFO: Computing for LV710
# [2022-11-14 22:12:47,603] INFO: Computing for LV711
# [2022-11-14 22:12:47,741] INFO: Computing for LV712
# [2022-11-14 22:12:47,878] INFO: Computing for LV713
# [2022-11-14 22:12:48,014] INFO: Computing for LV714
# [2022-11-14 22:12:48,151] INFO: Computing for LV715
# [2022-11-14 22:12:48,288] INFO: Computing for LV716
# [2022-11-14 22:12:48,439] INFO: Computing for LV717
# [2022-11-14 22:12:48,577] INFO: Computing for LV718
# [2022-11-14 22:12:48,716] INFO: Computing for LV719
# [2022-11-14 22:12:48,853] INFO: Computing for LV720
# [2022-11-14 22:12:48,992] INFO: Computing for LV721
# [2022-11-14 22:12:49,130] INFO: Computing for LV722
# [2022-11-14 22:12:49,268] INFO: Computing for LV723
# [2022-11-14 22:12:49,408] INFO: Computing for LV724
# [2022-11-14 22:12:49,559] INFO: Computing for LV725
# [2022-11-14 22:12:49,696] INFO: Computing for LV726
# [2022-11-14 22:12:49,833] INFO: Computing for LV727
# [2022-11-14 22:12:49,971] INFO: Computing for LV728
# [2022-11-14 22:12:50,108] INFO: Computing for LV729
# [2022-11-14 22:12:50,245] INFO: Computing for LV730
# [2022-11-14 22:12:50,383] INFO: Computing for LV731
# [2022-11-14 22:12:50,528] INFO: Computing for LV732
# [2022-11-14 22:12:50,666] INFO: Computing for LV733
# [2022-11-14 22:12:50,804] INFO: Computing for LV734
# [2022-11-14 22:12:50,942] INFO: Computing for LV735
# [2022-11-14 22:12:51,080] INFO: Computing for LV736
# [2022-11-14 22:12:51,217] INFO: Computing for LV737
# [2022-11-14 22:12:51,355] INFO: Computing for LV738
# [2022-11-14 22:12:51,513] INFO: Computing for LV739
# [2022-11-14 22:12:51,650] INFO: Computing for LV740
# [2022-11-14 22:12:51,788] INFO: Computing for LV741
# [2022-11-14 22:12:51,925] INFO: Computing for LV742
# [2022-11-14 22:12:52,064] INFO: Computing for LV743
# [2022-11-14 22:12:52,201] INFO: Computing for LV744
# [2022-11-14 22:12:52,338] INFO: Computing for LV745
# [2022-11-14 22:12:52,499] INFO: Computing for LV746
# [2022-11-14 22:12:52,637] INFO: Computing for LV747
# [2022-11-14 22:12:52,774] INFO: Computing for LV748
# [2022-11-14 22:12:52,911] INFO: Computing for LV749
# [2022-11-14 22:12:53,048] INFO: Computing for LV750
# [2022-11-14 22:12:53,187] INFO: Computing for LV751
# [2022-11-14 22:12:53,323] INFO: Computing for LV752
# [2022-11-14 22:12:53,487] INFO: Computing for LV753
# [2022-11-14 22:12:53,638] INFO: Computing for LV754
# [2022-11-14 22:12:53,776] INFO: Computing for LV755
# [2022-11-14 22:12:53,916] INFO: Computing for LV756
# [2022-11-14 22:12:54,054] INFO: Computing for LV757
# [2022-11-14 22:12:54,193] INFO: Computing for LV758
# [2022-11-14 22:12:54,332] INFO: Computing for LV759
# [2022-11-14 22:12:54,490] INFO: Computing for LV760
# [2022-11-14 22:12:54,632] INFO: Computing for LV761
# [2022-11-14 22:12:54,772] INFO: Computing for LV762
# [2022-11-14 22:12:54,911] INFO: Computing for LV763
# [2022-11-14 22:12:55,050] INFO: Computing for LV764
# [2022-11-14 22:12:55,188] INFO: Computing for LV765
# [2022-11-14 22:12:55,329] INFO: Computing for LV766
# [2022-11-14 22:12:55,487] INFO: Computing for LV767
# [2022-11-14 22:12:55,655] INFO: Computing for LV768
# [2022-11-14 22:12:55,798] INFO: Computing for LV769
# [2022-11-14 22:12:55,936] INFO: Computing for LV770
# [2022-11-14 22:12:56,074] INFO: Computing for LV771
# [2022-11-14 22:12:56,210] INFO: Computing for LV772
# [2022-11-14 22:12:56,347] INFO: Computing for LV773
# [2022-11-14 22:12:56,499] INFO: Computing for LV774
# [2022-11-14 22:12:56,637] INFO: Computing for LV775
# [2022-11-14 22:12:56,774] INFO: Computing for LV776
# [2022-11-14 22:12:56,911] INFO: Computing for LV777
# [2022-11-14 22:12:57,050] INFO: Computing for LV778
# [2022-11-14 22:12:57,188] INFO: Computing for LV779
# [2022-11-14 22:12:57,326] INFO: Computing for LV780
# [2022-11-14 22:12:57,463] INFO: Computing for LV781
# [2022-11-14 22:12:57,612] INFO: Computing for LV782
# [2022-11-14 22:12:57,750] INFO: Computing for LV783
# [2022-11-14 22:12:57,887] INFO: Computing for LV784
# [2022-11-14 22:12:58,024] INFO: Computing for LV785
# [2022-11-14 22:12:58,162] INFO: Computing for LV786
# [2022-11-14 22:12:58,297] INFO: Computing for LV787
# [2022-11-14 22:12:58,432] INFO: Computing for LV788
# [2022-11-14 22:12:58,586] INFO: Computing for LV789
# [2022-11-14 22:12:58,722] INFO: Computing for LV790
# [2022-11-14 22:12:58,858] INFO: Computing for LV791
# [2022-11-14 22:12:58,994] INFO: Computing for LV792
# [2022-11-14 22:12:59,131] INFO: Computing for LV793
# [2022-11-14 22:12:59,267] INFO: Computing for LV794
# [2022-11-14 22:12:59,404] INFO: Computing for LV795
# [2022-11-14 22:12:59,560] INFO: Computing for LV796
# [2022-11-14 22:12:59,695] INFO: Computing for LV797
# [2022-11-14 22:12:59,832] INFO: Computing for LV798
# [2022-11-14 22:12:59,969] INFO: Computing for LV799
# [2022-11-14 22:13:00,105] INFO: Computing for LV800
# [2022-11-14 22:13:00,240] INFO: Computing for LV801
# [2022-11-14 22:13:00,376] INFO: Computing for LV802
# [2022-11-14 22:13:00,529] INFO: Computing for LV803
# [2022-11-14 22:13:00,669] INFO: Computing for LV804
# [2022-11-14 22:13:00,807] INFO: Computing for LV805
# [2022-11-14 22:13:00,945] INFO: Computing for LV806
# [2022-11-14 22:13:01,082] INFO: Computing for LV807
# [2022-11-14 22:13:01,220] INFO: Computing for LV808
# [2022-11-14 22:13:01,357] INFO: Computing for LV809
# [2022-11-14 22:13:01,499] INFO: Computing for LV810
# [2022-11-14 22:13:01,654] INFO: Computing for LV811
# [2022-11-14 22:13:01,791] INFO: Computing for LV812
# [2022-11-14 22:13:01,929] INFO: Computing for LV813
# [2022-11-14 22:13:02,066] INFO: Computing for LV814
# [2022-11-14 22:13:02,203] INFO: Computing for LV815
# [2022-11-14 22:13:02,341] INFO: Computing for LV816
# [2022-11-14 22:13:02,478] INFO: Computing for LV817
# [2022-11-14 22:13:02,622] INFO: Computing for LV818
# [2022-11-14 22:13:02,771] INFO: Computing for LV819
# [2022-11-14 22:13:02,908] INFO: Computing for LV820
# [2022-11-14 22:13:03,047] INFO: Computing for LV821
# [2022-11-14 22:13:03,183] INFO: Computing for LV822
# [2022-11-14 22:13:03,322] INFO: Computing for LV823
# [2022-11-14 22:13:03,459] INFO: Computing for LV824
# [2022-11-14 22:13:03,612] INFO: Computing for LV825
# [2022-11-14 22:13:03,760] INFO: Computing for LV826
# [2022-11-14 22:13:03,897] INFO: Computing for LV827
# [2022-11-14 22:13:04,035] INFO: Computing for LV828
# [2022-11-14 22:13:04,172] INFO: Computing for LV829
# [2022-11-14 22:13:04,309] INFO: Computing for LV830
# [2022-11-14 22:13:04,448] INFO: Computing for LV831
# [2022-11-14 22:13:04,600] INFO: Computing for LV832
# [2022-11-14 22:13:04,738] INFO: Computing for LV833
# [2022-11-14 22:13:04,875] INFO: Computing for LV834
# [2022-11-14 22:13:05,012] INFO: Computing for LV835
# [2022-11-14 22:13:05,149] INFO: Computing for LV836
# [2022-11-14 22:13:05,287] INFO: Computing for LV837
# [2022-11-14 22:13:05,424] INFO: Computing for LV838
# [2022-11-14 22:13:05,586] INFO: Computing for LV839
# [2022-11-14 22:13:05,725] INFO: Computing for LV840
# [2022-11-14 22:13:05,863] INFO: Computing for LV841
# [2022-11-14 22:13:06,000] INFO: Computing for LV842
# [2022-11-14 22:13:06,139] INFO: Computing for LV843
# [2022-11-14 22:13:06,277] INFO: Computing for LV844
# [2022-11-14 22:13:06,414] INFO: Computing for LV845
# [2022-11-14 22:13:06,575] INFO: Computing for LV846
# [2022-11-14 22:13:06,714] INFO: Computing for LV847
# [2022-11-14 22:13:06,852] INFO: Computing for LV848
# [2022-11-14 22:13:06,989] INFO: Computing for LV849
# [2022-11-14 22:13:07,127] INFO: Computing for LV850
# [2022-11-14 22:13:07,265] INFO: Computing for LV851
# [2022-11-14 22:13:07,403] INFO: Computing for LV852
# [2022-11-14 22:13:07,566] INFO: Computing for LV853
# [2022-11-14 22:13:07,707] INFO: Computing for LV854
# [2022-11-14 22:13:07,844] INFO: Computing for LV855
# [2022-11-14 22:13:07,982] INFO: Computing for LV856
# [2022-11-14 22:13:08,120] INFO: Computing for LV857
# [2022-11-14 22:13:08,260] INFO: Computing for LV858
# [2022-11-14 22:13:08,398] INFO: Computing for LV859
# [2022-11-14 22:13:08,551] INFO: Computing for LV860
# [2022-11-14 22:13:08,690] INFO: Computing for LV861
# [2022-11-14 22:13:08,854] INFO: Computing for LV862
# [2022-11-14 22:13:08,991] INFO: Computing for LV863
# [2022-11-14 22:13:09,128] INFO: Computing for LV864
# [2022-11-14 22:13:09,266] INFO: Computing for LV865
# [2022-11-14 22:13:09,404] INFO: Computing for LV866
# [2022-11-14 22:13:09,564] INFO: Computing for LV867
# [2022-11-14 22:13:09,720] INFO: Computing for LV868
# [2022-11-14 22:13:09,858] INFO: Computing for LV869
# [2022-11-14 22:13:09,995] INFO: Computing for LV870
# [2022-11-14 22:13:10,132] INFO: Computing for LV871
# [2022-11-14 22:13:10,270] INFO: Computing for LV872
# [2022-11-14 22:13:10,408] INFO: Computing for LV873
# [2022-11-14 22:13:10,559] INFO: Computing for LV874
# [2022-11-14 22:13:10,696] INFO: Computing for LV875
# [2022-11-14 22:13:10,846] INFO: Computing for LV876
# [2022-11-14 22:13:10,984] INFO: Computing for LV877
# [2022-11-14 22:13:11,121] INFO: Computing for LV878
# [2022-11-14 22:13:11,258] INFO: Computing for LV879
# [2022-11-14 22:13:11,397] INFO: Computing for LV880
# [2022-11-14 22:13:11,535] INFO: Computing for LV881
# [2022-11-14 22:13:11,682] INFO: Computing for LV882
# [2022-11-14 22:13:11,836] INFO: Computing for LV883
# [2022-11-14 22:13:11,973] INFO: Computing for LV884
# [2022-11-14 22:13:12,110] INFO: Computing for LV885
# [2022-11-14 22:13:12,247] INFO: Computing for LV886
# [2022-11-14 22:13:12,386] INFO: Computing for LV887
# [2022-11-14 22:13:12,522] INFO: Computing for LV888
# [2022-11-14 22:13:12,669] INFO: Computing for LV889
# [2022-11-14 22:13:12,807] INFO: Computing for LV890
# [2022-11-14 22:13:12,945] INFO: Computing for LV891
# [2022-11-14 22:13:13,082] INFO: Computing for LV892
# [2022-11-14 22:13:13,219] INFO: Computing for LV893
# [2022-11-14 22:13:13,356] INFO: Computing for LV894
# [2022-11-14 22:13:13,493] INFO: Computing for LV895
# [2022-11-14 22:13:13,640] INFO: Computing for LV896
# [2022-11-14 22:13:13,777] INFO: Computing for LV897
# [2022-11-14 22:13:13,914] INFO: Computing for LV898
# [2022-11-14 22:13:14,052] INFO: Computing for LV899
# [2022-11-14 22:13:14,190] INFO: Computing for LV900
# [2022-11-14 22:13:14,327] INFO: Computing for LV901
# [2022-11-14 22:13:14,464] INFO: Computing for LV902
# [2022-11-14 22:13:14,621] INFO: Computing for LV903
# [2022-11-14 22:13:14,758] INFO: Computing for LV904
# [2022-11-14 22:13:14,895] INFO: Computing for LV905
# [2022-11-14 22:13:15,033] INFO: Computing for LV906
# [2022-11-14 22:13:15,171] INFO: Computing for LV907
# [2022-11-14 22:13:15,308] INFO: Computing for LV908
# [2022-11-14 22:13:15,445] INFO: Computing for LV909
# [2022-11-14 22:13:15,606] INFO: Computing for LV910
# [2022-11-14 22:13:15,742] INFO: Computing for LV911
# [2022-11-14 22:13:15,878] INFO: Computing for LV912
# [2022-11-14 22:13:16,016] INFO: Computing for LV913
# [2022-11-14 22:13:16,153] INFO: Computing for LV914
# [2022-11-14 22:13:16,290] INFO: Computing for LV915
# [2022-11-14 22:13:16,427] INFO: Computing for LV916
# [2022-11-14 22:13:16,570] INFO: Computing for LV917
# [2022-11-14 22:13:16,713] INFO: Computing for LV918
# [2022-11-14 22:13:16,853] INFO: Computing for LV919
# [2022-11-14 22:13:17,031] INFO: Computing for LV920
# [2022-11-14 22:13:17,168] INFO: Computing for LV921
# [2022-11-14 22:13:17,304] INFO: Computing for LV922
# [2022-11-14 22:13:17,441] INFO: Computing for LV923
# [2022-11-14 22:13:17,590] INFO: Computing for LV924
# [2022-11-14 22:13:17,730] INFO: Computing for LV925
# [2022-11-14 22:13:17,875] INFO: Computing for LV926
# [2022-11-14 22:13:18,010] INFO: Computing for LV927
# [2022-11-14 22:13:18,147] INFO: Computing for LV928
# [2022-11-14 22:13:18,283] INFO: Computing for LV929
# [2022-11-14 22:13:18,419] INFO: Computing for LV930
# [2022-11-14 22:13:18,556] INFO: Computing for LV931
# [2022-11-14 22:13:18,704] INFO: Computing for LV932
# [2022-11-14 22:13:18,856] INFO: Computing for LV933
# [2022-11-14 22:13:18,993] INFO: Computing for LV934
# [2022-11-14 22:13:19,129] INFO: Computing for LV935
# [2022-11-14 22:13:19,268] INFO: Computing for LV936
# [2022-11-14 22:13:19,406] INFO: Computing for LV937
# [2022-11-14 22:13:19,543] INFO: Computing for LV938
# [2022-11-14 22:13:19,690] INFO: Computing for LV939
# [2022-11-14 22:13:19,829] INFO: Computing for LV940
# [2022-11-14 22:13:19,980] INFO: Computing for LV941
# [2022-11-14 22:13:20,117] INFO: Computing for LV942
# [2022-11-14 22:13:20,254] INFO: Computing for LV943
# [2022-11-14 22:13:20,391] INFO: Computing for LV944
# [2022-11-14 22:13:20,530] INFO: Computing for LV945
# [2022-11-14 22:13:20,679] INFO: Computing for LV946
# [2022-11-14 22:13:20,816] INFO: Computing for LV947
# [2022-11-14 22:13:20,952] INFO: Computing for LV948
# [2022-11-14 22:13:21,089] INFO: Computing for LV949
# [2022-11-14 22:13:21,227] INFO: Computing for LV950
# [2022-11-14 22:13:21,365] INFO: Computing for LV951
# [2022-11-14 22:13:21,501] INFO: Computing for LV952
# [2022-11-14 22:13:21,665] INFO: Computing for LV953
# [2022-11-14 22:13:21,802] INFO: Computing for LV954
# [2022-11-14 22:13:21,939] INFO: Computing for LV955
# [2022-11-14 22:13:22,076] INFO: Computing for LV956
# [2022-11-14 22:13:22,212] INFO: Computing for LV957
# [2022-11-14 22:13:22,349] INFO: Computing for LV958
# [2022-11-14 22:13:22,486] INFO: Computing for LV959
# [2022-11-14 22:13:22,649] INFO: Computing for LV960
# [2022-11-14 22:13:22,786] INFO: Computing for LV961
# [2022-11-14 22:13:22,923] INFO: Computing for LV962
# [2022-11-14 22:13:23,060] INFO: Computing for LV963
# [2022-11-14 22:13:23,197] INFO: Computing for LV964
# [2022-11-14 22:13:23,333] INFO: Computing for LV965
# [2022-11-14 22:13:23,473] INFO: Computing for LV966
# [2022-11-14 22:13:23,634] INFO: Computing for LV967
# [2022-11-14 22:13:23,771] INFO: Computing for LV968
# [2022-11-14 22:13:23,910] INFO: Computing for LV969
# [2022-11-14 22:13:24,047] INFO: Computing for LV970
# [2022-11-14 22:13:24,184] INFO: Computing for LV971
# [2022-11-14 22:13:24,321] INFO: Computing for LV972
# [2022-11-14 22:13:24,458] INFO: Computing for LV973
# [2022-11-14 22:13:24,597] INFO: Computing for LV974
# [2022-11-14 22:13:24,742] INFO: Computing for LV975
# [2022-11-14 22:13:24,881] INFO: Computing for LV976
# [2022-11-14 22:13:25,019] INFO: Computing for LV977
# [2022-11-14 22:13:25,156] INFO: Computing for LV978
# [2022-11-14 22:13:25,294] INFO: Computing for LV979
# [2022-11-14 22:13:25,433] INFO: Computing for LV980
# [2022-11-14 22:13:25,571] INFO: Computing for LV981
# [2022-11-14 22:13:25,714] INFO: Computing for LV982
# [2022-11-14 22:13:25,864] INFO: Computing for LV983
# [2022-11-14 22:13:26,001] INFO: Computing for LV984
# [2022-11-14 22:13:26,139] INFO: Computing for LV985
# [2022-11-14 22:13:26,277] INFO: Computing for LV986
# [2022-11-14 22:13:26,413] INFO: Computing for LV987
# [2022-11-14 22:13:26,555] INFO: Writing results to /tmp/gls_phenoplier-basophill_percentage.tsv.gz

# %% [markdown]
# As you can see from the output, the tool performs some preprocessing of the input TWAS file, and then computes an association for all LVs in the model (987 in our case) and the gene p-values from TWAS. The output is finally written to the path specified.
#
# **IMPORTANT:** keep in mind that you have to use a gene correlation matrix that is specific to your TWAS results. This is because gene correlations depend on the variants present in the original GWAS used. Check out [the notebooks here](https://github.com/greenelab/phenoplier/tree/main/nbs/15_gsa_gls) to see how to compute a gene correlation matrix specific for your trait of interest.

# %% [markdown]
# # Load LV-trait results

# %%
lv_df = pd.read_csv("/tmp/gls_phenoplier-basophill_percentage.tsv.gz", sep="\t")

# %%
lv_df
# Out:
#         lv      beta   beta_se         t  pvalue_twosided  pvalue_onesided
# 0    LV603  0.988076  0.127500  7.749615     1.064641e-14     5.323207e-15
# 1    LV719  0.903596  0.130457  6.926399     4.736869e-12     2.368434e-12
# 2     LV68  0.859876  0.126886  6.776776     1.338216e-11     6.691079e-12
# 3    LV517  0.831304  0.125022  6.649252     3.188491e-11     1.594246e-11
# 4    LV599  0.728474  0.126189  5.772889     8.156289e-09     4.078144e-09
# ..     ...       ...       ...       ...              ...              ...
# 982  LV213 -0.194986  0.125889 -1.548863     1.214639e-01     9.392681e-01
# 983  LV322 -0.202912  0.125966 -1.610849     1.072618e-01     9.463691e-01
# 984  LV632 -0.203234  0.124819 -1.628234     1.035242e-01     9.482379e-01
# 985  LV776 -0.205448  0.125552 -1.636362     1.018129e-01     9.490936e-01
# 986  LV317 -0.215741  0.127047 -1.698124     8.953278e-02     9.552336e-01
#
# [987 rows x 6 columns]

# %% [markdown]
# As you can see, LV603 is at the top of the LVs associations for basophil percentage.
# However, the onesided p-value here (`5.32e-15`) is larger than a simple correlation (`2.94e-27`), suggesting that we have correlated genes at the top of the LV.

# %% [markdown]
# # Conclusions

# %% [markdown]
# Hopefully, now have a more clear idea of the main data matrixes involved in PhenoPLIER (matrix Z, PhenomeXcan gene-trait associations, etc).
# We also see how to compute a p-value between an LV (group of genes or gene module) and a trait of interest.
# To do this with your own data, you need to compute the S-MultiXcan TWAS results (gene-based) from your GWAS summary stats and generate your own gene correlation matrix.
#
# In the next notebook (`02-LV_cell_types-...`), we'll see how to check in which tissues or cell types are our LV603'genes expressed.
