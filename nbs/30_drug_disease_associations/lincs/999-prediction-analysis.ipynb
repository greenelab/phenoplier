# %% [markdown]
# # Description

# %% [markdown]
# **TODO**

# %% [markdown]
# # Modules loading

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

import numpy as np
import pandas as pd

from entity import Gene
import conf

# %% [markdown]
# # Settings

# %%
OUTPUT_DIR = conf.RESULTS["DRUG_DISEASE_ANALYSES"]
display(OUTPUT_DIR)

assert OUTPUT_DIR.exists()
# OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
# Out:
# PosixPath('/media/miltondp/Elements1/projects/phenoplier/results/drug_disease_analyses')

# %%
INPUT_DATA_DIR = Path(
    conf.RESULTS["DRUG_DISEASE_ANALYSES"],
    "data",
)
display(INPUT_DATA_DIR)
# Out:
# PosixPath('/media/miltondp/Elements1/projects/phenoplier/results/drug_disease_analyses/data')

# %%
OUTPUT_PREDICTIONS_DIR = Path(
    conf.RESULTS["DRUG_DISEASE_ANALYSES"], "predictions", "dotprod_neg"
)
display(OUTPUT_PREDICTIONS_DIR)
# Out:
# PosixPath('/media/miltondp/Elements1/projects/phenoplier/results/drug_disease_analyses/predictions/dotprod_neg')

# %% [markdown]
# # S-MultiXcan projection

# %%
input_file = Path(
    conf.RESULTS["PROJECTIONS_DIR"],
    "projection-smultixcan-efo_partial-mashr-zscores.pkl",
).resolve()
display(input_file)
# Out:
# PosixPath('/home/miltondp/projects/labs/greenelab/phenoplier/base/results/projections/projection-smultixcan-efo_partial-mashr-zscores.pkl')

# %%
smultixcan_proj = pd.read_pickle(input_file)

# %%
smultixcan_proj.shape
# Out:
# (987, 3752)

# %%
smultixcan_proj.head()
# Out:
#      100001_raw-Food_weight  100002_raw-Energy  100003_raw-Protein  \
# LV1               -0.021292          -0.046815           -0.021585
# LV2                0.056061          -0.009864           -0.028888
# LV3                0.001650          -0.004262            0.019211
# LV4                0.026265          -0.007235            0.004304
# LV5               -0.015616           0.010799            0.017792
#
#      100004_raw-Fat  100005_raw-Carbohydrate  100006_raw-Saturated_fat  \
# LV1       -0.030324                -0.017773                 -0.007844
# LV2       -0.053573                 0.006951                 -0.054597
# LV3        0.007484                 0.004548                  0.006548
# LV4       -0.042464                -0.001093                 -0.041208
# LV5        0.010591                 0.001972                  0.040024
#
#      100007_raw-Polyunsaturated_fat  100008_raw-Total_sugars  \
# LV1                       -0.015529                -0.011609
# LV2                       -0.030748                 0.014519
# LV3                        0.006741                -0.005634
# LV4                       -0.051179                 0.009060
# LV5                       -0.027612                -0.001540
#
#      100009_raw-Englyst_dietary_fibre  100010-Portion_size  ...  \
# LV1                         -0.051342            -0.036813  ...
# LV2                         -0.026933             0.009024  ...
# LV3                         -0.022129            -0.017256  ...
# LV4                         -0.003999            -0.005874  ...
# LV5                          0.033072             0.009477  ...
#
#      visual impairment  vitiligo  vitreous body disease  vocal cord polyp  \
# LV1          -0.001614  0.002102              -0.005318         -0.003041
# LV2          -0.029614 -0.033636               0.020768          0.010656
# LV3           0.010539 -0.019591              -0.013391         -0.044369
# LV4          -0.018162  0.012136              -0.046232         -0.030949
# LV5           0.030632 -0.023253               0.015853         -0.002222
#
#      voice disorders  wellbeing measurement AND family relationship  wheezing  \
# LV1         0.012873                                      -0.015951 -0.018904
# LV2        -0.013305                                       0.050738  0.012085
# LV3         0.020142                                       0.006052  0.020869
# LV4        -0.040147                                       0.044545  0.009865
# LV5         0.019385                                      -0.015501 -0.031477
#
#      whooping cough  worry measurement  wrist fracture
# LV1        0.009576           0.019755        0.010027
# LV2       -0.032372          -0.024540       -0.002616
# LV3        0.043931           0.058049       -0.013144
# LV4       -0.049828          -0.013725        0.024988
# LV5       -0.002554          -0.032620        0.017731
#
# [5 rows x 3752 columns]

# %% [markdown]
# # S-MultiXcan

# %%
# smultixcan_zscores = pd.read_pickle(conf.PHENOMEXCAN["SMULTIXCAN_MASHR_ZSCORES_FILE"])
smultixcan_zscores = pd.read_pickle(
    conf.PHENOMEXCAN["SMULTIXCAN_EFO_PARTIAL_MASHR_ZSCORES_FILE"]
)

# %%
smultixcan_zscores = smultixcan_zscores.rename(index=Gene.GENE_ID_TO_NAME_MAP)

# %%
smultixcan_zscores = smultixcan_zscores[~smultixcan_zscores.index.duplicated()]

# %%
smultixcan_zscores = smultixcan_zscores.dropna(how="any")

# %%
smultixcan_zscores.shape
# Out:
# (22508, 3752)

# %%
smultixcan_zscores.head()
# Out:
#            100001_raw-Food_weight  100002_raw-Energy  100003_raw-Protein  \
# gene_name
# DPM1                     1.145442           0.724557            0.090876
# SCYL3                    0.618066           1.028131            2.218420
# C1orf112                 0.515724           0.403596            1.251359
# FGR                      0.280781           0.253910            0.879148
# CFH                      0.548127           0.389877            0.723469
#
#            100004_raw-Fat  100005_raw-Carbohydrate  100006_raw-Saturated_fat  \
# gene_name
# DPM1             0.298165                 1.134347                  1.371138
# SCYL3            0.762584                 0.934418                  0.192993
# C1orf112         0.433091                 0.413466                  0.246261
# FGR              0.352705                 0.051846                  0.184212
# CFH              1.167250                 0.315952                  0.324939
#
#            100007_raw-Polyunsaturated_fat  100008_raw-Total_sugars  \
# gene_name
# DPM1                             0.065718                 0.794317
# SCYL3                            1.080230                 0.765997
# C1orf112                         1.236151                 0.827430
# FGR                              0.148566                 0.009989
# CFH                              1.613932                 0.311432
#
#            100009_raw-Englyst_dietary_fibre  100010-Portion_size  ...  \
# gene_name                                                         ...
# DPM1                               0.600342             0.317652  ...
# SCYL3                              0.375898             0.678731  ...
# C1orf112                           0.571985             0.782174  ...
# FGR                                0.363751             0.374514  ...
# CFH                                0.333548             1.807243  ...
#
#            visual impairment  vitiligo  vitreous body disease  \
# gene_name
# DPM1                0.360518  1.351624               1.157695
# SCYL3               2.134504  0.127830               0.534690
# C1orf112            1.768905  0.992408               0.548215
# FGR                 0.656552  2.046041               2.746832
# CFH                 0.260482  0.646204               1.080240
#
#            vocal cord polyp  voice disorders  \
# gene_name
# DPM1               0.835289         1.173072
# SCYL3              0.120516         0.517464
# C1orf112           0.412341         1.499415
# FGR                0.108211         1.008258
# CFH                0.678330         1.465358
#
#            wellbeing measurement AND family relationship  wheezing  \
# gene_name
# DPM1                                            1.337280  1.743822
# SCYL3                                           2.545363  0.673331
# C1orf112                                        1.366780  0.443318
# FGR                                             0.755695  0.896228
# CFH                                             0.307672  0.118376
#
#            whooping cough  worry measurement  wrist fracture
# gene_name
# DPM1             1.017226           1.512184        0.972241
# SCYL3            2.003092           0.344000        2.033122
# C1orf112         0.417630           0.225934        1.613246
# FGR              0.875047           0.476405        1.693057
# CFH              1.419812           0.000002        1.040737
#
# [5 rows x 3752 columns]

# %% [markdown]
# # PharmacotherapyDB: load gold standard

# %% [markdown]
# ## Final

# %%
gold_standard = pd.read_pickle(
    Path(conf.RESULTS["DRUG_DISEASE_ANALYSES"], "gold_standard.pkl"),
)

# %%
gold_standard.shape
# Out:
# (998, 3)

# %%
gold_standard.head()
# Out:
#         trait     drug  true_class
# 0  DOID:10652  DB00843           1
# 1  DOID:10652  DB00674           1
# 2  DOID:10652  DB01043           1
# 3  DOID:10652  DB00989           1
# 4  DOID:10652  DB00810           0

# %%
gold_standard["trait"].unique().shape
# Out:
# (87,)

# %%
gold_standard["drug"].unique().shape
# Out:
# (465,)

# %%
gold_standard["true_class"].value_counts()
# Out:
# 1    755
# 0    243
# Name: true_class, dtype: int64

# %%
gold_standard["true_class"].value_counts(normalize=True)
# Out:
# 1    0.756513
# 0    0.243487
# Name: true_class, dtype: float64

# %% [markdown]
# ## Info

# %%
# TODO hardcoded
input_file = Path(
    conf.DATA_DIR, "hetionet/pharmacotherapydb-v1.0", "indications.tsv"
).resolve()
display(input_file)
# Out:
# PosixPath('/home/miltondp/projects/labs/greenelab/phenoplier/base/data/hetionet/pharmacotherapydb-v1.0/indications.tsv')

# %%
gold_standard_info = pd.read_csv(input_file, sep="\t")

# %%
gold_standard_info = gold_standard_info.rename(columns={"drug": "drug_name"})

# %%
gold_standard_info.shape
# Out:
# (1388, 7)

# %%
gold_standard_info.head()
# Out:
#       doid_id drugbank_id              disease     drug_name category  \
# 0  DOID:10652     DB00843  Alzheimer's disease     Donepezil       DM
# 1  DOID:10652     DB00674  Alzheimer's disease   Galantamine       DM
# 2  DOID:10652     DB01043  Alzheimer's disease     Memantine       DM
# 3  DOID:10652     DB00989  Alzheimer's disease  Rivastigmine       DM
# 4  DOID:10652     DB00245  Alzheimer's disease  Benzatropine      SYM
#
#    n_curators  n_resources
# 0           2            1
# 1           1            4
# 2           1            3
# 3           1            3
# 4           3            1

# %%
gold_standard_info = (
    gold_standard.set_index(["trait", "drug"])
    .join(
        gold_standard_info.rename(
            columns={"doid_id": "trait", "drugbank_id": "drug"}
        ).set_index(["trait", "drug"])
    )
    .reset_index()
)

# %%
gold_standard_info.shape
# Out:
# (998, 8)

# %%
gold_standard_info.head()
# Out:
#         trait     drug  true_class              disease     drug_name  \
# 0  DOID:10652  DB00843           1  Alzheimer's disease     Donepezil
# 1  DOID:10652  DB00674           1  Alzheimer's disease   Galantamine
# 2  DOID:10652  DB01043           1  Alzheimer's disease     Memantine
# 3  DOID:10652  DB00989           1  Alzheimer's disease  Rivastigmine
# 4  DOID:10652  DB00810           0  Alzheimer's disease     Biperiden
#
#   category  n_curators  n_resources
# 0       DM           2            1
# 1       DM           1            4
# 2       DM           1            3
# 3       DM           1            3
# 4      NOT           2            1

# %% [markdown]
# # LINCS data

# %%
input_file = Path(INPUT_DATA_DIR, "raw", "lincs-data.pkl").resolve()

display(input_file)
# Out:
# PosixPath('/media/miltondp/Elements1/projects/phenoplier/results/drug_disease_analyses/data_for_each_tissue_bak/raw/lincs-data.pkl')

# %%
lincs_data = pd.read_pickle(input_file).T.rename(columns=Gene.GENE_ID_TO_NAME_MAP)

# %%
display(lincs_data.shape)
# Out:
# (1170, 7120)

# %%
display(lincs_data.head())
# Out:
#                ADA   CDH2   AKT3   MED6  ACOT8   ABI1  GNPDA1   CDH3   TANK  \
# perturbagen
# DB00014     -1.001  1.146 -0.693 -0.037  0.162 -0.380   0.649 -1.952  0.294
# DB00091     -1.835 -1.863  1.694  0.383 -0.899  0.628  -4.878  2.527  1.709
# DB00121      1.391  0.011 -0.804  0.269  0.105 -0.588  -1.899  0.306 -1.178
# DB00130      1.132 -1.020 -0.164 -0.997 -0.090  0.195  -2.341  0.494 -0.813
# DB00131      0.257  1.143  1.145  0.185 -1.291 -0.457   0.038  1.442 -1.692
#
#              TOPORS-AS1  ...   RBX1  CDC42  THOC1   RCE1  HNRNPDL  DMTF1  \
# perturbagen              ...
# DB00014           0.274  ... -0.592  0.178  0.270 -0.013    0.351 -0.128
# DB00091          -0.981  ... -0.668 -2.795 -0.333 -0.027    0.578  6.926
# DB00121           0.120  ... -0.962  0.450 -0.999  1.358   -1.476  0.423
# DB00130          -1.140  ... -0.553 -0.528  0.308  0.534   -0.320  3.001
# DB00131           0.593  ... -0.556 -0.600  0.092 -0.564    0.174 -1.203
#
#              PPP4R1   CDH1  PTBP3  CASP8AP2
# perturbagen
# DB00014       0.274 -0.734 -0.048     0.036
# DB00091      -1.875  4.382  0.266    -4.995
# DB00121      -1.356 -1.897 -0.299    -0.732
# DB00130      -0.414  0.134  0.147     2.158
# DB00131      -1.080 -0.575 -0.792    -0.095
#
# [5 rows x 7120 columns]

# %%
lincs_data.index.is_unique
# Out:
# True

# %%
lincs_data.columns.is_unique
# Out:
# True

# %% [markdown]
# # LINCS projection

# %%
input_file = Path(INPUT_DATA_DIR, "proj", "lincs-projection.pkl").resolve()

display(input_file)
# Out:
# PosixPath('/media/miltondp/Elements1/projects/phenoplier/results/drug_disease_analyses/data_for_each_tissue_bak/proj/lincs-projection.pkl')

# %%
lincs_projection = pd.read_pickle(input_file).T

# %%
display(lincs_projection.shape)
# Out:
# (1170, 987)

# %%
display(lincs_projection.head())
# Out:
#                   LV1       LV2       LV3       LV4       LV5       LV6  \
# perturbagen
# DB00014      0.036115  0.012281 -0.005533 -0.004151 -0.015156 -0.010861
# DB00091     -0.358610  0.009738 -0.059174 -0.032884 -0.005276  0.063369
# DB00121      0.091067  0.004650  0.013454  0.005934  0.025747  0.004324
# DB00130      0.008923 -0.006554  0.008906 -0.003991  0.000346  0.008212
# DB00131      0.046469  0.021758 -0.004939 -0.028524 -0.013932  0.012231
#
#                   LV7       LV8       LV9      LV10  ...     LV978     LV979  \
# perturbagen                                          ...
# DB00014      0.008181 -0.008148  0.004948 -0.009869  ... -0.003139  0.003546
# DB00091     -0.079522 -0.018980 -0.025782  0.021540  ... -0.019892  0.003610
# DB00121     -0.001865 -0.019613  0.051503  0.013032  ...  0.001629 -0.012565
# DB00130      0.001242 -0.012771  0.014221  0.008269  ... -0.026139 -0.002977
# DB00131     -0.001325  0.003787  0.035189 -0.004377  ...  0.017373  0.005304
#
#                 LV980     LV981     LV982     LV983     LV984     LV985  \
# perturbagen
# DB00014     -0.006242  0.002449 -0.004391 -0.004334 -0.019902  0.004292
# DB00091     -0.016165  0.008686  0.065335 -0.042051  0.065516  0.016261
# DB00121      0.009613 -0.014404 -0.009188  0.006544  0.047466 -0.016220
# DB00130      0.021969  0.001204 -0.012731 -0.000076 -0.029127 -0.022679
# DB00131     -0.001649  0.004017 -0.000622 -0.006477  0.021663  0.000988
#
#                 LV986     LV987
# perturbagen
# DB00014     -0.010378  0.002000
# DB00091      0.056314 -0.051035
# DB00121     -0.018844  0.034675
# DB00130      0.016179 -0.003029
# DB00131      0.002038 -0.011747
#
# [5 rows x 987 columns]

# %% [markdown]
# # MultiPLIER Z

# %%
multiplier_z = pd.read_pickle(conf.MULTIPLIER["MODEL_Z_MATRIX_FILE"])

# %%
multiplier_z.shape
# Out:
# (6750, 987)

# %%
multiplier_z.head()
# Out:
#                LV1  LV2       LV3  LV4       LV5       LV6  LV7       LV8  \
# GAS6      0.000000  0.0  0.039438  0.0  0.050476  0.000000  0.0  0.000000
# MMP14     0.000000  0.0  0.000000  0.0  0.070072  0.000000  0.0  0.004904
# DSP       0.000000  0.0  0.000000  0.0  0.000000  0.041697  0.0  0.005718
# MARCKSL1  0.305212  0.0  0.000000  0.0  0.000000  0.000000  0.0  0.000000
# SPARC     0.000000  0.0  0.000000  0.0  0.000000  0.000000  0.0  0.000000
#
#                LV9      LV10  ...     LV978    LV979     LV980     LV981  \
# GAS6      0.590949  0.000000  ...  0.050125  0.00000  0.033407  0.000000
# MMP14     1.720179  2.423595  ...  0.000000  0.00000  0.001007  0.000000
# DSP       0.000000  0.000000  ...  0.020853  0.00000  0.000000  0.000000
# MARCKSL1  0.161843  0.149471  ...  0.027134  0.05272  0.000000  0.030189
# SPARC     0.000000  0.014014  ...  0.000000  0.00000  0.000000  0.000000
#
#              LV982     LV983     LV984  LV985     LV986     LV987
# GAS6      0.000000  0.005963  0.347362    0.0  0.000000  0.000000
# MMP14     0.035747  0.000000  0.000000    0.0  0.014978  0.000000
# DSP       0.000000  0.005774  0.000000    0.0  0.000000  0.416405
# MARCKSL1  0.060884  0.000000  0.000000    0.0  0.000000  0.448480
# SPARC     0.000000  0.000000  0.067779    0.0  0.122417  0.062665
#
# [5 rows x 987 columns]

# %% [markdown]
# # Prediction results

# %% [markdown]
# ## Full

# %%
output_file = Path(OUTPUT_DIR, "predictions", "predictions_results.pkl").resolve()
display(output_file)
# Out:
# PosixPath('/media/miltondp/Elements1/projects/phenoplier/results/drug_disease_analyses/predictions_using_each_tissue_bak/predictions_results.pkl')

# %%
predictions = pd.read_pickle(output_file)

# %%
predictions.shape
# Out:
# (316540, 8)

# %%
predictions.head()
# Out:
#           trait     drug  score  true_class      method  n_top_genes  \
# 0  DOID:0050741  DB00215  146.0           1  Gene-based         -1.0
# 1  DOID:0050741  DB00704  465.0           1  Gene-based         -1.0
# 2  DOID:0050741  DB00822  530.0           1  Gene-based         -1.0
# 3    DOID:10283  DB00014  124.0           1  Gene-based         -1.0
# 4    DOID:10283  DB00175  309.0           0  Gene-based         -1.0
#
#                                                 data                tissue
# 0  spredixcan-mashr-zscores-Adipose_Subcutaneous-...  Adipose_Subcutaneous
# 1  spredixcan-mashr-zscores-Adipose_Subcutaneous-...  Adipose_Subcutaneous
# 2  spredixcan-mashr-zscores-Adipose_Subcutaneous-...  Adipose_Subcutaneous
# 3  spredixcan-mashr-zscores-Adipose_Subcutaneous-...  Adipose_Subcutaneous
# 4  spredixcan-mashr-zscores-Adipose_Subcutaneous-...  Adipose_Subcutaneous

# %%
def _reduce_mean(x):
    return pd.Series(
        {
            "score": x["score"].mean(),
            "true_class": x["true_class"].unique()[0]
            #             if x["true_class"].unique().shape[0] == 1
            #             else None,
        }
    )

# %%
predictions_by_tissue = (
    predictions.groupby(["trait", "drug", "method", "tissue"])
    .apply(_reduce_mean)
    .dropna()
    .sort_index()
    .reset_index()
)

# %%
predictions_by_tissue.head()
# Out:
#           trait     drug      method                    tissue  score  \
# 0  DOID:0050741  DB00215  Gene-based      Adipose_Subcutaneous   92.0
# 1  DOID:0050741  DB00215  Gene-based  Adipose_Visceral_Omentum  114.2
# 2  DOID:0050741  DB00215  Gene-based             Adrenal_Gland  243.2
# 3  DOID:0050741  DB00215  Gene-based              Artery_Aorta  163.4
# 4  DOID:0050741  DB00215  Gene-based           Artery_Coronary  116.6
#
#    true_class
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0

# %% [markdown]
# ## Aggregated

# %%
output_file = Path(
    OUTPUT_DIR, "predictions", "predictions_results_aggregated.pkl"
).resolve()
display(output_file)
# Out:
# PosixPath('/media/miltondp/Elements1/projects/phenoplier/results/drug_disease_analyses/predictions_using_each_tissue_bak/predictions_results_aggregated.pkl')

# %%
predictions_avg = pd.read_pickle(output_file)

# %%
predictions_avg.shape
# Out:
# (1292, 5)

# %%
predictions_avg.head()
# Out:
#           trait     drug        method  score  true_class
# 0  DOID:0050741  DB00215    Gene-based  460.0         1.0
# 1  DOID:0050741  DB00215  Module-based  437.8         1.0
# 2  DOID:0050741  DB00704    Gene-based  544.4         1.0
# 3  DOID:0050741  DB00704  Module-based  562.8         1.0
# 4  DOID:0050741  DB00822    Gene-based  598.2         1.0

# %% [markdown]
# # Merge

# %%
pharmadb_predictions = pd.merge(
    gold_standard_info,
    predictions_avg,
    #     left_on=["doid_id", "drugbank_id"],
    on=["trait", "drug"],
    how="inner",
)

# %%
pharmadb_predictions
# Out:
#            trait     drug  true_class_x              disease     drug_name  \
# 0     DOID:10652  DB00843             1  Alzheimer's disease     Donepezil
# 1     DOID:10652  DB00843             1  Alzheimer's disease     Donepezil
# 2     DOID:10652  DB00674             1  Alzheimer's disease   Galantamine
# 3     DOID:10652  DB00674             1  Alzheimer's disease   Galantamine
# 4     DOID:10652  DB01043             1  Alzheimer's disease     Memantine
# ...          ...      ...           ...                  ...           ...
# 1287    DOID:363  DB00917             0       uterine cancer  Dinoprostone
# 1288    DOID:363  DB00783             0       uterine cancer     Estradiol
# 1289    DOID:363  DB00783             0       uterine cancer     Estradiol
# 1290  DOID:12306  DB00553             1             vitiligo   Methoxsalen
# 1291  DOID:12306  DB00553             1             vitiligo   Methoxsalen
#
#      category  n_curators  n_resources        method  score  true_class_y
# 0          DM           2            1    Gene-based  345.0           1.0
# 1          DM           2            1  Module-based  475.2           1.0
# 2          DM           1            4    Gene-based  505.4           1.0
# 3          DM           1            4  Module-based  508.0           1.0
# 4          DM           1            3    Gene-based  484.6           1.0
# ...       ...         ...          ...           ...    ...           ...
# 1287      NOT           3            1  Module-based  476.0           0.0
# 1288      NOT           2            1    Gene-based  546.2           0.0
# 1289      NOT           2            1  Module-based  603.0           0.0
# 1290       DM           3            1    Gene-based  513.4           1.0
# 1291       DM           3            1  Module-based  506.8           1.0
#
# [1292 rows x 11 columns]

# %%
pharmadb_predictions = pharmadb_predictions[
    ["trait", "drug", "disease", "drug_name", "method", "score", "true_class_x"]
].rename(columns={"true_class_x": "true_class", "drug_x": "drug"})

# %%
display(pharmadb_predictions.shape)
assert pharmadb_predictions.shape[0] == predictions_avg.shape[0]
# Out:
# (1292, 7)

# %%
pharmadb_predictions.head()
# Out:
#         trait     drug              disease    drug_name        method  score  \
# 0  DOID:10652  DB00843  Alzheimer's disease    Donepezil    Gene-based  345.0
# 1  DOID:10652  DB00843  Alzheimer's disease    Donepezil  Module-based  475.2
# 2  DOID:10652  DB00674  Alzheimer's disease  Galantamine    Gene-based  505.4
# 3  DOID:10652  DB00674  Alzheimer's disease  Galantamine  Module-based  508.0
# 4  DOID:10652  DB01043  Alzheimer's disease    Memantine    Gene-based  484.6
#
#    true_class
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
pharmadb_predictions["trait"].unique().shape
# Out:
# (53,)

# %%
pharmadb_predictions["drug"].unique().shape
# Out:
# (322,)

# %%
data_stats = pharmadb_predictions.groupby("method")["score"].describe()
display(data_stats)
# Out:
#               count        mean        std    min    25%    50%    75%    max
# method
# Gene-based    646.0  520.671207  89.368962  205.6  464.5  535.3  591.8  646.0
# Module-based  646.0  530.429721  73.472425  220.4  484.1  535.0  587.9  646.0

# %%
# Standardize scores by method
def _standardize(x):
    #     return (x["score"] - data_stats.loc[x["method"], "min"]) / (
    #         data_stats.loc[x["method"], "max"] - data_stats.loc[x["method"], "min"]
    #     )
    return (x["score"] - data_stats.loc[x["method"], "mean"]) / data_stats.loc[
        x["method"], "std"
    ]

# %%
pharmadb_predictions = pharmadb_predictions.assign(
    score_std=pharmadb_predictions.apply(_standardize, axis=1)
)

# %%
pharmadb_predictions
# Out:
#            trait     drug              disease     drug_name        method  \
# 0     DOID:10652  DB00843  Alzheimer's disease     Donepezil    Gene-based
# 1     DOID:10652  DB00843  Alzheimer's disease     Donepezil  Module-based
# 2     DOID:10652  DB00674  Alzheimer's disease   Galantamine    Gene-based
# 3     DOID:10652  DB00674  Alzheimer's disease   Galantamine  Module-based
# 4     DOID:10652  DB01043  Alzheimer's disease     Memantine    Gene-based
# ...          ...      ...                  ...           ...           ...
# 1287    DOID:363  DB00917       uterine cancer  Dinoprostone  Module-based
# 1288    DOID:363  DB00783       uterine cancer     Estradiol    Gene-based
# 1289    DOID:363  DB00783       uterine cancer     Estradiol  Module-based
# 1290  DOID:12306  DB00553             vitiligo   Methoxsalen    Gene-based
# 1291  DOID:12306  DB00553             vitiligo   Methoxsalen  Module-based
#
#       score  true_class  score_std
# 0     345.0           1  -1.965685
# 1     475.2           1  -0.751707
# 2     505.4           1  -0.170878
# 3     508.0           1  -0.305281
# 4     484.6           1  -0.403621
# ...     ...         ...        ...
# 1287  476.0           0  -0.740818
# 1288  546.2           0   0.285656
# 1289  603.0           0   0.987721
# 1290  513.4           1  -0.081362
# 1291  506.8           1  -0.321613
#
# [1292 rows x 8 columns]

# %%
_tmp = pharmadb_predictions.groupby("method")[["score", "score_std"]].describe()
display(_tmp)
# Out:
#               score                                                            \
#               count        mean        std    min    25%    50%    75%    max
# method
# Gene-based    646.0  520.671207  89.368962  205.6  464.5  535.3  591.8  646.0
# Module-based  646.0  530.429721  73.472425  220.4  484.1  535.0  587.9  646.0
#
#              score_std                                                   \
#                  count          mean  std       min       25%       50%
# method
# Gene-based       646.0  9.459238e-16  1.0 -3.525510 -0.628531  0.163690
# Module-based     646.0  2.034836e-16  1.0 -4.219675 -0.630573  0.062204
#
#
#                    75%       max
# method
# Gene-based    0.795900  1.402375
# Module-based  0.782202  1.572975

# %%
_tmp0 = pharmadb_predictions[(pharmadb_predictions["method"] == "Gene-based")][
    ["score", "score_std"]
]

# %%
assert all(_tmp0.corr() > 0.99999)

# %%
_tmp0 = pharmadb_predictions[(pharmadb_predictions["method"] == "Module-based")][
    ["score", "score_std"]
]

# %%
assert all(_tmp0.corr() > 0.99999)

# %% [markdown]
# # List diseases

# %%
pharmadb_predictions["disease"].unique()
# Out:
# array(["Alzheimer's disease", "Crohn's disease", "Parkinson's disease",
#        'alcohol dependence', 'allergic rhinitis', 'anemia',
#        'ankylosing spondylitis', 'asthma', 'atherosclerosis',
#        'bone cancer', 'brain cancer', 'breast cancer', 'cervical cancer',
#        'chronic kidney failure', 'chronic obstructive pulmonary disease',
#        'coronary artery disease', 'epilepsy syndrome',
#        'esophageal cancer', 'gestational diabetes', 'glaucoma', 'gout',
#        'hematologic cancer', 'hypertension', 'hypothyroidism',
#        'kidney cancer', 'liver cancer', 'lung cancer', 'malaria',
#        'melanoma', 'migraine', 'multiple sclerosis', 'nephrolithiasis',
#        'obesity', 'osteoarthritis', 'osteoporosis', 'pancreatic cancer',
#        'pancreatitis', 'periodontitis', 'prostate cancer', 'psoriasis',
#        'psoriatic arthritis', 'rheumatoid arthritis', 'skin cancer',
#        'stomach cancer', 'systemic lupus erythematosus',
#        'testicular cancer', 'thyroid cancer', 'type 1 diabetes mellitus',
#        'type 2 diabetes mellitus', 'ulcerative colitis',
#        'urinary bladder cancer', 'uterine cancer', 'vitiligo'],
#       dtype=object)

# %% [markdown]
# # Testing magma-like models

# %% [markdown]
# ```
# LV38    -0.006532
# LV881   -0.004783
# LV116   -0.004641
# LV163   -0.002454
# LV74    -0.002268
# LV1     -0.002113
# LV509   -0.001988
# LV824   -0.001976
# LV840   -0.001944
# LV189   -0.001757
# LV604   -0.001690
# LV854   -0.001651
# LV583   -0.001562
# LV170   -0.001536
# LV608   -0.001452
# LV926   -0.001390
# LV420   -0.001304
# LV272   -0.001180
# LV60    -0.001168
# LV905   -0.001164
# LV667   -0.001161
# LV395   -0.001144
# LV205   -0.001127
# LV59    -0.001080
# LV187   -0.001064
# LV21    -0.001057
# LV136   -0.001048
# LV924   -0.001008
# ```

# %% [markdown]
# ```
# LV881    0.154953
# LV116    0.097558
# LV743    0.097299
# LV38     0.088232
# LV841    0.086833
# LV163    0.080580
# LV161    0.070249
# LV931    0.069832
# LV9      0.069249
# LV536    0.068436
# LV50     0.067657
# LV707    0.067467
# LV142    0.064834
# LV95     0.061820
# LV97     0.061123
# LV74     0.056454
# LV66     0.055342
# LV974    0.053342
# LV678    0.051296
# LV879    0.050419
# Name: DB00627, dtype: float64
# ```

# %%
_tmp = multiplier_z["LV246"].rename("lv")
_tmp.index.rename("gene", inplace=True)
_tmp.sort_values(ascending=False).to_csv("/tmp/gene_set.txt")

# %%
_pheno_name = "coronary artery disease"
# _pheno_name = "hypercholesterolemia"

_tmp = smultixcan_zscores[_pheno_name].rename("pheno")
_tmp.index.rename("gene", inplace=True)
_tmp.sort_values(ascending=False).to_csv("/tmp/gene_zscores_pheno.txt")

# %%
_tmp = lincs_data.loc["DB00627"].rename("pheno")
_tmp.index.rename("gene", inplace=True)
_tmp.sort_values(ascending=False).to_csv("/tmp/gene_zscores_drug.txt")

# %%
from multiplier import MultiplierProjection

# %%
mproj = MultiplierProjection()

# %%
_tmp = pd.DataFrame(
    {
        "trait1": [10, 20, 30, 40, 50],
        "trait2": [-10, -20, -30, -40, -50],
        "trait3": [-10, 20, -30, 40, -50],
    },
    index=["SCD", "ACSS2", "GPAM", "DGAT2", "ACLY"],
)

# %%
_tmp
# Out:
#        trait1  trait2  trait3
# SCD        10     -10     -10
# ACSS2      20     -20      20
# GPAM       30     -30     -30
# DGAT2      40     -40      40
# ACLY       50     -50     -50

# %%
_tmp_proj = mproj.transform(_tmp)

# %%
_tmp_proj.loc["LV246"]
# Out:
# trait1    0.041885
# trait2   -0.036533
# trait3   -0.005351
# Name: LV246, dtype: float64

# %% [markdown]
# # Looks for differences in scores of both methods

# %%
np.all(pharmadb_predictions.groupby(["trait", "drug"]).count() == 2)
# Out:
# True

# %%
def _compare(x):
    assert x.shape[0] == 2
    x_sign = np.sign(x["score_std"].values)
    x0 = x.iloc[0]["score_std"]
    x1 = x.iloc[1]["score_std"]

    return pd.Series(
        {"different_sign": x_sign[0] != x_sign[1], "score_difference": np.abs(x0 - x1)}
    )

# %%
pharmadb_predictions = pharmadb_predictions.set_index(["trait", "drug"]).join(
    pharmadb_predictions.groupby(["trait", "drug"]).apply(_compare)
)

# %%
pharmadb_predictions.head()
# Out:
#                                  disease   drug_name        method  score  \
# trait        drug
# DOID:0050741 DB00215  alcohol dependence  Citalopram    Gene-based  460.0
#              DB00215  alcohol dependence  Citalopram  Module-based  437.8
#              DB00704  alcohol dependence  Naltrexone    Gene-based  544.4
#              DB00704  alcohol dependence  Naltrexone  Module-based  562.8
#              DB00822  alcohol dependence  Disulfiram    Gene-based  598.2
#
#                       true_class  score_std  different_sign  score_difference
# trait        drug
# DOID:0050741 DB00215           1  -0.678885           False          0.581857
#              DB00215           1  -1.260741           False          0.581857
#              DB00704           1   0.265515           False          0.175062
#              DB00704           1   0.440577           False          0.175062
#              DB00822           1   0.867514           False          0.057599

# %%
def find_differences(trait_name):
    with pd.option_context(
        "display.max_rows", None, "display.max_columns", None, "max_colwidth", None
    ):
        _tmp = pharmadb_predictions[
            (pharmadb_predictions["disease"] == trait_name)
            & (pharmadb_predictions["different_sign"])
        ].sort_values(
            ["score_difference", "drug_name", "method"], ascending=[False, False, False]
        )
        display(_tmp)

# %% [markdown]
# ## any disease

# %%
with pd.option_context(
    "display.max_rows", None, "display.max_columns", None, "max_colwidth", None
):
    _tmp = pharmadb_predictions[
        (pharmadb_predictions["different_sign"])
        & (~pharmadb_predictions["disease"].str.contains("cancer"))  # avoid cancer
    ].sort_values(
        ["score_difference", "drug_name", "method"], ascending=[False, False, False]
    )
    display(_tmp.head(100))
# Out:
#                                          disease            drug_name  \
# trait      drug
# DOID:10763 DB01136                  hypertension           Carvedilol
#            DB01136                  hypertension           Carvedilol
# DOID:9008  DB01234           psoriatic arthritis        Dexamethasone
#            DB01234           psoriatic arthritis        Dexamethasone
#            DB00443           psoriatic arthritis        Betamethasone
#            DB00443           psoriatic arthritis        Betamethasone
# DOID:13189 DB01394                          gout           Colchicine
#            DB01394                          gout           Colchicine
# DOID:7147  DB00620        ankylosing spondylitis        Triamcinolone
#            DB00620        ankylosing spondylitis        Triamcinolone
# DOID:8577  DB01014            ulcerative colitis          Balsalazide
#            DB01014            ulcerative colitis          Balsalazide
# DOID:10763 DB00820                  hypertension            Tadalafil
#            DB00820                  hypertension            Tadalafil
# DOID:2841  DB00938                        asthma           Salmeterol
#            DB00938                        asthma           Salmeterol
# DOID:4989  DB00424                  pancreatitis          Hyoscyamine
#            DB00424                  pancreatitis          Hyoscyamine
#            DB00572                  pancreatitis             Atropine
#            DB00572                  pancreatitis             Atropine
# DOID:10763 DB01001                  hypertension           Salbutamol
#            DB01001                  hypertension           Salbutamol
#            DB00758                  hypertension          Clopidogrel
#            DB00758                  hypertension          Clopidogrel
#            DB00598                  hypertension            Labetalol
#            DB00598                  hypertension            Labetalol
# DOID:12365 DB00205                       malaria        Pyrimethamine
#            DB00205                       malaria        Pyrimethamine
# DOID:9352  DB00222      type 2 diabetes mellitus          Glimepiride
#            DB00222      type 2 diabetes mellitus          Glimepiride
# DOID:4481  DB01234             allergic rhinitis        Dexamethasone
#            DB01234             allergic rhinitis        Dexamethasone
#            DB00443             allergic rhinitis        Betamethasone
#            DB00443             allergic rhinitis        Betamethasone
# DOID:1936  DB00227               atherosclerosis           Lovastatin
#            DB00227               atherosclerosis           Lovastatin
# DOID:4481  DB00741             allergic rhinitis       Hydrocortisone
#            DB00741             allergic rhinitis       Hydrocortisone
# DOID:9074  DB00959  systemic lupus erythematosus   Methylprednisolone
#            DB00959  systemic lupus erythematosus   Methylprednisolone
# DOID:585   DB00999               nephrolithiasis  Hydrochlorothiazide
#            DB00999               nephrolithiasis  Hydrochlorothiazide
# DOID:1936  DB00973               atherosclerosis            Ezetimibe
#            DB00973               atherosclerosis            Ezetimibe
# DOID:10763 DB00521                  hypertension            Carteolol
#            DB00521                  hypertension            Carteolol
# DOID:9352  DB01200      type 2 diabetes mellitus        Bromocriptine
#            DB01200      type 2 diabetes mellitus        Bromocriptine
# DOID:8778  DB01014               Crohn's disease          Balsalazide
#            DB01014               Crohn's disease          Balsalazide
# DOID:10763 DB01194                  hypertension         Brinzolamide
#            DB01194                  hypertension         Brinzolamide
# DOID:1826  DB00909             epilepsy syndrome           Zonisamide
#            DB00909             epilepsy syndrome           Zonisamide
# DOID:10763 DB00384                  hypertension          Triamterene
#            DB00384                  hypertension          Triamterene
#            DB00374                  hypertension         Treprostinil
#            DB00374                  hypertension         Treprostinil
# DOID:3393  DB00177       coronary artery disease            Valsartan
#            DB00177       coronary artery disease            Valsartan
# DOID:8893  DB00635                     psoriasis           Prednisone
#            DB00635                     psoriasis           Prednisone
# DOID:10763 DB00350                  hypertension            Minoxidil
#            DB00350                  hypertension            Minoxidil
# DOID:10652 DB00190           Alzheimer's disease            Carbidopa
#            DB00190           Alzheimer's disease            Carbidopa
# DOID:12365 DB00806                       malaria       Pentoxifylline
#            DB00806                       malaria       Pentoxifylline
# DOID:8893  DB01091                     psoriasis           Butenafine
#            DB01091                     psoriasis           Butenafine
# DOID:7148  DB00338          rheumatoid arthritis           Omeprazole
#            DB00338          rheumatoid arthritis           Omeprazole
#            DB00736          rheumatoid arthritis         Esomeprazole
#            DB00736          rheumatoid arthritis         Esomeprazole
# DOID:11714 DB01016          gestational diabetes            Glyburide
#            DB01016          gestational diabetes            Glyburide
# DOID:4481  DB00959             allergic rhinitis   Methylprednisolone
#            DB00959             allergic rhinitis   Methylprednisolone
# DOID:2841  DB00535                        asthma             Cefdinir
#            DB00535                        asthma             Cefdinir
# DOID:7148  DB00795          rheumatoid arthritis        Sulfasalazine
#            DB00795          rheumatoid arthritis        Sulfasalazine
# DOID:2841  DB00860                        asthma         Prednisolone
#            DB00860                        asthma         Prednisolone
# DOID:9352  DB00284      type 2 diabetes mellitus             Acarbose
#            DB00284      type 2 diabetes mellitus             Acarbose
# DOID:2377  DB00953            multiple sclerosis          Rizatriptan
#            DB00953            multiple sclerosis          Rizatriptan
# DOID:9008  DB00995           psoriatic arthritis            Auranofin
#            DB00995           psoriatic arthritis            Auranofin
# DOID:9074  DB00635  systemic lupus erythematosus           Prednisone
#            DB00635  systemic lupus erythematosus           Prednisone
# DOID:2841  DB00741                        asthma       Hydrocortisone
#            DB00741                        asthma       Hydrocortisone
# DOID:3393  DB00700       coronary artery disease           Eplerenone
#            DB00700       coronary artery disease           Eplerenone
# DOID:10763 DB01203                  hypertension              Nadolol
#            DB01203                  hypertension              Nadolol
# DOID:3393  DB00627       coronary artery disease               Niacin
#            DB00627       coronary artery disease               Niacin
#
#                           method  score  true_class  score_std  \
# trait      drug
# DOID:10763 DB01136  Module-based  289.2           1  -3.283269
#            DB01136    Gene-based  560.2           1   0.442310
# DOID:9008  DB01234  Module-based  589.3           1   0.801257
#            DB01234    Gene-based  349.9           1  -1.910856
#            DB00443  Module-based  589.3           1   0.801257
#            DB00443    Gene-based  349.9           1  -1.910856
# DOID:13189 DB01394  Module-based  590.2           1   0.813506
#            DB01394    Gene-based  351.2           1  -1.896309
# DOID:7147  DB00620  Module-based  578.6           1   0.655624
#            DB00620    Gene-based  342.2           1  -1.997016
# DOID:8577  DB01014  Module-based  564.2           1   0.459632
#            DB01014    Gene-based  364.0           1  -1.753083
# DOID:10763 DB00820  Module-based  419.6           0  -1.508453
#            DB00820    Gene-based  582.4           0   0.690718
# DOID:2841  DB00938  Module-based  414.8           1  -1.573784
#            DB00938    Gene-based  574.2           1   0.598964
# DOID:4989  DB00424  Module-based  389.9           1  -1.912687
#            DB00424    Gene-based  538.3           1   0.197259
#            DB00572  Module-based  389.9           0  -1.912687
#            DB00572    Gene-based  538.3           0   0.197259
# DOID:10763 DB01001  Module-based  401.2           0  -1.758887
#            DB01001    Gene-based  551.8           0   0.348318
#            DB00758  Module-based  466.4           0  -0.871480
#            DB00758    Gene-based  626.6           0   1.185297
#            DB00598  Module-based  388.8           1  -1.927658
#            DB00598    Gene-based  526.2           1   0.061865
# DOID:12365 DB00205  Module-based  553.0           1   0.307194
#            DB00205    Gene-based  373.2           1  -1.650139
# DOID:9352  DB00222  Module-based  536.0           1   0.075815
#            DB00222    Gene-based  364.2           1  -1.750845
# DOID:4481  DB01234  Module-based  618.7           1   1.201407
#            DB01234    Gene-based  472.7           1  -0.536777
#            DB00443  Module-based  618.7           1   1.201407
#            DB00443    Gene-based  472.7           1  -0.536777
# DOID:1936  DB00227  Module-based  439.0           1  -1.244409
#            DB00227    Gene-based  563.4           1   0.478117
# DOID:4481  DB00741  Module-based  551.8           1   0.290861
#            DB00741    Gene-based  394.2           1  -1.415158
# DOID:9074  DB00959  Module-based  479.6           1  -0.691820
#            DB00959    Gene-based  610.6           1   1.006264
# DOID:585   DB00999  Module-based  474.2           1  -0.765317
#            DB00999    Gene-based  599.4           1   0.880941
# DOID:1936  DB00973  Module-based  420.2           1  -1.500287
#            DB00973    Gene-based  533.0           1   0.137954
# DOID:10763 DB00521  Module-based  445.0           0  -1.162745
#            DB00521    Gene-based  560.8           0   0.449024
# DOID:9352  DB01200  Module-based  419.4           1  -1.511175
#            DB01200    Gene-based  528.2           1   0.084244
# DOID:8778  DB01014  Module-based  463.8           1  -0.906867
#            DB01014    Gene-based  581.2           1   0.677291
# DOID:10763 DB01194  Module-based  569.2           0   0.527685
#            DB01194    Gene-based  431.4           0  -0.998906
# DOID:1826  DB00909  Module-based  474.2           1  -0.765317
#            DB00909    Gene-based  585.6           1   0.726525
# DOID:10763 DB00384  Module-based  568.2           1   0.514074
#            DB00384    Gene-based  434.0           1  -0.969813
#            DB00374  Module-based  638.8           0   1.474979
#            DB00374    Gene-based  520.6           0  -0.000797
# DOID:3393  DB00177  Module-based  431.0           1  -1.353293
#            DB00177    Gene-based  531.6           1   0.122288
# DOID:8893  DB00635  Module-based  471.4           1  -0.803427
#            DB00635    Gene-based  574.6           1   0.603440
# DOID:10763 DB00350  Module-based  471.0           1  -0.808871
#            DB00350    Gene-based  573.0           1   0.585537
# DOID:10652 DB00190  Module-based  467.4           0  -0.857869
#            DB00190    Gene-based  566.8           0   0.516161
# DOID:12365 DB00806  Module-based  443.6           1  -1.181800
#            DB00806    Gene-based  537.4           1   0.187188
# DOID:8893  DB01091  Module-based  443.4           0  -1.184522
#            DB01091    Gene-based  536.6           0   0.178236
# DOID:7148  DB00338  Module-based  494.7           0  -0.486301
#            DB00338    Gene-based  597.9           0   0.864157
#            DB00736  Module-based  494.7           0  -0.486301
#            DB00736    Gene-based  597.9           0   0.864157
# DOID:11714 DB01016  Module-based  592.6           1   0.846172
#            DB01016    Gene-based  475.8           1  -0.502089
# DOID:4481  DB00959  Module-based  538.4           1   0.108480
#            DB00959    Gene-based  411.0           1  -1.227173
# DOID:2841  DB00535  Module-based  439.8           0  -1.233520
#            DB00535    Gene-based  521.0           0   0.003679
# DOID:7148  DB00795  Module-based  465.0           1  -0.890534
#            DB00795    Gene-based  551.2           1   0.341604
# DOID:2841  DB00860  Module-based  494.6           1  -0.487662
#            DB00860    Gene-based  586.2           1   0.733239
# DOID:9352  DB00284  Module-based  552.0           1   0.293583
#            DB00284    Gene-based  438.6           1  -0.918341
# DOID:2377  DB00953  Module-based  475.4           0  -0.748985
#            DB00953    Gene-based  560.0           0   0.440072
# DOID:9008  DB00995  Module-based  579.4           1   0.666512
#            DB00995    Gene-based  474.0           1  -0.522231
# DOID:9074  DB00635  Module-based  559.6           1   0.397023
#            DB00635    Gene-based  453.0           1  -0.757212
# DOID:2841  DB00741  Module-based  520.0           1  -0.141954
#            DB00741    Gene-based  610.4           1   1.004026
# DOID:3393  DB00700  Module-based  538.6           1   0.111202
#            DB00700    Gene-based  428.2           1  -1.034713
# DOID:10763 DB01203  Module-based  479.2           1  -0.697265
#            DB01203    Gene-based  560.0           1   0.440072
# DOID:3393  DB00627  Module-based  601.0           1   0.960500
#            DB00627    Gene-based  505.6           1  -0.168640
#
#                     different_sign  score_difference
# trait      drug
# DOID:10763 DB01136            True          3.725579
#            DB01136            True          3.725579
# DOID:9008  DB01234            True          2.712113
#            DB01234            True          2.712113
#            DB00443            True          2.712113
#            DB00443            True          2.712113
# DOID:13189 DB01394            True          2.709816
#            DB01394            True          2.709816
# DOID:7147  DB00620            True          2.652639
#            DB00620            True          2.652639
# DOID:8577  DB01014            True          2.212715
#            DB01014            True          2.212715
# DOID:10763 DB00820            True          2.199172
#            DB00820            True          2.199172
# DOID:2841  DB00938            True          2.172748
#            DB00938            True          2.172748
# DOID:4989  DB00424            True          2.109945
#            DB00424            True          2.109945
#            DB00572            True          2.109945
#            DB00572            True          2.109945
# DOID:10763 DB01001            True          2.107205
#            DB01001            True          2.107205
#            DB00758            True          2.056777
#            DB00758            True          2.056777
#            DB00598            True          1.989523
#            DB00598            True          1.989523
# DOID:12365 DB00205            True          1.957333
#            DB00205            True          1.957333
# DOID:9352  DB00222            True          1.826660
#            DB00222            True          1.826660
# DOID:4481  DB01234            True          1.738184
#            DB01234            True          1.738184
#            DB00443            True          1.738184
#            DB00443            True          1.738184
# DOID:1936  DB00227            True          1.722525
#            DB00227            True          1.722525
# DOID:4481  DB00741            True          1.706019
#            DB00741            True          1.706019
# DOID:9074  DB00959            True          1.698085
#            DB00959            True          1.698085
# DOID:585   DB00999            True          1.646258
#            DB00999            True          1.646258
# DOID:1936  DB00973            True          1.638241
#            DB00973            True          1.638241
# DOID:10763 DB00521            True          1.611769
#            DB00521            True          1.611769
# DOID:9352  DB01200            True          1.595419
#            DB01200            True          1.595419
# DOID:8778  DB01014            True          1.584158
#            DB01014            True          1.584158
# DOID:10763 DB01194            True          1.526591
#            DB01194            True          1.526591
# DOID:1826  DB00909            True          1.491842
#            DB00909            True          1.491842
# DOID:10763 DB00384            True          1.483888
#            DB00384            True          1.483888
#            DB00374            True          1.475776
#            DB00374            True          1.475776
# DOID:3393  DB00177            True          1.475582
#            DB00177            True          1.475582
# DOID:8893  DB00635            True          1.406867
#            DB00635            True          1.406867
# DOID:10763 DB00350            True          1.394408
#            DB00350            True          1.394408
# DOID:10652 DB00190            True          1.374030
#            DB00190            True          1.374030
# DOID:12365 DB00806            True          1.368988
#            DB00806            True          1.368988
# DOID:8893  DB01091            True          1.362759
#            DB01091            True          1.362759
# DOID:7148  DB00338            True          1.350458
#            DB00338            True          1.350458
#            DB00736            True          1.350458
#            DB00736            True          1.350458
# DOID:11714 DB01016            True          1.348261
#            DB01016            True          1.348261
# DOID:4481  DB00959            True          1.335653
#            DB00959            True          1.335653
# DOID:2841  DB00535            True          1.237199
#            DB00535            True          1.237199
# DOID:7148  DB00795            True          1.232138
#            DB00795            True          1.232138
# DOID:2841  DB00860            True          1.220901
#            DB00860            True          1.220901
# DOID:9352  DB00284            True          1.211925
#            DB00284            True          1.211925
# DOID:2377  DB00953            True          1.189057
#            DB00953            True          1.189057
# DOID:9008  DB00995            True          1.188743
#            DB00995            True          1.188743
# DOID:9074  DB00635            True          1.154235
#            DB00635            True          1.154235
# DOID:2841  DB00741            True          1.145981
#            DB00741            True          1.145981
# DOID:3393  DB00700            True          1.145915
#            DB00700            True          1.145915
# DOID:10763 DB01203            True          1.137337
#            DB01203            True          1.137337
# DOID:3393  DB00627            True          1.129140
#            DB00627            True          1.129140

# %% [markdown]
# ## coronary artery disease

# %%
find_differences("coronary artery disease")
# Out:
#                                    disease    drug_name        method  score  \
# trait     drug
# DOID:3393 DB00177  coronary artery disease    Valsartan  Module-based  431.0
#           DB00177  coronary artery disease    Valsartan    Gene-based  531.6
#           DB00700  coronary artery disease   Eplerenone  Module-based  538.6
#           DB00700  coronary artery disease   Eplerenone    Gene-based  428.2
#           DB00627  coronary artery disease       Niacin  Module-based  601.0
#           DB00627  coronary artery disease       Niacin    Gene-based  505.6
#           DB01197  coronary artery disease    Captopril  Module-based  580.2
#           DB01197  coronary artery disease    Captopril    Gene-based  488.2
#           DB00988  coronary artery disease     Dopamine  Module-based  527.6
#           DB00988  coronary artery disease     Dopamine    Gene-based  560.6
#           DB00790  coronary artery disease  Perindopril  Module-based  555.8
#           DB00790  coronary artery disease  Perindopril    Gene-based  519.8
#           DB00175  coronary artery disease  Pravastatin  Module-based  547.0
#           DB00175  coronary artery disease  Pravastatin    Gene-based  515.8
#           DB01583  coronary artery disease      Liotrix  Module-based  534.0
#           DB01583  coronary artery disease      Liotrix    Gene-based  501.8
#
#                    true_class  score_std  different_sign  score_difference
# trait     drug
# DOID:3393 DB00177           1  -1.353293            True          1.475582
#           DB00177           1   0.122288            True          1.475582
#           DB00700           1   0.111202            True          1.145915
#           DB00700           1  -1.034713            True          1.145915
#           DB00627           1   0.960500            True          1.129140
#           DB00627           1  -0.168640            True          1.129140
#           DB01197           1   0.677401            True          1.040740
#           DB01197           1  -0.363339            True          1.040740
#           DB00988           0  -0.038514            True          0.485300
#           DB00988           0   0.446786            True          0.485300
#           DB00790           1   0.345303            True          0.355052
#           DB00790           1  -0.009748            True          0.355052
#           DB00175           1   0.225531            True          0.280037
#           DB00175           1  -0.054507            True          0.280037
#           DB01583           0   0.048593            True          0.259754
#           DB01583           0  -0.211161            True          0.259754

# %% [markdown]
# ## atherosclerosis

# %%
find_differences("atherosclerosis")
# Out:
#                            disease    drug_name        method  score  \
# trait     drug
# DOID:1936 DB00227  atherosclerosis   Lovastatin  Module-based  439.0
#           DB00227  atherosclerosis   Lovastatin    Gene-based  563.4
#           DB00973  atherosclerosis    Ezetimibe  Module-based  420.2
#           DB00973  atherosclerosis    Ezetimibe    Gene-based  533.0
#           DB00758  atherosclerosis  Clopidogrel  Module-based  503.2
#           DB00758  atherosclerosis  Clopidogrel    Gene-based  582.2
#           DB00627  atherosclerosis       Niacin  Module-based  568.6
#           DB00627  atherosclerosis       Niacin    Gene-based  512.6
#
#                    true_class  score_std  different_sign  score_difference
# trait     drug
# DOID:1936 DB00227           1  -1.244409            True          1.722525
#           DB00227           1   0.478117            True          1.722525
#           DB00973           1  -1.500287            True          1.638241
#           DB00973           1   0.137954            True          1.638241
#           DB00758           0  -0.370611            True          1.059092
#           DB00758           0   0.688481            True          1.059092
#           DB00627           1   0.519518            True          0.609832
#           DB00627           1  -0.090313            True          0.609832

# %% [markdown]
# # Niacin and vascular diseases

# %%
from entity import Trait

# %%
d = Trait.get_trait(
    full_code="I25-Diagnoses_main_ICD10_I25_Chronic_ischaemic_heart_disease"
)

# %%
d.get_efo_info()
# Out:
# EfoInfo(id='EFO:0001645', label='coronary artery disease')

# %%
d.get_do_info()
# Out:
# EfoInfo(id=['DOID:3393'], label=None)

# %%
dd = Trait.get_trait(full_code="CARDIoGRAM_C4D_CAD_ADDITIVE")

# %%
dd.get_do_info()
# Out:
# EfoInfo(id=['DOID:3393'], label=None)

# %%
_common_genes = multiplier_z.index.intersection(smultixcan_zscores.index)
display(_common_genes.shape)
# Out:
# (6416,)

# %%
z_genes = multiplier_z["LV246"].sort_values(ascending=False)
display(z_genes.head(10))
# Out:
# SCD      6.672060
# ACSS2    6.258514
# GPAM     5.714077
# DGAT2    4.738347
# ACLY     3.708678
# GPD1     3.346001
# MVD      3.320598
# FASN     2.915241
# LPL      2.858278
# ACSL1    2.682199
# Name: LV246, dtype: float64

# %%
gene_zscores = smultixcan_zscores[
    "I70-Diagnoses_main_ICD10_I70_Atherosclerosis"
].sort_values(ascending=False)
display(gene_zscores.head(10))

z_genes.loc[_common_genes].dot(gene_zscores.loc[_common_genes])
# Out:
# gene_name
# ANGPTL6           4.406559
# C8orf37           4.281967
# LL22NC03-2H8.4    4.275022
# NMRK1             4.123662
# TUB               3.975139
# RP11-147G16.1     3.869610
# C19orf66          3.807595
# TRH               3.795503
# MTPN              3.751397
# ELN               3.672622
# Name: I70-Diagnoses_main_ICD10_I70_Atherosclerosis, dtype: float64
# 251.206262115323

# %%
display(gene_zscores.name)
z_genes.loc[_common_genes].dot(gene_zscores.loc[_common_genes])
# Out:
# 'I70-Diagnoses_main_ICD10_I70_Atherosclerosis'
# 251.206262115323

# %%
display(gene_zscores.name)
z_genes.loc[_common_genes].dot(gene_zscores.loc[_common_genes])
# Out:
# 'I70-Diagnoses_main_ICD10_I70_Atherosclerosis'
# 251.206262115323

# %%
lincs_data.loc["DB00627", "LDLR"]
# Out:
# -3.322

# %%
lincs_data.loc["DB00627", "LPL"]
# Out:
# 1.305

# %%
smultixcan_proj.loc["LV246", "coronary artery disease"]
# Out:
# 0.050205810032839915

# %%
smultixcan_proj["coronary artery disease"].describe()
# Out:
# count    987.000000
# mean       0.001821
# std        0.040750
# min       -0.085158
# 25%       -0.022395
# 50%       -0.004310
# 75%        0.021285
# max        0.285909
# Name: coronary artery disease, dtype: float64

# %%
smultixcan_proj["coronary artery disease"].sort_values(ascending=False).head(40)
# Out:
# LV688    0.285909
# LV140    0.255131
# LV455    0.230422
# LV136    0.210545
# LV574    0.200082
# LV479    0.166240
# LV309    0.161377
# LV597    0.157898
# LV331    0.157337
# LV650    0.145811
# LV301    0.136925
# LV766    0.130056
# LV145    0.124132
# LV916    0.121425
# LV885    0.112923
# LV131    0.111845
# LV914    0.106631
# LV19     0.100657
# LV952    0.098271
# LV345    0.097711
# LV302    0.091947
# LV858    0.091247
# LV561    0.089119
# LV503    0.084928
# LV566    0.084820
# LV764    0.084409
# LV12     0.084010
# LV757    0.083889
# LV615    0.083839
# LV217    0.083804
# LV130    0.083110
# LV291    0.082544
# LV33     0.081060
# LV541    0.080280
# LV811    0.079341
# LV925    0.079257
# LV183    0.078733
# LV184    0.078089
# LV637    0.077818
# LV863    0.077808
# Name: coronary artery disease, dtype: float64

# %%
smultixcan_proj.loc["LV246", "atherosclerosis"]
# Out:
# 0.004372351336443016

# %%
smultixcan_proj["atherosclerosis"].describe()
# Out:
# count    987.000000
# mean       0.001284
# std        0.031977
# min       -0.089754
# 25%       -0.020391
# 50%       -0.002008
# 75%        0.022456
# max        0.114301
# Name: atherosclerosis, dtype: float64

# %%
smultixcan_proj["atherosclerosis"].sort_values(ascending=False).head(40)
# Out:
# LV454    0.114301
# LV617    0.105424
# LV978    0.089881
# LV439    0.088056
# LV351    0.087743
# LV416    0.085818
# LV924    0.083838
# LV882    0.080570
# LV272    0.079342
# LV759    0.078313
# LV433    0.076840
# LV868    0.076766
# LV149    0.076518
# LV496    0.076100
# LV396    0.075142
# LV744    0.074974
# LV363    0.074817
# LV495    0.074692
# LV535    0.074438
# LV247    0.074219
# LV630    0.072699
# LV25     0.072543
# LV220    0.070199
# LV333    0.070190
# LV646    0.069706
# LV524    0.069418
# LV204    0.068682
# LV794    0.068218
# LV608    0.065499
# LV842    0.064531
# LV64     0.063908
# LV29     0.063853
# LV44     0.062224
# LV961    0.061330
# LV377    0.060955
# LV219    0.060578
# LV955    0.060427
# LV4      0.059981
# LV17     0.059905
# LV271    0.059019
# Name: atherosclerosis, dtype: float64

# %%
_doid = "DOID:1936"
_phenomexcan_traits = ["I70-Diagnoses_main_ICD10_I70_Atherosclerosis"]

# _doid = "DOID:3393"
# _phenomexcan_traits = [
#     "I25-Diagnoses_main_ICD10_I25_Chronic_ischaemic_heart_disease",
#     "CARDIoGRAM_C4D_CAD_ADDITIVE"
# ]

_drug_id = "DB00627"
_drug_name = "Niacin"

# %%
pharmadb_predictions[pharmadb_predictions["drug_name"] == _drug_name].sort_values(
    ["disease", "method"]
)
# Out:
#                                    disease drug_name        method  score  \
# trait     drug
# DOID:1936 DB00627          atherosclerosis    Niacin    Gene-based  512.6
#           DB00627          atherosclerosis    Niacin  Module-based  568.6
# DOID:3393 DB00627  coronary artery disease    Niacin    Gene-based  505.6
#           DB00627  coronary artery disease    Niacin  Module-based  601.0
# DOID:4989 DB00627             pancreatitis    Niacin    Gene-based  485.2
#           DB00627             pancreatitis    Niacin  Module-based  518.8
#
#                    true_class  score_std  different_sign  score_difference
# trait     drug
# DOID:1936 DB00627           1  -0.090313            True          0.609832
#           DB00627           1   0.519518            True          0.609832
# DOID:3393 DB00627           1  -0.168640            True          1.129140
#           DB00627           1   0.960500            True          1.129140
# DOID:4989 DB00627           0  -0.396907           False          0.238621
#           DB00627           0  -0.158287           False          0.238621

# %%
predictions_avg[
    (predictions_avg["trait"] == _doid) & (predictions_avg["drug"] == _drug_id)
]
# Out:
#          trait     drug        method  score  true_class
# 588  DOID:1936  DB00627    Gene-based  512.6         1.0
# 589  DOID:1936  DB00627  Module-based  568.6         1.0

# %%
with pd.option_context(
    "display.max_rows", None, "display.max_columns", None, "max_colwidth", None
):
    _tmp = (
        predictions_by_tissue[
            (predictions_by_tissue["trait"] == _doid)
            & (predictions_by_tissue["drug"] == _drug_id)
        ]
        .groupby("method")["score"]
        .idxmax()
    )
    display(predictions_by_tissue.loc[_tmp.values])

    _tmp = predictions_by_tissue.loc[_tmp.values][["method", "tissue"]].set_index(
        "method"
    )
    _gene_based_tissue = _tmp.loc["Gene-based", "tissue"]
    display(_gene_based_tissue)

    _module_tissue = _tmp.loc["Module-based", "tissue"]
    display(_module_tissue)
# Out:
#            trait     drug        method                      tissue  score  \
# 28856  DOID:1936  DB00627    Gene-based                      Testis  512.6
# 28881  DOID:1936  DB00627  Module-based  Cells_Cultured_fibroblasts  568.6
#
#        true_class
# 28856         1.0
# 28881         1.0
# 'Testis'
# 'Cells_Cultured_fibroblasts'

# %%
# predictions_by_tissue[
#     (predictions_by_tissue["trait"] == _doid)
#     & (predictions_by_tissue["drug"] == _drug_id)
# ].sort_values("score", ascending=False)

# %%
# _module_tissue = "Adipose_Subcutaneous"

# %% [markdown]
# ### Gene module-based - LVs driving association

# %%
_module_tissue_data_raw = pd.read_pickle(
    INPUT_DATA_DIR / "raw" / f"spredixcan-mashr-zscores-{_module_tissue}-data.pkl"
)
_module_tissue_data_raw = _module_tissue_data_raw.rename(index=Gene.GENE_ID_TO_NAME_MAP)

display(_module_tissue_data_raw.shape)
display(_module_tissue_data_raw.head())
# Out:
# (13395, 4091)
#          I9_PHLETHROMBDVTLOW-DVT_of_lower_extremities  \
# gene_id
# SCYL3                                        1.542728
# CFH                                          2.221978
# FUCA2                                       -1.290055
# GCLC                                         1.039654
# STPG1                                       -0.848960
#
#          I71-Diagnoses_main_ICD10_I71_Aortic_aneurysm_and_dissection  \
# gene_id
# SCYL3                                             0.374937
# CFH                                              -0.029211
# FUCA2                                             0.997560
# GCLC                                              0.020216
# STPG1                                             0.083508
#
#          G62-Diagnoses_main_ICD10_G62_Other_polyneuropathies  \
# gene_id
# SCYL3                                            -1.180026
# CFH                                              -0.082311
# FUCA2                                            -0.608218
# GCLC                                             -0.175122
# STPG1                                            -0.112559
#
#          2395_4-Hairbalding_pattern_Pattern_4  \
# gene_id
# SCYL3                                3.617304
# CFH                                 -0.707300
# FUCA2                               -0.704553
# GCLC                                 0.427606
# STPG1                               -3.302466
#
#          20003_1141168590-Treatmentmedication_code_pariet_10mg_ec_tablet  \
# gene_id
# SCYL3                                            -1.436877
# CFH                                               0.860528
# FUCA2                                            -1.278815
# GCLC                                             -0.152778
# STPG1                                            -0.956408
#
#          4056_raw-Age_stroke_diagnosed  \
# gene_id
# SCYL3                        -1.150046
# CFH                          -0.435167
# FUCA2                        -1.201553
# GCLC                          2.209256
# STPG1                        -0.402499
#
#          M13_FOREIGNBODY-Residual_foreign_body_in_soft_tissue  \
# gene_id
# SCYL3                                            -0.671733
# CFH                                               0.210884
# FUCA2                                             0.817245
# GCLC                                              0.484214
# STPG1                                            -0.236055
#
#          20002_1494-Noncancer_illness_code_selfreported_varicose_veins  \
# gene_id
# SCYL3                                             0.681798
# CFH                                               1.454587
# FUCA2                                             0.653960
# GCLC                                              1.482017
# STPG1                                            -0.007223
#
#          I85-Diagnoses_main_ICD10_I85_Oesophageal_varices  \
# gene_id
# SCYL3                                            1.653683
# CFH                                              1.331105
# FUCA2                                            0.318084
# GCLC                                             0.495467
# STPG1                                            1.315015
#
#          6158_4-Why_reduced_smoking_Financial_reasons  ...  \
# gene_id                                                ...
# SCYL3                                        1.580276  ...
# CFH                                         -0.155145  ...
# FUCA2                                       -0.600657  ...
# GCLC                                        -1.217398  ...
# STPG1                                        0.550110  ...
#
#          41215_0-Detention_categories_Informal_not_formally_detained  \
# gene_id
# SCYL3                                             0.100557
# CFH                                               3.271953
# FUCA2                                            -2.057690
# GCLC                                              0.538651
# STPG1                                             2.092645
#
#          M76-Diagnoses_main_ICD10_M76_Enthesopathies_of_lower_limb_excluding_foot  \
# gene_id
# SCYL3                                             1.150549
# CFH                                              -0.805236
# FUCA2                                             0.036173
# GCLC                                             -0.282506
# STPG1                                             0.320062
#
#          22601_35633208-Job_coding_vocational_or_industrial_trainerinstructor  \
# gene_id
# SCYL3                                            -0.099058
# CFH                                              -1.050279
# FUCA2                                             0.498194
# GCLC                                             -0.253741
# STPG1                                             0.584716
#
#          H7_RETINALDETACH-Retinal_detachments_and_breaks  \
# gene_id
# SCYL3                                          -0.522253
# CFH                                            -0.311062
# FUCA2                                           0.824913
# GCLC                                           -0.948048
# STPG1                                          -0.415151
#
#          20003_1141172918-Treatmentmedication_code_celluvisc_1_singleuse_eye_drops  \
# gene_id
# SCYL3                                            -0.875756
# CFH                                              -0.266324
# FUCA2                                             0.674138
# GCLC                                             -0.561655
# STPG1                                             0.542228
#
#          22601_35643209-Job_coding_careers_adviser_or_vocational_guidance_specialist_placement_advisor  \
# gene_id
# SCYL3                                            -0.323892
# CFH                                              -0.961981
# FUCA2                                             0.121689
# GCLC                                              0.990805
# STPG1                                            -0.520030
#
#          20002_1537-Noncancer_illness_code_selfreported_joint_pain  \
# gene_id
# SCYL3                                            -1.355607
# CFH                                               1.025476
# FUCA2                                            -0.093050
# GCLC                                              1.286077
# STPG1                                             0.912408
#
#          20514-Recent_lack_of_interest_or_pleasure_in_doing_things  \
# gene_id
# SCYL3                                             0.546768
# CFH                                               1.432934
# FUCA2                                             2.578375
# GCLC                                              1.382912
# STPG1                                             0.971265
#
#          22601_53192534-Job_coding_builder_building_contractor  \
# gene_id
# SCYL3                                            -2.618420
# CFH                                               1.262197
# FUCA2                                            -0.591618
# GCLC                                              0.836434
# STPG1                                             1.032357
#
#          30280_raw-Immature_reticulocyte_fraction
# gene_id
# SCYL3                                   -0.003352
# CFH                                     -0.042457
# FUCA2                                   -1.505238
# GCLC                                    -0.015618
# STPG1                                   -1.008020
#
# [5 rows x 4091 columns]

# %%
_module_tissue_data_raw.index.is_unique
# Out:
# False

# %%
_module_tissue_data_raw.index[_module_tissue_data_raw.index.duplicated(keep="first")]
# Out:
# Index(['SPATA13', 'LINC00484'], dtype='object', name='gene_id')

# %%
_module_tissue_data_raw = _module_tissue_data_raw.loc[
    ~_module_tissue_data_raw.index.duplicated(keep="first")
]

# %%
_module_tissue_data_raw.shape
# Out:
# (13393, 4091)

# %%
_module_tissue_data_raw.index.is_unique
# Out:
# True

# %%
_module_tissue_data = pd.read_pickle(
    INPUT_DATA_DIR
    / "proj"
    / f"spredixcan-mashr-zscores-{_module_tissue}-projection.pkl"
)
display(_module_tissue_data.head())
# Out:
#      I9_PHLETHROMBDVTLOW-DVT_of_lower_extremities  \
# LV1                                     -0.019600
# LV2                                      0.045221
# LV3                                     -0.012891
# LV4                                     -0.012022
# LV5                                     -0.010747
#
#      I71-Diagnoses_main_ICD10_I71_Aortic_aneurysm_and_dissection  \
# LV1                                           0.037370
# LV2                                           0.015686
# LV3                                           0.002663
# LV4                                           0.002787
# LV5                                           0.000051
#
#      G62-Diagnoses_main_ICD10_G62_Other_polyneuropathies  \
# LV1                                           0.015432
# LV2                                          -0.018787
# LV3                                           0.045862
# LV4                                           0.006922
# LV5                                          -0.016533
#
#      2395_4-Hairbalding_pattern_Pattern_4  \
# LV1                              0.103213
# LV2                              0.003183
# LV3                             -0.024472
# LV4                             -0.038151
# LV5                              0.035076
#
#      20003_1141168590-Treatmentmedication_code_pariet_10mg_ec_tablet  \
# LV1                                          -0.043647
# LV2                                           0.015054
# LV3                                           0.020005
# LV4                                           0.034503
# LV5                                           0.002675
#
#      4056_raw-Age_stroke_diagnosed  \
# LV1                       0.017953
# LV2                       0.006919
# LV3                      -0.020490
# LV4                       0.009894
# LV5                       0.011499
#
#      M13_FOREIGNBODY-Residual_foreign_body_in_soft_tissue  \
# LV1                                          -0.017080
# LV2                                          -0.032647
# LV3                                          -0.027314
# LV4                                           0.018250
# LV5                                           0.011403
#
#      20002_1494-Noncancer_illness_code_selfreported_varicose_veins  \
# LV1                                          -0.040636
# LV2                                           0.034986
# LV3                                          -0.024277
# LV4                                           0.019581
# LV5                                           0.012799
#
#      I85-Diagnoses_main_ICD10_I85_Oesophageal_varices  \
# LV1                                          0.034560
# LV2                                         -0.004918
# LV3                                          0.035376
# LV4                                          0.020272
# LV5                                          0.009265
#
#      6158_4-Why_reduced_smoking_Financial_reasons  ...  \
# LV1                                     -0.013533  ...
# LV2                                      0.003432  ...
# LV3                                      0.010420  ...
# LV4                                     -0.023895  ...
# LV5                                      0.035350  ...
#
#      41215_0-Detention_categories_Informal_not_formally_detained  \
# LV1                                           0.053705
# LV2                                           0.012654
# LV3                                          -0.015451
# LV4                                          -0.022380
# LV5                                          -0.011572
#
#      M76-Diagnoses_main_ICD10_M76_Enthesopathies_of_lower_limb_excluding_foot  \
# LV1                                          -0.021551
# LV2                                          -0.002942
# LV3                                           0.005034
# LV4                                          -0.035518
# LV5                                          -0.016130
#
#      22601_35633208-Job_coding_vocational_or_industrial_trainerinstructor  \
# LV1                                           0.015006
# LV2                                          -0.037361
# LV3                                          -0.006526
# LV4                                          -0.028791
# LV5                                          -0.011499
#
#      H7_RETINALDETACH-Retinal_detachments_and_breaks  \
# LV1                                         0.020924
# LV2                                         0.023963
# LV3                                         0.024579
# LV4                                        -0.021367
# LV5                                        -0.027826
#
#      20003_1141172918-Treatmentmedication_code_celluvisc_1_singleuse_eye_drops  \
# LV1                                           0.063630
# LV2                                           0.001036
# LV3                                           0.035953
# LV4                                          -0.018474
# LV5                                          -0.012679
#
#      22601_35643209-Job_coding_careers_adviser_or_vocational_guidance_specialist_placement_advisor  \
# LV1                                           0.014546
# LV2                                          -0.009236
# LV3                                          -0.001680
# LV4                                           0.012211
# LV5                                           0.037951
#
#      20002_1537-Noncancer_illness_code_selfreported_joint_pain  \
# LV1                                           0.031569
# LV2                                          -0.047476
# LV3                                           0.007341
# LV4                                          -0.003103
# LV5                                           0.067566
#
#      20514-Recent_lack_of_interest_or_pleasure_in_doing_things  \
# LV1                                           0.025669
# LV2                                          -0.033387
# LV3                                          -0.006215
# LV4                                          -0.011157
# LV5                                          -0.046590
#
#      22601_53192534-Job_coding_builder_building_contractor  \
# LV1                                          -0.032848
# LV2                                           0.019026
# LV3                                          -0.022623
# LV4                                          -0.001598
# LV5                                          -0.018380
#
#      30280_raw-Immature_reticulocyte_fraction
# LV1                                  0.050867
# LV2                                  0.000041
# LV3                                 -0.051306
# LV4                                  0.056887
# LV5                                  0.004543
#
# [5 rows x 4091 columns]

# %%
_all_dfs = []

for ntc in (None, 5, 10, 25, 50):
    _prefix = "all_genes"
    if ntc is not None:
        _prefix = f"top_{ntc}_genes"

    _df = pd.read_hdf(
        OUTPUT_PREDICTIONS_DIR
        / f"spredixcan-mashr-zscores-{_module_tissue}-projection-{_prefix}-prediction_scores.h5",
        key="prediction",
    )

    _score_col_name = f"score_{_prefix}"
    _df = (
        pd.merge(_df, gold_standard, on=["trait", "drug"], how="inner")
        .drop(columns=["true_class"])
        .set_index(["trait", "drug"])
        .rename(columns={"score": _score_col_name})
    )

    _df[_score_col_name] = _df[_score_col_name].rank()

    _all_dfs.append(_df)

# %%
_predictions_tissue = pd.concat(_all_dfs, axis=1, join="inner")  # .mean(axis=1)

# %%
_predictions_tissue.shape
# Out:
# (646, 5)

# %%
_predictions_tissue.head()
# Out:
#                       score_all_genes  score_top_5_genes  score_top_10_genes  \
# trait        drug
# DOID:0050741 DB00215            281.0              481.0               186.0
#              DB00704            505.0              559.0               523.0
#              DB00822            278.0              329.0               397.0
# DOID:10283   DB00014            115.0               77.0               148.0
#              DB00175            490.0              157.0               285.0
#
#                       score_top_25_genes  score_top_50_genes
# trait        drug
# DOID:0050741 DB00215                83.0               100.0
#              DB00704               533.0               420.0
#              DB00822                61.0               134.0
# DOID:10283   DB00014               190.0                89.0
#              DB00175               112.0               146.0

# %%
_predictions_tissue = _predictions_tissue.mean(axis=1)

# %%
display(_predictions_tissue.shape)
display(_predictions_tissue.head())

assert _df.shape[0] == _predictions_tissue.shape[0]
assert not _predictions_tissue.isna().any().any()
# Out:
# (646,)
# trait         drug
# DOID:0050741  DB00215    226.2
#               DB00704    508.0
#               DB00822    239.8
# DOID:10283    DB00014    123.8
#               DB00175    238.0
# dtype: float64

# %%
_predictions_tissue.loc[
    _doid, _drug_id
]  # .query(f"(trait == '{_doid}') and (drug == '{_drug_id}')")
# Out:
# 568.6

# %%
# FIXME: add assert here to make sure this number above is the same in predictions_avg

# %%
# _traits_proj = pd.read_pickle(INPUT_DATA_DIR / "proj" / f"spredixcan-mashr-zscores-{_module_tissue}-projection.pkl")

_module_tissue_data = _module_tissue_data[
    _phenomexcan_traits[0]
    #     "C62-Diagnoses_main_ICD10_C62_Malignant_neoplasm_of_testis",
    #     "I25-Diagnoses_main_ICD10_I25_Chronic_ischaemic_heart_disease",
].to_frame()

# _traits_proj = _traits_proj.apply(
#     lambda x: _zero_nontop_genes(x, 50, use_abs=True)
# )

# %%
_module_tissue_data.head()
# Out:
#      I70-Diagnoses_main_ICD10_I70_Atherosclerosis
# LV1                                      0.005720
# LV2                                     -0.002927
# LV3                                      0.002734
# LV4                                      0.015454
# LV5                                      0.027796

# %%
_module_tissue_data.squeeze().sort_values()
# Out:
# LV329   -0.084602
# LV318   -0.073914
# LV802   -0.071899
# LV377   -0.068738
# LV220   -0.068666
#            ...
# LV927    0.069571
# LV697    0.073310
# LV550    0.074915
# LV454    0.077556
# LV744    0.086199
# Name: I70-Diagnoses_main_ICD10_I70_Atherosclerosis, Length: 987, dtype: float64

# %%
lincs_projection.T[_drug_id].sort_values()
# Out:
# LV841   -0.086833
# LV163   -0.080580
# LV161   -0.070249
# LV931   -0.069832
# LV9     -0.069249
#            ...
# LV974    0.053342
# LV38     0.088232
# LV743    0.097299
# LV116    0.097558
# LV881    0.154953
# Name: DB00627, Length: 987, dtype: float64

# %%
_tmp = (-1.0 * lincs_projection.loc[_drug_id].dot(_module_tissue_data)).sort_values(
    ascending=False
)
display(_tmp)

_top_phenomexcan_trait = _tmp.index[0]
display(_top_phenomexcan_trait)
# Out:
# I70-Diagnoses_main_ICD10_I70_Atherosclerosis    0.023
# Name: DB00627, dtype: float64
# 'I70-Diagnoses_main_ICD10_I70_Atherosclerosis'

# %%
_tmp = (
    lincs_projection.loc[_drug_id]
    .multiply(_module_tissue_data[_top_phenomexcan_trait])
    .sort_values(ascending=True)
)
display(_tmp[_tmp < 0.0].head(60))
# Out:
# LV116   -0.006180
# LV931   -0.004843
# LV744   -0.002292
# LV697   -0.002231
# LV885   -0.001984
# LV536   -0.001956
# LV550   -0.001933
# LV220   -0.001822
# LV272   -0.001785
# LV739   -0.001770
# LV678   -0.001525
# LV470   -0.001444
# LV66    -0.001375
# LV189   -0.001371
# LV517   -0.001296
# LV840   -0.001285
# LV246   -0.001253
# LV502   -0.001249
# LV525   -0.001227
# LV85    -0.001220
# LV926   -0.001217
# LV824   -0.001205
# LV496   -0.001181
# LV545   -0.001147
# LV541   -0.001083
# LV143   -0.001054
# LV221   -0.001040
# LV122   -0.001037
# LV802   -0.001008
# LV106   -0.001007
# LV798   -0.000935
# LV50    -0.000923
# LV23    -0.000912
# LV631   -0.000863
# LV6     -0.000856
# LV893   -0.000851
# LV882   -0.000841
# LV142   -0.000806
# LV913   -0.000796
# LV478   -0.000789
# LV387   -0.000737
# LV879   -0.000733
# LV855   -0.000718
# LV248   -0.000714
# LV532   -0.000706
# LV512   -0.000692
# LV353   -0.000692
# LV202   -0.000686
# LV848   -0.000684
# LV319   -0.000676
# LV354   -0.000660
# LV5     -0.000657
# LV78    -0.000654
# LV715   -0.000649
# LV522   -0.000647
# LV570   -0.000632
# LV211   -0.000631
# LV872   -0.000629
# LV35    -0.000624
# LV368   -0.000607
# dtype: float64

# %%
# I should try all LVs associated with lipids
_tmp.loc["LV246"]
# Out:
# -0.0012534801167192772

# %%
",".join(_tmp.head(20).index)
# Out:
# 'LV116,LV931,LV744,LV697,LV885,LV536,LV550,LV220,LV272,LV739,LV678,LV470,LV66,LV189,LV517,LV840,LV246,LV502,LV525,LV85'

# %%
_tmp2 = _tmp[_tmp < 0.0].sort_values(ascending=True)
display(_tmp2)
_tmp2.to_pickle("/tmp/lv_list.pkl")
# Out:
# LV116   -6.179892e-03
# LV931   -4.842918e-03
# LV744   -2.292495e-03
# LV697   -2.230769e-03
# LV885   -1.983519e-03
#              ...
# LV574   -9.320074e-07
# LV764   -8.293981e-07
# LV683   -7.304520e-07
# LV916   -9.235917e-08
# LV877   -8.433177e-09
# Length: 485, dtype: float64

# %%
_lv_name = "LV246"

# %%
_lv_genes = multiplier_z[_lv_name].sort_values(ascending=False).head(40)
display(_lv_genes)
# Out:
# SCD         6.672060
# ACSS2       6.258514
# GPAM        5.714077
# DGAT2       4.738347
# ACLY        3.708678
# GPD1        3.346001
# MVD         3.320598
# FASN        2.915241
# LPL         2.858278
# ACSL1       2.682199
# LSS         2.535996
# FADS2       2.504681
# AGPAT2      2.237759
# ACACA       2.138277
# ME1         2.107366
# ELOVL5      2.022853
# HSD17B12    2.007114
# SLC7A10     1.968451
# G0S2        1.900780
# SREBF1      1.783389
# CD36        1.763034
# PC          1.744431
# ELOVL3      1.676619
# LPIN1       1.673466
# CYB5A       1.641386
# ELOVL6      1.617832
# FZD4        1.612687
# ACACB       1.549111
# GBE1        1.539272
# HMGCS1      1.507852
# ACO1        1.480638
# SLC25A1     1.478971
# LPCAT3      1.475193
# NSDHL       1.431425
# HMGCR       1.398405
# PCYT2       1.395157
# LDLR        1.384271
# IDI1        1.358324
# NR1H3       1.321484
# FAR2        1.291955
# Name: LV246, dtype: float64

# %%
_module_tissue_data.loc[_lv_name, _top_phenomexcan_trait]
# Out:
# -0.027018854880268575

# %%
lincs_projection.loc[_drug_id, _lv_name]  # .sort_values()
# Out:
# -0.042009476075034115

# %%
# FIXME: here, if I want to see per gene, I should multiply by the gene weight in the LV
_genes_assoc_data = _module_tissue_data_raw.reindex(_lv_genes.index)[
    _top_phenomexcan_trait
]

display(_genes_assoc_data)
# Out:
# IFIT1      -0.153820
# MX1         0.523317
# IFIT2            NaN
# OAS3       -1.985314
# OASL       -1.384930
# IFIT3       0.345956
# OAS2             NaN
# OAS1             NaN
# MX2        -0.496785
# RSAD2      -0.811156
# IRF7        0.414957
# CMPK2      -0.811156
# ISG15      -0.959396
# DDX58      -0.098424
# IFIH1       0.239437
# USP18       1.257177
# IFI35      -2.422760
# DHX58      -2.825454
# STAT2      -0.706492
# IFI6             NaN
# ISG20      -0.053109
# SIGLEC1    -0.344810
# SAMD9            NaN
# EPSTI1           NaN
# TNFSF10     1.169996
# HERC5      -0.042516
# XAF1       -0.472897
# IFI44L           NaN
# PARP14     -0.937098
# ZBP1        0.465123
# APOBEC3A         NaN
# IFITM1     -1.496117
# STAT1       1.008516
# DTX3L            NaN
# PML         2.515950
# IRF9             NaN
# UNC93B1    -1.416375
# APOL6       0.288779
# UBE2L6      0.729684
# TRIM25           NaN
# Name: I25-Diagnoses_main_ICD10_I25_Chronic_ischaemic_heart_disease, dtype: float64

# %%
_lincs_assoc_data = lincs_data.T.reindex(_lv_genes.index)[_drug_id]

display(_lincs_assoc_data)
# Out:
# IFIT1       2.275
# MX1         1.869
# IFIT2         NaN
# OAS3        1.737
# OASL        1.230
# IFIT3       1.948
# OAS2        2.890
# OAS1        1.360
# MX2         1.026
# RSAD2       2.406
# IRF7        1.039
# CMPK2         NaN
# ISG15       1.789
# DDX58       0.148
# IFIH1       1.954
# USP18       2.395
# IFI35       1.065
# DHX58       0.432
# STAT2         NaN
# IFI6        2.168
# ISG20       0.310
# SIGLEC1       NaN
# SAMD9       0.976
# EPSTI1        NaN
# TNFSF10    -0.039
# HERC5       1.249
# XAF1        1.783
# IFI44L      2.212
# PARP14        NaN
# ZBP1          NaN
# APOBEC3A      NaN
# IFITM1      1.674
# STAT1       0.709
# DTX3L         NaN
# PML        -0.098
# IRF9        2.043
# UNC93B1    -1.054
# APOL6       0.819
# UBE2L6      1.673
# TRIM25        NaN
# Name: DB00627, dtype: float64

# %%
_genes_assoc_data.multiply(_lincs_assoc_data).sort_values(ascending=True)
# Out:
# OAS3       -3.448490
# IFI35      -2.580240
# IFITM1     -2.504500
# RSAD2      -1.951641
# ISG15      -1.716359
# OASL       -1.703463
# DHX58      -1.220596
# XAF1       -0.843175
# MX2        -0.509701
# IFIT1      -0.349941
# PML        -0.246563
# HERC5      -0.053102
# TNFSF10    -0.045630
# ISG20      -0.016464
# DDX58      -0.014567
# APOL6       0.236510
# IRF7        0.431141
# IFIH1       0.467859
# IFIT3       0.673923
# STAT1       0.715038
# MX1         0.978079
# UBE2L6      1.220762
# UNC93B1     1.492859
# USP18       3.010940
# IFIT2            NaN
# OAS2             NaN
# OAS1             NaN
# CMPK2            NaN
# STAT2            NaN
# IFI6             NaN
# SIGLEC1          NaN
# SAMD9            NaN
# EPSTI1           NaN
# IFI44L           NaN
# PARP14           NaN
# ZBP1             NaN
# APOBEC3A         NaN
# DTX3L            NaN
# IRF9             NaN
# TRIM25           NaN
# dtype: float64

# %%
# lincs_projection.loc[_drug_id].sort_values()

# %%
# _module_tissue_data.squeeze().sort_values().head(10)

# %%
_tmp = lincs_projection.T[_drug_id].abs()

_tmp2 = _tmp[_tmp > 0.0].sort_values(ascending=False)
display(_tmp2)
_tmp2.to_pickle("/tmp/niacin_lv_list.pkl")
# Out:
# LV881    0.154953
# LV116    0.097558
# LV743    0.097299
# LV38     0.088232
# LV841    0.086833
#            ...
# LV671    0.000046
# LV335    0.000045
# LV681    0.000040
# LV728    0.000032
# LV877    0.000001
# Name: DB00627, Length: 987, dtype: float64

# %%
_tmp2.head(20)
# Out:
# LV881    0.154953
# LV116    0.097558
# LV743    0.097299
# LV38     0.088232
# LV841    0.086833
# LV163    0.080580
# LV161    0.070249
# LV931    0.069832
# LV9      0.069249
# LV536    0.068436
# LV50     0.067657
# LV707    0.067467
# LV142    0.064834
# LV95     0.061820
# LV97     0.061123
# LV74     0.056454
# LV66     0.055342
# LV974    0.053342
# LV678    0.051296
# LV879    0.050419
# Name: DB00627, dtype: float64

# %%
",".join(_tmp2.head(20).index)
# Out:
# 'LV881,LV116,LV743,LV38,LV841,LV163,LV161,LV931,LV9,LV536,LV50,LV707,LV142,LV95,LV97,LV74,LV66,LV974,LV678,LV879'

# %% [markdown]
# ### Gene-based - Genes driving association

# %%
_gene_based_tissue_data = pd.read_pickle(
    INPUT_DATA_DIR / "raw" / f"spredixcan-mashr-zscores-{_gene_based_tissue}-data.pkl"
)
_gene_based_tissue_data = _gene_based_tissue_data.rename(index=Gene.GENE_ID_TO_NAME_MAP)

display(_gene_based_tissue_data.shape)
display(_gene_based_tissue_data.head())
# Out:
# (16972, 4091)
#           I9_PHLETHROMBDVTLOW-DVT_of_lower_extremities  \
# gene_id
# SCYL3                                        -3.380623
# C1orf112                                     -3.310312
# FGR                                           1.917626
# CFH                                           0.466666
# FUCA2                                        -0.653523
#
#           I71-Diagnoses_main_ICD10_I71_Aortic_aneurysm_and_dissection  \
# gene_id
# SCYL3                                             -0.668495
# C1orf112                                          -0.802099
# FGR                                                0.208054
# CFH                                               -0.091782
# FUCA2                                              0.791157
#
#           G62-Diagnoses_main_ICD10_G62_Other_polyneuropathies  \
# gene_id
# SCYL3                                              0.152390
# C1orf112                                           0.509401
# FGR                                               -0.294232
# CFH                                                0.870694
# FUCA2                                              0.215262
#
#           2395_4-Hairbalding_pattern_Pattern_4  \
# gene_id
# SCYL3                                 1.973963
# C1orf112                              2.057412
# FGR                                  -0.706293
# CFH                                   0.628786
# FUCA2                                 0.717572
#
#           20003_1141168590-Treatmentmedication_code_pariet_10mg_ec_tablet  \
# gene_id
# SCYL3                                             -1.662351
# C1orf112                                          -1.181577
# FGR                                                1.390585
# CFH                                               -0.472838
# FUCA2                                             -2.534597
#
#           4056_raw-Age_stroke_diagnosed  \
# gene_id
# SCYL3                         -0.392219
# C1orf112                      -0.627847
# FGR                           -0.111784
# CFH                           -0.519768
# FUCA2                          0.284291
#
#           M13_FOREIGNBODY-Residual_foreign_body_in_soft_tissue  \
# gene_id
# SCYL3                                             -0.469066
# C1orf112                                          -0.402729
# FGR                                                0.124277
# CFH                                                2.424860
# FUCA2                                             -0.411587
#
#           20002_1494-Noncancer_illness_code_selfreported_varicose_veins  \
# gene_id
# SCYL3                                             -1.096786
# C1orf112                                          -1.119259
# FGR                                                1.135089
# CFH                                               -1.551633
# FUCA2                                              0.228705
#
#           I85-Diagnoses_main_ICD10_I85_Oesophageal_varices  \
# gene_id
# SCYL3                                            -1.001884
# C1orf112                                         -1.037078
# FGR                                               0.097681
# CFH                                              -0.287467
# FUCA2                                             0.853281
#
#           6158_4-Why_reduced_smoking_Financial_reasons  ...  \
# gene_id                                                 ...
# SCYL3                                        -0.718271  ...
# C1orf112                                     -0.640086  ...
# FGR                                          -1.829892  ...
# CFH                                          -0.867953  ...
# FUCA2                                        -0.436868  ...
#
#           41215_0-Detention_categories_Informal_not_formally_detained  \
# gene_id
# SCYL3                                             -0.608140
# C1orf112                                          -0.405886
# FGR                                               -0.485489
# CFH                                               -0.934352
# FUCA2                                             -2.085503
#
#           M76-Diagnoses_main_ICD10_M76_Enthesopathies_of_lower_limb_excluding_foot  \
# gene_id
# SCYL3                                              0.169738
# C1orf112                                           0.278882
# FGR                                               -0.177272
# CFH                                                0.300906
# FUCA2                                             -1.295726
#
#           22601_35633208-Job_coding_vocational_or_industrial_trainerinstructor  \
# gene_id
# SCYL3                                              0.030607
# C1orf112                                           0.135687
# FGR                                                0.007996
# CFH                                               -0.619276
# FUCA2                                              0.619484
#
#           H7_RETINALDETACH-Retinal_detachments_and_breaks  \
# gene_id
# SCYL3                                            0.402069
# C1orf112                                         0.059612
# FGR                                              0.934915
# CFH                                              0.197975
# FUCA2                                            0.702873
#
#           20003_1141172918-Treatmentmedication_code_celluvisc_1_singleuse_eye_drops  \
# gene_id
# SCYL3                                              0.311547
# C1orf112                                           0.376847
# FGR                                               -0.660882
# CFH                                               -0.647014
# FUCA2                                              1.450982
#
#           22601_35643209-Job_coding_careers_adviser_or_vocational_guidance_specialist_placement_advisor  \
# gene_id
# SCYL3                                              0.844089
# C1orf112                                           0.900322
# FGR                                               -0.685404
# CFH                                                0.715572
# FUCA2                                             -0.728286
#
#           20002_1537-Noncancer_illness_code_selfreported_joint_pain  \
# gene_id
# SCYL3                                              0.329361
# C1orf112                                           0.550222
# FGR                                                0.587479
# CFH                                               -0.713293
# FUCA2                                             -0.448195
#
#           20514-Recent_lack_of_interest_or_pleasure_in_doing_things  \
# gene_id
# SCYL3                                             -2.067595
# C1orf112                                          -1.953270
# FGR                                               -0.313904
# CFH                                               -2.474839
# FUCA2                                              2.412672
#
#           22601_53192534-Job_coding_builder_building_contractor  \
# gene_id
# SCYL3                                              1.963715
# C1orf112                                           2.162665
# FGR                                                1.020958
# CFH                                               -2.248581
# FUCA2                                             -1.695031
#
#           30280_raw-Immature_reticulocyte_fraction
# gene_id
# SCYL3                                    -0.017090
# C1orf112                                 -0.433549
# FGR                                       0.290251
# CFH                                       0.460525
# FUCA2                                    -0.928210
#
# [5 rows x 4091 columns]

# %%
_gene_based_tissue_data.index.is_unique
# Out:
# False

# %%
_gene_based_tissue_data.index[_gene_based_tissue_data.index.duplicated(keep="first")]
# Out:
# Index(['SPATA13', 'LINC01422', 'LINC00484', 'LINC01115', 'LYNX1'], dtype='object', name='gene_id')

# %%
_gene_based_tissue_data = _gene_based_tissue_data.loc[
    ~_gene_based_tissue_data.index.duplicated(keep="first")
]

# %%
_gene_based_tissue_data.shape
# Out:
# (16967, 4091)

# %%
_gene_based_tissue_data.index.is_unique
# Out:
# True

# %%
# from drug_disease import _zero_nontop_genes

# %%
OUTPUT_PREDICTIONS_DIR
# Out:
# PosixPath('/media/miltondp/Elements1/projects/phenoplier/results/drug_disease_analyses/predictions/dotprod_neg')

# %%
# _prefix = "top_5_genes"

_all_dfs = []

for ntc in (None, 50, 100, 250, 500):
    _prefix = "all_genes"
    if ntc is not None:
        _prefix = f"top_{ntc}_genes"

    _df = pd.read_hdf(
        OUTPUT_PREDICTIONS_DIR
        / f"spredixcan-mashr-zscores-{_gene_based_tissue}-data-{_prefix}-prediction_scores.h5",
        key="prediction",
    )

    _score_col_name = f"score_{_prefix}"
    _df = (
        pd.merge(_df, gold_standard, on=["trait", "drug"], how="inner")
        .drop(columns=["true_class"])
        .set_index(["trait", "drug"])
        .rename(columns={"score": _score_col_name})
    )

    _df[_score_col_name] = _df[_score_col_name].rank()

    _all_dfs.append(_df)

# %%
_df
# Out:
#                       score_top_500_genes
# trait        drug
# DOID:0050741 DB00215                311.0
#              DB00704                503.0
#              DB00822                477.0
# DOID:10283   DB00014                 52.0
#              DB00175                 77.0
# ...                                   ...
# DOID:9970    DB00397                 45.0
#              DB00501                 80.0
#              DB01083                 83.0
#              DB01105                183.0
#              DB01156                 26.0
#
# [646 rows x 1 columns]

# %%
_raw_predictions_tissue = pd.concat(_all_dfs, axis=1, join="inner")  # .mean(axis=1)

# %%
_raw_predictions_tissue.shape
# Out:
# (646, 5)

# %%
_raw_predictions_tissue.head()
# Out:
#                       score_all_genes  score_top_50_genes  \
# trait        drug
# DOID:0050741 DB00215            303.0               260.0
#              DB00704            482.0               444.0
#              DB00822            437.0               256.0
# DOID:10283   DB00014             58.0                62.0
#              DB00175             44.0                65.0
#
#                       score_top_100_genes  score_top_250_genes  \
# trait        drug
# DOID:0050741 DB00215                181.0                190.0
#              DB00704                396.0                482.0
#              DB00822                459.0                255.0
# DOID:10283   DB00014                 69.0                 45.0
#              DB00175                 71.0                 76.0
#
#                       score_top_500_genes
# trait        drug
# DOID:0050741 DB00215                311.0
#              DB00704                503.0
#              DB00822                477.0
# DOID:10283   DB00014                 52.0
#              DB00175                 77.0

# %%
_raw_predictions_tissue = _raw_predictions_tissue.mean(axis=1)

# %%
display(_raw_predictions_tissue.shape)
display(_raw_predictions_tissue.head())

assert _df.shape[0] == _raw_predictions_tissue.shape[0]
assert not _raw_predictions_tissue.isna().any().any()
# Out:
# (646,)
# trait         drug
# DOID:0050741  DB00215    249.0
#               DB00704    461.4
#               DB00822    376.8
# DOID:10283    DB00014     57.2
#               DB00175     66.6
# dtype: float64

# %%
_raw_predictions_tissue.loc[
    _doid, _drug_id
]  # .query(f"(trait == '{_doid}') and (drug == '{_drug_id}')")
# Out:
# 512.6

# %%
# FIXME: add assert here to make sure this number above is the same in predictions_avg

# %%
# _traits_proj = pd.read_pickle(INPUT_DATA_DIR / "proj" / f"spredixcan-mashr-zscores-{_module_tissue}-projection.pkl")

_gene_based_tissue_data = _gene_based_tissue_data[
    _phenomexcan_traits
    #     "C62-Diagnoses_main_ICD10_C62_Malignant_neoplasm_of_testis",
    #     "I25-Diagnoses_main_ICD10_I25_Chronic_ischaemic_heart_disease",
]

# _traits_proj = _traits_proj.apply(
#     lambda x: _zero_nontop_genes(x, 50, use_abs=True)
# )

# %%
_gene_based_tissue_data.head()
# Out:
#           I70-Diagnoses_main_ICD10_I70_Atherosclerosis
# gene_id
# SCYL3                                        -1.106146
# C1orf112                                     -1.258885
# FGR                                          -1.781236
# CFH                                          -0.233247
# FUCA2                                         0.801598

# %%
_gene_based_tissue_data.squeeze().sort_values()
# Out:
# gene_id
# NMRK1          -4.415421
# RP11-54O7.18   -4.065244
# OSTF1          -3.979124
# RP5-916L7.2    -3.772428
# AGRN           -3.685653
#                   ...
# SEMA4C          3.597588
# MTF1            3.777043
# FAM178B         4.457912
# SEC14L1         4.542709
# LPA             4.872263
# Name: I70-Diagnoses_main_ICD10_I70_Atherosclerosis, Length: 16967, dtype: float64

# %%
lincs_data.T[_drug_id].sort_values()
# Out:
# TAGLN    -6.716
# IFRD2    -5.166
# S100P    -4.709
# LONP1    -4.120
# ACADVL   -3.765
#           ...
# OLFM1     3.665
# FZD1      3.934
# PPBP      4.168
# HERC6     4.233
# WIF1      4.620
# Name: DB00627, Length: 7120, dtype: float64

# %%
# get common genes with lincs
common_genes = _gene_based_tissue_data.index.intersection(lincs_data.columns)
_gene_data = _gene_based_tissue_data.loc[common_genes]
_lincs_data = lincs_data[common_genes]

# %%
_gene_data.shape
# Out:
# (5767, 1)

# %%
_lincs_data.shape
# Out:
# (1170, 5767)

# %%
_tmp = (-1.0 * _lincs_data.loc[_drug_id].dot(_gene_data)).sort_values(ascending=False)
display(_tmp)

_top_phenomexcan_trait = _tmp.index[0]
display(_top_phenomexcan_trait)
# Out:
# I70-Diagnoses_main_ICD10_I70_Atherosclerosis    191.118501
# Name: DB00627, dtype: float64
# 'I70-Diagnoses_main_ICD10_I70_Atherosclerosis'

# %%
_tmp = (
    _lincs_data.loc[_drug_id]
    .multiply(_gene_data[_top_phenomexcan_trait])
    .sort_values(ascending=True)
)
display(_tmp.head(20))
# Out:
# IFNAR1    -6.731023
# NT5DC2    -6.705433
# TRIM22    -6.552178
# HEBP1     -6.430294
# R3HDM4    -6.119445
# SYK       -6.047916
# PRR15L    -5.998544
# CAMSAP2   -5.853971
# USP18     -5.402533
# N6AMT1    -5.391901
# ISOC1     -5.330889
# PRKCD     -5.312601
# NMRK1     -5.179289
# MTF1      -4.827061
# MICA      -4.594171
# CLTB      -4.561361
# ASL       -4.539134
# SF3A3     -4.416862
# IFIT1     -4.357457
# TRMT61B   -4.341936
# dtype: float64

# %%
",".join(_tmp.head(20).index)
# Out:
# 'IFNAR1,NT5DC2,TRIM22,HEBP1,R3HDM4,SYK,PRR15L,CAMSAP2,USP18,N6AMT1,ISOC1,PRKCD,NMRK1,MTF1,MICA,CLTB,ASL,SF3A3,IFIT1,TRMT61B'

# %%
_tmp[_tmp < 0.0].shape
# Out:
# (2930,)

# %%
_lincs_data.loc[_drug_id].sort_values()
# Out:
# TAGLN    -6.716
# S100P    -4.709
# LONP1    -4.120
# ACADVL   -3.765
# VAT1     -3.698
#           ...
# PRR15L    3.606
# FGFR2     3.648
# OLFM1     3.665
# HERC6     4.233
# WIF1      4.620
# Name: DB00627, Length: 5767, dtype: float64

# %%
_lincs_data.loc[_drug_id, "NT5DC2"]  # .sort_values()
# Out:
# -2.529

# %%
_gene_data.squeeze().sort_values()
# Out:
# NMRK1      -4.415421
# OSTF1      -3.979124
# AGRN       -3.685653
# PDHB       -3.597112
# PLA2G16    -3.450018
#               ...
# NUPL2       3.417509
# KIAA0040    3.588833
# SEMA4C      3.597588
# MTF1        3.777043
# SEC14L1     4.542709
# Name: I70-Diagnoses_main_ICD10_I70_Atherosclerosis, Length: 5767, dtype: float64

# %%
_gene_data.squeeze().loc["NT5DC2"]
# Out:
# 2.651416778564453

# %% [markdown]
# ## hypertension

# %%
find_differences("hypertension")
# Out:
#                              disease                  drug        method  \
# doid_id    drugbank_id
# DOID:10763 DB01136      hypertension            Carvedilol  Module-based
#            DB01136      hypertension            Carvedilol    Gene-based
#            DB00820      hypertension             Tadalafil  Module-based
#            DB00820      hypertension             Tadalafil    Gene-based
#            DB01001      hypertension            Salbutamol  Module-based
#            DB01001      hypertension            Salbutamol    Gene-based
#            DB00758      hypertension           Clopidogrel  Module-based
#            DB00758      hypertension           Clopidogrel    Gene-based
#            DB00598      hypertension             Labetalol  Module-based
#            DB00598      hypertension             Labetalol    Gene-based
#            DB00521      hypertension             Carteolol  Module-based
#            DB00521      hypertension             Carteolol    Gene-based
#            DB01194      hypertension          Brinzolamide  Module-based
#            DB01194      hypertension          Brinzolamide    Gene-based
#            DB00384      hypertension           Triamterene  Module-based
#            DB00384      hypertension           Triamterene    Gene-based
#            DB00374      hypertension          Treprostinil  Module-based
#            DB00374      hypertension          Treprostinil    Gene-based
#            DB00350      hypertension             Minoxidil  Module-based
#            DB00350      hypertension             Minoxidil    Gene-based
#            DB01203      hypertension               Nadolol  Module-based
#            DB01203      hypertension               Nadolol    Gene-based
#            DB00524      hypertension            Metolazone  Module-based
#            DB00524      hypertension            Metolazone    Gene-based
#            DB00887      hypertension            Bumetanide  Module-based
#            DB00887      hypertension            Bumetanide    Gene-based
#            DB01083      hypertension              Orlistat  Module-based
#            DB01083      hypertension              Orlistat    Gene-based
#            DB01023      hypertension            Felodipine  Module-based
#            DB01023      hypertension            Felodipine    Gene-based
#            DB00905      hypertension           Bimatoprost  Module-based
#            DB00905      hypertension           Bimatoprost    Gene-based
#            DB01244      hypertension              Bepridil  Module-based
#            DB01244      hypertension              Bepridil    Gene-based
#            DB00177      hypertension             Valsartan  Module-based
#            DB00177      hypertension             Valsartan    Gene-based
#            DB00722      hypertension            Lisinopril  Module-based
#            DB00722      hypertension            Lisinopril    Gene-based
#            DB00457      hypertension              Prazosin  Module-based
#            DB00457      hypertension              Prazosin    Gene-based
#            DB00187      hypertension               Esmolol  Module-based
#            DB00187      hypertension               Esmolol    Gene-based
#            DB00436      hypertension   Bendroflumethiazide  Module-based
#            DB00436      hypertension   Bendroflumethiazide    Gene-based
#            DB00492      hypertension            Fosinopril  Module-based
#            DB00492      hypertension            Fosinopril    Gene-based
#            DB00206      hypertension             Reserpine  Module-based
#            DB00206      hypertension             Reserpine    Gene-based
#            DB00774      hypertension    Hydroflumethiazide  Module-based
#            DB00774      hypertension    Hydroflumethiazide    Gene-based
#            DB00264      hypertension            Metoprolol  Module-based
#            DB00264      hypertension            Metoprolol    Gene-based
#            DB00218      hypertension          Moxifloxacin  Module-based
#            DB00218      hypertension          Moxifloxacin    Gene-based
#            DB00800      hypertension            Fenoldopam  Module-based
#            DB00800      hypertension            Fenoldopam    Gene-based
#            DB00449      hypertension            Dipivefrin  Module-based
#            DB00449      hypertension            Dipivefrin    Gene-based
#            DB00657      hypertension          Mecamylamine  Module-based
#            DB00657      hypertension          Mecamylamine    Gene-based
#            DB00883      hypertension  Isosorbide Dinitrate  Module-based
#            DB00883      hypertension  Isosorbide Dinitrate    Gene-based
#            DB00629      hypertension             Guanabenz  Module-based
#            DB00629      hypertension             Guanabenz    Gene-based
#
#                         score  true_class  score_zscore  different_sign  \
# doid_id    drugbank_id
# DOID:10763 DB01136      289.2         1.0     -3.283269            True
#            DB01136      560.2         1.0      0.442310            True
#            DB00820      419.6         0.0     -1.508453            True
#            DB00820      582.4         0.0      0.690718            True
#            DB01001      401.2         0.0     -1.758887            True
#            DB01001      551.8         0.0      0.348318            True
#            DB00758      466.4         0.0     -0.871480            True
#            DB00758      626.6         0.0      1.185297            True
#            DB00598      388.8         1.0     -1.927658            True
#            DB00598      526.2         1.0      0.061865            True
#            DB00521      445.0         0.0     -1.162745            True
#            DB00521      560.8         0.0      0.449024            True
#            DB01194      569.2         0.0      0.527685            True
#            DB01194      431.4         0.0     -0.998906            True
#            DB00384      568.2         1.0      0.514074            True
#            DB00384      434.0         1.0     -0.969813            True
#            DB00374      638.8         0.0      1.474979            True
#            DB00374      520.6         0.0     -0.000797            True
#            DB00350      471.0         1.0     -0.808871            True
#            DB00350      573.0         1.0      0.585537            True
#            DB01203      479.2         1.0     -0.697265            True
#            DB01203      560.0         1.0      0.440072            True
#            DB00524      586.8         1.0      0.767230            True
#            DB00524      489.0         1.0     -0.354387            True
#            DB00887      500.0         1.0     -0.414165            True
#            DB00887      582.4         1.0      0.690718            True
#            DB01083      506.2         0.0     -0.329780            True
#            DB01083      586.4         0.0      0.735477            True
#            DB01023      577.0         1.0      0.633847            True
#            DB01023      483.0         1.0     -0.421525            True
#            DB00905      570.0         0.0      0.538573            True
#            DB00905      477.2         0.0     -0.486424            True
#            DB01244      476.4         1.0     -0.735374            True
#            DB01244      545.8         1.0      0.281180            True
#            DB00177      490.8         1.0     -0.539382            True
#            DB00177      560.0         1.0      0.440072            True
#            DB00722      546.0         1.0      0.211920            True
#            DB00722      465.8         1.0     -0.613985            True
#            DB00457      510.4         1.0     -0.272615            True
#            DB00457      567.4         1.0      0.522875            True
#            DB00187      491.8         1.0     -0.525772            True
#            DB00187      539.8         1.0      0.214043            True
#            DB00436      578.8         1.0      0.658346            True
#            DB00436      516.4         1.0     -0.047793            True
#            DB00492      550.0         1.0      0.266362            True
#            DB00492      497.6         1.0     -0.258157            True
#            DB00206      563.6         1.0      0.451466            True
#            DB00206      515.6         1.0     -0.056745            True
#            DB00774      542.8         1.0      0.168366            True
#            DB00774      490.4         1.0     -0.338722            True
#            DB00264      498.6         1.0     -0.433220            True
#            DB00264      523.8         1.0      0.035010            True
#            DB00218      531.6         0.0      0.015928            True
#            DB00218      488.8         0.0     -0.356625            True
#            DB00800      535.8         1.0      0.073092            True
#            DB00800      494.2         1.0     -0.296201            True
#            DB00449      549.2         0.0      0.255474            True
#            DB00449      513.4         0.0     -0.081362            True
#            DB00657      530.2         1.0     -0.003127            True
#            DB00657      547.4         1.0      0.299084            True
#            DB00883      529.8         0.0     -0.008571            True
#            DB00883      532.6         0.0      0.133478            True
#            DB00629      528.6         1.0     -0.024904            True
#            DB00629      521.6         1.0      0.010393            True
#
#                         score_difference
# doid_id    drugbank_id
# DOID:10763 DB01136              3.725579
#            DB01136              3.725579
#            DB00820              2.199172
#            DB00820              2.199172
#            DB01001              2.107205
#            DB01001              2.107205
#            DB00758              2.056777
#            DB00758              2.056777
#            DB00598              1.989523
#            DB00598              1.989523
#            DB00521              1.611769
#            DB00521              1.611769
#            DB01194              1.526591
#            DB01194              1.526591
#            DB00384              1.483888
#            DB00384              1.483888
#            DB00374              1.475776
#            DB00374              1.475776
#            DB00350              1.394408
#            DB00350              1.394408
#            DB01203              1.137337
#            DB01203              1.137337
#            DB00524              1.121618
#            DB00524              1.121618
#            DB00887              1.104884
#            DB00887              1.104884
#            DB01083              1.065257
#            DB01083              1.065257
#            DB01023              1.055372
#            DB01023              1.055372
#            DB00905              1.024997
#            DB00905              1.024997
#            DB01244              1.016554
#            DB01244              1.016554
#            DB00177              0.979454
#            DB00177              0.979454
#            DB00722              0.825905
#            DB00722              0.825905
#            DB00457              0.795490
#            DB00457              0.795490
#            DB00187              0.739815
#            DB00187              0.739815
#            DB00436              0.706139
#            DB00436              0.706139
#            DB00492              0.524519
#            DB00492              0.524519
#            DB00206              0.508210
#            DB00206              0.508210
#            DB00774              0.507088
#            DB00774              0.507088
#            DB00264              0.468230
#            DB00264              0.468230
#            DB00218              0.372553
#            DB00218              0.372553
#            DB00800              0.369294
#            DB00800              0.369294
#            DB00449              0.336835
#            DB00449              0.336835
#            DB00657              0.302210
#            DB00657              0.302210
#            DB00883              0.142049
#            DB00883              0.142049
#            DB00629              0.035296
#            DB00629              0.035296

# %% [markdown]
# ## allergic rhinitis

# %%
find_differences("allergic rhinitis")
# Out:
#                                  disease                drug        method  \
# doid_id   drugbank_id
# DOID:4481 DB00443      allergic rhinitis       Betamethasone    Gene-based
#           DB00443      allergic rhinitis       Betamethasone  Module-based
#           DB01234      allergic rhinitis       Dexamethasone    Gene-based
#           DB01234      allergic rhinitis       Dexamethasone  Module-based
#           DB00741      allergic rhinitis      Hydrocortisone    Gene-based
#           DB00741      allergic rhinitis      Hydrocortisone  Module-based
#           DB00959      allergic rhinitis  Methylprednisolone    Gene-based
#           DB00959      allergic rhinitis  Methylprednisolone  Module-based
#           DB00620      allergic rhinitis       Triamcinolone    Gene-based
#           DB00620      allergic rhinitis       Triamcinolone  Module-based
#           DB00180      allergic rhinitis         Flunisolide    Gene-based
#           DB00180      allergic rhinitis         Flunisolide  Module-based
#           DB00860      allergic rhinitis        Prednisolone    Gene-based
#           DB00860      allergic rhinitis        Prednisolone  Module-based
#
#                        score  true_class  score_zscore  different_sign  \
# doid_id   drugbank_id
# DOID:4481 DB00443      472.7         1.0     -0.536777            True
#           DB00443      618.7         1.0      1.201407            True
#           DB01234      472.7         1.0     -0.536777            True
#           DB01234      618.7         1.0      1.201407            True
#           DB00741      394.2         1.0     -1.415158            True
#           DB00741      551.8         1.0      0.290861            True
#           DB00959      411.0         1.0     -1.227173            True
#           DB00959      538.4         1.0      0.108480            True
#           DB00620      484.2         1.0     -0.408097            True
#           DB00620      574.2         1.0      0.595738            True
#           DB00180      509.0         1.0     -0.130596            True
#           DB00180      563.6         1.0      0.451466            True
#           DB00860      527.8         1.0      0.079768            True
#           DB00860      503.8         1.0     -0.362445            True
#
#                        score_difference
# doid_id   drugbank_id
# DOID:4481 DB00443              1.738184
#           DB00443              1.738184
#           DB01234              1.738184
#           DB01234              1.738184
#           DB00741              1.706019
#           DB00741              1.706019
#           DB00959              1.335653
#           DB00959              1.335653
#           DB00620              1.003835
#           DB00620              1.003835
#           DB00180              0.582061
#           DB00180              0.582061
#           DB00860              0.442213
#           DB00860              0.442213

# %% [markdown]
# # Alzheimer's disease

# %%
with pd.option_context(
    "display.max_rows", None, "display.max_columns", None, "max_colwidth", None
):
    _tmp = (
        pharmadb_predictions[
            pharmadb_predictions["disease"].isin(["allergic rhinitis"])
        ]
        #         .query("method == 'Module-based'")
        .sort_values(["score_zscore"], ascending=[False])
    )
    display(_tmp)
# Out:
#       doid_id drugbank_id            disease                drug  \
# 61  DOID:4481     DB01234  allergic rhinitis       Dexamethasone
# 53  DOID:4481     DB00443  allergic rhinitis       Betamethasone
# 57  DOID:4481     DB00434  allergic rhinitis      Cyproheptadine
# 56  DOID:4481     DB00434  allergic rhinitis      Cyproheptadine
# 77  DOID:4481     DB00620  allergic rhinitis       Triamcinolone
# 54  DOID:4481     DB00341  allergic rhinitis          Cetirizine
# 63  DOID:4481     DB00180  allergic rhinitis         Flunisolide
# 72  DOID:4481     DB00768  allergic rhinitis         Olopatadine
# 73  DOID:4481     DB00768  allergic rhinitis         Olopatadine
# 55  DOID:4481     DB00341  allergic rhinitis          Cetirizine
# 65  DOID:4481     DB00741  allergic rhinitis      Hydrocortisone
# 69  DOID:4481     DB00959  allergic rhinitis  Methylprednisolone
# 74  DOID:4481     DB00860  allergic rhinitis        Prednisolone
# 62  DOID:4481     DB00180  allergic rhinitis         Flunisolide
# 67  DOID:4481     DB00455  allergic rhinitis          Loratadine
# 75  DOID:4481     DB00860  allergic rhinitis        Prednisolone
# 66  DOID:4481     DB00455  allergic rhinitis          Loratadine
# 76  DOID:4481     DB00620  allergic rhinitis       Triamcinolone
# 60  DOID:4481     DB01234  allergic rhinitis       Dexamethasone
# 52  DOID:4481     DB00443  allergic rhinitis       Betamethasone
# 78  DOID:4481     DB00535  allergic rhinitis            Cefdinir
# 58  DOID:4481     DB00967  allergic rhinitis       Desloratadine
# 68  DOID:4481     DB00959  allergic rhinitis  Methylprednisolone
# 81  DOID:4481     DB00736  allergic rhinitis        Esomeprazole
# 83  DOID:4481     DB00338  allergic rhinitis          Omeprazole
# 64  DOID:4481     DB00741  allergic rhinitis      Hydrocortisone
# 70  DOID:4481     DB00471  allergic rhinitis         Montelukast
# 71  DOID:4481     DB00471  allergic rhinitis         Montelukast
# 79  DOID:4481     DB00535  allergic rhinitis            Cefdinir
# 59  DOID:4481     DB00967  allergic rhinitis       Desloratadine
# 80  DOID:4481     DB00736  allergic rhinitis        Esomeprazole
# 82  DOID:4481     DB00338  allergic rhinitis          Omeprazole
#
#           method  score  true_class  score_zscore
# 61  Module-based  618.7         1.0      1.201407
# 53  Module-based  618.7         1.0      1.201407
# 57  Module-based  578.0         1.0      0.647458
# 56    Gene-based  576.8         1.0      0.628057
# 77  Module-based  574.2         1.0      0.595738
# 54    Gene-based  562.6         1.0      0.469165
# 63  Module-based  563.6         1.0      0.451466
# 72    Gene-based  556.4         1.0      0.399790
# 73  Module-based  556.2         1.0      0.350748
# 55  Module-based  552.6         1.0      0.301750
# 65  Module-based  551.8         1.0      0.290861
# 69  Module-based  538.4         1.0      0.108480
# 74    Gene-based  527.8         1.0      0.079768
# 62    Gene-based  509.0         1.0     -0.130596
# 67  Module-based  507.0         1.0     -0.318891
# 75  Module-based  503.8         1.0     -0.362445
# 66    Gene-based  488.2         1.0     -0.363339
# 76    Gene-based  484.2         1.0     -0.408097
# 60    Gene-based  472.7         1.0     -0.536777
# 52    Gene-based  472.7         1.0     -0.536777
# 78    Gene-based  441.2         0.0     -0.889248
# 58    Gene-based  439.4         1.0     -0.909390
# 68    Gene-based  411.0         1.0     -1.227173
# 81  Module-based  439.5         0.0     -1.237603
# 83  Module-based  439.5         0.0     -1.237603
# 64    Gene-based  394.2         1.0     -1.415158
# 70    Gene-based  376.4         1.0     -1.614332
# 71  Module-based  401.2         1.0     -1.758887
# 79  Module-based  366.0         0.0     -2.237979
# 59  Module-based  342.2         1.0     -2.561910
# 80    Gene-based  215.3         0.0     -3.416972
# 82    Gene-based  215.3         0.0     -3.416972
