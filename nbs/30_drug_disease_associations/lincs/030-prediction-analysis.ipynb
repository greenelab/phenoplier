# %% [markdown]
# # Description

# %% [markdown]
# This notebooks analyzes the drug-disease prediction differences between the gene-based and module-based approaches.
# It focuses on pairs discussed in the manuscript.

# %% [markdown]
# # Modules loading

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

import numpy as np
import pandas as pd

from entity import Gene
import conf

# %% [markdown]
# # Settings

# %% [markdown]
# # Data loading

# %% [markdown]
# ## PharmacotherapyDB

# %% [markdown]
# ### Gold standard set

# %%
gold_standard = pd.read_pickle(
    Path(conf.RESULTS["DRUG_DISEASE_ANALYSES"], "gold_standard.pkl"),
)

# %%
gold_standard.shape
# Out:
# (998, 3)

# %%
gold_standard.head()
# Out:
#         trait     drug  true_class
# 0  DOID:10652  DB00843           1
# 1  DOID:10652  DB00674           1
# 2  DOID:10652  DB01043           1
# 3  DOID:10652  DB00989           1
# 4  DOID:10652  DB00810           0

# %% [markdown]
# ### Info

# %%
input_file = conf.PHARMACOTHERAPYDB["INDICATIONS_FILE"]
display(input_file)
# Out:
# PosixPath('/home/miltondp/projects/labs/greenelab/phenoplier/base/data/hetionet/pharmacotherapydb-v1.0/indications.tsv')

# %%
gold_standard_info = pd.read_csv(input_file, sep="\t")

# %%
gold_standard_info = gold_standard_info.rename(columns={"drug": "drug_name"})

# %%
gold_standard_info.shape
# Out:
# (1388, 7)

# %%
gold_standard_info.head()
# Out:
#       doid_id drugbank_id              disease     drug_name category  \
# 0  DOID:10652     DB00843  Alzheimer's disease     Donepezil       DM
# 1  DOID:10652     DB00674  Alzheimer's disease   Galantamine       DM
# 2  DOID:10652     DB01043  Alzheimer's disease     Memantine       DM
# 3  DOID:10652     DB00989  Alzheimer's disease  Rivastigmine       DM
# 4  DOID:10652     DB00245  Alzheimer's disease  Benzatropine      SYM
#
#    n_curators  n_resources
# 0           2            1
# 1           1            4
# 2           1            3
# 3           1            3
# 4           3            1

# %%
gold_standard_info = (
    gold_standard.set_index(["trait", "drug"])
    .join(
        gold_standard_info.rename(
            columns={"doid_id": "trait", "drugbank_id": "drug"}
        ).set_index(["trait", "drug"])
    )
    .reset_index()
)

# %%
gold_standard_info.shape
# Out:
# (998, 8)

# %%
gold_standard_info.head()
# Out:
#         trait     drug  true_class              disease     drug_name  \
# 0  DOID:10652  DB00843           1  Alzheimer's disease     Donepezil
# 1  DOID:10652  DB00674           1  Alzheimer's disease   Galantamine
# 2  DOID:10652  DB01043           1  Alzheimer's disease     Memantine
# 3  DOID:10652  DB00989           1  Alzheimer's disease  Rivastigmine
# 4  DOID:10652  DB00810           0  Alzheimer's disease     Biperiden
#
#   category  n_curators  n_resources
# 0       DM           2            1
# 1       DM           1            4
# 2       DM           1            3
# 3       DM           1            3
# 4      NOT           2            1

# %% [markdown]
# ## LINCS data

# %%
input_file = Path(
    conf.RESULTS["DRUG_DISEASE_ANALYSES"], "lincs", "lincs-data.pkl"
).resolve()

display(input_file)
# Out:
# PosixPath('/home/miltondp/projects/labs/greenelab/phenoplier/base/results/drug_disease_analyses/lincs/lincs-data.pkl')

# %%
lincs_data = pd.read_pickle(input_file).T.rename(columns=Gene.GENE_ID_TO_NAME_MAP)

# %%
display(lincs_data.shape)
# Out:
# (1170, 7120)

# %%
display(lincs_data.head())
# Out:
#                ADA   CDH2   AKT3   MED6  ACOT8   ABI1  GNPDA1   CDH3   TANK  \
# perturbagen
# DB00014     -1.001  1.146 -0.693 -0.037  0.162 -0.380   0.649 -1.952  0.294
# DB00091     -1.835 -1.863  1.694  0.383 -0.899  0.628  -4.878  2.527  1.709
# DB00121      1.391  0.011 -0.804  0.269  0.105 -0.588  -1.899  0.306 -1.178
# DB00130      1.132 -1.020 -0.164 -0.997 -0.090  0.195  -2.341  0.494 -0.813
# DB00131      0.257  1.143  1.145  0.185 -1.291 -0.457   0.038  1.442 -1.692
#
#              TOPORS-AS1  ...   RBX1  CDC42  THOC1   RCE1  HNRNPDL  DMTF1  \
# perturbagen              ...
# DB00014           0.274  ... -0.592  0.178  0.270 -0.013    0.351 -0.128
# DB00091          -0.981  ... -0.668 -2.795 -0.333 -0.027    0.578  6.926
# DB00121           0.120  ... -0.962  0.450 -0.999  1.358   -1.476  0.423
# DB00130          -1.140  ... -0.553 -0.528  0.308  0.534   -0.320  3.001
# DB00131           0.593  ... -0.556 -0.600  0.092 -0.564    0.174 -1.203
#
#              PPP4R1   CDH1  PTBP3  CASP8AP2
# perturbagen
# DB00014       0.274 -0.734 -0.048     0.036
# DB00091      -1.875  4.382  0.266    -4.995
# DB00121      -1.356 -1.897 -0.299    -0.732
# DB00130      -0.414  0.134  0.147     2.158
# DB00131      -1.080 -0.575 -0.792    -0.095
#
# [5 rows x 7120 columns]

# %% [markdown]
# ## Prediction results (aggregated)

# %%
output_file = Path(
    conf.RESULTS["DRUG_DISEASE_ANALYSES"],
    "lincs",
    "predictions",
    "predictions_results_aggregated.pkl",
).resolve()
display(output_file)
# Out:
# PosixPath('/home/miltondp/projects/labs/greenelab/phenoplier/base/results/drug_disease_analyses/lincs/predictions/predictions_results_aggregated.pkl')

# %%
predictions_avg = pd.read_pickle(output_file)

# %%
predictions_avg.shape
# Out:
# (1292, 5)

# %%
predictions_avg.head()
# Out:
#           trait     drug        method  score  true_class
# 0  DOID:0050741  DB00215    Gene-based  359.0         1.0
# 1  DOID:0050741  DB00215  Module-based  437.8         1.0
# 2  DOID:0050741  DB00704    Gene-based  395.8         1.0
# 3  DOID:0050741  DB00704  Module-based  562.8         1.0
# 4  DOID:0050741  DB00822    Gene-based  556.8         1.0

# %% [markdown]
# ### Merge with gold standard set

# %%
pharmadb_predictions = pd.merge(
    gold_standard_info,
    predictions_avg,
    on=["trait", "drug"],
    how="inner",
)

# %%
pharmadb_predictions
# Out:
#            trait     drug  true_class_x              disease     drug_name  \
# 0     DOID:10652  DB00843             1  Alzheimer's disease     Donepezil
# 1     DOID:10652  DB00843             1  Alzheimer's disease     Donepezil
# 2     DOID:10652  DB00674             1  Alzheimer's disease   Galantamine
# 3     DOID:10652  DB00674             1  Alzheimer's disease   Galantamine
# 4     DOID:10652  DB01043             1  Alzheimer's disease     Memantine
# ...          ...      ...           ...                  ...           ...
# 1287    DOID:363  DB00917             0       uterine cancer  Dinoprostone
# 1288    DOID:363  DB00783             0       uterine cancer     Estradiol
# 1289    DOID:363  DB00783             0       uterine cancer     Estradiol
# 1290  DOID:12306  DB00553             1             vitiligo   Methoxsalen
# 1291  DOID:12306  DB00553             1             vitiligo   Methoxsalen
#
#      category  n_curators  n_resources        method  score  true_class_y
# 0          DM           2            1    Gene-based  311.6           1.0
# 1          DM           2            1  Module-based  475.2           1.0
# 2          DM           1            4    Gene-based  509.4           1.0
# 3          DM           1            4  Module-based  508.0           1.0
# 4          DM           1            3    Gene-based  452.4           1.0
# ...       ...         ...          ...           ...    ...           ...
# 1287      NOT           3            1  Module-based  476.0           0.0
# 1288      NOT           2            1    Gene-based  556.0           0.0
# 1289      NOT           2            1  Module-based  603.0           0.0
# 1290       DM           3            1    Gene-based  550.8           1.0
# 1291       DM           3            1  Module-based  506.8           1.0
#
# [1292 rows x 11 columns]

# %%
pharmadb_predictions = pharmadb_predictions[
    ["trait", "drug", "disease", "drug_name", "method", "score", "true_class_x"]
].rename(columns={"true_class_x": "true_class", "drug_x": "drug"})

# %%
display(pharmadb_predictions.shape)
assert pharmadb_predictions.shape[0] == predictions_avg.shape[0]
# Out:
# (1292, 7)

# %%
pharmadb_predictions.head()
# Out:
#         trait     drug              disease    drug_name        method  score  \
# 0  DOID:10652  DB00843  Alzheimer's disease    Donepezil    Gene-based  311.6
# 1  DOID:10652  DB00843  Alzheimer's disease    Donepezil  Module-based  475.2
# 2  DOID:10652  DB00674  Alzheimer's disease  Galantamine    Gene-based  509.4
# 3  DOID:10652  DB00674  Alzheimer's disease  Galantamine  Module-based  508.0
# 4  DOID:10652  DB01043  Alzheimer's disease    Memantine    Gene-based  452.4
#
#    true_class
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
pharmadb_predictions["trait"].unique().shape
# Out:
# (53,)

# %%
pharmadb_predictions["drug"].unique().shape
# Out:
# (322,)

# %%
data_stats = pharmadb_predictions.groupby("method")["score"].describe()
display(data_stats)
# Out:
#               count        mean        std    min     25%    50%     75%  \
# method
# Gene-based    646.0  517.657585  93.950154   87.3  458.95  535.4  591.75
# Module-based  646.0  530.429721  73.472425  220.4  484.10  535.0  587.90
#
#                 max
# method
# Gene-based    646.0
# Module-based  646.0

# %% [markdown]
# # Standardize scores for each method

# %%
# Standardize scores by method
def _standardize(x):
    return (x["score"] - data_stats.loc[x["method"], "mean"]) / data_stats.loc[
        x["method"], "std"
    ]

# %%
pharmadb_predictions = pharmadb_predictions.assign(
    score_std=pharmadb_predictions.apply(_standardize, axis=1)
)

# %%
pharmadb_predictions
# Out:
#            trait     drug              disease     drug_name        method  \
# 0     DOID:10652  DB00843  Alzheimer's disease     Donepezil    Gene-based
# 1     DOID:10652  DB00843  Alzheimer's disease     Donepezil  Module-based
# 2     DOID:10652  DB00674  Alzheimer's disease   Galantamine    Gene-based
# 3     DOID:10652  DB00674  Alzheimer's disease   Galantamine  Module-based
# 4     DOID:10652  DB01043  Alzheimer's disease     Memantine    Gene-based
# ...          ...      ...                  ...           ...           ...
# 1287    DOID:363  DB00917       uterine cancer  Dinoprostone  Module-based
# 1288    DOID:363  DB00783       uterine cancer     Estradiol    Gene-based
# 1289    DOID:363  DB00783       uterine cancer     Estradiol  Module-based
# 1290  DOID:12306  DB00553             vitiligo   Methoxsalen    Gene-based
# 1291  DOID:12306  DB00553             vitiligo   Methoxsalen  Module-based
#
#       score  true_class  score_std
# 0     311.6           1  -2.193265
# 1     475.2           1  -0.751707
# 2     509.4           1  -0.087893
# 3     508.0           1  -0.305281
# 4     452.4           1  -0.694598
# ...     ...         ...        ...
# 1287  476.0           0  -0.740818
# 1288  556.0           0   0.408114
# 1289  603.0           0   0.987721
# 1290  550.8           1   0.352766
# 1291  506.8           1  -0.321613
#
# [1292 rows x 8 columns]

# %% [markdown]
# ### Testing

# %%
_tmp = pharmadb_predictions.groupby("method")[["score", "score_std"]].describe()
display(_tmp)
# Out:
#               score                                                       \
#               count        mean        std    min     25%    50%     75%
# method
# Gene-based    646.0  517.657585  93.950154   87.3  458.95  535.4  591.75
# Module-based  646.0  530.429721  73.472425  220.4  484.10  535.0  587.90
#
#                     score_std                                         \
#                 max     count          mean  std       min       25%
# method
# Gene-based    646.0     646.0 -5.609548e-16  1.0 -4.580701 -0.624880
# Module-based  646.0     646.0  2.034836e-16  1.0 -4.219675 -0.630573
#
#
#                    50%       75%       max
# method
# Gene-based    0.188849  0.788635  1.366069
# Module-based  0.062204  0.782202  1.572975

# %%
_tmp0 = pharmadb_predictions[(pharmadb_predictions["method"] == "Gene-based")][
    ["score", "score_std"]
]

# %%
assert all(_tmp0.corr() > 0.99999)

# %%
_tmp0 = pharmadb_predictions[(pharmadb_predictions["method"] == "Module-based")][
    ["score", "score_std"]
]

# %%
assert all(_tmp0.corr() > 0.99999)

# %% [markdown]
# # List diseases

# %%
pharmadb_predictions["disease"].unique()
# Out:
# array(["Alzheimer's disease", "Crohn's disease", "Parkinson's disease",
#        'alcohol dependence', 'allergic rhinitis', 'anemia',
#        'ankylosing spondylitis', 'asthma', 'atherosclerosis',
#        'bone cancer', 'brain cancer', 'breast cancer', 'cervical cancer',
#        'chronic kidney failure', 'chronic obstructive pulmonary disease',
#        'coronary artery disease', 'epilepsy syndrome',
#        'esophageal cancer', 'gestational diabetes', 'glaucoma', 'gout',
#        'hematologic cancer', 'hypertension', 'hypothyroidism',
#        'kidney cancer', 'liver cancer', 'lung cancer', 'malaria',
#        'melanoma', 'migraine', 'multiple sclerosis', 'nephrolithiasis',
#        'obesity', 'osteoarthritis', 'osteoporosis', 'pancreatic cancer',
#        'pancreatitis', 'periodontitis', 'prostate cancer', 'psoriasis',
#        'psoriatic arthritis', 'rheumatoid arthritis', 'skin cancer',
#        'stomach cancer', 'systemic lupus erythematosus',
#        'testicular cancer', 'thyroid cancer', 'type 1 diabetes mellitus',
#        'type 2 diabetes mellitus', 'ulcerative colitis',
#        'urinary bladder cancer', 'uterine cancer', 'vitiligo'],
#       dtype=object)

# %% [markdown]
# # Looks for differences in scores of both methods

# %%
def _compare(x):
    assert x.shape[0] == 2
    x_sign = np.sign(x["score_std"].values)
    x0 = x.iloc[0]["score_std"]
    x1 = x.iloc[1]["score_std"]

    return pd.Series(
        {"different_sign": x_sign[0] != x_sign[1], "score_difference": np.abs(x0 - x1)}
    )

# %%
pharmadb_predictions = pharmadb_predictions.set_index(["trait", "drug"]).join(
    pharmadb_predictions.groupby(["trait", "drug"]).apply(_compare)
)

# %%
pharmadb_predictions.head()
# Out:
#                                  disease   drug_name        method  score  \
# trait        drug
# DOID:0050741 DB00215  alcohol dependence  Citalopram    Gene-based  359.0
#              DB00215  alcohol dependence  Citalopram  Module-based  437.8
#              DB00704  alcohol dependence  Naltrexone    Gene-based  395.8
#              DB00704  alcohol dependence  Naltrexone  Module-based  562.8
#              DB00822  alcohol dependence  Disulfiram    Gene-based  556.8
#
#                       true_class  score_std  different_sign  score_difference
# trait        drug
# DOID:0050741 DB00215           1  -1.688742           False          0.428001
#              DB00215           1  -1.260741           False          0.428001
#              DB00704           1  -1.297045            True          1.737622
#              DB00704           1   0.440577            True          1.737622
#              DB00822           1   0.416630           False          0.508483

# %% [markdown]
# ## any disease

# %%
with pd.option_context(
    "display.max_rows", None, "display.max_columns", None, "max_colwidth", None
):
    _tmp = pharmadb_predictions[(pharmadb_predictions["different_sign"])].sort_values(
        ["score_difference", "drug_name", "method"], ascending=[False, False, False]
    )

    display(_tmp.shape)
    display(_tmp)
# Out:
# (326, 8)
#                                                     disease  \
# trait        drug
# DOID:2998    DB00445                      testicular cancer
#              DB00445                      testicular cancer
#              DB00997                      testicular cancer
#              DB00997                      testicular cancer
#              DB00970                      testicular cancer
#              DB00970                      testicular cancer
# DOID:10763   DB01136                           hypertension
#              DB01136                           hypertension
# DOID:4481    DB00959                      allergic rhinitis
#              DB00959                      allergic rhinitis
#              DB01234                      allergic rhinitis
#              DB01234                      allergic rhinitis
#              DB00443                      allergic rhinitis
#              DB00443                      allergic rhinitis
# DOID:10763   DB00374                           hypertension
#              DB00374                           hypertension
# DOID:1793    DB01248                      pancreatic cancer
#              DB01248                      pancreatic cancer
# DOID:10763   DB00384                           hypertension
#              DB00384                           hypertension
#              DB00966                           hypertension
#              DB00966                           hypertension
# DOID:10283   DB01248                        prostate cancer
#              DB01248                        prostate cancer
# DOID:10763   DB01001                           hypertension
#              DB01001                           hypertension
# DOID:7147    DB00620                 ankylosing spondylitis
#              DB00620                 ankylosing spondylitis
# DOID:10763   DB00227                           hypertension
#              DB00227                           hypertension
#              DB00820                           hypertension
#              DB00820                           hypertension
#              DB00598                           hypertension
#              DB00598                           hypertension
#              DB00905                           hypertension
#              DB00905                           hypertension
#              DB00774                           hypertension
#              DB00774                           hypertension
# DOID:4481    DB00741                      allergic rhinitis
#              DB00741                      allergic rhinitis
# DOID:2841    DB00938                                 asthma
#              DB00938                                 asthma
# DOID:8893    DB01091                              psoriasis
#              DB01091                              psoriasis
# DOID:4481    DB00620                      allergic rhinitis
#              DB00620                      allergic rhinitis
# DOID:10763   DB00436                           hypertension
#              DB00436                           hypertension
#              DB00758                           hypertension
#              DB00758                           hypertension
# DOID:9352    DB01200               type 2 diabetes mellitus
#              DB01200               type 2 diabetes mellitus
# DOID:10763   DB01194                           hypertension
#              DB01194                           hypertension
# DOID:0050741 DB00704                     alcohol dependence
#              DB00704                     alcohol dependence
# DOID:13189   DB01394                                   gout
#              DB01394                                   gout
# DOID:2841    DB00535                                 asthma
#              DB00535                                 asthma
# DOID:8778    DB01014                        Crohn's disease
#              DB01014                        Crohn's disease
# DOID:10283   DB00286                        prostate cancer
#              DB00286                        prostate cancer
# DOID:10763   DB00988                           hypertension
#              DB00988                           hypertension
# DOID:1936    DB00227                        atherosclerosis
#              DB00227                        atherosclerosis
# DOID:585     DB00999                        nephrolithiasis
#              DB00999                        nephrolithiasis
# DOID:9352    DB00284               type 2 diabetes mellitus
#              DB00284               type 2 diabetes mellitus
# DOID:10534   DB00563                         stomach cancer
#              DB00563                         stomach cancer
# DOID:363     DB00773                         uterine cancer
#              DB00773                         uterine cancer
# DOID:1612    DB00361                          breast cancer
#              DB00361                          breast cancer
# DOID:3393    DB01197                coronary artery disease
#              DB01197                coronary artery disease
# DOID:9970    DB01083                                obesity
#              DB01083                                obesity
# DOID:9008    DB00563                    psoriatic arthritis
#              DB00563                    psoriatic arthritis
# DOID:2531    DB01168                     hematologic cancer
#              DB01168                     hematologic cancer
# DOID:2841    DB00332                                 asthma
#              DB00332                                 asthma
# DOID:12365   DB00806                                malaria
#              DB00806                                malaria
# DOID:10652   DB00190                    Alzheimer's disease
#              DB00190                    Alzheimer's disease
# DOID:11476   DB04574                           osteoporosis
#              DB04574                           osteoporosis
#              DB00286                           osteoporosis
#              DB00286                           osteoporosis
# DOID:9074    DB00635           systemic lupus erythematosus
#              DB00635           systemic lupus erythematosus
# DOID:2841    DB01137                                 asthma
#              DB01137                                 asthma
# DOID:3571    DB00398                           liver cancer
#              DB00398                           liver cancer
# DOID:2841    DB01003                                 asthma
#              DB01003                                 asthma
#              DB00983                                 asthma
#              DB00983                                 asthma
#              DB01274                                 asthma
#              DB01274                                 asthma
# DOID:11714   DB01016                   gestational diabetes
#              DB01016                   gestational diabetes
# DOID:2377    DB00953                     multiple sclerosis
#              DB00953                     multiple sclerosis
# DOID:2998    DB00291                      testicular cancer
#              DB00291                      testicular cancer
# DOID:11476   DB00977                           osteoporosis
#              DB00977                           osteoporosis
# DOID:7148    DB00995                   rheumatoid arthritis
#              DB00995                   rheumatoid arthritis
# DOID:10763   DB01083                           hypertension
#              DB01083                           hypertension
# DOID:9970    DB01156                                obesity
#              DB01156                                obesity
# DOID:1826    DB00909                      epilepsy syndrome
#              DB00909                      epilepsy syndrome
# DOID:1612    DB00762                          breast cancer
#              DB00762                          breast cancer
# DOID:7148    DB00959                   rheumatoid arthritis
#              DB00959                   rheumatoid arthritis
# DOID:12365   DB00205                                malaria
#              DB00205                                malaria
# DOID:10534   DB01248                         stomach cancer
#              DB01248                         stomach cancer
# DOID:10763   DB00177                           hypertension
#              DB00177                           hypertension
# DOID:13189   DB00328                                   gout
#              DB00328                                   gout
# DOID:8778    DB00916                        Crohn's disease
#              DB00916                        Crohn's disease
# DOID:10763   DB00350                           hypertension
#              DB00350                           hypertension
# DOID:9074    DB01097           systemic lupus erythematosus
#              DB01097           systemic lupus erythematosus
# DOID:1324    DB01168                            lung cancer
#              DB01168                            lung cancer
# DOID:9970    DB01105                                obesity
#              DB01105                                obesity
# DOID:9352    DB00222               type 2 diabetes mellitus
#              DB00222               type 2 diabetes mellitus
# DOID:8893    DB00635                              psoriasis
#              DB00635                              psoriasis
# DOID:7148    DB00338                   rheumatoid arthritis
#              DB00338                   rheumatoid arthritis
#              DB00736                   rheumatoid arthritis
#              DB00736                   rheumatoid arthritis
# DOID:10763   DB00206                           hypertension
#              DB00206                           hypertension
# DOID:1612    DB00441                          breast cancer
#              DB00441                          breast cancer
# DOID:9008    DB00620                    psoriatic arthritis
#              DB00620                    psoriatic arthritis
# DOID:10763   DB01244                           hypertension
#              DB01244                           hypertension
# DOID:13189   DB00959                                   gout
#              DB00959                                   gout
# DOID:1936    DB00175                        atherosclerosis
#              DB00175                        atherosclerosis
# DOID:3393    DB00451                coronary artery disease
#              DB00451                coronary artery disease
#              DB00509                coronary artery disease
#              DB00509                coronary artery disease
# DOID:9074    DB00860           systemic lupus erythematosus
#              DB00860           systemic lupus erythematosus
# DOID:3393    DB00700                coronary artery disease
#              DB00700                coronary artery disease
# DOID:2531    DB01181                     hematologic cancer
#              DB01181                     hematologic cancer
# DOID:10763   DB00722                           hypertension
#              DB00722                           hypertension
# DOID:10283   DB00175                        prostate cancer
#              DB00175                        prostate cancer
# DOID:9352    DB01083               type 2 diabetes mellitus
#              DB01083               type 2 diabetes mellitus
# DOID:1936    DB00758                        atherosclerosis
#              DB00758                        atherosclerosis
# DOID:9352    DB01132               type 2 diabetes mellitus
#              DB01132               type 2 diabetes mellitus
# DOID:7148    DB00795                   rheumatoid arthritis
#              DB00795                   rheumatoid arthritis
# DOID:784     DB00567                 chronic kidney failure
#              DB00567                 chronic kidney failure
# DOID:4481    DB00180                      allergic rhinitis
#              DB00180                      allergic rhinitis
# DOID:1612    DB00544                          breast cancer
#              DB00544                          breast cancer
# DOID:10763   DB01118                           hypertension
#              DB01118                           hypertension
# DOID:9074    DB00993           systemic lupus erythematosus
#              DB00993           systemic lupus erythematosus
# DOID:1686    DB00703                               glaucoma
#              DB00703                               glaucoma
# DOID:2841    DB00218                                 asthma
#              DB00218                                 asthma
# DOID:9074    DB00959           systemic lupus erythematosus
#              DB00959           systemic lupus erythematosus
# DOID:6364    DB00313                               migraine
#              DB00313                               migraine
# DOID:11476   DB00136                           osteoporosis
#              DB00136                           osteoporosis
# DOID:2841    DB00959                                 asthma
#              DB00959                                 asthma
# DOID:1781    DB00398                         thyroid cancer
#              DB00398                         thyroid cancer
# DOID:2841    DB01001                                 asthma
#              DB01001                                 asthma
# DOID:11476   DB00999                           osteoporosis
#              DB00999                           osteoporosis
# DOID:10763   DB00524                           hypertension
#              DB00524                           hypertension
# DOID:263     DB00603                          kidney cancer
#              DB00603                          kidney cancer
# DOID:1826    DB00555                      epilepsy syndrome
#              DB00555                      epilepsy syndrome
# DOID:8577    DB01014                     ulcerative colitis
#              DB01014                     ulcerative colitis
# DOID:2841    DB00744                                 asthma
#              DB00744                                 asthma
# DOID:3083    DB01001  chronic obstructive pulmonary disease
#              DB01001  chronic obstructive pulmonary disease
# DOID:2841    DB00455                                 asthma
#              DB00455                                 asthma
# DOID:10763   DB00195                           hypertension
#              DB00195                           hypertension
# DOID:2841    DB00920                                 asthma
#              DB00920                                 asthma
# DOID:8893    DB00136                              psoriasis
#              DB00136                              psoriasis
# DOID:12306   DB00553                               vitiligo
#              DB00553                               vitiligo
# DOID:10763   DB00218                           hypertension
#              DB00218                           hypertension
# DOID:7148    DB00993                   rheumatoid arthritis
#              DB00993                   rheumatoid arthritis
# DOID:1612    DB01229                          breast cancer
#              DB01229                          breast cancer
# DOID:1781    DB00451                         thyroid cancer
#              DB00451                         thyroid cancer
#              DB00509                         thyroid cancer
#              DB00509                         thyroid cancer
# DOID:1612    DB01248                          breast cancer
#              DB01248                          breast cancer
#              DB01259                          breast cancer
#              DB01259                          breast cancer
# DOID:9352    DB01076               type 2 diabetes mellitus
#              DB01076               type 2 diabetes mellitus
# DOID:1612    DB00291                          breast cancer
#              DB00291                          breast cancer
# DOID:10763   DB00457                           hypertension
#              DB00457                           hypertension
#              DB00264                           hypertension
#              DB00264                           hypertension
# DOID:8577    DB00741                     ulcerative colitis
#              DB00741                     ulcerative colitis
# DOID:2841    DB00860                                 asthma
#              DB00860                                 asthma
# DOID:2355    DB00860                                 anemia
#              DB00860                                 anemia
# DOID:13189   DB00860                                   gout
#              DB00860                                   gout
# DOID:9352    DB00912               type 2 diabetes mellitus
#              DB00912               type 2 diabetes mellitus
# DOID:7148    DB00635                   rheumatoid arthritis
#              DB00635                   rheumatoid arthritis
# DOID:3393    DB00790                coronary artery disease
#              DB00790                coronary artery disease
# DOID:4481    DB00860                      allergic rhinitis
#              DB00860                      allergic rhinitis
# DOID:10763   DB00887                           hypertension
#              DB00887                           hypertension
# DOID:1826    DB00620                      epilepsy syndrome
#              DB00620                      epilepsy syndrome
# DOID:11054   DB04572                 urinary bladder cancer
#              DB04572                 urinary bladder cancer
# DOID:1936    DB00627                        atherosclerosis
#              DB00627                        atherosclerosis
# DOID:8398    DB00201                         osteoarthritis
#              DB00201                         osteoarthritis
# DOID:10534   DB00322                         stomach cancer
#              DB00322                         stomach cancer
# DOID:10763   DB01193                           hypertension
#              DB01193                           hypertension
# DOID:8577    DB00959                     ulcerative colitis
#              DB00959                     ulcerative colitis
# DOID:8893    DB00741                              psoriasis
#              DB00741                              psoriasis
# DOID:10763   DB00629                           hypertension
#              DB00629                           hypertension
# DOID:1793    DB01268                      pancreatic cancer
#              DB01268                      pancreatic cancer
# DOID:824     DB00417                          periodontitis
#              DB00417                          periodontitis
# DOID:1826    DB00292                      epilepsy syndrome
#              DB00292                      epilepsy syndrome
# DOID:8577    DB00537                     ulcerative colitis
#              DB00537                     ulcerative colitis
#              DB00620                     ulcerative colitis
#              DB00620                     ulcerative colitis
# DOID:4159    DB00724                            skin cancer
#              DB00724                            skin cancer
# DOID:2841    DB00741                                 asthma
#              DB00741                                 asthma
# DOID:3083    DB00471  chronic obstructive pulmonary disease
#              DB00471  chronic obstructive pulmonary disease
# DOID:9352    DB01029               type 2 diabetes mellitus
#              DB01029               type 2 diabetes mellitus
# DOID:10763   DB00800                           hypertension
#              DB00800                           hypertension
# DOID:1319    DB01168                           brain cancer
#              DB01168                           brain cancer
# DOID:263     DB01065                          kidney cancer
#              DB01065                          kidney cancer
# DOID:10283   DB00513                        prostate cancer
#              DB00513                        prostate cancer
# DOID:3393    DB01039                coronary artery disease
#              DB01039                coronary artery disease
# DOID:7148    DB00425                   rheumatoid arthritis
#              DB00425                   rheumatoid arthritis
#
#                                         drug_name        method  score  \
# trait        drug
# DOID:2998    DB00445                   Epirubicin  Module-based  618.9
#              DB00445                   Epirubicin    Gene-based   87.3
#              DB00997                  Doxorubicin  Module-based  618.9
#              DB00997                  Doxorubicin    Gene-based   87.3
#              DB00970                 Dactinomycin  Module-based  532.2
#              DB00970                 Dactinomycin    Gene-based  126.4
# DOID:10763   DB01136                   Carvedilol  Module-based  289.2
#              DB01136                   Carvedilol    Gene-based  551.6
# DOID:4481    DB00959           Methylprednisolone  Module-based  538.4
#              DB00959           Methylprednisolone    Gene-based  208.8
#              DB01234                Dexamethasone  Module-based  618.7
#              DB01234                Dexamethasone    Gene-based  335.1
#              DB00443                Betamethasone  Module-based  618.7
#              DB00443                Betamethasone    Gene-based  335.1
# DOID:10763   DB00374                 Treprostinil  Module-based  638.8
#              DB00374                 Treprostinil    Gene-based  384.8
# DOID:1793    DB01248                    Docetaxel  Module-based  563.4
#              DB01248                    Docetaxel    Gene-based  304.4
# DOID:10763   DB00384                  Triamterene  Module-based  568.2
#              DB00384                  Triamterene    Gene-based  320.4
#              DB00966                  Telmisartan  Module-based  378.2
#              DB00966                  Telmisartan    Gene-based  555.2
# DOID:10283   DB01248                    Docetaxel  Module-based  579.2
#              DB01248                    Docetaxel    Gene-based  351.4
# DOID:10763   DB01001                   Salbutamol  Module-based  401.2
#              DB01001                   Salbutamol    Gene-based  577.0
# DOID:7147    DB00620                Triamcinolone  Module-based  578.6
#              DB00620                Triamcinolone    Gene-based  372.8
# DOID:10763   DB00227                   Lovastatin  Module-based  622.4
#              DB00227                   Lovastatin    Gene-based  429.0
#              DB00820                    Tadalafil  Module-based  419.6
#              DB00820                    Tadalafil    Gene-based  580.4
#              DB00598                    Labetalol  Module-based  388.8
#              DB00598                    Labetalol    Gene-based  540.4
#              DB00905                  Bimatoprost  Module-based  570.0
#              DB00905                  Bimatoprost    Gene-based  364.8
#              DB00774           Hydroflumethiazide  Module-based  542.8
#              DB00774           Hydroflumethiazide    Gene-based  337.2
# DOID:4481    DB00741               Hydrocortisone  Module-based  551.8
#              DB00741               Hydrocortisone    Gene-based  349.2
# DOID:2841    DB00938                   Salmeterol  Module-based  414.8
#              DB00938                   Salmeterol    Gene-based  555.8
# DOID:8893    DB01091                   Butenafine  Module-based  443.4
#              DB01091                   Butenafine    Gene-based  589.0
# DOID:4481    DB00620                Triamcinolone  Module-based  574.2
#              DB00620                Triamcinolone    Gene-based  400.0
# DOID:10763   DB00436          Bendroflumethiazide  Module-based  578.8
#              DB00436          Bendroflumethiazide    Gene-based  408.4
#              DB00758                  Clopidogrel  Module-based  466.4
#              DB00758                  Clopidogrel    Gene-based  604.6
# DOID:9352    DB01200                Bromocriptine  Module-based  419.4
#              DB01200                Bromocriptine    Gene-based  543.2
# DOID:10763   DB01194                 Brinzolamide  Module-based  569.2
#              DB01194                 Brinzolamide    Gene-based  400.8
# DOID:0050741 DB00704                   Naltrexone  Module-based  562.8
#              DB00704                   Naltrexone    Gene-based  395.8
# DOID:13189   DB01394                   Colchicine  Module-based  590.2
#              DB01394                   Colchicine    Gene-based  433.0
# DOID:2841    DB00535                     Cefdinir  Module-based  439.8
#              DB00535                     Cefdinir    Gene-based  559.4
# DOID:8778    DB01014                  Balsalazide  Module-based  463.8
#              DB01014                  Balsalazide    Gene-based  590.0
# DOID:10283   DB00286         Conjugated Estrogens  Module-based  542.2
#              DB00286         Conjugated Estrogens    Gene-based  375.6
# DOID:10763   DB00988                     Dopamine  Module-based  428.2
#              DB00988                     Dopamine    Gene-based  540.4
# DOID:1936    DB00227                   Lovastatin  Module-based  439.0
#              DB00227                   Lovastatin    Gene-based  553.8
# DOID:585     DB00999          Hydrochlorothiazide  Module-based  474.2
#              DB00999          Hydrochlorothiazide    Gene-based  598.8
# DOID:9352    DB00284                     Acarbose  Module-based  552.0
#              DB00284                     Acarbose    Gene-based  396.4
# DOID:10534   DB00563                 Methotrexate  Module-based  473.6
#              DB00563                 Methotrexate    Gene-based  588.8
# DOID:363     DB00773                    Etoposide  Module-based  500.0
#              DB00773                    Etoposide    Gene-based  617.8
# DOID:1612    DB00361                  Vinorelbine  Module-based  569.4
#              DB00361                  Vinorelbine    Gene-based  430.0
# DOID:3393    DB01197                    Captopril  Module-based  580.2
#              DB01197                    Captopril    Gene-based  448.0
# DOID:9970    DB01083                     Orlistat  Module-based  462.4
#              DB01083                     Orlistat    Gene-based  560.6
# DOID:9008    DB00563                 Methotrexate  Module-based  574.0
#              DB00563                 Methotrexate    Gene-based  444.8
# DOID:2531    DB01168                 Procarbazine  Module-based  535.6
#              DB01168                 Procarbazine    Gene-based  396.2
# DOID:2841    DB00332          Ipratropium bromide  Module-based  492.2
#              DB00332          Ipratropium bromide    Gene-based  595.4
# DOID:12365   DB00806               Pentoxifylline  Module-based  443.6
#              DB00806               Pentoxifylline    Gene-based  529.4
# DOID:10652   DB00190                    Carbidopa  Module-based  467.4
#              DB00190                    Carbidopa    Gene-based  558.2
# DOID:11476   DB04574                  Estropipate  Module-based  575.5
#              DB04574                  Estropipate    Gene-based  454.3
#              DB00286         Conjugated Estrogens  Module-based  575.5
#              DB00286         Conjugated Estrogens    Gene-based  454.3
# DOID:9074    DB00635                   Prednisone  Module-based  559.6
#              DB00635                   Prednisone    Gene-based  434.4
# DOID:2841    DB01137                 Levofloxacin  Module-based  506.8
#              DB01137                 Levofloxacin    Gene-based  607.6
# DOID:3571    DB00398                    Sorafenib  Module-based  498.6
#              DB00398                    Sorafenib    Gene-based  595.6
# DOID:2841    DB01003             Cromoglicic acid  Module-based  464.4
#              DB01003             Cromoglicic acid    Gene-based  551.2
#              DB00983                   Formoterol  Module-based  515.5
#              DB00983                   Formoterol    Gene-based  616.5
#              DB01274                 Arformoterol  Module-based  515.5
#              DB01274                 Arformoterol    Gene-based  616.5
# DOID:11714   DB01016                    Glyburide  Module-based  592.6
#              DB01016                    Glyburide    Gene-based  480.2
# DOID:2377    DB00953                  Rizatriptan  Module-based  475.4
#              DB00953                  Rizatriptan    Gene-based  560.8
# DOID:2998    DB00291                 Chlorambucil  Module-based  546.0
#              DB00291                 Chlorambucil    Gene-based  425.0
# DOID:11476   DB00977            Ethinyl Estradiol  Module-based  464.0
#              DB00977            Ethinyl Estradiol    Gene-based  544.8
# DOID:7148    DB00995                    Auranofin  Module-based  524.6
#              DB00995                    Auranofin    Gene-based  622.0
# DOID:10763   DB01083                     Orlistat  Module-based  506.2
#              DB01083                     Orlistat    Gene-based  598.4
# DOID:9970    DB01156                    Bupropion  Module-based  483.2
#              DB01156                    Bupropion    Gene-based  567.6
# DOID:1826    DB00909                   Zonisamide  Module-based  474.2
#              DB00909                   Zonisamide    Gene-based  555.6
# DOID:1612    DB00762                   Irinotecan  Module-based  498.8
#              DB00762                   Irinotecan    Gene-based  586.8
# DOID:7148    DB00959           Methylprednisolone  Module-based  509.8
#              DB00959           Methylprednisolone    Gene-based  600.4
# DOID:12365   DB00205                Pyrimethamine  Module-based  553.0
#              DB00205                Pyrimethamine    Gene-based  438.2
# DOID:10534   DB01248                    Docetaxel  Module-based  575.8
#              DB01248                    Docetaxel    Gene-based  468.2
# DOID:10763   DB00177                    Valsartan  Module-based  490.8
#              DB00177                    Valsartan    Gene-based  574.4
# DOID:13189   DB00328                 Indomethacin  Module-based  492.6
#              DB00328                 Indomethacin    Gene-based  575.4
# DOID:8778    DB00916                Metronidazole  Module-based  454.2
#              DB00916                Metronidazole    Gene-based  525.2
# DOID:10763   DB00350                    Minoxidil  Module-based  471.0
#              DB00350                    Minoxidil    Gene-based  546.2
# DOID:9074    DB01097                  Leflunomide  Module-based  533.8
#              DB01097                  Leflunomide    Gene-based  419.4
# DOID:1324    DB01168                 Procarbazine  Module-based  475.2
#              DB01168                 Procarbazine    Gene-based  549.0
# DOID:9970    DB01105                  Sibutramine  Module-based  460.0
#              DB01105                  Sibutramine    Gene-based  528.4
# DOID:9352    DB00222                  Glimepiride  Module-based  536.0
#              DB00222                  Glimepiride    Gene-based  424.4
# DOID:8893    DB00635                   Prednisone  Module-based  471.4
#              DB00635                   Prednisone    Gene-based  542.2
# DOID:7148    DB00338                   Omeprazole  Module-based  494.7
#              DB00338                   Omeprazole    Gene-based  571.1
#              DB00736                 Esomeprazole  Module-based  494.7
#              DB00736                 Esomeprazole    Gene-based  571.1
# DOID:10763   DB00206                    Reserpine  Module-based  563.6
#              DB00206                    Reserpine    Gene-based  461.2
# DOID:1612    DB00441                  Gemcitabine  Module-based  518.0
#              DB00441                  Gemcitabine    Gene-based  599.8
# DOID:9008    DB00620                Triamcinolone  Module-based  484.0
#              DB00620                Triamcinolone    Gene-based  555.4
# DOID:10763   DB01244                     Bepridil  Module-based  476.4
#              DB01244                     Bepridil    Gene-based  545.6
# DOID:13189   DB00959           Methylprednisolone  Module-based  502.8
#              DB00959           Methylprednisolone    Gene-based  579.2
# DOID:1936    DB00175                  Pravastatin  Module-based  470.0
#              DB00175                  Pravastatin    Gene-based  534.4
# DOID:3393    DB00451                Levothyroxine  Module-based  483.5
#              DB00451                Levothyroxine    Gene-based  551.3
#              DB00509              Dextrothyroxine  Module-based  483.5
#              DB00509              Dextrothyroxine    Gene-based  551.3
# DOID:9074    DB00860                 Prednisolone  Module-based  523.4
#              DB00860                 Prednisolone    Gene-based  601.2
# DOID:3393    DB00700                   Eplerenone  Module-based  538.6
#              DB00700                   Eplerenone    Gene-based  437.2
# DOID:2531    DB01181                   Ifosfamide  Module-based  498.2
#              DB01181                   Ifosfamide    Gene-based  566.0
# DOID:10763   DB00722                   Lisinopril  Module-based  546.0
#              DB00722                   Lisinopril    Gene-based  448.4
# DOID:10283   DB00175                  Pravastatin  Module-based  578.4
#              DB00175                  Pravastatin    Gene-based  490.6
# DOID:9352    DB01083                     Orlistat  Module-based  497.0
#              DB01083                     Orlistat    Gene-based  561.8
# DOID:1936    DB00758                  Clopidogrel  Module-based  503.2
#              DB00758                  Clopidogrel    Gene-based  569.4
# DOID:9352    DB01132                 Pioglitazone  Module-based  549.8
#              DB01132                 Pioglitazone    Gene-based  456.6
# DOID:7148    DB00795                Sulfasalazine  Module-based  465.0
#              DB00795                Sulfasalazine    Gene-based  519.8
# DOID:784     DB00567                   Cephalexin  Module-based  468.2
#              DB00567                   Cephalexin    Gene-based  523.6
# DOID:4481    DB00180                  Flunisolide  Module-based  563.6
#              DB00180                  Flunisolide    Gene-based  475.4
# DOID:1612    DB00544                 Fluorouracil  Module-based  561.2
#              DB00544                 Fluorouracil    Gene-based  473.0
# DOID:10763   DB01118                   Amiodarone  Module-based  504.2
#              DB01118                   Amiodarone    Gene-based  567.0
# DOID:9074    DB00993                 Azathioprine  Module-based  515.0
#              DB00993                 Azathioprine    Gene-based  580.0
# DOID:1686    DB00703                Methazolamide  Module-based  534.8
#              DB00703                Methazolamide    Gene-based  441.4
# DOID:2841    DB00218                 Moxifloxacin  Module-based  481.0
#              DB00218                 Moxifloxacin    Gene-based  535.6
# DOID:9074    DB00959           Methylprednisolone  Module-based  479.6
#              DB00959           Methylprednisolone    Gene-based  533.6
# DOID:6364    DB00313                Valproic Acid  Module-based  561.4
#              DB00313                Valproic Acid    Gene-based  477.6
# DOID:11476   DB00136                   Calcitriol  Module-based  580.4
#              DB00136                   Calcitriol    Gene-based  504.4
# DOID:2841    DB00959           Methylprednisolone  Module-based  509.0
#              DB00959           Methylprednisolone    Gene-based  566.6
# DOID:1781    DB00398                    Sorafenib  Module-based  508.8
#              DB00398                    Sorafenib    Gene-based  565.8
# DOID:2841    DB01001                   Salbutamol  Module-based  517.8
#              DB01001                   Salbutamol    Gene-based  577.2
# DOID:11476   DB00999          Hydrochlorothiazide  Module-based  553.2
#              DB00999          Hydrochlorothiazide    Gene-based  471.2
# DOID:10763   DB00524                   Metolazone  Module-based  586.8
#              DB00524                   Metolazone    Gene-based  514.8
# DOID:263     DB00603  Medroxyprogesterone Acetate  Module-based  516.8
#              DB00603  Medroxyprogesterone Acetate    Gene-based  573.2
# DOID:1826    DB00555                  Lamotrigine  Module-based  568.8
#              DB00555                  Lamotrigine    Gene-based  494.4
# DOID:8577    DB01014                  Balsalazide  Module-based  564.2
#              DB01014                  Balsalazide    Gene-based  490.2
# DOID:2841    DB00744                     Zileuton  Module-based  515.6
#              DB00744                     Zileuton    Gene-based  568.6
# DOID:3083    DB01001                   Salbutamol  Module-based  479.0
#              DB01001                   Salbutamol    Gene-based  519.6
# DOID:2841    DB00455                   Loratadine  Module-based  517.8
#              DB00455                   Loratadine    Gene-based  569.2
# DOID:10763   DB00195                    Betaxolol  Module-based  548.4
#              DB00195                    Betaxolol    Gene-based  473.4
# DOID:2841    DB00920                    Ketotifen  Module-based  533.6
#              DB00920                    Ketotifen    Gene-based  454.6
# DOID:8893    DB00136                   Calcitriol  Module-based  488.2
#              DB00136                   Calcitriol    Gene-based  530.6
# DOID:12306   DB00553                  Methoxsalen  Module-based  506.8
#              DB00553                  Methoxsalen    Gene-based  550.8
# DOID:10763   DB00218                 Moxifloxacin  Module-based  531.6
#              DB00218                 Moxifloxacin    Gene-based  455.8
# DOID:7148    DB00993                 Azathioprine  Module-based  556.6
#              DB00993                 Azathioprine    Gene-based  488.2
# DOID:1612    DB01229                   Paclitaxel  Module-based  546.2
#              DB01229                   Paclitaxel    Gene-based  475.8
# DOID:1781    DB00451                Levothyroxine  Module-based  484.5
#              DB00451                Levothyroxine    Gene-based  519.9
#              DB00509              Dextrothyroxine  Module-based  484.5
#              DB00509              Dextrothyroxine    Gene-based  519.9
# DOID:1612    DB01248                    Docetaxel  Module-based  564.2
#              DB01248                    Docetaxel    Gene-based  500.0
#              DB01259                    Lapatinib  Module-based  493.2
#              DB01259                    Lapatinib    Gene-based  528.4
# DOID:9352    DB01076                 Atorvastatin  Module-based  523.6
#              DB01076                 Atorvastatin    Gene-based  566.6
# DOID:1612    DB00291                 Chlorambucil  Module-based  513.6
#              DB00291                 Chlorambucil    Gene-based  552.6
# DOID:10763   DB00457                     Prazosin  Module-based  510.4
#              DB00457                     Prazosin    Gene-based  548.0
#              DB00264                   Metoprolol  Module-based  498.6
#              DB00264                   Metoprolol    Gene-based  532.6
# DOID:8577    DB00741               Hydrocortisone  Module-based  493.0
#              DB00741               Hydrocortisone    Gene-based  525.4
# DOID:2841    DB00860                 Prednisolone  Module-based  494.6
#              DB00860                 Prednisolone    Gene-based  527.2
# DOID:2355    DB00860                 Prednisolone  Module-based  531.0
#              DB00860                 Prednisolone    Gene-based  463.4
# DOID:13189   DB00860                 Prednisolone  Module-based  501.6
#              DB00860                 Prednisolone    Gene-based  534.6
# DOID:9352    DB00912                  Repaglinide  Module-based  533.4
#              DB00912                  Repaglinide    Gene-based  468.2
# DOID:7148    DB00635                   Prednisone  Module-based  532.6
#              DB00635                   Prednisone    Gene-based  467.4
# DOID:3393    DB00790                  Perindopril  Module-based  555.8
#              DB00790                  Perindopril    Gene-based  498.0
# DOID:4481    DB00860                 Prednisolone  Module-based  503.8
#              DB00860                 Prednisolone    Gene-based  535.2
# DOID:10763   DB00887                   Bumetanide  Module-based  500.0
#              DB00887                   Bumetanide    Gene-based  529.8
# DOID:1826    DB00620                Triamcinolone  Module-based  533.2
#              DB00620                Triamcinolone    Gene-based  470.2
# DOID:11054   DB04572                     Thiotepa  Module-based  505.8
#              DB04572                     Thiotepa    Gene-based  536.4
# DOID:1936    DB00627                       Niacin  Module-based  568.6
#              DB00627                       Niacin    Gene-based  516.6
# DOID:8398    DB00201                     Caffeine  Module-based  511.2
#              DB00201                     Caffeine    Gene-based  542.6
# DOID:10534   DB00322                  Floxuridine  Module-based  523.4
#              DB00322                  Floxuridine    Gene-based  558.2
# DOID:10763   DB01193                   Acebutolol  Module-based  492.4
#              DB01193                   Acebutolol    Gene-based  518.0
# DOID:8577    DB00959           Methylprednisolone  Module-based  495.4
#              DB00959           Methylprednisolone    Gene-based  520.4
# DOID:8893    DB00741               Hydrocortisone  Module-based  548.6
#              DB00741               Hydrocortisone    Gene-based  494.2
# DOID:10763   DB00629                    Guanabenz  Module-based  528.6
#              DB00629                    Guanabenz    Gene-based  561.4
# DOID:1793    DB01268                    Sunitinib  Module-based  552.2
#              DB01268                    Sunitinib    Gene-based  500.0
# DOID:824     DB00417                 Penicillin V  Module-based  527.2
#              DB00417                 Penicillin V    Gene-based  558.8
# DOID:1826    DB00292                    Etomidate  Module-based  549.6
#              DB00292                    Etomidate    Gene-based  497.0
# DOID:8577    DB00537                Ciprofloxacin  Module-based  504.8
#              DB00537                Ciprofloxacin    Gene-based  530.0
#              DB00620                Triamcinolone  Module-based  549.2
#              DB00620                Triamcinolone    Gene-based  497.0
# DOID:4159    DB00724                    Imiquimod  Module-based  526.6
#              DB00724                    Imiquimod    Gene-based  552.4
# DOID:2841    DB00741               Hydrocortisone  Module-based  520.0
#              DB00741               Hydrocortisone    Gene-based  543.8
# DOID:3083    DB00471                  Montelukast  Module-based  554.0
#              DB00471                  Montelukast    Gene-based  509.2
# DOID:9352    DB01029                   Irbesartan  Module-based  535.0
#              DB01029                   Irbesartan    Gene-based  485.4
# DOID:10763   DB00800                   Fenoldopam  Module-based  535.8
#              DB00800                   Fenoldopam    Gene-based  486.8
# DOID:1319    DB01168                 Procarbazine  Module-based  502.6
#              DB01168                 Procarbazine    Gene-based  518.0
# DOID:263     DB01065                    Melatonin  Module-based  506.0
#              DB01065                    Melatonin    Gene-based  518.2
# DOID:10283   DB00513            Aminocaproic Acid  Module-based  508.6
#              DB00513            Aminocaproic Acid    Gene-based  518.2
# DOID:3393    DB01039                  Fenofibrate  Module-based  533.6
#              DB01039                  Fenofibrate    Gene-based  497.4
# DOID:7148    DB00425                     Zolpidem  Module-based  514.2
#              DB00425                     Zolpidem    Gene-based  520.2
#
#                       true_class  score_std  different_sign  score_difference
# trait        drug
# DOID:2998    DB00445           1   1.204129            True          5.784830
#              DB00445           1  -4.580701            True          5.784830
#              DB00997           1   1.204129            True          5.784830
#              DB00997           1  -4.580701            True          5.784830
#              DB00970           1   0.024094            True          4.188618
#              DB00970           1  -4.164523            True          4.188618
# DOID:10763   DB01136           1  -3.283269            True          3.644550
#              DB01136           1   0.361281            True          3.644550
# DOID:4481    DB00959           1   0.108480            True          3.395942
#              DB00959           1  -3.287462            True          3.395942
#              DB01234           1   1.201407            True          3.144539
#              DB01234           1  -1.943132            True          3.144539
#              DB00443           1   1.201407            True          3.144539
#              DB00443           1  -1.943132            True          3.144539
# DOID:10763   DB00374           0   1.474979            True          2.889107
#              DB00374           0  -1.414128            True          2.889107
# DOID:1793    DB01248           1   0.448744            True          2.718645
#              DB01248           1  -2.269901            True          2.718645
# DOID:10763   DB00384           1   0.514074            True          2.613673
#              DB00384           1  -2.099598            True          2.613673
#              DB00966           1  -2.071930            True          2.471529
#              DB00966           1   0.399599            True          2.471529
# DOID:10283   DB01248           1   0.663790            True          2.433426
#              DB01248           1  -1.769636            True          2.433426
# DOID:10763   DB01001           0  -1.758887            True          2.390525
#              DB01001           0   0.631637            True          2.390525
# DOID:7147    DB00620           1   0.655624            True          2.197480
#              DB00620           1  -1.541856            True          2.197480
# DOID:10763   DB00227           0   1.251766            True          2.195432
#              DB00227           0  -0.943666            True          2.195432
#              DB00820           0  -1.508453            True          2.176280
#              DB00820           0   0.667827            True          2.176280
#              DB00598           1  -1.927658            True          2.169727
#              DB00598           1   0.242069            True          2.169727
#              DB00905           0   0.538573            True          2.165580
#              DB00905           0  -1.627007            True          2.165580
# ...
# DOID:7148    DB00959           1  -0.280782            True          1.161487
#              DB00959           1   0.880705            True          1.161487
# DOID:12365   DB00205           1   0.307194            True          1.152936
#              DB00205           1  -0.845742            True          1.152936
# DOID:10534   DB01248           1   0.617514            True          1.143938
#              DB01248           1  -0.526424            True          1.143938
# DOID:10763   DB00177           1  -0.539382            True          1.143345
#              DB00177           1   0.603963            True          1.143345
# DOID:13189   DB00328           1  -0.514883            True          1.129490
#              DB00328           1   0.614607            True          1.129490
# DOID:8778    DB00916           0  -1.037528            True          1.117809
#              DB00916           0   0.080281            True          1.117809
# DOID:10763   DB00350           1  -0.808871            True          1.112675
#              DB00350           1   0.303804            True          1.112675
# DOID:9074    DB01097           1   0.045871            True          1.091719
#              DB01097           1  -1.045848            True          1.091719
# DOID:1324    DB01168           0  -0.751707            True          1.085314
#              DB01168           0   0.333607            True          1.085314
# DOID:9970    DB01105           1  -0.958587            True          1.072929
#              DB01105           1   0.114342            True          1.072929
# DOID:9352    DB00222           1   0.075815            True          1.068443
#              DB00222           1  -0.992628            True          1.068443
# DOID:8893    DB00635           1  -0.803427            True          1.064655
#              DB00635           1   0.261228            True          1.064655
# DOID:7148    DB00338           0  -0.486301            True          1.055139
#              DB00338           0   0.568838            True          1.055139
#              DB00736           0  -0.486301            True          1.055139
#              DB00736           0   0.568838            True          1.055139
# DOID:10763   DB00206           1   0.451466            True          1.052397
#              DB00206           1  -0.600931            True          1.052397
# DOID:1612    DB00441           1  -0.169175            True          1.043494
#              DB00441           1   0.874319            True          1.043494
# DOID:9008    DB00620           1  -0.631934            True          1.033662
#              DB00620           1   0.401728            True          1.033662
# DOID:10763   DB01244           1  -0.735374            True          1.032792
#              DB01244           1   0.297417            True          1.032792
# DOID:13189   DB00959           1  -0.376056            True          1.031110
#              DB00959           1   0.655054            True          1.031110
# DOID:1936    DB00175           1  -0.822482            True          1.000687
#              DB00175           1   0.178205            True          1.000687
# DOID:3393    DB00451           0  -0.638739            True          0.996827
#              DB00451           0   0.358088            True          0.996827
#              DB00509           0  -0.638739            True          0.996827
#              DB00509           0   0.358088            True          0.996827
# DOID:9074    DB00860           1  -0.095678            True          0.984899
#              DB00860           1   0.889221            True          0.984899
# DOID:3393    DB00700           1   0.111202            True          0.967588
#              DB00700           1  -0.856386            True          0.967588
# DOID:2531    DB01181           1  -0.438664            True          0.953218
#              DB01181           1   0.514554            True          0.953218
# DOID:10763   DB00722           1   0.211920            True          0.949094
#              DB00722           1  -0.737174            True          0.949094
# DOID:10283   DB00175           0   0.652902            True          0.940901
#              DB00175           0  -0.287999            True          0.940901
# DOID:9352    DB01083           1  -0.454997            True          0.924846
#              DB01083           1   0.469849            True          0.924846
# DOID:1936    DB00758           0  -0.370611            True          0.921355
#              DB00758           0   0.550743            True          0.921355
# DOID:9352    DB01132           1   0.263640            True          0.913534
#              DB01132           1  -0.649893            True          0.913534
# DOID:7148    DB00795           1  -0.890534            True          0.913338
#              DB00795           1   0.022804            True          0.913338
# DOID:784     DB00567           0  -0.846981            True          0.910231
#              DB00567           0   0.063251            True          0.910231
# DOID:4481    DB00180           1   0.451466            True          0.901253
#              DB00180           1  -0.449787            True          0.901253
# DOID:1612    DB00544           1   0.418800            True          0.894133
#              DB00544           1  -0.475333            True          0.894133
# DOID:10763   DB01118           0  -0.357001            True          0.882199
#              DB01118           0   0.525198            True          0.882199
# DOID:9074    DB00993           1  -0.210007            True          0.873576
#              DB00993           1   0.663569            True          0.873576
# DOID:1686    DB00703           1   0.059482            True          0.871163
#              DB00703           1  -0.811681            True          0.871163
# DOID:2841    DB00218           0  -0.672766            True          0.863744
#              DB00218           0   0.190978            True          0.863744
# DOID:9074    DB00959           1  -0.691820            True          0.861511
#              DB00959           1   0.169690            True          0.861511
# DOID:6364    DB00313           1   0.421522            True          0.847893
#              DB00313           1  -0.426371            True          0.847893
# DOID:11476   DB00136           1   0.680123            True          0.821236
#              DB00136           1  -0.141113            True          0.821236
# DOID:2841    DB00959           1  -0.291670            True          0.812610
#              DB00959           1   0.520940            True          0.812610
# DOID:1781    DB00398           1  -0.294392            True          0.806817
#              DB00398           1   0.512425            True          0.806817
# DOID:2841    DB01001           1  -0.171897            True          0.805663
#              DB01001           1   0.633766            True          0.805663
# DOID:11476   DB00999           0   0.309916            True          0.804408
#              DB00999           0  -0.494492            True          0.804408
# DOID:10763   DB00524           1   0.767230            True          0.797646
#              DB00524           1  -0.030416            True          0.797646
# DOID:263     DB00603           0  -0.185508            True          0.776698
#              DB00603           0   0.591190            True          0.776698
# DOID:1826    DB00555           1   0.522241            True          0.769793
#              DB00555           1  -0.247552            True          0.769793
# DOID:8577    DB01014           1   0.459632            True          0.751889
#              DB01014           1  -0.292257            True          0.751889
# DOID:2841    DB00744           1  -0.201841            True          0.744069
#              DB00744           1   0.542228            True          0.744069
# DOID:3083    DB01001           1  -0.699987            True          0.720662
#              DB01001           1   0.020675            True          0.720662
# DOID:2841    DB00455           1  -0.171897            True          0.720512
#              DB00455           1   0.548614            True          0.720512
# DOID:10763   DB00195           1   0.244585            True          0.715661
#              DB00195           1  -0.471075            True          0.715661
# DOID:2841    DB00920           1   0.043149            True          0.714331
#              DB00920           1  -0.671181            True          0.714331
# DOID:8893    DB00136           1  -0.574770            True          0.712528
#              DB00136           1   0.137758            True          0.712528
# DOID:12306   DB00553           1  -0.321613            True          0.674379
#              DB00553           1   0.352766            True          0.674379
# DOID:10763   DB00218           0   0.015928            True          0.674337
#              DB00218           0  -0.658409            True          0.674337
# DOID:7148    DB00993           1   0.356192            True          0.669737
#              DB00993           1  -0.313545            True          0.669737
# DOID:1612    DB01229           1   0.214642            True          0.660172
#              DB01229           1  -0.445530            True          0.660172
# DOID:1781    DB00451           0  -0.625129            True          0.648997
#              DB00451           0   0.023868            True          0.648997
#              DB00509           0  -0.625129            True          0.648997
#              DB00509           0   0.023868            True          0.648997
# DOID:1612    DB01248           1   0.459632            True          0.647578
#              DB01248           1  -0.187946            True          0.647578
#              DB01259           1  -0.506717            True          0.621059
#              DB01259           1   0.114342            True          0.621059
# DOID:9352    DB01076           0  -0.092956            True          0.613896
#              DB01076           0   0.520940            True          0.613896
# DOID:1612    DB00291           1  -0.229062            True          0.600987
#              DB00291           1   0.371925            True          0.600987
# DOID:10763   DB00457           1  -0.272615            True          0.595578
#              DB00457           1   0.322963            True          0.595578
#              DB00264           1  -0.433220            True          0.592266
#              DB00264           1   0.159046            True          0.592266
# DOID:8577    DB00741           1  -0.509439            True          0.591849
#              DB00741           1   0.082410            True          0.591849
# DOID:2841    DB00860           1  -0.487662            True          0.589231
#              DB00860           1   0.101569            True          0.589231
# DOID:2355    DB00860           0   0.007762            True          0.585276
#              DB00860           0  -0.577515            True          0.585276
# DOID:13189   DB00860           1  -0.392388            True          0.572722
#              DB00860           1   0.180334            True          0.572722
# DOID:9352    DB00912           1   0.040427            True          0.566851
#              DB00912           1  -0.526424            True          0.566851
# DOID:7148    DB00635           1   0.029539            True          0.564478
#              DB00635           1  -0.534939            True          0.564478
# DOID:3393    DB00790           1   0.345303            True          0.554538
#              DB00790           1  -0.209234            True          0.554538
# DOID:4481    DB00860           1  -0.362445            True          0.549166
#              DB00860           1   0.186720            True          0.549166
# DOID:10763   DB00887           1  -0.414165            True          0.543408
#              DB00887           1   0.129243            True          0.543408
# DOID:1826    DB00620           0   0.037705            True          0.542841
#              DB00620           0  -0.505136            True          0.542841
# DOID:11054   DB04572           1  -0.335224            True          0.534717
#              DB04572           1   0.199493            True          0.534717
# DOID:1936    DB00627           1   0.519518            True          0.530775
#              DB00627           1  -0.011257            True          0.530775
# DOID:8398    DB00201           0  -0.261727            True          0.527213
#              DB00201           0   0.265486            True          0.527213
# DOID:10534   DB00322           1  -0.095678            True          0.527209
#              DB00322           1   0.431531            True          0.527209
# DOID:10763   DB01193           1  -0.517605            True          0.521250
#              DB01193           1   0.003645            True          0.521250
# DOID:8577    DB00959           1  -0.476774            True          0.505964
#              DB00959           1   0.029190            True          0.505964
# DOID:8893    DB00741           1   0.247307            True          0.496989
#              DB00741           1  -0.249681            True          0.496989
# DOID:10763   DB00629           1  -0.024904            True          0.490495
#              DB00629           1   0.465592            True          0.490495
# DOID:1793    DB01268           1   0.296305            True          0.484252
#              DB01268           1  -0.187946            True          0.484252
# DOID:824     DB00417           0  -0.043958            True          0.481876
#              DB00417           0   0.437917            True          0.481876
# DOID:1826    DB00292           0   0.260918            True          0.480796
#              DB00292           0  -0.219878            True          0.480796
# DOID:8577    DB00537           0  -0.348835            True          0.480207
#              DB00537           0   0.131372            True          0.480207
#              DB00620           1   0.255474            True          0.475352
#              DB00620           1  -0.219878            True          0.475352
# DOID:4159    DB00724           1  -0.052125            True          0.421921
#              DB00724           1   0.369796            True          0.421921
# DOID:2841    DB00741           1  -0.141954            True          0.420213
#              DB00741           1   0.278258            True          0.420213
# DOID:3083    DB00471           1   0.320804            True          0.410826
#              DB00471           1  -0.090022            True          0.410826
# DOID:9352    DB01029           1   0.062204            True          0.405552
#              DB01029           1  -0.343348            True          0.405552
# DOID:10763   DB00800           1   0.073092            True          0.401539
#              DB00800           1  -0.328446            True          0.401539
# DOID:1319    DB01168           1  -0.378778            True          0.382422
#              DB01168           1   0.003645            True          0.382422
# DOID:263     DB01065           0  -0.332502            True          0.338275
#              DB01065           0   0.005773            True          0.338275
# DOID:10283   DB00513           0  -0.297114            True          0.302888
#              DB00513           0   0.005773            True          0.302888
# DOID:3393    DB01039           1   0.043149            True          0.258770
#              DB01039           1  -0.215621            True          0.258770
# DOID:7148    DB00425           0  -0.220895            True          0.247957
#              DB00425           0   0.027061            True          0.247957

# %%
def find_differences(trait_name):
    with pd.option_context(
        "display.max_rows", None, "display.max_columns", None, "max_colwidth", None
    ):
        _tmp = pharmadb_predictions[
            (pharmadb_predictions["disease"] == trait_name)
            & (pharmadb_predictions["different_sign"])
        ].sort_values(
            ["score_difference", "drug_name", "method"], ascending=[False, False, False]
        )
        display(_tmp)

# %% [markdown]
# ## coronary artery disease

# %%
with pd.option_context(
    "display.max_rows", None, "display.max_columns", None, "max_colwidth", None
):
    _tmp = pharmadb_predictions[
        (pharmadb_predictions["drug_name"] == "Niacin")
        & (pharmadb_predictions["disease"] == "coronary artery disease")  # avoid cancer
    ].sort_values(
        ["score_difference", "drug_name", "method"], ascending=[False, False, False]
    )
    display(_tmp.head(50))
# Out:
#                                    disease drug_name        method  score  \
# trait     drug
# DOID:3393 DB00627  coronary artery disease    Niacin  Module-based  601.0
#           DB00627  coronary artery disease    Niacin    Gene-based  565.4
#
#                    true_class  score_std  different_sign  score_difference
# trait     drug
# DOID:3393 DB00627           1   0.960500           False          0.452333
#           DB00627           1   0.508167           False          0.452333

# %%
find_differences("coronary artery disease")
# Out:
#                                    disease        drug_name        method  \
# trait     drug
# DOID:3393 DB01197  coronary artery disease        Captopril  Module-based
#           DB01197  coronary artery disease        Captopril    Gene-based
#           DB00451  coronary artery disease    Levothyroxine  Module-based
#           DB00451  coronary artery disease    Levothyroxine    Gene-based
#           DB00509  coronary artery disease  Dextrothyroxine  Module-based
#           DB00509  coronary artery disease  Dextrothyroxine    Gene-based
#           DB00700  coronary artery disease       Eplerenone  Module-based
#           DB00700  coronary artery disease       Eplerenone    Gene-based
#           DB00790  coronary artery disease      Perindopril  Module-based
#           DB00790  coronary artery disease      Perindopril    Gene-based
#           DB01039  coronary artery disease      Fenofibrate  Module-based
#           DB01039  coronary artery disease      Fenofibrate    Gene-based
#
#                    score  true_class  score_std  different_sign  \
# trait     drug
# DOID:3393 DB01197  580.2           1   0.677401            True
#           DB01197  448.0           1  -0.741431            True
#           DB00451  483.5           0  -0.638739            True
#           DB00451  551.3           0   0.358088            True
#           DB00509  483.5           0  -0.638739            True
#           DB00509  551.3           0   0.358088            True
#           DB00700  538.6           1   0.111202            True
#           DB00700  437.2           1  -0.856386            True
#           DB00790  555.8           1   0.345303            True
#           DB00790  498.0           1  -0.209234            True
#           DB01039  533.6           1   0.043149            True
#           DB01039  497.4           1  -0.215621            True
#
#                    score_difference
# trait     drug
# DOID:3393 DB01197          1.418832
#           DB01197          1.418832
#           DB00451          0.996827
#           DB00451          0.996827
#           DB00509          0.996827
#           DB00509          0.996827
#           DB00700          0.967588
#           DB00700          0.967588
#           DB00790          0.554538
#           DB00790          0.554538
#           DB01039          0.258770
#           DB01039          0.258770

# %% [markdown]
# ## atherosclerosis

# %%
with pd.option_context(
    "display.max_rows", None, "display.max_columns", None, "max_colwidth", None
):
    _tmp = pharmadb_predictions[
        (pharmadb_predictions["drug_name"] == "Niacin")
        & (pharmadb_predictions["disease"] == "atherosclerosis")  # avoid cancer
    ].sort_values(
        ["score_difference", "drug_name", "method"], ascending=[False, False, False]
    )
    display(_tmp.head(50))
# Out:
#                            disease drug_name        method  score  true_class  \
# trait     drug
# DOID:1936 DB00627  atherosclerosis    Niacin  Module-based  568.6           1
#           DB00627  atherosclerosis    Niacin    Gene-based  516.6           1
#
#                    score_std  different_sign  score_difference
# trait     drug
# DOID:1936 DB00627   0.519518            True          0.530775
#           DB00627  -0.011257            True          0.530775

# %%
find_differences("atherosclerosis")
# Out:
#                            disease    drug_name        method  score  \
# trait     drug
# DOID:1936 DB00227  atherosclerosis   Lovastatin  Module-based  439.0
#           DB00227  atherosclerosis   Lovastatin    Gene-based  553.8
#           DB00175  atherosclerosis  Pravastatin  Module-based  470.0
#           DB00175  atherosclerosis  Pravastatin    Gene-based  534.4
#           DB00758  atherosclerosis  Clopidogrel  Module-based  503.2
#           DB00758  atherosclerosis  Clopidogrel    Gene-based  569.4
#           DB00627  atherosclerosis       Niacin  Module-based  568.6
#           DB00627  atherosclerosis       Niacin    Gene-based  516.6
#
#                    true_class  score_std  different_sign  score_difference
# trait     drug
# DOID:1936 DB00227           1  -1.244409            True          1.629106
#           DB00227           1   0.384698            True          1.629106
#           DB00175           1  -0.822482            True          1.000687
#           DB00175           1   0.178205            True          1.000687
#           DB00758           0  -0.370611            True          0.921355
#           DB00758           0   0.550743            True          0.921355
#           DB00627           1   0.519518            True          0.530775
#           DB00627           1  -0.011257            True          0.530775
