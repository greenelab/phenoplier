# %% [markdown]
# # Description

# %% [markdown]
# It uses the `clustree` package to generate clustering tree visualizations.

# %% [markdown]
# # Modules loading

# %%
library(clustree)
library(tidyverse)
# Out:
# Loading required package: ggraph
#
# Loading required package: ggplot2
#
# ── Attaching packages ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ tibble  3.1.0     ✔ dplyr   1.0.4
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
# ✔ purrr   0.3.4
#
# ── Conflicts ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# # Settings

# %%
CLUSTERING_DIR <- Sys.getenv("PHENOPLIER_RESULTS_CLUSTERING_DIR")

# %%
CLUSTERING_DIR
# Out:
# [1] "/home/miltondp/projects/labs/greenelab/phenoplier/bases_data/base_orig/results/clustering"

# %%
CONSENSUS_CLUSTERING_DIR = file.path(CLUSTERING_DIR, "consensus_clustering")

# %%
CONSENSUS_CLUSTERING_DIR
# Out:
# [1] "/home/miltondp/projects/labs/greenelab/phenoplier/bases_data/base_orig/results/clustering/consensus_clustering"

# %%
MANUSCRIPT_FIGURES_DIR <- Sys.getenv("PHENOPLIER_MANUSCRIPT_FIGURES_DIR")

# %%
if (MANUSCRIPT_FIGURES_DIR == "") {
    MANUSCRIPT_FIGURES_DIR = "/tmp"
}

# %%
MANUSCRIPT_FIGURES_DIR
# Out:
# [1] "/home/miltondp/projects/labs/greenelab/phenoplier_manuscript/content/images"

# %%
OUTPUT_FIG_DIR = file.path(MANUSCRIPT_FIGURES_DIR, "clustering")
dir.create(OUTPUT_FIG_DIR, showWarnings = FALSE)

# %%
OUTPUT_FIG_DIR
# Out:
# [1] "/home/miltondp/projects/labs/greenelab/phenoplier_manuscript/content/images/clustering"

# %% [markdown]
# # Load data

# %%
data <- read_tsv(file.path(CONSENSUS_CLUSTERING_DIR, "clustering_tree_data.tsv"))
# Out:
# ── Column specification ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# cols(
#   .default = col_double(),
#   trait = col_character()
# )
# ℹ Use `spec()` for the full column specifications.

# %%
dim(data)
# Out:
# [1] 3752   26

# %%
head(data)
# Out:
#   trait                    PCA1        PCA2         PCA3      PCA4
# 1 100001_raw-Food_weight    0.80521563 -0.865389766 0.6994802 -0.06597626
# 2 100002_raw-Energy         0.58850738 -1.491772157 1.7563401 -3.59329473
# 3 100003_raw-Protein        1.91015954 -1.873687235 1.8766772 -3.83255651
# 4 100004_raw-Fat            0.75079911 -0.294732888 1.3177099 -1.34608112
# 5 100005_raw-Carbohydrate  -0.53004448 -0.007398246 0.6114183 -3.60409358
# 6 100006_raw-Saturated_fat  0.06631347 -0.351939999 1.1056447 -2.46327220
#   PCA5      UMAP1      UMAP2     UMAP3    UMAP4     ⋯ k15 k8 k16 k9 k7 k6 k5
# 1 0.9996165  0.4265545 0.6705319 7.363805 1.1718369 ⋯ 0   0  0   8  0  5  0
# 2 2.1006066 -1.6051790 0.8156988 8.288521 0.9903937 ⋯ 0   0  0   8  0  5  0
# 3 1.2407043 -1.6561775 0.7882972 8.355906 1.0170716 ⋯ 0   0  0   8  0  5  0
# 4 2.0064032 -1.5083255 0.8025361 8.328274 1.0339391 ⋯ 0   0  0   8  0  5  0
# 5 2.2278719 -1.6178721 0.8127108 8.307973 1.0205753 ⋯ 0   0  0   8  0  5  0
# 6 1.0044179 -1.5298475 0.8014859 8.330169 1.0320061 ⋯ 0   0  0   8  0  5  0
#   k25 k26 k29
# 1  0   0   0
# 2 21  21  22
# 3 21  21  22
# 4 21  21  22
# 5 21  21  22
# 6 21  21  22

# %% [markdown]
# # Plot clustering tree

# %% [markdown]
# ## Plain

# %%
options(repr.plot.width = 20, repr.plot.height = 15)
clustree(
    data,
    prefix = "k",
    return="plot",
    node_size_range = c(10, 18),
    node_text_size = 6,
) + theme(text = element_text(size = 25))   

ggsave(
    file.path(OUTPUT_FIG_DIR, "clustering_tree.svg"),
    height=15,
    width=20,
    scale=1,
)
# Out:
# Warning message:
# “The `add` argument of `group_by()` is deprecated as of dplyr 1.0.0.
# Please use the `.add` argument instead.
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_warnings()` to see where this warning was generated.”
# plot without title
