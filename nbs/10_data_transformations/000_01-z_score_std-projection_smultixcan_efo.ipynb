# %% [markdown]
# # Description

# %% [markdown]
# It standardizes the features (latent variables) of an input file.

# %% [markdown]
# # Modules loading

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
from IPython.display import display

import numpy as np
import pandas as pd
from sklearn.preprocessing import scale

import conf

# %% [markdown]
# # Settings

# %%
INPUT_FILEPATH_STEM = 'projection-smultixcan-efo_partial-mashr-zscores'

# %%
INPUT_FILEPATH = Path(
    conf.RESULTS["DATA_TRANSFORMATIONS_DIR"],
    'traits_selections',
    f'diseases_only-{INPUT_FILEPATH_STEM}.pkl',
).resolve()
display(INPUT_FILEPATH)

input_filepath_stem = INPUT_FILEPATH.stem
display(input_filepath_stem)
# Out:
# PosixPath('/media/miltondp/Elements1/projects/phenoplier/results/data_transformations/traits_selections/diseases_only-projection-smultixcan-efo_partial-mashr-zscores.pkl')
# 'diseases_only-projection-smultixcan-efo_partial-mashr-zscores'

# %%
# output dir for this notebook
RESULTS_DIR = Path(
    conf.RESULTS["DATA_TRANSFORMATIONS_DIR"],
    'z_score_std'
).resolve()
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

display(RESULTS_DIR)
# Out:
# PosixPath('/media/miltondp/Elements1/projects/phenoplier/results/data_transformations/z_score_std')

# %% [markdown]
# # Load input file

# %%
data = pd.read_pickle(INPUT_FILEPATH)

# %%
data.shape
# Out:
# (538, 987)

# %%
data.head()
# Out:
#                                               LV1       LV2       LV3  \
# vascular disease AND intestinal disease  0.014921  0.007221 -0.021297
# osteoarthritis, knee                    -0.027514 -0.011319 -0.005507
# carpal tunnel syndrome                   0.037605  0.026694 -0.004169
# gastritis                               -0.028098  0.006805  0.011964
# neoplasm                                 0.015709  0.004118 -0.015952
#
#                                               LV4       LV5       LV6  \
# vascular disease AND intestinal disease -0.013469 -0.004764  0.019406
# osteoarthritis, knee                     0.024660 -0.012269 -0.037501
# carpal tunnel syndrome                  -0.009875 -0.038713 -0.019403
# gastritis                               -0.008576 -0.034687 -0.033875
# neoplasm                                 0.016398  0.010938 -0.017170
#
#                                               LV7       LV8       LV9  \
# vascular disease AND intestinal disease  0.034742  0.015188 -0.054239
# osteoarthritis, knee                    -0.041009 -0.018378  0.056720
# carpal tunnel syndrome                  -0.035912  0.008916  0.009359
# gastritis                               -0.043080  0.037237 -0.006757
# neoplasm                                 0.011790  0.055354 -0.020357
#
#                                              LV10  ...     LV978     LV979  \
# vascular disease AND intestinal disease -0.057495  ... -0.000006  0.009317
# osteoarthritis, knee                    -0.035201  ... -0.021507  0.023317
# carpal tunnel syndrome                   0.034914  ... -0.009627  0.073954
# gastritis                                0.003071  ...  0.037084  0.039675
# neoplasm                                 0.018452  ... -0.002537 -0.004774
#
#                                             LV980     LV981     LV982  \
# vascular disease AND intestinal disease -0.021804 -0.025295  0.004658
# osteoarthritis, knee                    -0.020850  0.025021  0.003739
# carpal tunnel syndrome                  -0.045759  0.030834 -0.013835
# gastritis                                0.034724  0.004581  0.021483
# neoplasm                                 0.006254 -0.008180 -0.014205
#
#                                             LV983     LV984     LV985  \
# vascular disease AND intestinal disease -0.007537 -0.038976 -0.000494
# osteoarthritis, knee                    -0.008428 -0.040916  0.012425
# carpal tunnel syndrome                  -0.016858  0.003820 -0.012988
# gastritis                               -0.023586  0.031696 -0.003781
# neoplasm                                 0.031993  0.021475  0.015875
#
#                                             LV986     LV987
# vascular disease AND intestinal disease -0.046299  0.039424
# osteoarthritis, knee                     0.033130  0.009771
# carpal tunnel syndrome                  -0.036130 -0.011489
# gastritis                                0.017152  0.041463
# neoplasm                                 0.031616 -0.041767
#
# [5 rows x 987 columns]

# %% [markdown]
# # Data preprocessing for clustering

# %%
data_stats = data.iloc[:, :10].describe()
display(data_stats)
# Out:
#               LV1         LV2         LV3         LV4         LV5         LV6  \
# count  538.000000  538.000000  538.000000  538.000000  538.000000  538.000000
# mean     0.003408    0.003693    0.001227    0.000010    0.003355    0.000744
# std      0.030738    0.028711    0.032734    0.029188    0.030048    0.024417
# min     -0.086921   -0.070797   -0.071927   -0.113464   -0.077479   -0.065300
# 25%     -0.016248   -0.014140   -0.022035   -0.020283   -0.015180   -0.016420
# 50%      0.000781    0.002916   -0.002880    0.000290    0.001330    0.000638
# 75%      0.020723    0.021349    0.020373    0.017406    0.019986    0.017114
# max      0.145803    0.104972    0.152061    0.127454    0.175236    0.086365
#
#               LV7         LV8         LV9        LV10
# count  538.000000  538.000000  538.000000  538.000000
# mean     0.001294    0.002137   -0.002282    0.002483
# std      0.030404    0.029454    0.024401    0.030183
# min     -0.082169   -0.081589   -0.057677   -0.090015
# 25%     -0.019859   -0.017899   -0.018994   -0.017924
# 50%      0.000603    0.000554   -0.003910   -0.000653
# 75%      0.021776    0.019323    0.014551    0.021329
# max      0.120677    0.128672    0.139215    0.102153

# %% [markdown]
# ## Standardize

# %%
scaled_data = pd.DataFrame(
    data=scale(data),
    index=data.index.copy(),
    columns=data.columns.copy()
)

# %%
scaled_data.shape
# Out:
# (538, 987)

# %%
scaled_data.head()
# Out:
#                                               LV1       LV2       LV3  \
# vascular disease AND intestinal disease  0.374886  0.123010 -0.688734
# osteoarthritis, knee                    -1.006925 -0.523367 -0.205909
# carpal tunnel syndrome                   1.113546  0.801889 -0.165020
# gastritis                               -1.025944  0.108498  0.328317
# neoplasm                                 0.400556  0.014828 -0.525315
#
#                                               LV4       LV5       LV6  \
# vascular disease AND intestinal disease -0.462234 -0.270475  0.765010
# osteoarthritis, knee                     0.845292 -0.520447 -1.567783
# carpal tunnel syndrome                  -0.339000 -1.401320 -0.825885
# gastritis                               -0.294424 -1.267212 -1.419151
# neoplasm                                 0.561977  0.252577 -0.734367
#
#                                               LV7       LV8       LV9  \
# vascular disease AND intestinal disease  1.101153  0.443515 -2.131315
# osteoarthritis, knee                    -1.392684 -0.697141  2.420293
# carpal tunnel syndrome                  -1.224864  0.230387  0.477523
# gastritis                               -1.460856  1.192783 -0.183589
# neoplasm                                 0.345537  1.808464 -0.741470
#
#                                              LV10  ...     LV978     LV979  \
# vascular disease AND intestinal disease -1.989014  ... -0.084253  0.291335
# osteoarthritis, knee                    -1.249693  ... -0.859185  0.803672
# carpal tunnel syndrome                   1.075486  ... -0.431015  2.656686
# gastritis                                0.019485  ...  1.252517  1.402279
# neoplasm                                 0.529550  ... -0.175486 -0.224286
#
#                                             LV980     LV981     LV982  \
# vascular disease AND intestinal disease -0.829496 -0.944208  0.070689
# osteoarthritis, knee                    -0.792661  0.941227  0.038807
# carpal tunnel syndrome                  -1.755027  1.159056 -0.570832
# gastritis                                1.354473  0.175315  0.654345
# neoplasm                                 0.254540 -0.302883 -0.583656
#
#                                             LV983     LV984     LV985  \
# vascular disease AND intestinal disease -0.310739 -1.054390 -0.058465
# osteoarthritis, knee                    -0.335750 -1.109207  0.426400
# carpal tunnel syndrome                  -0.572341  0.155003 -0.527333
# gastritis                               -0.761176  0.942745 -0.181810
# neoplasm                                 0.798698  0.653916  0.555870
#
#                                             LV986     LV987
# vascular disease AND intestinal disease -1.718400  1.318405
# osteoarthritis, knee                     1.151830  0.396533
# carpal tunnel syndrome                  -1.350922 -0.264405
# gastritis                                0.574468  1.381791
# neoplasm                                 1.097121 -1.205670
#
# [5 rows x 987 columns]

# %%
scaled_data_stats = scaled_data.iloc[:,:10].describe()
display(scaled_data_stats)
# Out:
#                 LV1         LV2           LV3           LV4         LV5  \
# count  5.380000e+02  538.000000  5.380000e+02  5.380000e+02  538.000000
# mean  -2.641423e-17    0.000000 -1.981067e-17 -6.603557e-18    0.000000
# std    1.000931e+00    1.000931  1.000931e+00  1.000931e+00    1.000931
# min   -2.941388e+00   -2.596924 -2.236890e+00 -3.891242e+00   -2.692662
# 25%   -6.400544e-01   -0.621685 -7.113162e-01 -6.959125e-01   -0.617438
# 50%   -8.555821e-02   -0.027065 -1.255999e-01  9.578703e-03   -0.067449
# 75%    5.638433e-01    0.615557  5.854459e-01  5.965339e-01    0.553988
# max    4.636823e+00    3.530850  4.612159e+00  4.370314e+00    5.725491
#
#                 LV6           LV7         LV8           LV9          LV10
# count  5.380000e+02  5.380000e+02  538.000000  5.380000e+02  5.380000e+02
# mean   6.603557e-18 -1.320711e-17    0.000000 -8.254446e-18 -3.301779e-18
# std    1.000931e+00  1.000931e+00    1.000931  1.000931e+00  1.000931e+00
# min   -2.707335e+00 -2.747730e+00   -2.845200 -2.272341e+00 -3.067467e+00
# 25%   -7.035961e-01 -6.963790e-01   -0.680856 -6.855642e-01 -6.767709e-01
# 50%   -4.370927e-03 -2.274865e-02   -0.053768 -6.678430e-02 -1.040252e-01
# 75%    6.710451e-01  6.742816e-01    0.584045  6.904782e-01  6.249664e-01
# max    3.509831e+00  3.930267e+00    4.299952  5.804287e+00  3.305272e+00

# %% [markdown]
# ## Testing

# %%
assert np.all([np.isclose(scaled_data_stats.loc['mean', c], 0.0) for c in scaled_data_stats.columns])

# %%
assert np.all([np.isclose(scaled_data_stats.loc['std', c], 1.0, atol=1e-03) for c in scaled_data_stats.columns])

# %% [markdown]
# # Save

# %%
output_file = Path(
    RESULTS_DIR,
    f'z_score_std-{input_filepath_stem}.pkl',
).resolve()

display(output_file)
# Out:
# PosixPath('/media/miltondp/Elements1/projects/phenoplier/results/data_transformations/z_score_std/z_score_std-diseases_only-projection-smultixcan-efo_partial-mashr-zscores.pkl')

# %%
scaled_data.to_pickle(output_file)
